# %% [markdown]
# ## Make R4 SearchParameter Table of type, code and url using Jinja2 and Python Dict
#
# - Fetch SP Bundle file from definitions.zip
# - Transform to Python model
# - use Jinja2 template to create a summary markdown file
# - save markdown file

# %% [markdown]
# ### import python modules

# %%
from json import dumps, loads, load
import os
from pprint import pprint
from jinja2 import Environment, FileSystemLoader, select_autoescape
from commonmark import commonmark
from IPython.display import display, HTML, Markdown

# %% [markdown]
# ### Get file and return as dict

# %%
def open_file():  #Get Bundle
    in_path = '/Users/ehaas/Downloads/definitionsR4.json/search-parameters.json'
    with open(f'{in_path}') as f:
        r = f.read()
        return(loads(r))
        
b = open_file()

sp_list = []
for e in b['entry']:
        r = e['resource']
        u = r['url']
        c = r['code']
        for t in r['base']:
            sp_list.append((t,c,u))
sp_list = sorted(sp_list)#resort
pprint(sp_list, width = 200)
# Out:
# [('Account', 'identifier', 'http://hl7.org/fhir/SearchParameter/Account-identifier'),
#  ('Account', 'name', 'http://hl7.org/fhir/SearchParameter/Account-name'),
#  ('Account', 'owner', 'http://hl7.org/fhir/SearchParameter/Account-owner'),
#  ('Account', 'patient', 'http://hl7.org/fhir/SearchParameter/Account-patient'),
#  ('Account', 'period', 'http://hl7.org/fhir/SearchParameter/Account-period'),
#  ('Account', 'status', 'http://hl7.org/fhir/SearchParameter/Account-status'),
#  ('Account', 'subject', 'http://hl7.org/fhir/SearchParameter/Account-subject'),
#  ('Account', 'type', 'http://hl7.org/fhir/SearchParameter/Account-type'),
#  ('ActivityDefinition', 'composed-of', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-composed-of'),
#  ('ActivityDefinition', 'context', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-context'),
#  ('ActivityDefinition', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-quantity'),
#  ('ActivityDefinition', 'context-type', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-type'),
#  ('ActivityDefinition', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-type-quantity'),
#  ('ActivityDefinition', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-type-value'),
#  ('ActivityDefinition', 'date', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-date'),
#  ('ActivityDefinition', 'depends-on', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-depends-on'),
#  ('ActivityDefinition', 'derived-from', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-derived-from'),
#  ('ActivityDefinition', 'description', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-description'),
#  ('ActivityDefinition', 'effective', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-effective'),
#  ('ActivityDefinition', 'identifier', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-identifier'),
#  ('ActivityDefinition', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-jurisdiction'),
#  ('ActivityDefinition', 'name', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-name'),
#  ('ActivityDefinition', 'predecessor', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-predecessor'),
#  ('ActivityDefinition', 'publisher', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-publisher'),
#  ('ActivityDefinition', 'status', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-status'),
#  ('ActivityDefinition', 'successor', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-successor'),
#  ('ActivityDefinition', 'title', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-title'),
#  ('ActivityDefinition', 'topic', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-topic'),
#  ('ActivityDefinition', 'url', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-url'),
#  ('ActivityDefinition', 'version', 'http://hl7.org/fhir/SearchParameter/ActivityDefinition-version'),
#  ('AdverseEvent', 'actuality', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-actuality'),
#  ('AdverseEvent', 'category', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-category'),
#  ('AdverseEvent', 'date', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-date'),
#  ('AdverseEvent', 'event', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-event'),
#  ('AdverseEvent', 'location', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-location'),
#  ('AdverseEvent', 'recorder', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-recorder'),
#  ('AdverseEvent', 'resultingcondition', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-resultingcondition'),
#  ('AdverseEvent', 'seriousness', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-seriousness'),
#  ('AdverseEvent', 'severity', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-severity'),
#  ('AdverseEvent', 'study', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-study'),
#  ('AdverseEvent', 'subject', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-subject'),
#  ('AdverseEvent', 'substance', 'http://hl7.org/fhir/SearchParameter/AdverseEvent-substance'),
#  ('AllergyIntolerance', 'asserter', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-asserter'),
#  ('AllergyIntolerance', 'category', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-category'),
#  ('AllergyIntolerance', 'clinical-status', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-clinical-status'),
#  ('AllergyIntolerance', 'code', 'http://hl7.org/fhir/SearchParameter/clinical-code'),
#  ('AllergyIntolerance', 'criticality', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-criticality'),
#  ('AllergyIntolerance', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('AllergyIntolerance', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('AllergyIntolerance', 'last-date', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-last-date'),
#  ('AllergyIntolerance', 'manifestation', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-manifestation'),
#  ('AllergyIntolerance', 'onset', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-onset'),
#  ('AllergyIntolerance', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('AllergyIntolerance', 'recorder', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-recorder'),
#  ('AllergyIntolerance', 'route', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-route'),
#  ('AllergyIntolerance', 'severity', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-severity'),
#  ('AllergyIntolerance', 'type', 'http://hl7.org/fhir/SearchParameter/clinical-type'),
#  ('AllergyIntolerance', 'verification-status', 'http://hl7.org/fhir/SearchParameter/AllergyIntolerance-verification-status'),
#  ('Appointment', 'actor', 'http://hl7.org/fhir/SearchParameter/Appointment-actor'),
#  ('Appointment', 'appointment-type', 'http://hl7.org/fhir/SearchParameter/Appointment-appointment-type'),
#  ('Appointment', 'based-on', 'http://hl7.org/fhir/SearchParameter/Appointment-based-on'),
#  ('Appointment', 'date', 'http://hl7.org/fhir/SearchParameter/Appointment-date'),
#  ('Appointment', 'identifier', 'http://hl7.org/fhir/SearchParameter/Appointment-identifier'),
#  ('Appointment', 'location', 'http://hl7.org/fhir/SearchParameter/Appointment-location'),
#  ('Appointment', 'part-status', 'http://hl7.org/fhir/SearchParameter/Appointment-part-status'),
#  ('Appointment', 'patient', 'http://hl7.org/fhir/SearchParameter/Appointment-patient'),
#  ('Appointment', 'practitioner', 'http://hl7.org/fhir/SearchParameter/Appointment-practitioner'),
#  ('Appointment', 'reason-code', 'http://hl7.org/fhir/SearchParameter/Appointment-reason-code'),
#  ('Appointment', 'reason-reference', 'http://hl7.org/fhir/SearchParameter/Appointment-reason-reference'),
#  ('Appointment', 'service-category', 'http://hl7.org/fhir/SearchParameter/Appointment-service-category'),
#  ('Appointment', 'service-type', 'http://hl7.org/fhir/SearchParameter/Appointment-service-type'),
#  ('Appointment', 'slot', 'http://hl7.org/fhir/SearchParameter/Appointment-slot'),
#  ('Appointment', 'specialty', 'http://hl7.org/fhir/SearchParameter/Appointment-specialty'),
#  ('Appointment', 'status', 'http://hl7.org/fhir/SearchParameter/Appointment-status'),
#  ('Appointment', 'supporting-info', 'http://hl7.org/fhir/SearchParameter/Appointment-supporting-info'),
#  ('AppointmentResponse', 'actor', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-actor'),
#  ('AppointmentResponse', 'appointment', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-appointment'),
#  ('AppointmentResponse', 'identifier', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-identifier'),
#  ('AppointmentResponse', 'location', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-location'),
#  ('AppointmentResponse', 'part-status', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-part-status'),
#  ('AppointmentResponse', 'patient', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-patient'),
#  ('AppointmentResponse', 'practitioner', 'http://hl7.org/fhir/SearchParameter/AppointmentResponse-practitioner'),
#  ('AuditEvent', 'action', 'http://hl7.org/fhir/SearchParameter/AuditEvent-action'),
#  ('AuditEvent', 'address', 'http://hl7.org/fhir/SearchParameter/AuditEvent-address'),
#  ('AuditEvent', 'agent', 'http://hl7.org/fhir/SearchParameter/AuditEvent-agent'),
#  ('AuditEvent', 'agent-name', 'http://hl7.org/fhir/SearchParameter/AuditEvent-agent-name'),
#  ('AuditEvent', 'agent-role', 'http://hl7.org/fhir/SearchParameter/AuditEvent-agent-role'),
#  ('AuditEvent', 'altid', 'http://hl7.org/fhir/SearchParameter/AuditEvent-altid'),
#  ('AuditEvent', 'date', 'http://hl7.org/fhir/SearchParameter/AuditEvent-date'),
#  ('AuditEvent', 'entity', 'http://hl7.org/fhir/SearchParameter/AuditEvent-entity'),
#  ('AuditEvent', 'entity-name', 'http://hl7.org/fhir/SearchParameter/AuditEvent-entity-name'),
#  ('AuditEvent', 'entity-role', 'http://hl7.org/fhir/SearchParameter/AuditEvent-entity-role'),
#  ('AuditEvent', 'entity-type', 'http://hl7.org/fhir/SearchParameter/AuditEvent-entity-type'),
#  ('AuditEvent', 'outcome', 'http://hl7.org/fhir/SearchParameter/AuditEvent-outcome'),
#  ('AuditEvent', 'patient', 'http://hl7.org/fhir/SearchParameter/AuditEvent-patient'),
#  ('AuditEvent', 'policy', 'http://hl7.org/fhir/SearchParameter/AuditEvent-policy'),
#  ('AuditEvent', 'site', 'http://hl7.org/fhir/SearchParameter/AuditEvent-site'),
#  ('AuditEvent', 'source', 'http://hl7.org/fhir/SearchParameter/AuditEvent-source'),
#  ('AuditEvent', 'subtype', 'http://hl7.org/fhir/SearchParameter/AuditEvent-subtype'),
#  ('AuditEvent', 'type', 'http://hl7.org/fhir/SearchParameter/AuditEvent-type'),
#  ('Basic', 'author', 'http://hl7.org/fhir/SearchParameter/Basic-author'),
#  ('Basic', 'code', 'http://hl7.org/fhir/SearchParameter/Basic-code'),
#  ('Basic', 'created', 'http://hl7.org/fhir/SearchParameter/Basic-created'),
#  ('Basic', 'identifier', 'http://hl7.org/fhir/SearchParameter/Basic-identifier'),
#  ('Basic', 'patient', 'http://hl7.org/fhir/SearchParameter/Basic-patient'),
#  ('Basic', 'subject', 'http://hl7.org/fhir/SearchParameter/Basic-subject'),
#  ('BodyStructure', 'identifier', 'http://hl7.org/fhir/SearchParameter/BodyStructure-identifier'),
#  ('BodyStructure', 'location', 'http://hl7.org/fhir/SearchParameter/BodyStructure-location'),
#  ('BodyStructure', 'morphology', 'http://hl7.org/fhir/SearchParameter/BodyStructure-morphology'),
#  ('BodyStructure', 'patient', 'http://hl7.org/fhir/SearchParameter/BodyStructure-patient'),
#  ('Bundle', 'composition', 'http://hl7.org/fhir/SearchParameter/Bundle-composition'),
#  ('Bundle', 'identifier', 'http://hl7.org/fhir/SearchParameter/Bundle-identifier'),
#  ('Bundle', 'message', 'http://hl7.org/fhir/SearchParameter/Bundle-message'),
#  ('Bundle', 'timestamp', 'http://hl7.org/fhir/SearchParameter/Bundle-timestamp'),
#  ('Bundle', 'type', 'http://hl7.org/fhir/SearchParameter/Bundle-type'),
#  ('CapabilityStatement', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('CapabilityStatement', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('CapabilityStatement', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('CapabilityStatement', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('CapabilityStatement', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('CapabilityStatement', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('CapabilityStatement', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('CapabilityStatement', 'fhirversion', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-fhirversion'),
#  ('CapabilityStatement', 'format', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-format'),
#  ('CapabilityStatement', 'guide', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-guide'),
#  ('CapabilityStatement', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('CapabilityStatement', 'mode', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-mode'),
#  ('CapabilityStatement', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('CapabilityStatement', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('CapabilityStatement', 'resource', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-resource'),
#  ('CapabilityStatement', 'resource-profile', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-resource-profile'),
#  ('CapabilityStatement', 'security-service', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-security-service'),
#  ('CapabilityStatement', 'software', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-software'),
#  ('CapabilityStatement', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('CapabilityStatement', 'supported-profile', 'http://hl7.org/fhir/SearchParameter/CapabilityStatement-supported-profile'),
#  ('CapabilityStatement', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('CapabilityStatement', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('CapabilityStatement', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('CarePlan', 'activity-code', 'http://hl7.org/fhir/SearchParameter/CarePlan-activity-code'),
#  ('CarePlan', 'activity-date', 'http://hl7.org/fhir/SearchParameter/CarePlan-activity-date'),
#  ('CarePlan', 'activity-reference', 'http://hl7.org/fhir/SearchParameter/CarePlan-activity-reference'),
#  ('CarePlan', 'based-on', 'http://hl7.org/fhir/SearchParameter/CarePlan-based-on'),
#  ('CarePlan', 'care-team', 'http://hl7.org/fhir/SearchParameter/CarePlan-care-team'),
#  ('CarePlan', 'category', 'http://hl7.org/fhir/SearchParameter/CarePlan-category'),
#  ('CarePlan', 'condition', 'http://hl7.org/fhir/SearchParameter/CarePlan-condition'),
#  ('CarePlan', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('CarePlan', 'encounter', 'http://hl7.org/fhir/SearchParameter/CarePlan-encounter'),
#  ('CarePlan', 'goal', 'http://hl7.org/fhir/SearchParameter/CarePlan-goal'),
#  ('CarePlan', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('CarePlan', 'instantiates-canonical', 'http://hl7.org/fhir/SearchParameter/CarePlan-instantiates-canonical'),
#  ('CarePlan', 'instantiates-uri', 'http://hl7.org/fhir/SearchParameter/CarePlan-instantiates-uri'),
#  ('CarePlan', 'intent', 'http://hl7.org/fhir/SearchParameter/CarePlan-intent'),
#  ('CarePlan', 'part-of', 'http://hl7.org/fhir/SearchParameter/CarePlan-part-of'),
#  ('CarePlan', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('CarePlan', 'performer', 'http://hl7.org/fhir/SearchParameter/CarePlan-performer'),
#  ('CarePlan', 'replaces', 'http://hl7.org/fhir/SearchParameter/CarePlan-replaces'),
#  ('CarePlan', 'status', 'http://hl7.org/fhir/SearchParameter/CarePlan-status'),
#  ('CarePlan', 'subject', 'http://hl7.org/fhir/SearchParameter/CarePlan-subject'),
#  ('CareTeam', 'category', 'http://hl7.org/fhir/SearchParameter/CareTeam-category'),
#  ('CareTeam', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('CareTeam', 'encounter', 'http://hl7.org/fhir/SearchParameter/CareTeam-encounter'),
#  ('CareTeam', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('CareTeam', 'participant', 'http://hl7.org/fhir/SearchParameter/CareTeam-participant'),
#  ('CareTeam', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('CareTeam', 'status', 'http://hl7.org/fhir/SearchParameter/CareTeam-status'),
#  ('CareTeam', 'subject', 'http://hl7.org/fhir/SearchParameter/CareTeam-subject'),
#  ('ChargeItem', 'account', 'http://hl7.org/fhir/SearchParameter/ChargeItem-account'),
#  ('ChargeItem', 'code', 'http://hl7.org/fhir/SearchParameter/ChargeItem-code'),
#  ('ChargeItem', 'context', 'http://hl7.org/fhir/SearchParameter/ChargeItem-context'),
#  ('ChargeItem', 'entered-date', 'http://hl7.org/fhir/SearchParameter/ChargeItem-entered-date'),
#  ('ChargeItem', 'enterer', 'http://hl7.org/fhir/SearchParameter/ChargeItem-enterer'),
#  ('ChargeItem', 'factor-override', 'http://hl7.org/fhir/SearchParameter/ChargeItem-factor-override'),
#  ('ChargeItem', 'identifier', 'http://hl7.org/fhir/SearchParameter/ChargeItem-identifier'),
#  ('ChargeItem', 'occurrence', 'http://hl7.org/fhir/SearchParameter/ChargeItem-occurrence'),
#  ('ChargeItem', 'patient', 'http://hl7.org/fhir/SearchParameter/ChargeItem-patient'),
#  ('ChargeItem', 'performer-actor', 'http://hl7.org/fhir/SearchParameter/ChargeItem-performer-actor'),
#  ('ChargeItem', 'performer-function', 'http://hl7.org/fhir/SearchParameter/ChargeItem-performer-function'),
#  ('ChargeItem', 'performing-organization', 'http://hl7.org/fhir/SearchParameter/ChargeItem-performing-organization'),
#  ('ChargeItem', 'price-override', 'http://hl7.org/fhir/SearchParameter/ChargeItem-price-override'),
#  ('ChargeItem', 'quantity', 'http://hl7.org/fhir/SearchParameter/ChargeItem-quantity'),
#  ('ChargeItem', 'requesting-organization', 'http://hl7.org/fhir/SearchParameter/ChargeItem-requesting-organization'),
#  ('ChargeItem', 'service', 'http://hl7.org/fhir/SearchParameter/ChargeItem-service'),
#  ('ChargeItem', 'subject', 'http://hl7.org/fhir/SearchParameter/ChargeItem-subject'),
#  ('ChargeItemDefinition', 'context', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context'),
#  ('ChargeItemDefinition', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-quantity'),
#  ('ChargeItemDefinition', 'context-type', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-type'),
#  ('ChargeItemDefinition', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-type-quantity'),
#  ('ChargeItemDefinition', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-type-value'),
#  ('ChargeItemDefinition', 'date', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-date'),
#  ('ChargeItemDefinition', 'description', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-description'),
#  ('ChargeItemDefinition', 'effective', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-effective'),
#  ('ChargeItemDefinition', 'identifier', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-identifier'),
#  ('ChargeItemDefinition', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-jurisdiction'),
#  ('ChargeItemDefinition', 'publisher', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-publisher'),
#  ('ChargeItemDefinition', 'status', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-status'),
#  ('ChargeItemDefinition', 'title', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-title'),
#  ('ChargeItemDefinition', 'url', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-url'),
#  ('ChargeItemDefinition', 'version', 'http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-version'),
#  ('Claim', 'care-team', 'http://hl7.org/fhir/SearchParameter/Claim-care-team'),
#  ('Claim', 'created', 'http://hl7.org/fhir/SearchParameter/Claim-created'),
#  ('Claim', 'detail-udi', 'http://hl7.org/fhir/SearchParameter/Claim-detail-udi'),
#  ('Claim', 'encounter', 'http://hl7.org/fhir/SearchParameter/Claim-encounter'),
#  ('Claim', 'enterer', 'http://hl7.org/fhir/SearchParameter/Claim-enterer'),
#  ('Claim', 'facility', 'http://hl7.org/fhir/SearchParameter/Claim-facility'),
#  ('Claim', 'identifier', 'http://hl7.org/fhir/SearchParameter/Claim-identifier'),
#  ('Claim', 'insurer', 'http://hl7.org/fhir/SearchParameter/Claim-insurer'),
#  ('Claim', 'item-udi', 'http://hl7.org/fhir/SearchParameter/Claim-item-udi'),
#  ('Claim', 'patient', 'http://hl7.org/fhir/SearchParameter/Claim-patient'),
#  ('Claim', 'payee', 'http://hl7.org/fhir/SearchParameter/Claim-payee'),
#  ('Claim', 'priority', 'http://hl7.org/fhir/SearchParameter/Claim-priority'),
#  ('Claim', 'procedure-udi', 'http://hl7.org/fhir/SearchParameter/Claim-procedure-udi'),
#  ('Claim', 'provider', 'http://hl7.org/fhir/SearchParameter/Claim-provider'),
#  ('Claim', 'status', 'http://hl7.org/fhir/SearchParameter/Claim-status'),
#  ('Claim', 'subdetail-udi', 'http://hl7.org/fhir/SearchParameter/Claim-subdetail-udi'),
#  ('Claim', 'use', 'http://hl7.org/fhir/SearchParameter/Claim-use'),
#  ('ClaimResponse', 'created', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-created'),
#  ('ClaimResponse', 'disposition', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-disposition'),
#  ('ClaimResponse', 'identifier', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-identifier'),
#  ('ClaimResponse', 'insurer', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-insurer'),
#  ('ClaimResponse', 'outcome', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-outcome'),
#  ('ClaimResponse', 'patient', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-patient'),
#  ('ClaimResponse', 'payment-date', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-payment-date'),
#  ('ClaimResponse', 'request', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-request'),
#  ('ClaimResponse', 'requestor', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-requestor'),
#  ('ClaimResponse', 'status', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-status'),
#  ('ClaimResponse', 'use', 'http://hl7.org/fhir/SearchParameter/ClaimResponse-use'),
#  ('ClinicalImpression', 'assessor', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-assessor'),
#  ('ClinicalImpression', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('ClinicalImpression', 'encounter', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-encounter'),
#  ('ClinicalImpression', 'finding-code', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-finding-code'),
#  ('ClinicalImpression', 'finding-ref', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-finding-ref'),
#  ('ClinicalImpression', 'identifier', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-identifier'),
#  ('ClinicalImpression', 'investigation', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-investigation'),
#  ('ClinicalImpression', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('ClinicalImpression', 'previous', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-previous'),
#  ('ClinicalImpression', 'problem', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-problem'),
#  ('ClinicalImpression', 'status', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-status'),
#  ('ClinicalImpression', 'subject', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-subject'),
#  ('ClinicalImpression', 'supporting-info', 'http://hl7.org/fhir/SearchParameter/ClinicalImpression-supporting-info'),
#  ('CodeSystem', 'code', 'http://hl7.org/fhir/SearchParameter/CodeSystem-code'),
#  ('CodeSystem', 'content-mode', 'http://hl7.org/fhir/SearchParameter/CodeSystem-content-mode'),
#  ('CodeSystem', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('CodeSystem', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('CodeSystem', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('CodeSystem', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('CodeSystem', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('CodeSystem', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('CodeSystem', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('CodeSystem', 'identifier', 'http://hl7.org/fhir/SearchParameter/conformance-identifier'),
#  ('CodeSystem', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('CodeSystem', 'language', 'http://hl7.org/fhir/SearchParameter/CodeSystem-language'),
#  ('CodeSystem', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('CodeSystem', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('CodeSystem', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('CodeSystem', 'supplements', 'http://hl7.org/fhir/SearchParameter/CodeSystem-supplements'),
#  ('CodeSystem', 'system', 'http://hl7.org/fhir/SearchParameter/CodeSystem-system'),
#  ('CodeSystem', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('CodeSystem', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('CodeSystem', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('Communication', 'based-on', 'http://hl7.org/fhir/SearchParameter/Communication-based-on'),
#  ('Communication', 'category', 'http://hl7.org/fhir/SearchParameter/Communication-category'),
#  ('Communication', 'encounter', 'http://hl7.org/fhir/SearchParameter/Communication-encounter'),
#  ('Communication', 'identifier', 'http://hl7.org/fhir/SearchParameter/Communication-identifier'),
#  ('Communication', 'instantiates-canonical', 'http://hl7.org/fhir/SearchParameter/Communication-instantiates-canonical'),
#  ('Communication', 'instantiates-uri', 'http://hl7.org/fhir/SearchParameter/Communication-instantiates-uri'),
#  ('Communication', 'medium', 'http://hl7.org/fhir/SearchParameter/Communication-medium'),
#  ('Communication', 'part-of', 'http://hl7.org/fhir/SearchParameter/Communication-part-of'),
#  ('Communication', 'patient', 'http://hl7.org/fhir/SearchParameter/Communication-patient'),
#  ('Communication', 'received', 'http://hl7.org/fhir/SearchParameter/Communication-received'),
#  ('Communication', 'recipient', 'http://hl7.org/fhir/SearchParameter/Communication-recipient'),
#  ('Communication', 'sender', 'http://hl7.org/fhir/SearchParameter/Communication-sender'),
#  ('Communication', 'sent', 'http://hl7.org/fhir/SearchParameter/Communication-sent'),
#  ('Communication', 'status', 'http://hl7.org/fhir/SearchParameter/Communication-status'),
#  ('Communication', 'subject', 'http://hl7.org/fhir/SearchParameter/Communication-subject'),
#  ('CommunicationRequest', 'authored', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-authored'),
#  ('CommunicationRequest', 'based-on', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-based-on'),
#  ('CommunicationRequest', 'category', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-category'),
#  ('CommunicationRequest', 'encounter', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-encounter'),
#  ('CommunicationRequest', 'group-identifier', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-group-identifier'),
#  ('CommunicationRequest', 'identifier', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-identifier'),
#  ('CommunicationRequest', 'medium', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-medium'),
#  ('CommunicationRequest', 'occurrence', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-occurrence'),
#  ('CommunicationRequest', 'patient', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-patient'),
#  ('CommunicationRequest', 'priority', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-priority'),
#  ('CommunicationRequest', 'recipient', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-recipient'),
#  ('CommunicationRequest', 'replaces', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-replaces'),
#  ('CommunicationRequest', 'requester', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-requester'),
#  ('CommunicationRequest', 'sender', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-sender'),
#  ('CommunicationRequest', 'status', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-status'),
#  ('CommunicationRequest', 'subject', 'http://hl7.org/fhir/SearchParameter/CommunicationRequest-subject'),
#  ('CompartmentDefinition', 'code', 'http://hl7.org/fhir/SearchParameter/CompartmentDefinition-code'),
#  ('CompartmentDefinition', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('CompartmentDefinition', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('CompartmentDefinition', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('CompartmentDefinition', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('CompartmentDefinition', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('CompartmentDefinition', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('CompartmentDefinition', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('CompartmentDefinition', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('CompartmentDefinition', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('CompartmentDefinition', 'resource', 'http://hl7.org/fhir/SearchParameter/CompartmentDefinition-resource'),
#  ('CompartmentDefinition', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('CompartmentDefinition', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('CompartmentDefinition', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('Composition', 'attester', 'http://hl7.org/fhir/SearchParameter/Composition-attester'),
#  ('Composition', 'author', 'http://hl7.org/fhir/SearchParameter/Composition-author'),
#  ('Composition', 'category', 'http://hl7.org/fhir/SearchParameter/Composition-category'),
#  ('Composition', 'confidentiality', 'http://hl7.org/fhir/SearchParameter/Composition-confidentiality'),
#  ('Composition', 'context', 'http://hl7.org/fhir/SearchParameter/Composition-context'),
#  ('Composition', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('Composition', 'encounter', 'http://hl7.org/fhir/SearchParameter/clinical-encounter'),
#  ('Composition', 'entry', 'http://hl7.org/fhir/SearchParameter/Composition-entry'),
#  ('Composition', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('Composition', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('Composition', 'period', 'http://hl7.org/fhir/SearchParameter/Composition-period'),
#  ('Composition', 'related-id', 'http://hl7.org/fhir/SearchParameter/Composition-related-id'),
#  ('Composition', 'related-ref', 'http://hl7.org/fhir/SearchParameter/Composition-related-ref'),
#  ('Composition', 'section', 'http://hl7.org/fhir/SearchParameter/Composition-section'),
#  ('Composition', 'status', 'http://hl7.org/fhir/SearchParameter/Composition-status'),
#  ('Composition', 'subject', 'http://hl7.org/fhir/SearchParameter/Composition-subject'),
#  ('Composition', 'title', 'http://hl7.org/fhir/SearchParameter/Composition-title'),
#  ('Composition', 'type', 'http://hl7.org/fhir/SearchParameter/clinical-type'),
#  ('ConceptMap', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('ConceptMap', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('ConceptMap', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('ConceptMap', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('ConceptMap', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('ConceptMap', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('ConceptMap', 'dependson', 'http://hl7.org/fhir/SearchParameter/ConceptMap-dependson'),
#  ('ConceptMap', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('ConceptMap', 'identifier', 'http://hl7.org/fhir/SearchParameter/conformance-identifier'),
#  ('ConceptMap', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('ConceptMap', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('ConceptMap', 'other', 'http://hl7.org/fhir/SearchParameter/ConceptMap-other'),
#  ('ConceptMap', 'product', 'http://hl7.org/fhir/SearchParameter/ConceptMap-product'),
#  ('ConceptMap', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('ConceptMap', 'source', 'http://hl7.org/fhir/SearchParameter/ConceptMap-source'),
#  ('ConceptMap', 'source-code', 'http://hl7.org/fhir/SearchParameter/ConceptMap-source-code'),
#  ('ConceptMap', 'source-system', 'http://hl7.org/fhir/SearchParameter/ConceptMap-source-system'),
#  ('ConceptMap', 'source-uri', 'http://hl7.org/fhir/SearchParameter/ConceptMap-source-uri'),
#  ('ConceptMap', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('ConceptMap', 'target', 'http://hl7.org/fhir/SearchParameter/ConceptMap-target'),
#  ('ConceptMap', 'target-code', 'http://hl7.org/fhir/SearchParameter/ConceptMap-target-code'),
#  ('ConceptMap', 'target-system', 'http://hl7.org/fhir/SearchParameter/ConceptMap-target-system'),
#  ('ConceptMap', 'target-uri', 'http://hl7.org/fhir/SearchParameter/ConceptMap-target-uri'),
#  ('ConceptMap', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('ConceptMap', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('ConceptMap', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('Condition', 'abatement-age', 'http://hl7.org/fhir/SearchParameter/Condition-abatement-age'),
#  ('Condition', 'abatement-date', 'http://hl7.org/fhir/SearchParameter/Condition-abatement-date'),
#  ('Condition', 'abatement-string', 'http://hl7.org/fhir/SearchParameter/Condition-abatement-string'),
#  ('Condition', 'asserter', 'http://hl7.org/fhir/SearchParameter/Condition-asserter'),
#  ('Condition', 'body-site', 'http://hl7.org/fhir/SearchParameter/Condition-body-site'),
#  ('Condition', 'category', 'http://hl7.org/fhir/SearchParameter/Condition-category'),
#  ('Condition', 'clinical-status', 'http://hl7.org/fhir/SearchParameter/Condition-clinical-status'),
#  ('Condition', 'code', 'http://hl7.org/fhir/SearchParameter/clinical-code'),
#  ('Condition', 'encounter', 'http://hl7.org/fhir/SearchParameter/Condition-encounter'),
#  ('Condition', 'evidence', 'http://hl7.org/fhir/SearchParameter/Condition-evidence'),
#  ('Condition', 'evidence-detail', 'http://hl7.org/fhir/SearchParameter/Condition-evidence-detail'),
#  ('Condition', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('Condition', 'onset-age', 'http://hl7.org/fhir/SearchParameter/Condition-onset-age'),
#  ('Condition', 'onset-date', 'http://hl7.org/fhir/SearchParameter/Condition-onset-date'),
#  ('Condition', 'onset-info', 'http://hl7.org/fhir/SearchParameter/Condition-onset-info'),
#  ('Condition', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('Condition', 'recorded-date', 'http://hl7.org/fhir/SearchParameter/Condition-recorded-date'),
#  ('Condition', 'severity', 'http://hl7.org/fhir/SearchParameter/Condition-severity'),
#  ('Condition', 'stage', 'http://hl7.org/fhir/SearchParameter/Condition-stage'),
#  ('Condition', 'subject', 'http://hl7.org/fhir/SearchParameter/Condition-subject'),
#  ('Condition', 'verification-status', 'http://hl7.org/fhir/SearchParameter/Condition-verification-status'),
#  ('Consent', 'action', 'http://hl7.org/fhir/SearchParameter/Consent-action'),
#  ('Consent', 'actor', 'http://hl7.org/fhir/SearchParameter/Consent-actor'),
#  ('Consent', 'category', 'http://hl7.org/fhir/SearchParameter/Consent-category'),
#  ('Consent', 'consentor', 'http://hl7.org/fhir/SearchParameter/Consent-consentor'),
#  ('Consent', 'data', 'http://hl7.org/fhir/SearchParameter/Consent-data'),
#  ('Consent', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('Consent', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('Consent', 'organization', 'http://hl7.org/fhir/SearchParameter/Consent-organization'),
#  ('Consent', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('Consent', 'period', 'http://hl7.org/fhir/SearchParameter/Consent-period'),
#  ('Consent', 'purpose', 'http://hl7.org/fhir/SearchParameter/Consent-purpose'),
#  ('Consent', 'scope', 'http://hl7.org/fhir/SearchParameter/Consent-scope'),
#  ('Consent', 'security-label', 'http://hl7.org/fhir/SearchParameter/Consent-security-label'),
#  ('Consent', 'source-reference', 'http://hl7.org/fhir/SearchParameter/Consent-source-reference'),
#  ('Consent', 'status', 'http://hl7.org/fhir/SearchParameter/Consent-status'),
#  ('Contract', 'authority', 'http://hl7.org/fhir/SearchParameter/Contract-authority'),
#  ('Contract', 'domain', 'http://hl7.org/fhir/SearchParameter/Contract-domain'),
#  ('Contract', 'identifier', 'http://hl7.org/fhir/SearchParameter/Contract-identifier'),
#  ('Contract', 'instantiates', 'http://hl7.org/fhir/SearchParameter/Contract-instantiates'),
#  ('Contract', 'issued', 'http://hl7.org/fhir/SearchParameter/Contract-issued'),
#  ('Contract', 'patient', 'http://hl7.org/fhir/SearchParameter/Contract-patient'),
#  ('Contract', 'signer', 'http://hl7.org/fhir/SearchParameter/Contract-signer'),
#  ('Contract', 'status', 'http://hl7.org/fhir/SearchParameter/Contract-status'),
#  ('Contract', 'subject', 'http://hl7.org/fhir/SearchParameter/Contract-subject'),
#  ('Contract', 'url', 'http://hl7.org/fhir/SearchParameter/Contract-url'),
#  ('Coverage', 'beneficiary', 'http://hl7.org/fhir/SearchParameter/Coverage-beneficiary'),
#  ('Coverage', 'class-type', 'http://hl7.org/fhir/SearchParameter/Coverage-class-type'),
#  ('Coverage', 'class-value', 'http://hl7.org/fhir/SearchParameter/Coverage-class-value'),
#  ('Coverage', 'dependent', 'http://hl7.org/fhir/SearchParameter/Coverage-dependent'),
#  ('Coverage', 'identifier', 'http://hl7.org/fhir/SearchParameter/Coverage-identifier'),
#  ('Coverage', 'patient', 'http://hl7.org/fhir/SearchParameter/Coverage-patient'),
#  ('Coverage', 'payor', 'http://hl7.org/fhir/SearchParameter/Coverage-payor'),
#  ('Coverage', 'policy-holder', 'http://hl7.org/fhir/SearchParameter/Coverage-policy-holder'),
#  ('Coverage', 'status', 'http://hl7.org/fhir/SearchParameter/Coverage-status'),
#  ('Coverage', 'subscriber', 'http://hl7.org/fhir/SearchParameter/Coverage-subscriber'),
#  ('Coverage', 'type', 'http://hl7.org/fhir/SearchParameter/Coverage-type'),
#  ('CoverageEligibilityRequest', 'created', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-created'),
#  ('CoverageEligibilityRequest', 'enterer', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-enterer'),
#  ('CoverageEligibilityRequest', 'facility', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-facility'),
#  ('CoverageEligibilityRequest', 'identifier', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-identifier'),
#  ('CoverageEligibilityRequest', 'patient', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-patient'),
#  ('CoverageEligibilityRequest', 'provider', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-provider'),
#  ('CoverageEligibilityRequest', 'status', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-status'),
#  ('CoverageEligibilityResponse', 'created', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-created'),
#  ('CoverageEligibilityResponse', 'disposition', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-disposition'),
#  ('CoverageEligibilityResponse', 'identifier', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-identifier'),
#  ('CoverageEligibilityResponse', 'insurer', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-insurer'),
#  ('CoverageEligibilityResponse', 'outcome', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-outcome'),
#  ('CoverageEligibilityResponse', 'patient', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-patient'),
#  ('CoverageEligibilityResponse', 'request', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-request'),
#  ('CoverageEligibilityResponse', 'requestor', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-requestor'),
#  ('CoverageEligibilityResponse', 'status', 'http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-status'),
#  ('DetectedIssue', 'author', 'http://hl7.org/fhir/SearchParameter/DetectedIssue-author'),
#  ('DetectedIssue', 'code', 'http://hl7.org/fhir/SearchParameter/DetectedIssue-code'),
#  ('DetectedIssue', 'identified', 'http://hl7.org/fhir/SearchParameter/DetectedIssue-identified'),
#  ('DetectedIssue', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('DetectedIssue', 'implicated', 'http://hl7.org/fhir/SearchParameter/DetectedIssue-implicated'),
#  ('DetectedIssue', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('Device', 'device-name', 'http://hl7.org/fhir/SearchParameter/Device-device-name'),
#  ('Device', 'identifier', 'http://hl7.org/fhir/SearchParameter/Device-identifier'),
#  ('Device', 'location', 'http://hl7.org/fhir/SearchParameter/Device-location'),
#  ('Device', 'manufacturer', 'http://hl7.org/fhir/SearchParameter/Device-manufacturer'),
#  ('Device', 'model', 'http://hl7.org/fhir/SearchParameter/Device-model'),
#  ('Device', 'organization', 'http://hl7.org/fhir/SearchParameter/Device-organization'),
#  ('Device', 'patient', 'http://hl7.org/fhir/SearchParameter/Device-patient'),
#  ('Device', 'status', 'http://hl7.org/fhir/SearchParameter/Device-status'),
#  ('Device', 'type', 'http://hl7.org/fhir/SearchParameter/Device-type'),
#  ('Device', 'udi-carrier', 'http://hl7.org/fhir/SearchParameter/Device-udi-carrier'),
#  ('Device', 'udi-di', 'http://hl7.org/fhir/SearchParameter/Device-udi-di'),
#  ('Device', 'url', 'http://hl7.org/fhir/SearchParameter/Device-url'),
#  ('DeviceDefinition', 'identifier', 'http://hl7.org/fhir/SearchParameter/DeviceDefinition-identifier'),
#  ('DeviceDefinition', 'parent', 'http://hl7.org/fhir/SearchParameter/DeviceDefinition-parent'),
#  ('DeviceDefinition', 'type', 'http://hl7.org/fhir/SearchParameter/DeviceDefinition-type'),
#  ('DeviceMetric', 'category', 'http://hl7.org/fhir/SearchParameter/DeviceMetric-category'),
#  ('DeviceMetric', 'identifier', 'http://hl7.org/fhir/SearchParameter/DeviceMetric-identifier'),
#  ('DeviceMetric', 'parent', 'http://hl7.org/fhir/SearchParameter/DeviceMetric-parent'),
#  ('DeviceMetric', 'source', 'http://hl7.org/fhir/SearchParameter/DeviceMetric-source'),
#  ('DeviceMetric', 'type', 'http://hl7.org/fhir/SearchParameter/DeviceMetric-type'),
#  ('DeviceRequest', 'authored-on', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-authored-on'),
#  ('DeviceRequest', 'based-on', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-based-on'),
#  ('DeviceRequest', 'code', 'http://hl7.org/fhir/SearchParameter/clinical-code'),
#  ('DeviceRequest', 'device', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-device'),
#  ('DeviceRequest', 'encounter', 'http://hl7.org/fhir/SearchParameter/clinical-encounter'),
#  ('DeviceRequest', 'event-date', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-event-date'),
#  ('DeviceRequest', 'group-identifier', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-group-identifier'),
#  ('DeviceRequest', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('DeviceRequest', 'instantiates-canonical', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-instantiates-canonical'),
#  ('DeviceRequest', 'instantiates-uri', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-instantiates-uri'),
#  ('DeviceRequest', 'insurance', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-insurance'),
#  ('DeviceRequest', 'intent', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-intent'),
#  ('DeviceRequest', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('DeviceRequest', 'performer', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-performer'),
#  ('DeviceRequest', 'prior-request', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-prior-request'),
#  ('DeviceRequest', 'requester', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-requester'),
#  ('DeviceRequest', 'status', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-status'),
#  ('DeviceRequest', 'subject', 'http://hl7.org/fhir/SearchParameter/DeviceRequest-subject'),
#  ('DeviceUseStatement', 'device', 'http://hl7.org/fhir/SearchParameter/DeviceUseStatement-device'),
#  ('DeviceUseStatement', 'identifier', 'http://hl7.org/fhir/SearchParameter/DeviceUseStatement-identifier'),
#  ('DeviceUseStatement', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('DeviceUseStatement', 'subject', 'http://hl7.org/fhir/SearchParameter/DeviceUseStatement-subject'),
#  ('DiagnosticReport', 'based-on', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-based-on'),
#  ('DiagnosticReport', 'category', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-category'),
#  ('DiagnosticReport', 'code', 'http://hl7.org/fhir/SearchParameter/clinical-code'),
#  ('DiagnosticReport', 'conclusion', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-conclusion'),
#  ('DiagnosticReport', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('DiagnosticReport', 'encounter', 'http://hl7.org/fhir/SearchParameter/clinical-encounter'),
#  ('DiagnosticReport', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('DiagnosticReport', 'issued', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-issued'),
#  ('DiagnosticReport', 'media', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-media'),
#  ('DiagnosticReport', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('DiagnosticReport', 'performer', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-performer'),
#  ('DiagnosticReport', 'result', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-result'),
#  ('DiagnosticReport', 'results-interpreter', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-results-interpreter'),
#  ('DiagnosticReport', 'specimen', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-specimen'),
#  ('DiagnosticReport', 'status', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-status'),
#  ('DiagnosticReport', 'subject', 'http://hl7.org/fhir/SearchParameter/DiagnosticReport-subject'),
#  ('DocumentManifest', 'author', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-author'),
#  ('DocumentManifest', 'created', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-created'),
#  ('DocumentManifest', 'description', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-description'),
#  ('DocumentManifest', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('DocumentManifest', 'item', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-item'),
#  ('DocumentManifest', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('DocumentManifest', 'recipient', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-recipient'),
#  ('DocumentManifest', 'related-id', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-related-id'),
#  ('DocumentManifest', 'related-ref', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-related-ref'),
#  ('DocumentManifest', 'source', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-source'),
#  ('DocumentManifest', 'status', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-status'),
#  ('DocumentManifest', 'subject', 'http://hl7.org/fhir/SearchParameter/DocumentManifest-subject'),
#  ('DocumentManifest', 'type', 'http://hl7.org/fhir/SearchParameter/clinical-type'),
#  ('DocumentReference', 'authenticator', 'http://hl7.org/fhir/SearchParameter/DocumentReference-authenticator'),
#  ('DocumentReference', 'author', 'http://hl7.org/fhir/SearchParameter/DocumentReference-author'),
#  ('DocumentReference', 'category', 'http://hl7.org/fhir/SearchParameter/DocumentReference-category'),
#  ('DocumentReference', 'contenttype', 'http://hl7.org/fhir/SearchParameter/DocumentReference-contenttype'),
#  ('DocumentReference', 'custodian', 'http://hl7.org/fhir/SearchParameter/DocumentReference-custodian'),
#  ('DocumentReference', 'date', 'http://hl7.org/fhir/SearchParameter/DocumentReference-date'),
#  ('DocumentReference', 'description', 'http://hl7.org/fhir/SearchParameter/DocumentReference-description'),
#  ('DocumentReference', 'encounter', 'http://hl7.org/fhir/SearchParameter/clinical-encounter'),
# ...
#  ('ServiceRequest', 'status', 'http://hl7.org/fhir/SearchParameter/ServiceRequest-status'),
#  ('ServiceRequest', 'subject', 'http://hl7.org/fhir/SearchParameter/ServiceRequest-subject'),
#  ('Slot', 'appointment-type', 'http://hl7.org/fhir/SearchParameter/Slot-appointment-type'),
#  ('Slot', 'identifier', 'http://hl7.org/fhir/SearchParameter/Slot-identifier'),
#  ('Slot', 'schedule', 'http://hl7.org/fhir/SearchParameter/Slot-schedule'),
#  ('Slot', 'service-category', 'http://hl7.org/fhir/SearchParameter/Slot-service-category'),
#  ('Slot', 'service-type', 'http://hl7.org/fhir/SearchParameter/Slot-service-type'),
#  ('Slot', 'specialty', 'http://hl7.org/fhir/SearchParameter/Slot-specialty'),
#  ('Slot', 'start', 'http://hl7.org/fhir/SearchParameter/Slot-start'),
#  ('Slot', 'status', 'http://hl7.org/fhir/SearchParameter/Slot-status'),
#  ('Specimen', 'accession', 'http://hl7.org/fhir/SearchParameter/Specimen-accession'),
#  ('Specimen', 'bodysite', 'http://hl7.org/fhir/SearchParameter/Specimen-bodysite'),
#  ('Specimen', 'collected', 'http://hl7.org/fhir/SearchParameter/Specimen-collected'),
#  ('Specimen', 'collector', 'http://hl7.org/fhir/SearchParameter/Specimen-collector'),
#  ('Specimen', 'container', 'http://hl7.org/fhir/SearchParameter/Specimen-container'),
#  ('Specimen', 'container-id', 'http://hl7.org/fhir/SearchParameter/Specimen-container-id'),
#  ('Specimen', 'identifier', 'http://hl7.org/fhir/SearchParameter/Specimen-identifier'),
#  ('Specimen', 'parent', 'http://hl7.org/fhir/SearchParameter/Specimen-parent'),
#  ('Specimen', 'patient', 'http://hl7.org/fhir/SearchParameter/Specimen-patient'),
#  ('Specimen', 'status', 'http://hl7.org/fhir/SearchParameter/Specimen-status'),
#  ('Specimen', 'subject', 'http://hl7.org/fhir/SearchParameter/Specimen-subject'),
#  ('Specimen', 'type', 'http://hl7.org/fhir/SearchParameter/Specimen-type'),
#  ('SpecimenDefinition', 'container', 'http://hl7.org/fhir/SearchParameter/SpecimenDefinition-container'),
#  ('SpecimenDefinition', 'identifier', 'http://hl7.org/fhir/SearchParameter/SpecimenDefinition-identifier'),
#  ('SpecimenDefinition', 'type', 'http://hl7.org/fhir/SearchParameter/SpecimenDefinition-type'),
#  ('StructureDefinition', 'abstract', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-abstract'),
#  ('StructureDefinition', 'base', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-base'),
#  ('StructureDefinition', 'base-path', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-base-path'),
#  ('StructureDefinition', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('StructureDefinition', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('StructureDefinition', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('StructureDefinition', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('StructureDefinition', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('StructureDefinition', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('StructureDefinition', 'derivation', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-derivation'),
#  ('StructureDefinition', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('StructureDefinition', 'experimental', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-experimental'),
#  ('StructureDefinition', 'ext-context', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-ext-context'),
#  ('StructureDefinition', 'identifier', 'http://hl7.org/fhir/SearchParameter/conformance-identifier'),
#  ('StructureDefinition', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('StructureDefinition', 'keyword', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-keyword'),
#  ('StructureDefinition', 'kind', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-kind'),
#  ('StructureDefinition', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('StructureDefinition', 'path', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-path'),
#  ('StructureDefinition', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('StructureDefinition', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('StructureDefinition', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('StructureDefinition', 'type', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-type'),
#  ('StructureDefinition', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('StructureDefinition', 'valueset', 'http://hl7.org/fhir/SearchParameter/StructureDefinition-valueset'),
#  ('StructureDefinition', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('StructureMap', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('StructureMap', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('StructureMap', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('StructureMap', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('StructureMap', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('StructureMap', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('StructureMap', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('StructureMap', 'identifier', 'http://hl7.org/fhir/SearchParameter/conformance-identifier'),
#  ('StructureMap', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('StructureMap', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('StructureMap', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('StructureMap', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('StructureMap', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('StructureMap', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('StructureMap', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('Subscription', 'contact', 'http://hl7.org/fhir/SearchParameter/Subscription-contact'),
#  ('Subscription', 'criteria', 'http://hl7.org/fhir/SearchParameter/Subscription-criteria'),
#  ('Subscription', 'payload', 'http://hl7.org/fhir/SearchParameter/Subscription-payload'),
#  ('Subscription', 'status', 'http://hl7.org/fhir/SearchParameter/Subscription-status'),
#  ('Subscription', 'type', 'http://hl7.org/fhir/SearchParameter/Subscription-type'),
#  ('Subscription', 'url', 'http://hl7.org/fhir/SearchParameter/Subscription-url'),
#  ('Substance', 'category', 'http://hl7.org/fhir/SearchParameter/Substance-category'),
#  ('Substance', 'code', 'http://hl7.org/fhir/SearchParameter/Substance-code'),
#  ('Substance', 'container-identifier', 'http://hl7.org/fhir/SearchParameter/Substance-container-identifier'),
#  ('Substance', 'expiry', 'http://hl7.org/fhir/SearchParameter/Substance-expiry'),
#  ('Substance', 'identifier', 'http://hl7.org/fhir/SearchParameter/Substance-identifier'),
#  ('Substance', 'quantity', 'http://hl7.org/fhir/SearchParameter/Substance-quantity'),
#  ('Substance', 'status', 'http://hl7.org/fhir/SearchParameter/Substance-status'),
#  ('Substance', 'substance-reference', 'http://hl7.org/fhir/SearchParameter/Substance-substance-reference'),
#  ('SubstanceSpecification', 'code', 'http://hl7.org/fhir/SearchParameter/SubstanceSpecification-code'),
#  ('SupplyDelivery', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('SupplyDelivery', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('SupplyDelivery', 'receiver', 'http://hl7.org/fhir/SearchParameter/SupplyDelivery-receiver'),
#  ('SupplyDelivery', 'status', 'http://hl7.org/fhir/SearchParameter/SupplyDelivery-status'),
#  ('SupplyDelivery', 'supplier', 'http://hl7.org/fhir/SearchParameter/SupplyDelivery-supplier'),
#  ('SupplyRequest', 'category', 'http://hl7.org/fhir/SearchParameter/SupplyRequest-category'),
#  ('SupplyRequest', 'date', 'http://hl7.org/fhir/SearchParameter/clinical-date'),
#  ('SupplyRequest', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('SupplyRequest', 'requester', 'http://hl7.org/fhir/SearchParameter/SupplyRequest-requester'),
#  ('SupplyRequest', 'status', 'http://hl7.org/fhir/SearchParameter/SupplyRequest-status'),
#  ('SupplyRequest', 'subject', 'http://hl7.org/fhir/SearchParameter/SupplyRequest-subject'),
#  ('SupplyRequest', 'supplier', 'http://hl7.org/fhir/SearchParameter/SupplyRequest-supplier'),
#  ('Task', 'authored-on', 'http://hl7.org/fhir/SearchParameter/Task-authored-on'),
#  ('Task', 'based-on', 'http://hl7.org/fhir/SearchParameter/Task-based-on'),
#  ('Task', 'business-status', 'http://hl7.org/fhir/SearchParameter/Task-business-status'),
#  ('Task', 'code', 'http://hl7.org/fhir/SearchParameter/Task-code'),
#  ('Task', 'encounter', 'http://hl7.org/fhir/SearchParameter/Task-encounter'),
#  ('Task', 'focus', 'http://hl7.org/fhir/SearchParameter/Task-focus'),
#  ('Task', 'group-identifier', 'http://hl7.org/fhir/SearchParameter/Task-group-identifier'),
#  ('Task', 'identifier', 'http://hl7.org/fhir/SearchParameter/Task-identifier'),
#  ('Task', 'intent', 'http://hl7.org/fhir/SearchParameter/Task-intent'),
#  ('Task', 'modified', 'http://hl7.org/fhir/SearchParameter/Task-modified'),
#  ('Task', 'owner', 'http://hl7.org/fhir/SearchParameter/Task-owner'),
#  ('Task', 'part-of', 'http://hl7.org/fhir/SearchParameter/Task-part-of'),
#  ('Task', 'patient', 'http://hl7.org/fhir/SearchParameter/Task-patient'),
#  ('Task', 'performer', 'http://hl7.org/fhir/SearchParameter/Task-performer'),
#  ('Task', 'period', 'http://hl7.org/fhir/SearchParameter/Task-period'),
#  ('Task', 'priority', 'http://hl7.org/fhir/SearchParameter/Task-priority'),
#  ('Task', 'requester', 'http://hl7.org/fhir/SearchParameter/Task-requester'),
#  ('Task', 'status', 'http://hl7.org/fhir/SearchParameter/Task-status'),
#  ('Task', 'subject', 'http://hl7.org/fhir/SearchParameter/Task-subject'),
#  ('TerminologyCapabilities', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('TerminologyCapabilities', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('TerminologyCapabilities', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('TerminologyCapabilities', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('TerminologyCapabilities', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('TerminologyCapabilities', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('TerminologyCapabilities', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('TerminologyCapabilities', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('TerminologyCapabilities', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('TerminologyCapabilities', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('TerminologyCapabilities', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('TerminologyCapabilities', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('TerminologyCapabilities', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('TerminologyCapabilities', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('TestReport', 'identifier', 'http://hl7.org/fhir/SearchParameter/TestReport-identifier'),
#  ('TestReport', 'issued', 'http://hl7.org/fhir/SearchParameter/TestReport-issued'),
#  ('TestReport', 'participant', 'http://hl7.org/fhir/SearchParameter/TestReport-participant'),
#  ('TestReport', 'result', 'http://hl7.org/fhir/SearchParameter/TestReport-result'),
#  ('TestReport', 'tester', 'http://hl7.org/fhir/SearchParameter/TestReport-tester'),
#  ('TestReport', 'testscript', 'http://hl7.org/fhir/SearchParameter/TestReport-testscript'),
#  ('TestScript', 'context', 'http://hl7.org/fhir/SearchParameter/TestScript-context'),
#  ('TestScript', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/TestScript-context-quantity'),
#  ('TestScript', 'context-type', 'http://hl7.org/fhir/SearchParameter/TestScript-context-type'),
#  ('TestScript', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/TestScript-context-type-quantity'),
#  ('TestScript', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/TestScript-context-type-value'),
#  ('TestScript', 'date', 'http://hl7.org/fhir/SearchParameter/TestScript-date'),
#  ('TestScript', 'description', 'http://hl7.org/fhir/SearchParameter/TestScript-description'),
#  ('TestScript', 'identifier', 'http://hl7.org/fhir/SearchParameter/TestScript-identifier'),
#  ('TestScript', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/TestScript-jurisdiction'),
#  ('TestScript', 'name', 'http://hl7.org/fhir/SearchParameter/TestScript-name'),
#  ('TestScript', 'publisher', 'http://hl7.org/fhir/SearchParameter/TestScript-publisher'),
#  ('TestScript', 'status', 'http://hl7.org/fhir/SearchParameter/TestScript-status'),
#  ('TestScript', 'testscript-capability', 'http://hl7.org/fhir/SearchParameter/TestScript-testscript-capability'),
#  ('TestScript', 'title', 'http://hl7.org/fhir/SearchParameter/TestScript-title'),
#  ('TestScript', 'url', 'http://hl7.org/fhir/SearchParameter/TestScript-url'),
#  ('TestScript', 'version', 'http://hl7.org/fhir/SearchParameter/TestScript-version'),
#  ('ValueSet', 'code', 'http://hl7.org/fhir/SearchParameter/ValueSet-code'),
#  ('ValueSet', 'context', 'http://hl7.org/fhir/SearchParameter/conformance-context'),
#  ('ValueSet', 'context-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-quantity'),
#  ('ValueSet', 'context-type', 'http://hl7.org/fhir/SearchParameter/conformance-context-type'),
#  ('ValueSet', 'context-type-quantity', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity'),
#  ('ValueSet', 'context-type-value', 'http://hl7.org/fhir/SearchParameter/conformance-context-type-value'),
#  ('ValueSet', 'date', 'http://hl7.org/fhir/SearchParameter/conformance-date'),
#  ('ValueSet', 'description', 'http://hl7.org/fhir/SearchParameter/conformance-description'),
#  ('ValueSet', 'expansion', 'http://hl7.org/fhir/SearchParameter/ValueSet-expansion'),
#  ('ValueSet', 'identifier', 'http://hl7.org/fhir/SearchParameter/conformance-identifier'),
#  ('ValueSet', 'jurisdiction', 'http://hl7.org/fhir/SearchParameter/conformance-jurisdiction'),
#  ('ValueSet', 'name', 'http://hl7.org/fhir/SearchParameter/conformance-name'),
#  ('ValueSet', 'publisher', 'http://hl7.org/fhir/SearchParameter/conformance-publisher'),
#  ('ValueSet', 'reference', 'http://hl7.org/fhir/SearchParameter/ValueSet-reference'),
#  ('ValueSet', 'status', 'http://hl7.org/fhir/SearchParameter/conformance-status'),
#  ('ValueSet', 'title', 'http://hl7.org/fhir/SearchParameter/conformance-title'),
#  ('ValueSet', 'url', 'http://hl7.org/fhir/SearchParameter/conformance-url'),
#  ('ValueSet', 'version', 'http://hl7.org/fhir/SearchParameter/conformance-version'),
#  ('VerificationResult', 'target', 'http://hl7.org/fhir/SearchParameter/VerificationResult-target'),
#  ('VisionPrescription', 'datewritten', 'http://hl7.org/fhir/SearchParameter/VisionPrescription-datewritten'),
#  ('VisionPrescription', 'encounter', 'http://hl7.org/fhir/SearchParameter/clinical-encounter'),
#  ('VisionPrescription', 'identifier', 'http://hl7.org/fhir/SearchParameter/clinical-identifier'),
#  ('VisionPrescription', 'patient', 'http://hl7.org/fhir/SearchParameter/clinical-patient'),
#  ('VisionPrescription', 'prescriber', 'http://hl7.org/fhir/SearchParameter/VisionPrescription-prescriber'),
#  ('VisionPrescription', 'status', 'http://hl7.org/fhir/SearchParameter/VisionPrescription-status')]

# %% [markdown]
# ### Using Jinja2 Template create md file for summary view

# %%
in_path = ''
template_path = 'sp_summary_template.j2'

def markdown(text, *args, **kwargs):
    return commonmark(text, *args, **kwargs)

env = Environment(
    loader=FileSystemLoader(searchpath = in_path),
    autoescape=select_autoescape(['html','xml','xhtml','j2','md'])
    )

env.filters['markdown'] = markdown

template = env.get_template(template_path)

d = template.render(sps = sp_list)
display(Markdown(d))
# Out:
# ## Alphabetical List of search parameters urls by Type and code
# |Row|Type|code|url|
# |---|---|---|---|
# |1.|Account|`identifier`|http://hl7.org/fhir/SearchParameter/Account-identifier|
# |2.|Account|`name`|http://hl7.org/fhir/SearchParameter/Account-name|
# |3.|Account|`owner`|http://hl7.org/fhir/SearchParameter/Account-owner|
# |4.|Account|`patient`|http://hl7.org/fhir/SearchParameter/Account-patient|
# |5.|Account|`period`|http://hl7.org/fhir/SearchParameter/Account-period|
# |6.|Account|`status`|http://hl7.org/fhir/SearchParameter/Account-status|
# |7.|Account|`subject`|http://hl7.org/fhir/SearchParameter/Account-subject|
# |8.|Account|`type`|http://hl7.org/fhir/SearchParameter/Account-type|
# |9.|ActivityDefinition|`composed-of`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-composed-of|
# |10.|ActivityDefinition|`context`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-context|
# |11.|ActivityDefinition|`context-quantity`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-quantity|
# |12.|ActivityDefinition|`context-type`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-type|
# |13.|ActivityDefinition|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-type-quantity|
# |14.|ActivityDefinition|`context-type-value`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-context-type-value|
# |15.|ActivityDefinition|`date`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-date|
# |16.|ActivityDefinition|`depends-on`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-depends-on|
# |17.|ActivityDefinition|`derived-from`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-derived-from|
# |18.|ActivityDefinition|`description`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-description|
# |19.|ActivityDefinition|`effective`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-effective|
# |20.|ActivityDefinition|`identifier`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-identifier|
# |21.|ActivityDefinition|`jurisdiction`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-jurisdiction|
# |22.|ActivityDefinition|`name`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-name|
# |23.|ActivityDefinition|`predecessor`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-predecessor|
# |24.|ActivityDefinition|`publisher`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-publisher|
# |25.|ActivityDefinition|`status`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-status|
# |26.|ActivityDefinition|`successor`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-successor|
# |27.|ActivityDefinition|`title`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-title|
# |28.|ActivityDefinition|`topic`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-topic|
# |29.|ActivityDefinition|`url`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-url|
# |30.|ActivityDefinition|`version`|http://hl7.org/fhir/SearchParameter/ActivityDefinition-version|
# |31.|AdverseEvent|`actuality`|http://hl7.org/fhir/SearchParameter/AdverseEvent-actuality|
# |32.|AdverseEvent|`category`|http://hl7.org/fhir/SearchParameter/AdverseEvent-category|
# |33.|AdverseEvent|`date`|http://hl7.org/fhir/SearchParameter/AdverseEvent-date|
# |34.|AdverseEvent|`event`|http://hl7.org/fhir/SearchParameter/AdverseEvent-event|
# |35.|AdverseEvent|`location`|http://hl7.org/fhir/SearchParameter/AdverseEvent-location|
# |36.|AdverseEvent|`recorder`|http://hl7.org/fhir/SearchParameter/AdverseEvent-recorder|
# |37.|AdverseEvent|`resultingcondition`|http://hl7.org/fhir/SearchParameter/AdverseEvent-resultingcondition|
# |38.|AdverseEvent|`seriousness`|http://hl7.org/fhir/SearchParameter/AdverseEvent-seriousness|
# |39.|AdverseEvent|`severity`|http://hl7.org/fhir/SearchParameter/AdverseEvent-severity|
# |40.|AdverseEvent|`study`|http://hl7.org/fhir/SearchParameter/AdverseEvent-study|
# |41.|AdverseEvent|`subject`|http://hl7.org/fhir/SearchParameter/AdverseEvent-subject|
# |42.|AdverseEvent|`substance`|http://hl7.org/fhir/SearchParameter/AdverseEvent-substance|
# |43.|AllergyIntolerance|`asserter`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-asserter|
# |44.|AllergyIntolerance|`category`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-category|
# |45.|AllergyIntolerance|`clinical-status`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-clinical-status|
# |46.|AllergyIntolerance|`code`|http://hl7.org/fhir/SearchParameter/clinical-code|
# |47.|AllergyIntolerance|`criticality`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-criticality|
# |48.|AllergyIntolerance|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |49.|AllergyIntolerance|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |50.|AllergyIntolerance|`last-date`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-last-date|
# |51.|AllergyIntolerance|`manifestation`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-manifestation|
# |52.|AllergyIntolerance|`onset`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-onset|
# |53.|AllergyIntolerance|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |54.|AllergyIntolerance|`recorder`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-recorder|
# |55.|AllergyIntolerance|`route`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-route|
# |56.|AllergyIntolerance|`severity`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-severity|
# |57.|AllergyIntolerance|`type`|http://hl7.org/fhir/SearchParameter/clinical-type|
# |58.|AllergyIntolerance|`verification-status`|http://hl7.org/fhir/SearchParameter/AllergyIntolerance-verification-status|
# |59.|Appointment|`actor`|http://hl7.org/fhir/SearchParameter/Appointment-actor|
# |60.|Appointment|`appointment-type`|http://hl7.org/fhir/SearchParameter/Appointment-appointment-type|
# |61.|Appointment|`based-on`|http://hl7.org/fhir/SearchParameter/Appointment-based-on|
# |62.|Appointment|`date`|http://hl7.org/fhir/SearchParameter/Appointment-date|
# |63.|Appointment|`identifier`|http://hl7.org/fhir/SearchParameter/Appointment-identifier|
# |64.|Appointment|`location`|http://hl7.org/fhir/SearchParameter/Appointment-location|
# |65.|Appointment|`part-status`|http://hl7.org/fhir/SearchParameter/Appointment-part-status|
# |66.|Appointment|`patient`|http://hl7.org/fhir/SearchParameter/Appointment-patient|
# |67.|Appointment|`practitioner`|http://hl7.org/fhir/SearchParameter/Appointment-practitioner|
# |68.|Appointment|`reason-code`|http://hl7.org/fhir/SearchParameter/Appointment-reason-code|
# |69.|Appointment|`reason-reference`|http://hl7.org/fhir/SearchParameter/Appointment-reason-reference|
# |70.|Appointment|`service-category`|http://hl7.org/fhir/SearchParameter/Appointment-service-category|
# |71.|Appointment|`service-type`|http://hl7.org/fhir/SearchParameter/Appointment-service-type|
# |72.|Appointment|`slot`|http://hl7.org/fhir/SearchParameter/Appointment-slot|
# |73.|Appointment|`specialty`|http://hl7.org/fhir/SearchParameter/Appointment-specialty|
# |74.|Appointment|`status`|http://hl7.org/fhir/SearchParameter/Appointment-status|
# |75.|Appointment|`supporting-info`|http://hl7.org/fhir/SearchParameter/Appointment-supporting-info|
# |76.|AppointmentResponse|`actor`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-actor|
# |77.|AppointmentResponse|`appointment`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-appointment|
# |78.|AppointmentResponse|`identifier`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-identifier|
# |79.|AppointmentResponse|`location`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-location|
# |80.|AppointmentResponse|`part-status`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-part-status|
# |81.|AppointmentResponse|`patient`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-patient|
# |82.|AppointmentResponse|`practitioner`|http://hl7.org/fhir/SearchParameter/AppointmentResponse-practitioner|
# |83.|AuditEvent|`action`|http://hl7.org/fhir/SearchParameter/AuditEvent-action|
# |84.|AuditEvent|`address`|http://hl7.org/fhir/SearchParameter/AuditEvent-address|
# |85.|AuditEvent|`agent`|http://hl7.org/fhir/SearchParameter/AuditEvent-agent|
# |86.|AuditEvent|`agent-name`|http://hl7.org/fhir/SearchParameter/AuditEvent-agent-name|
# |87.|AuditEvent|`agent-role`|http://hl7.org/fhir/SearchParameter/AuditEvent-agent-role|
# |88.|AuditEvent|`altid`|http://hl7.org/fhir/SearchParameter/AuditEvent-altid|
# |89.|AuditEvent|`date`|http://hl7.org/fhir/SearchParameter/AuditEvent-date|
# |90.|AuditEvent|`entity`|http://hl7.org/fhir/SearchParameter/AuditEvent-entity|
# |91.|AuditEvent|`entity-name`|http://hl7.org/fhir/SearchParameter/AuditEvent-entity-name|
# |92.|AuditEvent|`entity-role`|http://hl7.org/fhir/SearchParameter/AuditEvent-entity-role|
# |93.|AuditEvent|`entity-type`|http://hl7.org/fhir/SearchParameter/AuditEvent-entity-type|
# |94.|AuditEvent|`outcome`|http://hl7.org/fhir/SearchParameter/AuditEvent-outcome|
# |95.|AuditEvent|`patient`|http://hl7.org/fhir/SearchParameter/AuditEvent-patient|
# |96.|AuditEvent|`policy`|http://hl7.org/fhir/SearchParameter/AuditEvent-policy|
# |97.|AuditEvent|`site`|http://hl7.org/fhir/SearchParameter/AuditEvent-site|
# |98.|AuditEvent|`source`|http://hl7.org/fhir/SearchParameter/AuditEvent-source|
# |99.|AuditEvent|`subtype`|http://hl7.org/fhir/SearchParameter/AuditEvent-subtype|
# |100.|AuditEvent|`type`|http://hl7.org/fhir/SearchParameter/AuditEvent-type|
# |101.|Basic|`author`|http://hl7.org/fhir/SearchParameter/Basic-author|
# |102.|Basic|`code`|http://hl7.org/fhir/SearchParameter/Basic-code|
# |103.|Basic|`created`|http://hl7.org/fhir/SearchParameter/Basic-created|
# |104.|Basic|`identifier`|http://hl7.org/fhir/SearchParameter/Basic-identifier|
# |105.|Basic|`patient`|http://hl7.org/fhir/SearchParameter/Basic-patient|
# |106.|Basic|`subject`|http://hl7.org/fhir/SearchParameter/Basic-subject|
# |107.|BodyStructure|`identifier`|http://hl7.org/fhir/SearchParameter/BodyStructure-identifier|
# |108.|BodyStructure|`location`|http://hl7.org/fhir/SearchParameter/BodyStructure-location|
# |109.|BodyStructure|`morphology`|http://hl7.org/fhir/SearchParameter/BodyStructure-morphology|
# |110.|BodyStructure|`patient`|http://hl7.org/fhir/SearchParameter/BodyStructure-patient|
# |111.|Bundle|`composition`|http://hl7.org/fhir/SearchParameter/Bundle-composition|
# |112.|Bundle|`identifier`|http://hl7.org/fhir/SearchParameter/Bundle-identifier|
# |113.|Bundle|`message`|http://hl7.org/fhir/SearchParameter/Bundle-message|
# |114.|Bundle|`timestamp`|http://hl7.org/fhir/SearchParameter/Bundle-timestamp|
# |115.|Bundle|`type`|http://hl7.org/fhir/SearchParameter/Bundle-type|
# |116.|CapabilityStatement|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |117.|CapabilityStatement|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |118.|CapabilityStatement|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |119.|CapabilityStatement|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |120.|CapabilityStatement|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |121.|CapabilityStatement|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |122.|CapabilityStatement|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |123.|CapabilityStatement|`fhirversion`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-fhirversion|
# |124.|CapabilityStatement|`format`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-format|
# |125.|CapabilityStatement|`guide`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-guide|
# |126.|CapabilityStatement|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |127.|CapabilityStatement|`mode`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-mode|
# |128.|CapabilityStatement|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |129.|CapabilityStatement|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |130.|CapabilityStatement|`resource`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-resource|
# |131.|CapabilityStatement|`resource-profile`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-resource-profile|
# |132.|CapabilityStatement|`security-service`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-security-service|
# |133.|CapabilityStatement|`software`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-software|
# |134.|CapabilityStatement|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |135.|CapabilityStatement|`supported-profile`|http://hl7.org/fhir/SearchParameter/CapabilityStatement-supported-profile|
# |136.|CapabilityStatement|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |137.|CapabilityStatement|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |138.|CapabilityStatement|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |139.|CarePlan|`activity-code`|http://hl7.org/fhir/SearchParameter/CarePlan-activity-code|
# |140.|CarePlan|`activity-date`|http://hl7.org/fhir/SearchParameter/CarePlan-activity-date|
# |141.|CarePlan|`activity-reference`|http://hl7.org/fhir/SearchParameter/CarePlan-activity-reference|
# |142.|CarePlan|`based-on`|http://hl7.org/fhir/SearchParameter/CarePlan-based-on|
# |143.|CarePlan|`care-team`|http://hl7.org/fhir/SearchParameter/CarePlan-care-team|
# |144.|CarePlan|`category`|http://hl7.org/fhir/SearchParameter/CarePlan-category|
# |145.|CarePlan|`condition`|http://hl7.org/fhir/SearchParameter/CarePlan-condition|
# |146.|CarePlan|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |147.|CarePlan|`encounter`|http://hl7.org/fhir/SearchParameter/CarePlan-encounter|
# |148.|CarePlan|`goal`|http://hl7.org/fhir/SearchParameter/CarePlan-goal|
# |149.|CarePlan|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |150.|CarePlan|`instantiates-canonical`|http://hl7.org/fhir/SearchParameter/CarePlan-instantiates-canonical|
# |151.|CarePlan|`instantiates-uri`|http://hl7.org/fhir/SearchParameter/CarePlan-instantiates-uri|
# |152.|CarePlan|`intent`|http://hl7.org/fhir/SearchParameter/CarePlan-intent|
# |153.|CarePlan|`part-of`|http://hl7.org/fhir/SearchParameter/CarePlan-part-of|
# |154.|CarePlan|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |155.|CarePlan|`performer`|http://hl7.org/fhir/SearchParameter/CarePlan-performer|
# |156.|CarePlan|`replaces`|http://hl7.org/fhir/SearchParameter/CarePlan-replaces|
# |157.|CarePlan|`status`|http://hl7.org/fhir/SearchParameter/CarePlan-status|
# |158.|CarePlan|`subject`|http://hl7.org/fhir/SearchParameter/CarePlan-subject|
# |159.|CareTeam|`category`|http://hl7.org/fhir/SearchParameter/CareTeam-category|
# |160.|CareTeam|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |161.|CareTeam|`encounter`|http://hl7.org/fhir/SearchParameter/CareTeam-encounter|
# |162.|CareTeam|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |163.|CareTeam|`participant`|http://hl7.org/fhir/SearchParameter/CareTeam-participant|
# |164.|CareTeam|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |165.|CareTeam|`status`|http://hl7.org/fhir/SearchParameter/CareTeam-status|
# |166.|CareTeam|`subject`|http://hl7.org/fhir/SearchParameter/CareTeam-subject|
# |167.|ChargeItem|`account`|http://hl7.org/fhir/SearchParameter/ChargeItem-account|
# |168.|ChargeItem|`code`|http://hl7.org/fhir/SearchParameter/ChargeItem-code|
# |169.|ChargeItem|`context`|http://hl7.org/fhir/SearchParameter/ChargeItem-context|
# |170.|ChargeItem|`entered-date`|http://hl7.org/fhir/SearchParameter/ChargeItem-entered-date|
# |171.|ChargeItem|`enterer`|http://hl7.org/fhir/SearchParameter/ChargeItem-enterer|
# |172.|ChargeItem|`factor-override`|http://hl7.org/fhir/SearchParameter/ChargeItem-factor-override|
# |173.|ChargeItem|`identifier`|http://hl7.org/fhir/SearchParameter/ChargeItem-identifier|
# |174.|ChargeItem|`occurrence`|http://hl7.org/fhir/SearchParameter/ChargeItem-occurrence|
# |175.|ChargeItem|`patient`|http://hl7.org/fhir/SearchParameter/ChargeItem-patient|
# |176.|ChargeItem|`performer-actor`|http://hl7.org/fhir/SearchParameter/ChargeItem-performer-actor|
# |177.|ChargeItem|`performer-function`|http://hl7.org/fhir/SearchParameter/ChargeItem-performer-function|
# |178.|ChargeItem|`performing-organization`|http://hl7.org/fhir/SearchParameter/ChargeItem-performing-organization|
# |179.|ChargeItem|`price-override`|http://hl7.org/fhir/SearchParameter/ChargeItem-price-override|
# |180.|ChargeItem|`quantity`|http://hl7.org/fhir/SearchParameter/ChargeItem-quantity|
# |181.|ChargeItem|`requesting-organization`|http://hl7.org/fhir/SearchParameter/ChargeItem-requesting-organization|
# |182.|ChargeItem|`service`|http://hl7.org/fhir/SearchParameter/ChargeItem-service|
# |183.|ChargeItem|`subject`|http://hl7.org/fhir/SearchParameter/ChargeItem-subject|
# |184.|ChargeItemDefinition|`context`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context|
# |185.|ChargeItemDefinition|`context-quantity`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-quantity|
# |186.|ChargeItemDefinition|`context-type`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-type|
# |187.|ChargeItemDefinition|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-type-quantity|
# |188.|ChargeItemDefinition|`context-type-value`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-context-type-value|
# |189.|ChargeItemDefinition|`date`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-date|
# |190.|ChargeItemDefinition|`description`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-description|
# |191.|ChargeItemDefinition|`effective`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-effective|
# |192.|ChargeItemDefinition|`identifier`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-identifier|
# |193.|ChargeItemDefinition|`jurisdiction`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-jurisdiction|
# |194.|ChargeItemDefinition|`publisher`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-publisher|
# |195.|ChargeItemDefinition|`status`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-status|
# |196.|ChargeItemDefinition|`title`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-title|
# |197.|ChargeItemDefinition|`url`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-url|
# |198.|ChargeItemDefinition|`version`|http://hl7.org/fhir/SearchParameter/ChargeItemDefinition-version|
# |199.|Claim|`care-team`|http://hl7.org/fhir/SearchParameter/Claim-care-team|
# |200.|Claim|`created`|http://hl7.org/fhir/SearchParameter/Claim-created|
# |201.|Claim|`detail-udi`|http://hl7.org/fhir/SearchParameter/Claim-detail-udi|
# |202.|Claim|`encounter`|http://hl7.org/fhir/SearchParameter/Claim-encounter|
# |203.|Claim|`enterer`|http://hl7.org/fhir/SearchParameter/Claim-enterer|
# |204.|Claim|`facility`|http://hl7.org/fhir/SearchParameter/Claim-facility|
# |205.|Claim|`identifier`|http://hl7.org/fhir/SearchParameter/Claim-identifier|
# |206.|Claim|`insurer`|http://hl7.org/fhir/SearchParameter/Claim-insurer|
# |207.|Claim|`item-udi`|http://hl7.org/fhir/SearchParameter/Claim-item-udi|
# |208.|Claim|`patient`|http://hl7.org/fhir/SearchParameter/Claim-patient|
# |209.|Claim|`payee`|http://hl7.org/fhir/SearchParameter/Claim-payee|
# |210.|Claim|`priority`|http://hl7.org/fhir/SearchParameter/Claim-priority|
# |211.|Claim|`procedure-udi`|http://hl7.org/fhir/SearchParameter/Claim-procedure-udi|
# |212.|Claim|`provider`|http://hl7.org/fhir/SearchParameter/Claim-provider|
# |213.|Claim|`status`|http://hl7.org/fhir/SearchParameter/Claim-status|
# |214.|Claim|`subdetail-udi`|http://hl7.org/fhir/SearchParameter/Claim-subdetail-udi|
# |215.|Claim|`use`|http://hl7.org/fhir/SearchParameter/Claim-use|
# |216.|ClaimResponse|`created`|http://hl7.org/fhir/SearchParameter/ClaimResponse-created|
# |217.|ClaimResponse|`disposition`|http://hl7.org/fhir/SearchParameter/ClaimResponse-disposition|
# |218.|ClaimResponse|`identifier`|http://hl7.org/fhir/SearchParameter/ClaimResponse-identifier|
# |219.|ClaimResponse|`insurer`|http://hl7.org/fhir/SearchParameter/ClaimResponse-insurer|
# |220.|ClaimResponse|`outcome`|http://hl7.org/fhir/SearchParameter/ClaimResponse-outcome|
# |221.|ClaimResponse|`patient`|http://hl7.org/fhir/SearchParameter/ClaimResponse-patient|
# |222.|ClaimResponse|`payment-date`|http://hl7.org/fhir/SearchParameter/ClaimResponse-payment-date|
# |223.|ClaimResponse|`request`|http://hl7.org/fhir/SearchParameter/ClaimResponse-request|
# |224.|ClaimResponse|`requestor`|http://hl7.org/fhir/SearchParameter/ClaimResponse-requestor|
# |225.|ClaimResponse|`status`|http://hl7.org/fhir/SearchParameter/ClaimResponse-status|
# |226.|ClaimResponse|`use`|http://hl7.org/fhir/SearchParameter/ClaimResponse-use|
# |227.|ClinicalImpression|`assessor`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-assessor|
# |228.|ClinicalImpression|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |229.|ClinicalImpression|`encounter`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-encounter|
# |230.|ClinicalImpression|`finding-code`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-finding-code|
# |231.|ClinicalImpression|`finding-ref`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-finding-ref|
# |232.|ClinicalImpression|`identifier`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-identifier|
# |233.|ClinicalImpression|`investigation`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-investigation|
# |234.|ClinicalImpression|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |235.|ClinicalImpression|`previous`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-previous|
# |236.|ClinicalImpression|`problem`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-problem|
# |237.|ClinicalImpression|`status`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-status|
# |238.|ClinicalImpression|`subject`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-subject|
# |239.|ClinicalImpression|`supporting-info`|http://hl7.org/fhir/SearchParameter/ClinicalImpression-supporting-info|
# |240.|CodeSystem|`code`|http://hl7.org/fhir/SearchParameter/CodeSystem-code|
# |241.|CodeSystem|`content-mode`|http://hl7.org/fhir/SearchParameter/CodeSystem-content-mode|
# |242.|CodeSystem|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |243.|CodeSystem|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |244.|CodeSystem|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |245.|CodeSystem|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |246.|CodeSystem|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |247.|CodeSystem|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |248.|CodeSystem|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |249.|CodeSystem|`identifier`|http://hl7.org/fhir/SearchParameter/conformance-identifier|
# |250.|CodeSystem|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |251.|CodeSystem|`language`|http://hl7.org/fhir/SearchParameter/CodeSystem-language|
# |252.|CodeSystem|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |253.|CodeSystem|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |254.|CodeSystem|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |255.|CodeSystem|`supplements`|http://hl7.org/fhir/SearchParameter/CodeSystem-supplements|
# |256.|CodeSystem|`system`|http://hl7.org/fhir/SearchParameter/CodeSystem-system|
# |257.|CodeSystem|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |258.|CodeSystem|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |259.|CodeSystem|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |260.|Communication|`based-on`|http://hl7.org/fhir/SearchParameter/Communication-based-on|
# |261.|Communication|`category`|http://hl7.org/fhir/SearchParameter/Communication-category|
# |262.|Communication|`encounter`|http://hl7.org/fhir/SearchParameter/Communication-encounter|
# |263.|Communication|`identifier`|http://hl7.org/fhir/SearchParameter/Communication-identifier|
# |264.|Communication|`instantiates-canonical`|http://hl7.org/fhir/SearchParameter/Communication-instantiates-canonical|
# |265.|Communication|`instantiates-uri`|http://hl7.org/fhir/SearchParameter/Communication-instantiates-uri|
# |266.|Communication|`medium`|http://hl7.org/fhir/SearchParameter/Communication-medium|
# |267.|Communication|`part-of`|http://hl7.org/fhir/SearchParameter/Communication-part-of|
# |268.|Communication|`patient`|http://hl7.org/fhir/SearchParameter/Communication-patient|
# |269.|Communication|`received`|http://hl7.org/fhir/SearchParameter/Communication-received|
# |270.|Communication|`recipient`|http://hl7.org/fhir/SearchParameter/Communication-recipient|
# |271.|Communication|`sender`|http://hl7.org/fhir/SearchParameter/Communication-sender|
# |272.|Communication|`sent`|http://hl7.org/fhir/SearchParameter/Communication-sent|
# |273.|Communication|`status`|http://hl7.org/fhir/SearchParameter/Communication-status|
# |274.|Communication|`subject`|http://hl7.org/fhir/SearchParameter/Communication-subject|
# |275.|CommunicationRequest|`authored`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-authored|
# |276.|CommunicationRequest|`based-on`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-based-on|
# |277.|CommunicationRequest|`category`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-category|
# |278.|CommunicationRequest|`encounter`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-encounter|
# |279.|CommunicationRequest|`group-identifier`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-group-identifier|
# |280.|CommunicationRequest|`identifier`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-identifier|
# |281.|CommunicationRequest|`medium`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-medium|
# |282.|CommunicationRequest|`occurrence`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-occurrence|
# |283.|CommunicationRequest|`patient`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-patient|
# |284.|CommunicationRequest|`priority`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-priority|
# |285.|CommunicationRequest|`recipient`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-recipient|
# |286.|CommunicationRequest|`replaces`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-replaces|
# |287.|CommunicationRequest|`requester`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-requester|
# |288.|CommunicationRequest|`sender`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-sender|
# |289.|CommunicationRequest|`status`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-status|
# |290.|CommunicationRequest|`subject`|http://hl7.org/fhir/SearchParameter/CommunicationRequest-subject|
# |291.|CompartmentDefinition|`code`|http://hl7.org/fhir/SearchParameter/CompartmentDefinition-code|
# |292.|CompartmentDefinition|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |293.|CompartmentDefinition|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |294.|CompartmentDefinition|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |295.|CompartmentDefinition|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |296.|CompartmentDefinition|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |297.|CompartmentDefinition|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |298.|CompartmentDefinition|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |299.|CompartmentDefinition|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |300.|CompartmentDefinition|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |301.|CompartmentDefinition|`resource`|http://hl7.org/fhir/SearchParameter/CompartmentDefinition-resource|
# |302.|CompartmentDefinition|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |303.|CompartmentDefinition|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |304.|CompartmentDefinition|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |305.|Composition|`attester`|http://hl7.org/fhir/SearchParameter/Composition-attester|
# |306.|Composition|`author`|http://hl7.org/fhir/SearchParameter/Composition-author|
# |307.|Composition|`category`|http://hl7.org/fhir/SearchParameter/Composition-category|
# |308.|Composition|`confidentiality`|http://hl7.org/fhir/SearchParameter/Composition-confidentiality|
# |309.|Composition|`context`|http://hl7.org/fhir/SearchParameter/Composition-context|
# |310.|Composition|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |311.|Composition|`encounter`|http://hl7.org/fhir/SearchParameter/clinical-encounter|
# |312.|Composition|`entry`|http://hl7.org/fhir/SearchParameter/Composition-entry|
# |313.|Composition|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |314.|Composition|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |315.|Composition|`period`|http://hl7.org/fhir/SearchParameter/Composition-period|
# |316.|Composition|`related-id`|http://hl7.org/fhir/SearchParameter/Composition-related-id|
# |317.|Composition|`related-ref`|http://hl7.org/fhir/SearchParameter/Composition-related-ref|
# |318.|Composition|`section`|http://hl7.org/fhir/SearchParameter/Composition-section|
# |319.|Composition|`status`|http://hl7.org/fhir/SearchParameter/Composition-status|
# |320.|Composition|`subject`|http://hl7.org/fhir/SearchParameter/Composition-subject|
# |321.|Composition|`title`|http://hl7.org/fhir/SearchParameter/Composition-title|
# |322.|Composition|`type`|http://hl7.org/fhir/SearchParameter/clinical-type|
# |323.|ConceptMap|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |324.|ConceptMap|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |325.|ConceptMap|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |326.|ConceptMap|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |327.|ConceptMap|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |328.|ConceptMap|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |329.|ConceptMap|`dependson`|http://hl7.org/fhir/SearchParameter/ConceptMap-dependson|
# |330.|ConceptMap|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |331.|ConceptMap|`identifier`|http://hl7.org/fhir/SearchParameter/conformance-identifier|
# |332.|ConceptMap|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |333.|ConceptMap|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |334.|ConceptMap|`other`|http://hl7.org/fhir/SearchParameter/ConceptMap-other|
# |335.|ConceptMap|`product`|http://hl7.org/fhir/SearchParameter/ConceptMap-product|
# |336.|ConceptMap|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |337.|ConceptMap|`source`|http://hl7.org/fhir/SearchParameter/ConceptMap-source|
# |338.|ConceptMap|`source-code`|http://hl7.org/fhir/SearchParameter/ConceptMap-source-code|
# |339.|ConceptMap|`source-system`|http://hl7.org/fhir/SearchParameter/ConceptMap-source-system|
# |340.|ConceptMap|`source-uri`|http://hl7.org/fhir/SearchParameter/ConceptMap-source-uri|
# |341.|ConceptMap|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |342.|ConceptMap|`target`|http://hl7.org/fhir/SearchParameter/ConceptMap-target|
# |343.|ConceptMap|`target-code`|http://hl7.org/fhir/SearchParameter/ConceptMap-target-code|
# |344.|ConceptMap|`target-system`|http://hl7.org/fhir/SearchParameter/ConceptMap-target-system|
# |345.|ConceptMap|`target-uri`|http://hl7.org/fhir/SearchParameter/ConceptMap-target-uri|
# |346.|ConceptMap|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |347.|ConceptMap|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |348.|ConceptMap|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |349.|Condition|`abatement-age`|http://hl7.org/fhir/SearchParameter/Condition-abatement-age|
# |350.|Condition|`abatement-date`|http://hl7.org/fhir/SearchParameter/Condition-abatement-date|
# |351.|Condition|`abatement-string`|http://hl7.org/fhir/SearchParameter/Condition-abatement-string|
# |352.|Condition|`asserter`|http://hl7.org/fhir/SearchParameter/Condition-asserter|
# |353.|Condition|`body-site`|http://hl7.org/fhir/SearchParameter/Condition-body-site|
# |354.|Condition|`category`|http://hl7.org/fhir/SearchParameter/Condition-category|
# |355.|Condition|`clinical-status`|http://hl7.org/fhir/SearchParameter/Condition-clinical-status|
# |356.|Condition|`code`|http://hl7.org/fhir/SearchParameter/clinical-code|
# |357.|Condition|`encounter`|http://hl7.org/fhir/SearchParameter/Condition-encounter|
# |358.|Condition|`evidence`|http://hl7.org/fhir/SearchParameter/Condition-evidence|
# |359.|Condition|`evidence-detail`|http://hl7.org/fhir/SearchParameter/Condition-evidence-detail|
# |360.|Condition|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |361.|Condition|`onset-age`|http://hl7.org/fhir/SearchParameter/Condition-onset-age|
# |362.|Condition|`onset-date`|http://hl7.org/fhir/SearchParameter/Condition-onset-date|
# |363.|Condition|`onset-info`|http://hl7.org/fhir/SearchParameter/Condition-onset-info|
# |364.|Condition|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |365.|Condition|`recorded-date`|http://hl7.org/fhir/SearchParameter/Condition-recorded-date|
# |366.|Condition|`severity`|http://hl7.org/fhir/SearchParameter/Condition-severity|
# |367.|Condition|`stage`|http://hl7.org/fhir/SearchParameter/Condition-stage|
# |368.|Condition|`subject`|http://hl7.org/fhir/SearchParameter/Condition-subject|
# |369.|Condition|`verification-status`|http://hl7.org/fhir/SearchParameter/Condition-verification-status|
# |370.|Consent|`action`|http://hl7.org/fhir/SearchParameter/Consent-action|
# |371.|Consent|`actor`|http://hl7.org/fhir/SearchParameter/Consent-actor|
# |372.|Consent|`category`|http://hl7.org/fhir/SearchParameter/Consent-category|
# |373.|Consent|`consentor`|http://hl7.org/fhir/SearchParameter/Consent-consentor|
# |374.|Consent|`data`|http://hl7.org/fhir/SearchParameter/Consent-data|
# |375.|Consent|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |376.|Consent|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |377.|Consent|`organization`|http://hl7.org/fhir/SearchParameter/Consent-organization|
# |378.|Consent|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |379.|Consent|`period`|http://hl7.org/fhir/SearchParameter/Consent-period|
# |380.|Consent|`purpose`|http://hl7.org/fhir/SearchParameter/Consent-purpose|
# |381.|Consent|`scope`|http://hl7.org/fhir/SearchParameter/Consent-scope|
# |382.|Consent|`security-label`|http://hl7.org/fhir/SearchParameter/Consent-security-label|
# |383.|Consent|`source-reference`|http://hl7.org/fhir/SearchParameter/Consent-source-reference|
# |384.|Consent|`status`|http://hl7.org/fhir/SearchParameter/Consent-status|
# |385.|Contract|`authority`|http://hl7.org/fhir/SearchParameter/Contract-authority|
# |386.|Contract|`domain`|http://hl7.org/fhir/SearchParameter/Contract-domain|
# |387.|Contract|`identifier`|http://hl7.org/fhir/SearchParameter/Contract-identifier|
# |388.|Contract|`instantiates`|http://hl7.org/fhir/SearchParameter/Contract-instantiates|
# |389.|Contract|`issued`|http://hl7.org/fhir/SearchParameter/Contract-issued|
# |390.|Contract|`patient`|http://hl7.org/fhir/SearchParameter/Contract-patient|
# |391.|Contract|`signer`|http://hl7.org/fhir/SearchParameter/Contract-signer|
# |392.|Contract|`status`|http://hl7.org/fhir/SearchParameter/Contract-status|
# |393.|Contract|`subject`|http://hl7.org/fhir/SearchParameter/Contract-subject|
# |394.|Contract|`url`|http://hl7.org/fhir/SearchParameter/Contract-url|
# |395.|Coverage|`beneficiary`|http://hl7.org/fhir/SearchParameter/Coverage-beneficiary|
# |396.|Coverage|`class-type`|http://hl7.org/fhir/SearchParameter/Coverage-class-type|
# |397.|Coverage|`class-value`|http://hl7.org/fhir/SearchParameter/Coverage-class-value|
# |398.|Coverage|`dependent`|http://hl7.org/fhir/SearchParameter/Coverage-dependent|
# |399.|Coverage|`identifier`|http://hl7.org/fhir/SearchParameter/Coverage-identifier|
# |400.|Coverage|`patient`|http://hl7.org/fhir/SearchParameter/Coverage-patient|
# |401.|Coverage|`payor`|http://hl7.org/fhir/SearchParameter/Coverage-payor|
# |402.|Coverage|`policy-holder`|http://hl7.org/fhir/SearchParameter/Coverage-policy-holder|
# |403.|Coverage|`status`|http://hl7.org/fhir/SearchParameter/Coverage-status|
# |404.|Coverage|`subscriber`|http://hl7.org/fhir/SearchParameter/Coverage-subscriber|
# |405.|Coverage|`type`|http://hl7.org/fhir/SearchParameter/Coverage-type|
# |406.|CoverageEligibilityRequest|`created`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-created|
# |407.|CoverageEligibilityRequest|`enterer`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-enterer|
# |408.|CoverageEligibilityRequest|`facility`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-facility|
# |409.|CoverageEligibilityRequest|`identifier`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-identifier|
# |410.|CoverageEligibilityRequest|`patient`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-patient|
# |411.|CoverageEligibilityRequest|`provider`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-provider|
# |412.|CoverageEligibilityRequest|`status`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityRequest-status|
# |413.|CoverageEligibilityResponse|`created`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-created|
# |414.|CoverageEligibilityResponse|`disposition`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-disposition|
# |415.|CoverageEligibilityResponse|`identifier`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-identifier|
# |416.|CoverageEligibilityResponse|`insurer`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-insurer|
# |417.|CoverageEligibilityResponse|`outcome`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-outcome|
# |418.|CoverageEligibilityResponse|`patient`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-patient|
# |419.|CoverageEligibilityResponse|`request`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-request|
# |420.|CoverageEligibilityResponse|`requestor`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-requestor|
# |421.|CoverageEligibilityResponse|`status`|http://hl7.org/fhir/SearchParameter/CoverageEligibilityResponse-status|
# |422.|DetectedIssue|`author`|http://hl7.org/fhir/SearchParameter/DetectedIssue-author|
# |423.|DetectedIssue|`code`|http://hl7.org/fhir/SearchParameter/DetectedIssue-code|
# |424.|DetectedIssue|`identified`|http://hl7.org/fhir/SearchParameter/DetectedIssue-identified|
# |425.|DetectedIssue|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |426.|DetectedIssue|`implicated`|http://hl7.org/fhir/SearchParameter/DetectedIssue-implicated|
# |427.|DetectedIssue|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |428.|Device|`device-name`|http://hl7.org/fhir/SearchParameter/Device-device-name|
# |429.|Device|`identifier`|http://hl7.org/fhir/SearchParameter/Device-identifier|
# |430.|Device|`location`|http://hl7.org/fhir/SearchParameter/Device-location|
# |431.|Device|`manufacturer`|http://hl7.org/fhir/SearchParameter/Device-manufacturer|
# |432.|Device|`model`|http://hl7.org/fhir/SearchParameter/Device-model|
# |433.|Device|`organization`|http://hl7.org/fhir/SearchParameter/Device-organization|
# |434.|Device|`patient`|http://hl7.org/fhir/SearchParameter/Device-patient|
# |435.|Device|`status`|http://hl7.org/fhir/SearchParameter/Device-status|
# |436.|Device|`type`|http://hl7.org/fhir/SearchParameter/Device-type|
# |437.|Device|`udi-carrier`|http://hl7.org/fhir/SearchParameter/Device-udi-carrier|
# |438.|Device|`udi-di`|http://hl7.org/fhir/SearchParameter/Device-udi-di|
# |439.|Device|`url`|http://hl7.org/fhir/SearchParameter/Device-url|
# |440.|DeviceDefinition|`identifier`|http://hl7.org/fhir/SearchParameter/DeviceDefinition-identifier|
# |441.|DeviceDefinition|`parent`|http://hl7.org/fhir/SearchParameter/DeviceDefinition-parent|
# |442.|DeviceDefinition|`type`|http://hl7.org/fhir/SearchParameter/DeviceDefinition-type|
# |443.|DeviceMetric|`category`|http://hl7.org/fhir/SearchParameter/DeviceMetric-category|
# |444.|DeviceMetric|`identifier`|http://hl7.org/fhir/SearchParameter/DeviceMetric-identifier|
# |445.|DeviceMetric|`parent`|http://hl7.org/fhir/SearchParameter/DeviceMetric-parent|
# |446.|DeviceMetric|`source`|http://hl7.org/fhir/SearchParameter/DeviceMetric-source|
# |447.|DeviceMetric|`type`|http://hl7.org/fhir/SearchParameter/DeviceMetric-type|
# |448.|DeviceRequest|`authored-on`|http://hl7.org/fhir/SearchParameter/DeviceRequest-authored-on|
# |449.|DeviceRequest|`based-on`|http://hl7.org/fhir/SearchParameter/DeviceRequest-based-on|
# |450.|DeviceRequest|`code`|http://hl7.org/fhir/SearchParameter/clinical-code|
# |451.|DeviceRequest|`device`|http://hl7.org/fhir/SearchParameter/DeviceRequest-device|
# |452.|DeviceRequest|`encounter`|http://hl7.org/fhir/SearchParameter/clinical-encounter|
# |453.|DeviceRequest|`event-date`|http://hl7.org/fhir/SearchParameter/DeviceRequest-event-date|
# |454.|DeviceRequest|`group-identifier`|http://hl7.org/fhir/SearchParameter/DeviceRequest-group-identifier|
# |455.|DeviceRequest|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |456.|DeviceRequest|`instantiates-canonical`|http://hl7.org/fhir/SearchParameter/DeviceRequest-instantiates-canonical|
# |457.|DeviceRequest|`instantiates-uri`|http://hl7.org/fhir/SearchParameter/DeviceRequest-instantiates-uri|
# |458.|DeviceRequest|`insurance`|http://hl7.org/fhir/SearchParameter/DeviceRequest-insurance|
# |459.|DeviceRequest|`intent`|http://hl7.org/fhir/SearchParameter/DeviceRequest-intent|
# |460.|DeviceRequest|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |461.|DeviceRequest|`performer`|http://hl7.org/fhir/SearchParameter/DeviceRequest-performer|
# |462.|DeviceRequest|`prior-request`|http://hl7.org/fhir/SearchParameter/DeviceRequest-prior-request|
# |463.|DeviceRequest|`requester`|http://hl7.org/fhir/SearchParameter/DeviceRequest-requester|
# |464.|DeviceRequest|`status`|http://hl7.org/fhir/SearchParameter/DeviceRequest-status|
# |465.|DeviceRequest|`subject`|http://hl7.org/fhir/SearchParameter/DeviceRequest-subject|
# |466.|DeviceUseStatement|`device`|http://hl7.org/fhir/SearchParameter/DeviceUseStatement-device|
# |467.|DeviceUseStatement|`identifier`|http://hl7.org/fhir/SearchParameter/DeviceUseStatement-identifier|
# |468.|DeviceUseStatement|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |469.|DeviceUseStatement|`subject`|http://hl7.org/fhir/SearchParameter/DeviceUseStatement-subject|
# |470.|DiagnosticReport|`based-on`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-based-on|
# |471.|DiagnosticReport|`category`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-category|
# |472.|DiagnosticReport|`code`|http://hl7.org/fhir/SearchParameter/clinical-code|
# |473.|DiagnosticReport|`conclusion`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-conclusion|
# |474.|DiagnosticReport|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |475.|DiagnosticReport|`encounter`|http://hl7.org/fhir/SearchParameter/clinical-encounter|
# |476.|DiagnosticReport|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |477.|DiagnosticReport|`issued`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-issued|
# |478.|DiagnosticReport|`media`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-media|
# |479.|DiagnosticReport|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |480.|DiagnosticReport|`performer`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-performer|
# |481.|DiagnosticReport|`result`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-result|
# |482.|DiagnosticReport|`results-interpreter`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-results-interpreter|
# |483.|DiagnosticReport|`specimen`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-specimen|
# |484.|DiagnosticReport|`status`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-status|
# |485.|DiagnosticReport|`subject`|http://hl7.org/fhir/SearchParameter/DiagnosticReport-subject|
# |486.|DocumentManifest|`author`|http://hl7.org/fhir/SearchParameter/DocumentManifest-author|
# |487.|DocumentManifest|`created`|http://hl7.org/fhir/SearchParameter/DocumentManifest-created|
# |488.|DocumentManifest|`description`|http://hl7.org/fhir/SearchParameter/DocumentManifest-description|
# |489.|DocumentManifest|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |490.|DocumentManifest|`item`|http://hl7.org/fhir/SearchParameter/DocumentManifest-item|
# |491.|DocumentManifest|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |492.|DocumentManifest|`recipient`|http://hl7.org/fhir/SearchParameter/DocumentManifest-recipient|
# |493.|DocumentManifest|`related-id`|http://hl7.org/fhir/SearchParameter/DocumentManifest-related-id|
# |494.|DocumentManifest|`related-ref`|http://hl7.org/fhir/SearchParameter/DocumentManifest-related-ref|
# |495.|DocumentManifest|`source`|http://hl7.org/fhir/SearchParameter/DocumentManifest-source|
# |496.|DocumentManifest|`status`|http://hl7.org/fhir/SearchParameter/DocumentManifest-status|
# |497.|DocumentManifest|`subject`|http://hl7.org/fhir/SearchParameter/DocumentManifest-subject|
# |498.|DocumentManifest|`type`|http://hl7.org/fhir/SearchParameter/clinical-type|
# |499.|DocumentReference|`authenticator`|http://hl7.org/fhir/SearchParameter/DocumentReference-authenticator|
# |500.|DocumentReference|`author`|http://hl7.org/fhir/SearchParameter/DocumentReference-author|
# |501.|DocumentReference|`category`|http://hl7.org/fhir/SearchParameter/DocumentReference-category|
# |502.|DocumentReference|`contenttype`|http://hl7.org/fhir/SearchParameter/DocumentReference-contenttype|
# |503.|DocumentReference|`custodian`|http://hl7.org/fhir/SearchParameter/DocumentReference-custodian|
# |504.|DocumentReference|`date`|http://hl7.org/fhir/SearchParameter/DocumentReference-date|
# |505.|DocumentReference|`description`|http://hl7.org/fhir/SearchParameter/DocumentReference-description|
# |506.|DocumentReference|`encounter`|http://hl7.org/fhir/SearchParameter/clinical-encounter|
# |507.|DocumentReference|`event`|http://hl7.org/fhir/SearchParameter/DocumentReference-event|
# |508.|DocumentReference|`facility`|http://hl7.org/fhir/SearchParameter/DocumentReference-facility|
# |509.|DocumentReference|`format`|http://hl7.org/fhir/SearchParameter/DocumentReference-format|
# |510.|DocumentReference|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |511.|DocumentReference|`language`|http://hl7.org/fhir/SearchParameter/DocumentReference-language|
# |512.|DocumentReference|`location`|http://hl7.org/fhir/SearchParameter/DocumentReference-location|
# |513.|DocumentReference|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |514.|DocumentReference|`period`|http://hl7.org/fhir/SearchParameter/DocumentReference-period|
# |515.|DocumentReference|`related`|http://hl7.org/fhir/SearchParameter/DocumentReference-related|
# |516.|DocumentReference|`relatesto`|http://hl7.org/fhir/SearchParameter/DocumentReference-relatesto|
# |517.|DocumentReference|`relation`|http://hl7.org/fhir/SearchParameter/DocumentReference-relation|
# |518.|DocumentReference|`relationship`|http://hl7.org/fhir/SearchParameter/DocumentReference-relationship|
# |519.|DocumentReference|`security-label`|http://hl7.org/fhir/SearchParameter/DocumentReference-security-label|
# |520.|DocumentReference|`setting`|http://hl7.org/fhir/SearchParameter/DocumentReference-setting|
# |521.|DocumentReference|`status`|http://hl7.org/fhir/SearchParameter/DocumentReference-status|
# ...
# |1530.|ServiceRequest|`replaces`|http://hl7.org/fhir/SearchParameter/ServiceRequest-replaces|
# |1531.|ServiceRequest|`requester`|http://hl7.org/fhir/SearchParameter/ServiceRequest-requester|
# |1532.|ServiceRequest|`requisition`|http://hl7.org/fhir/SearchParameter/ServiceRequest-requisition|
# |1533.|ServiceRequest|`specimen`|http://hl7.org/fhir/SearchParameter/ServiceRequest-specimen|
# |1534.|ServiceRequest|`status`|http://hl7.org/fhir/SearchParameter/ServiceRequest-status|
# |1535.|ServiceRequest|`subject`|http://hl7.org/fhir/SearchParameter/ServiceRequest-subject|
# |1536.|Slot|`appointment-type`|http://hl7.org/fhir/SearchParameter/Slot-appointment-type|
# |1537.|Slot|`identifier`|http://hl7.org/fhir/SearchParameter/Slot-identifier|
# |1538.|Slot|`schedule`|http://hl7.org/fhir/SearchParameter/Slot-schedule|
# |1539.|Slot|`service-category`|http://hl7.org/fhir/SearchParameter/Slot-service-category|
# |1540.|Slot|`service-type`|http://hl7.org/fhir/SearchParameter/Slot-service-type|
# |1541.|Slot|`specialty`|http://hl7.org/fhir/SearchParameter/Slot-specialty|
# |1542.|Slot|`start`|http://hl7.org/fhir/SearchParameter/Slot-start|
# |1543.|Slot|`status`|http://hl7.org/fhir/SearchParameter/Slot-status|
# |1544.|Specimen|`accession`|http://hl7.org/fhir/SearchParameter/Specimen-accession|
# |1545.|Specimen|`bodysite`|http://hl7.org/fhir/SearchParameter/Specimen-bodysite|
# |1546.|Specimen|`collected`|http://hl7.org/fhir/SearchParameter/Specimen-collected|
# |1547.|Specimen|`collector`|http://hl7.org/fhir/SearchParameter/Specimen-collector|
# |1548.|Specimen|`container`|http://hl7.org/fhir/SearchParameter/Specimen-container|
# |1549.|Specimen|`container-id`|http://hl7.org/fhir/SearchParameter/Specimen-container-id|
# |1550.|Specimen|`identifier`|http://hl7.org/fhir/SearchParameter/Specimen-identifier|
# |1551.|Specimen|`parent`|http://hl7.org/fhir/SearchParameter/Specimen-parent|
# |1552.|Specimen|`patient`|http://hl7.org/fhir/SearchParameter/Specimen-patient|
# |1553.|Specimen|`status`|http://hl7.org/fhir/SearchParameter/Specimen-status|
# |1554.|Specimen|`subject`|http://hl7.org/fhir/SearchParameter/Specimen-subject|
# |1555.|Specimen|`type`|http://hl7.org/fhir/SearchParameter/Specimen-type|
# |1556.|SpecimenDefinition|`container`|http://hl7.org/fhir/SearchParameter/SpecimenDefinition-container|
# |1557.|SpecimenDefinition|`identifier`|http://hl7.org/fhir/SearchParameter/SpecimenDefinition-identifier|
# |1558.|SpecimenDefinition|`type`|http://hl7.org/fhir/SearchParameter/SpecimenDefinition-type|
# |1559.|StructureDefinition|`abstract`|http://hl7.org/fhir/SearchParameter/StructureDefinition-abstract|
# |1560.|StructureDefinition|`base`|http://hl7.org/fhir/SearchParameter/StructureDefinition-base|
# |1561.|StructureDefinition|`base-path`|http://hl7.org/fhir/SearchParameter/StructureDefinition-base-path|
# |1562.|StructureDefinition|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |1563.|StructureDefinition|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |1564.|StructureDefinition|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |1565.|StructureDefinition|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |1566.|StructureDefinition|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |1567.|StructureDefinition|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |1568.|StructureDefinition|`derivation`|http://hl7.org/fhir/SearchParameter/StructureDefinition-derivation|
# |1569.|StructureDefinition|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |1570.|StructureDefinition|`experimental`|http://hl7.org/fhir/SearchParameter/StructureDefinition-experimental|
# |1571.|StructureDefinition|`ext-context`|http://hl7.org/fhir/SearchParameter/StructureDefinition-ext-context|
# |1572.|StructureDefinition|`identifier`|http://hl7.org/fhir/SearchParameter/conformance-identifier|
# |1573.|StructureDefinition|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |1574.|StructureDefinition|`keyword`|http://hl7.org/fhir/SearchParameter/StructureDefinition-keyword|
# |1575.|StructureDefinition|`kind`|http://hl7.org/fhir/SearchParameter/StructureDefinition-kind|
# |1576.|StructureDefinition|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |1577.|StructureDefinition|`path`|http://hl7.org/fhir/SearchParameter/StructureDefinition-path|
# |1578.|StructureDefinition|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |1579.|StructureDefinition|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |1580.|StructureDefinition|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |1581.|StructureDefinition|`type`|http://hl7.org/fhir/SearchParameter/StructureDefinition-type|
# |1582.|StructureDefinition|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |1583.|StructureDefinition|`valueset`|http://hl7.org/fhir/SearchParameter/StructureDefinition-valueset|
# |1584.|StructureDefinition|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |1585.|StructureMap|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |1586.|StructureMap|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |1587.|StructureMap|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |1588.|StructureMap|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |1589.|StructureMap|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |1590.|StructureMap|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |1591.|StructureMap|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |1592.|StructureMap|`identifier`|http://hl7.org/fhir/SearchParameter/conformance-identifier|
# |1593.|StructureMap|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |1594.|StructureMap|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |1595.|StructureMap|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |1596.|StructureMap|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |1597.|StructureMap|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |1598.|StructureMap|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |1599.|StructureMap|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |1600.|Subscription|`contact`|http://hl7.org/fhir/SearchParameter/Subscription-contact|
# |1601.|Subscription|`criteria`|http://hl7.org/fhir/SearchParameter/Subscription-criteria|
# |1602.|Subscription|`payload`|http://hl7.org/fhir/SearchParameter/Subscription-payload|
# |1603.|Subscription|`status`|http://hl7.org/fhir/SearchParameter/Subscription-status|
# |1604.|Subscription|`type`|http://hl7.org/fhir/SearchParameter/Subscription-type|
# |1605.|Subscription|`url`|http://hl7.org/fhir/SearchParameter/Subscription-url|
# |1606.|Substance|`category`|http://hl7.org/fhir/SearchParameter/Substance-category|
# |1607.|Substance|`code`|http://hl7.org/fhir/SearchParameter/Substance-code|
# |1608.|Substance|`container-identifier`|http://hl7.org/fhir/SearchParameter/Substance-container-identifier|
# |1609.|Substance|`expiry`|http://hl7.org/fhir/SearchParameter/Substance-expiry|
# |1610.|Substance|`identifier`|http://hl7.org/fhir/SearchParameter/Substance-identifier|
# |1611.|Substance|`quantity`|http://hl7.org/fhir/SearchParameter/Substance-quantity|
# |1612.|Substance|`status`|http://hl7.org/fhir/SearchParameter/Substance-status|
# |1613.|Substance|`substance-reference`|http://hl7.org/fhir/SearchParameter/Substance-substance-reference|
# |1614.|SubstanceSpecification|`code`|http://hl7.org/fhir/SearchParameter/SubstanceSpecification-code|
# |1615.|SupplyDelivery|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |1616.|SupplyDelivery|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |1617.|SupplyDelivery|`receiver`|http://hl7.org/fhir/SearchParameter/SupplyDelivery-receiver|
# |1618.|SupplyDelivery|`status`|http://hl7.org/fhir/SearchParameter/SupplyDelivery-status|
# |1619.|SupplyDelivery|`supplier`|http://hl7.org/fhir/SearchParameter/SupplyDelivery-supplier|
# |1620.|SupplyRequest|`category`|http://hl7.org/fhir/SearchParameter/SupplyRequest-category|
# |1621.|SupplyRequest|`date`|http://hl7.org/fhir/SearchParameter/clinical-date|
# |1622.|SupplyRequest|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |1623.|SupplyRequest|`requester`|http://hl7.org/fhir/SearchParameter/SupplyRequest-requester|
# |1624.|SupplyRequest|`status`|http://hl7.org/fhir/SearchParameter/SupplyRequest-status|
# |1625.|SupplyRequest|`subject`|http://hl7.org/fhir/SearchParameter/SupplyRequest-subject|
# |1626.|SupplyRequest|`supplier`|http://hl7.org/fhir/SearchParameter/SupplyRequest-supplier|
# |1627.|Task|`authored-on`|http://hl7.org/fhir/SearchParameter/Task-authored-on|
# |1628.|Task|`based-on`|http://hl7.org/fhir/SearchParameter/Task-based-on|
# |1629.|Task|`business-status`|http://hl7.org/fhir/SearchParameter/Task-business-status|
# |1630.|Task|`code`|http://hl7.org/fhir/SearchParameter/Task-code|
# |1631.|Task|`encounter`|http://hl7.org/fhir/SearchParameter/Task-encounter|
# |1632.|Task|`focus`|http://hl7.org/fhir/SearchParameter/Task-focus|
# |1633.|Task|`group-identifier`|http://hl7.org/fhir/SearchParameter/Task-group-identifier|
# |1634.|Task|`identifier`|http://hl7.org/fhir/SearchParameter/Task-identifier|
# |1635.|Task|`intent`|http://hl7.org/fhir/SearchParameter/Task-intent|
# |1636.|Task|`modified`|http://hl7.org/fhir/SearchParameter/Task-modified|
# |1637.|Task|`owner`|http://hl7.org/fhir/SearchParameter/Task-owner|
# |1638.|Task|`part-of`|http://hl7.org/fhir/SearchParameter/Task-part-of|
# |1639.|Task|`patient`|http://hl7.org/fhir/SearchParameter/Task-patient|
# |1640.|Task|`performer`|http://hl7.org/fhir/SearchParameter/Task-performer|
# |1641.|Task|`period`|http://hl7.org/fhir/SearchParameter/Task-period|
# |1642.|Task|`priority`|http://hl7.org/fhir/SearchParameter/Task-priority|
# |1643.|Task|`requester`|http://hl7.org/fhir/SearchParameter/Task-requester|
# |1644.|Task|`status`|http://hl7.org/fhir/SearchParameter/Task-status|
# |1645.|Task|`subject`|http://hl7.org/fhir/SearchParameter/Task-subject|
# |1646.|TerminologyCapabilities|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |1647.|TerminologyCapabilities|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |1648.|TerminologyCapabilities|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |1649.|TerminologyCapabilities|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |1650.|TerminologyCapabilities|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |1651.|TerminologyCapabilities|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |1652.|TerminologyCapabilities|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |1653.|TerminologyCapabilities|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |1654.|TerminologyCapabilities|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |1655.|TerminologyCapabilities|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |1656.|TerminologyCapabilities|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |1657.|TerminologyCapabilities|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |1658.|TerminologyCapabilities|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |1659.|TerminologyCapabilities|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |1660.|TestReport|`identifier`|http://hl7.org/fhir/SearchParameter/TestReport-identifier|
# |1661.|TestReport|`issued`|http://hl7.org/fhir/SearchParameter/TestReport-issued|
# |1662.|TestReport|`participant`|http://hl7.org/fhir/SearchParameter/TestReport-participant|
# |1663.|TestReport|`result`|http://hl7.org/fhir/SearchParameter/TestReport-result|
# |1664.|TestReport|`tester`|http://hl7.org/fhir/SearchParameter/TestReport-tester|
# |1665.|TestReport|`testscript`|http://hl7.org/fhir/SearchParameter/TestReport-testscript|
# |1666.|TestScript|`context`|http://hl7.org/fhir/SearchParameter/TestScript-context|
# |1667.|TestScript|`context-quantity`|http://hl7.org/fhir/SearchParameter/TestScript-context-quantity|
# |1668.|TestScript|`context-type`|http://hl7.org/fhir/SearchParameter/TestScript-context-type|
# |1669.|TestScript|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/TestScript-context-type-quantity|
# |1670.|TestScript|`context-type-value`|http://hl7.org/fhir/SearchParameter/TestScript-context-type-value|
# |1671.|TestScript|`date`|http://hl7.org/fhir/SearchParameter/TestScript-date|
# |1672.|TestScript|`description`|http://hl7.org/fhir/SearchParameter/TestScript-description|
# |1673.|TestScript|`identifier`|http://hl7.org/fhir/SearchParameter/TestScript-identifier|
# |1674.|TestScript|`jurisdiction`|http://hl7.org/fhir/SearchParameter/TestScript-jurisdiction|
# |1675.|TestScript|`name`|http://hl7.org/fhir/SearchParameter/TestScript-name|
# |1676.|TestScript|`publisher`|http://hl7.org/fhir/SearchParameter/TestScript-publisher|
# |1677.|TestScript|`status`|http://hl7.org/fhir/SearchParameter/TestScript-status|
# |1678.|TestScript|`testscript-capability`|http://hl7.org/fhir/SearchParameter/TestScript-testscript-capability|
# |1679.|TestScript|`title`|http://hl7.org/fhir/SearchParameter/TestScript-title|
# |1680.|TestScript|`url`|http://hl7.org/fhir/SearchParameter/TestScript-url|
# |1681.|TestScript|`version`|http://hl7.org/fhir/SearchParameter/TestScript-version|
# |1682.|ValueSet|`code`|http://hl7.org/fhir/SearchParameter/ValueSet-code|
# |1683.|ValueSet|`context`|http://hl7.org/fhir/SearchParameter/conformance-context|
# |1684.|ValueSet|`context-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-quantity|
# |1685.|ValueSet|`context-type`|http://hl7.org/fhir/SearchParameter/conformance-context-type|
# |1686.|ValueSet|`context-type-quantity`|http://hl7.org/fhir/SearchParameter/conformance-context-type-quantity|
# |1687.|ValueSet|`context-type-value`|http://hl7.org/fhir/SearchParameter/conformance-context-type-value|
# |1688.|ValueSet|`date`|http://hl7.org/fhir/SearchParameter/conformance-date|
# |1689.|ValueSet|`description`|http://hl7.org/fhir/SearchParameter/conformance-description|
# |1690.|ValueSet|`expansion`|http://hl7.org/fhir/SearchParameter/ValueSet-expansion|
# |1691.|ValueSet|`identifier`|http://hl7.org/fhir/SearchParameter/conformance-identifier|
# |1692.|ValueSet|`jurisdiction`|http://hl7.org/fhir/SearchParameter/conformance-jurisdiction|
# |1693.|ValueSet|`name`|http://hl7.org/fhir/SearchParameter/conformance-name|
# |1694.|ValueSet|`publisher`|http://hl7.org/fhir/SearchParameter/conformance-publisher|
# |1695.|ValueSet|`reference`|http://hl7.org/fhir/SearchParameter/ValueSet-reference|
# |1696.|ValueSet|`status`|http://hl7.org/fhir/SearchParameter/conformance-status|
# |1697.|ValueSet|`title`|http://hl7.org/fhir/SearchParameter/conformance-title|
# |1698.|ValueSet|`url`|http://hl7.org/fhir/SearchParameter/conformance-url|
# |1699.|ValueSet|`version`|http://hl7.org/fhir/SearchParameter/conformance-version|
# |1700.|VerificationResult|`target`|http://hl7.org/fhir/SearchParameter/VerificationResult-target|
# |1701.|VisionPrescription|`datewritten`|http://hl7.org/fhir/SearchParameter/VisionPrescription-datewritten|
# |1702.|VisionPrescription|`encounter`|http://hl7.org/fhir/SearchParameter/clinical-encounter|
# |1703.|VisionPrescription|`identifier`|http://hl7.org/fhir/SearchParameter/clinical-identifier|
# |1704.|VisionPrescription|`patient`|http://hl7.org/fhir/SearchParameter/clinical-patient|
# |1705.|VisionPrescription|`prescriber`|http://hl7.org/fhir/SearchParameter/VisionPrescription-prescriber|
# |1706.|VisionPrescription|`status`|http://hl7.org/fhir/SearchParameter/VisionPrescription-status|

# %% [markdown]
# ### write to file

# %%
out_path = ''
out_file = 'R4sp_summary.md'

def write_file(path, f_name, data): # write file
    with open(f'{path}{f_name}', 'w') as f:
        f.write(data)

write_file(out_path,out_file,d)
