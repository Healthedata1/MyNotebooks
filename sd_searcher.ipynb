# %% [markdown]
# ## Search through StructureDefinition properties
#
# *USE Python 3.7+ to maintain order of Json files*
#
# This script requires several modules listed below and SUSHI (see how to install and use [here](https://fshschool.org/docs/sushi/))
# The URLS are fetched from a simple external csv file which I create from the output of the github_search.ipynb script
#
# - Fetch URLs from csv file
# - Fetch published URL
# - Convert to Python fhir-obj
# - Filter for StructureDefinition files
# - Search for SD elements

# %% [markdown]
# ### import python modules

# %%
from pathlib import Path
import pandas as pd
import csv
from json import loads, dumps
from requests import get,post
from fhir.resources.structuredefinition import StructureDefinition
from pprint import pprint

headers = {'Accept': 'application/fhir+json', 'Content-Type': 'application/fhir+json'}
in_path = Path(r'/Users/ehaas/Documents/FHIR/US-Core/my-notes/MedReq-MedDisp-profiles.csv')
in_path = Path(r'/Users/ehaas/Documents/FHIR/US-Core/my-notes/SD_URL.md.csv')
fsh_project = '/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project'
sushi_config_path = Path(r'/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/sushi-config.yml')
fsh_file_path = Path(r'/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/input/fsh/file.fsh')
fsh_gen_resource_path = Path('/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources')

in_path
# Out:
# PosixPath('/Users/ehaas/Documents/FHIR/US-Core/my-notes/SD_URL.md.csv')

# %% [markdown]
# ### Loop through SDs
#  - read sheet as DF
#  - iterate through urls
#    - fetch SD as xml, json, or fsh
#    - convert all to python fhir object  ( fsh files require runing new sushi project each time )
#    - filter out the SD resources for the type interested in  ( `test_type` )
#    - look for the particular element of interest. `test_me`
#    - print out the stats of how many found and the canonicals ( or best guess canonical for sushi files )

# %%
test_type = 'Coverage' #'MedicationRequest' #'ServiceRequest'#Coverage
#test_me = ["ServiceRequest.reasonCode","ServiceRequest.reasonReference",] #["MedicationRequest.reasonCode","MedicationRequest.reasonReference",]#["ServiceRequest.reasonCode","ServiceRequest.reasonReference",]
test_me =["Coverage.period",]
count1 = 1
count2 = 1
list1 = []
list2 = []

def check_element(sd):
    global count1, count2, list1, list2
    if sd.type == test_type:
        print(f'({count1}) Type = {test_type}')
        count1 += 1
        list1.append(sd.url)
        print(f'sd.id = {sd.id}')
        element_paths = [e.path for e in sd.differential.element]
        if any(item in element_paths for item in test_me):
                print(f'>>>>>>>>>({count2}) reason[x] element found!!<<<<<<<<<<')
                list2.append(sd.url)
                count2 += 1

                
def update_sushi(my_file):
    '''update the sushi-config.yaml file'''
    project_code  = my_file.split('/')[4:5][0]
    print(f'project_code: {project_code}')
    sushi_config = f'''
FSHOnly: true
fhirVersion: 4.0.1
canonical: "http://hl7.org/fhir/us/{project_code}"
name: Temp
status: draft
''' 
    # print(sushi_config)
    # print(config_path)
    sushi_config_path.write_text(sushi_config)

def make_fhir_object():
    for file in fsh_gen_resource_path.glob('*.json'):
        print(file)
        try:
            sd = StructureDefinition.parse_file(file)
            file.unlink()
        except:
            print(f'Error parsing {my_file}:\n {response.text[:75]}')
            file.unlink()
        else:
            return sd


df = pd.read_csv(in_path, header=0, encoding='utf-8')
for i,my_file in enumerate(df.url):
    print(f'*************************************\n{i+1}: {my_file}\n*************************************')
    with get(my_file, headers=headers) as response:
        if response.status_code == 200:
            if my_file.split('.')[-1] == 'xml':
                data = response.text.replace('<?xml version="1.0" encoding="UTF-8"?>','',1) # check all spellings!!!
                data = data.replace('<?xml version="1.0" encoding="utf-8"?>','',1) # check all spellings!!!
                try:       
                    sd = StructureDefinition.parse_raw(data, content_type="text/xml")
                except:
                    print(f'Error parsing {my_file}:\n {response.text[:75]}')
                else:
                    check_element(sd)
            if my_file.split('.')[-1]  == 'json':
                try:
                    sd = StructureDefinition.parse_obj(response.json())
                except:
                    print(f'Error parsing {my_file}:\n {response.text[:75]}')
                else:
                    check_element(sd)
            if my_file.split('.')[-1]  == 'fsh':
                print('convert fsh to json')
                update_sushi(my_file)
                fsh_file_path.write_text(response.text)
                #build json from fsh files using sushi
                # !sushi $fsh_project > "/Users/ehaas/Documents/Python/Jupyter/sushi.txt"
                sd = make_fhir_object()
                try:
                    check_element(sd)
                except AttributeError:
                    print(f'Error parsing {my_file}:\n sd = {sd}')

print(f'Total {test_type} Profiles = {len(set(list1))}')
pprint(set(list1))
print(f'Total {test_type} Profiles with {test_me} in differential = {len(set(list2))}')
pprint(set(list2))
print(f'Total Files = {i+1}')
# Out:
# *************************************
# 1: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-coverage.xml
# *************************************
# (1) Type = Coverage
# sd.id = PAOX-coverage
# *************************************
# 2: https://raw.githubusercontent.com/HL7/davinci-deqm/168acbe28688e4ea9641a57389017be77c4a3da7/input/resources/StructureDefinition-coverage-deqm.xml
# *************************************
# (2) Type = Coverage
# sd.id = coverage-deqm
# *************************************
# 3: https://raw.githubusercontent.com/HL7/davinci-pcde/58ace3091511bbfe7bc125a71485f07bfff972ac/input/resources/structuredefinition-pcde-task-request.xml
# *************************************
# *************************************
# 4: https://raw.githubusercontent.com/HL7/davinci-alerts/c006d6804eb706609361fa778f303da040530c10/input/resources/drafts/StructureDefinition-admit-discharge-notification-coverage.xml
# *************************************
# (3) Type = Coverage
# sd.id = adt-notification-coverage
# *************************************
# 5: https://raw.githubusercontent.com/HL7/bser/413cf21b766d42531454321d475cfa06c0b7195d/input/resources/structuredefinition/BSeR-Coverage.xml
# *************************************
# (4) Type = Coverage
# sd.id = BSeR-Coverage
# >>>>>>>>>(1) reason[x] element found!!<<<<<<<<<<
# *************************************
# 6: https://raw.githubusercontent.com/HL7/fhir-bfdr/9ca532a761933dd032290973657fbe4f47c5e633/input/resources/structuredefinition/Coverage-principal-payer-for-delivery.xml
# *************************************
# (5) Type = Coverage
# sd.id = Coverage-principal-payer-for-delivery
# *************************************
# 7: https://raw.githubusercontent.com/HL7/davinci-pcde/58ace3091511bbfe7bc125a71485f07bfff972ac/input/resources/structuredefinition-pcde-task-search.xml
# *************************************
# *************************************
# 8: https://raw.githubusercontent.com/HL7/davinci-crd/f1ab653cba5278d190dc132d78407e75aa028e8c/input/resources/StructureDefinition-ext-coverage-information.xml
# *************************************
# *************************************
# 9: https://raw.githubusercontent.com/HL7/fhir-specialty-rx/ba2a9bb54f9eded889ad0c1fcb4aed7574d83a76/input/resources/StructureDefinition/specialty-rx-coverage.xml
# *************************************
# (6) Type = Coverage
# sd.id = specialty-rx-coverage
# *************************************
# 10: https://raw.githubusercontent.com/HL7/davinci-ehrx/4abe773b610974c90be84b75d75c510963542f9d/input/resources/structuredefinition-hrex-parameters-member-match-in.xml
# *************************************
# *************************************
# 11: https://raw.githubusercontent.com/HL7/davinci-ehrx/4abe773b610974c90be84b75d75c510963542f9d/input/resources/structuredefinition-hrex-coverage.xml
# *************************************
# (7) Type = Coverage
# sd.id = hrex-coverage
# *************************************
# 12: https://raw.githubusercontent.com/HL7/davinci-pcde/58ace3091511bbfe7bc125a71485f07bfff972ac/input/resources/structuredefinition-profile-pcde-bundle.xml
# *************************************
# *************************************
# 13: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-coverage.json
# *************************************
# (8) Type = Coverage
# sd.id = PAOX-coverage
# *************************************
# 14: https://raw.githubusercontent.com/HL7/davinci-alerts/c006d6804eb706609361fa778f303da040530c10/input/resources/yaml/StructureDefinition-adt-notification-coverage.yml
# *************************************
# *************************************
# 15: https://raw.githubusercontent.com/HL7/davinci-alerts/c006d6804eb706609361fa778f303da040530c10/input/resources/StructureDefinition-adt-notification-coverage.json
# *************************************
# (9) Type = Coverage
# sd.id = adt-notification-coverage
# *************************************
# 16: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/af6001ba275b7ae7ddbcee6105889755d60b04f7/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.2.18.xml
# *************************************
# *************************************
# 17: https://raw.githubusercontent.com/HL7/davinci-pcde/58ace3091511bbfe7bc125a71485f07bfff972ac/input/resources/structuredefinition-profile-careplan.xml
# *************************************
# *************************************
# 18: https://raw.githubusercontent.com/HL7/carin-rtpbc/7d6a5bca70d068cf1ebb80809c2d8c505f04db80/input/resources/structuredefinition/rtpbc-coverage.xml
# *************************************
# (10) Type = Coverage
# sd.id = rtpbc-coverage
# *************************************
# 19: https://raw.githubusercontent.com/HL7/davinci-alerts/c006d6804eb706609361fa778f303da040530c10/input/resources/drafts/StructureDefinition-adt-notification-coverage.yml
# *************************************
# *************************************
# 20: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/af6001ba275b7ae7ddbcee6105889755d60b04f7/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.4.60.xml
# *************************************
# *************************************
# 21: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/structuredefinition/dental-referral-note.xml
# *************************************
# *************************************
# 22: https://raw.githubusercontent.com/HL7/bser/413cf21b766d42531454321d475cfa06c0b7195d/input/resources/structuredefinition/BSeR-Organization.xml
# *************************************
# *************************************
# 23: https://raw.githubusercontent.com/HL7/davinci-pcde/58ace3091511bbfe7bc125a71485f07bfff972ac/input/resources/structuredefinition-profile-composition.xml
# *************************************
# *************************************
# 24: https://raw.githubusercontent.com/HL7/carin-rtpbc/7d6a5bca70d068cf1ebb80809c2d8c505f04db80/input/resources/structuredefinition/rtpbc-request-bundle.xml
# *************************************
# *************************************
# 25: https://raw.githubusercontent.com/HL7/davinci-ehrx/343500d5eeee8e133a968f389e1c0b1c9833e6f1/input/resources/structuredefinition-hrex-patient-demographics.xml
# *************************************
# *************************************
# 26: https://raw.githubusercontent.com/HL7/PhCP-r4/285711544d07539241aa5cf33f99828be2c8bac1/input/resources/structuredefinition/PhCP-Coverage.xml
# *************************************
# (11) Type = Coverage
# sd.id = PhCP-Coverage
# *************************************
# 27: https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/structuredefinition/dental-servicerequest.xml
# *************************************
# *************************************
# 28: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/915f419c9dccda692145dfa0cab3f0f1400d0133/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.4.129.xml
# *************************************
# *************************************
# 29: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-medication-request.xml
# *************************************
# *************************************
# 30: https://raw.githubusercontent.com/HL7/carin-rtpbc/7d6a5bca70d068cf1ebb80809c2d8c505f04db80/input/resources/structuredefinition/rtpbc-request-claim.xml
# *************************************
# *************************************
# 31: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/915f419c9dccda692145dfa0cab3f0f1400d0133/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.4.41.xml
# *************************************
# *************************************
# 32: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/915f419c9dccda692145dfa0cab3f0f1400d0133/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.4.44.xml
# *************************************
# *************************************
# 33: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/structuredefinition/SDOHCC-Group.xml
# *************************************
# *************************************
# 34: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/915f419c9dccda692145dfa0cab3f0f1400d0133/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.4.43.xml
# *************************************
# *************************************
# 35: https://raw.githubusercontent.com/HL7/VhDir/7021570fad2e80c4bef2c70933379aaeede34a5b/input/resources/structuredefinition-profile-vhdir-insuranceplan.json
# *************************************
# *************************************
# 36: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-task.xml
# *************************************
# *************************************
# 37: https://raw.githubusercontent.com/HL7/davinci-deqm/1f51692460a635e49cf7264ee723c752afd1eda6/input/resources/StructureDefinition-datax-measurereport-deqm.xml
# *************************************
# *************************************
# 38: https://raw.githubusercontent.com/HL7/bser/413cf21b766d42531454321d475cfa06c0b7195d/input/resources/structuredefinition/BSeR-ReferralServiceRequest.xml
# *************************************
# *************************************
# 39: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-servicerequest.xml
# *************************************
# *************************************
# 40: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-medication-request.json
# *************************************
# *************************************
# 41: https://raw.githubusercontent.com/HL7/davinci-ecdx/7795645077f561238ed82718459acab6ddefd2e8/input/resources/structuredefinition-cdex-task-data-request.json
# *************************************
# *************************************
# 42: https://raw.githubusercontent.com/HL7/VhDir/7021570fad2e80c4bef2c70933379aaeede34a5b/input/resources/structuredefinition-profile-vhdir-network.json
# *************************************
# *************************************
# 43: https://raw.githubusercontent.com/HL7/davinci-ehrx/11f13256b312c2cf5b87cade68a413d0c7a68993/input/resources/structuredefinition-hrex-task-data-request.xml
# *************************************
# *************************************
# 44: https://raw.githubusercontent.com/HL7/PhCP-r4/285711544d07539241aa5cf33f99828be2c8bac1/input/resources/structuredefinition/PhCP-Composition.xml
# *************************************
# *************************************
# 45: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-task.json
# *************************************
# *************************************
# 46: https://raw.githubusercontent.com/HL7/VhDir/7021570fad2e80c4bef2c70933379aaeede34a5b/input/resources/structuredefinition-profile-vhdir-healthcareservice.json
# *************************************
# *************************************
# 47: https://raw.githubusercontent.com/HL7/CDA-ccda-2.1-sd/915f419c9dccda692145dfa0cab3f0f1400d0133/input/resources/structuredefinition/2.16.840.1.113883.10.20.22.4.61.xml
# *************************************
# *************************************
# 48: https://raw.githubusercontent.com/HL7/dental-data-exchange/d532d0a95713552dcc34baddfa22bd331ef13f38/input/resources/structuredefinition/dental-consult-note.xml
# *************************************
# *************************************
# 49: https://raw.githubusercontent.com/HL7/carin-rtpbc/7d6a5bca70d068cf1ebb80809c2d8c505f04db80/input/resources/structuredefinition/rtpbc-response-claimresponse.xml
# *************************************
# *************************************
# 50: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-servicerequest.json
# *************************************
# *************************************
# 51: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Continuity-of-Care-Document.xml
# *************************************
# *************************************
# 52: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Continuity-of-Care-Document.xml
# *************************************
# *************************************
# 53: https://raw.githubusercontent.com/HL7/fhir-bfdr/24c39b93774515741bfca839b30921a33e1f63c3/input/resources/structuredefinition/Composition-provider-live-birth-report.xml
# *************************************
# *************************************
# 54: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Transfer-Summary.xml
# *************************************
# *************************************
# 55: https://raw.githubusercontent.com/HL7/fhir-bfdr/24c39b93774515741bfca839b30921a33e1f63c3/input/resources/structuredefinition/Composition-jurisdiction-live-birth-report.xml
# *************************************
# *************************************
# 56: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Transfer-Summary.xml
# *************************************
# *************************************
# 57: https://raw.githubusercontent.com/HL7/carin-bb/0759f4ee87cc738c312d9811d694fac6a3563b0d/input/fsh/CoverageProfile.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17122) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17122) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-C4BB-Coverage.json
# (12) Type = Coverage
# sd.id = C4BB-Coverage
# >>>>>>>>>(2) reason[x] element found!!<<<<<<<<<<
# *************************************
# 58: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/06ed9d9b9b99fba17e6cedd36d3722cc924b4d9b/input/fsh/CoverageProfile.fsh
# *************************************
# convert fsh to json
# project_code: carin-digital-insurance-card
# (node:17135) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17135) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-C4DIC-Coverage.json
# (13) Type = Coverage
# sd.id = C4DIC-Coverage
# >>>>>>>>>(3) reason[x] element found!!<<<<<<<<<<
# *************************************
# 59: https://raw.githubusercontent.com/HL7/davinci-pct/6e5af9d97051035c417c683b78641add6c6d7f66/input/fsh/pct_coverage.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pct
# (node:17148) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17148) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pct/6e5af9d97051035c417c683b78641add6c6d7f66/input/fsh/pct_coverage.fsh:
#  sd = None
# *************************************
# 60: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/09247529534e7bb9704e2c54408c909e451d7946/input/fsh/scripts/capabilitystatement-c4dic.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/09247529534e7bb9704e2c54408c909e451d7946/input/fsh/scripts/capabilitystatement-c4dic.json:
#  {
#     "id": "c4dic",
#     "text": {
#         "div": "<div xmlns=\"http://www.
# *************************************
# 61: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/09247529534e7bb9704e2c54408c909e451d7946/input/fsh/scripts/Narrative-capabilitystatement-c4dic.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/09247529534e7bb9704e2c54408c909e451d7946/input/fsh/scripts/Narrative-capabilitystatement-c4dic.json:
#  {
#     "id": "c4dic",
#     "text": {
#         "div": "<div xmlns=\"http://www.
# *************************************
# 62: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/DEF_VersionInvariants.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17161) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17161) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/DEF_VersionInvariants.fsh:
#  sd = None
# *************************************
# 63: https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/7b430f769cffcb09b54a3700a7fc90a4163b98af/input/fsh/Formulary.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pdex-formulary
# (node:17174) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17174) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-usdf-FormularyItem.json
# *************************************
# 64: https://raw.githubusercontent.com/HL7/davinci-epdx/f1c284705b6d1897cb4395e82763edcd1f6f7836/input/fsh/PDexCoverage.fsh
# *************************************
# convert fsh to json
# project_code: davinci-epdx
# (node:17187) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17187) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-hrex-coverage.json
# (14) Type = Coverage
# sd.id = hrex-coverage
# *************************************
# 65: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/4b01e73e99513ca711c935d55fc0c2bbde54234c/input/fsh/PatientProfile.fsh
# *************************************
# convert fsh to json
# project_code: carin-digital-insurance-card
# (node:17201) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17201) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-C4DIC-Patient.json
# *************************************
# 66: https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17214) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17214) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-health-or-human-services-endpoint.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-health-or-human-services-expanded.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-basic-endpoint.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-basic-expanded.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-provider-expanded.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-provider-endpoint.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-human-services-endpoint.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-directory-query-human-services-expanded.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#
#
#
#
# //Health & Human Services
#
# Instance: directory-query-health-or-human-se
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/e4ec683eaf840ae21ff2f7d1a5ca6e2a243e283a/input/fsh/cap-statements.fsh:
#  sd = None
# *************************************
# 67: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/EOBBaseProfile.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17227) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17227) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-C4BB-ExplanationOfBenefit.json
# *************************************
# 68: https://raw.githubusercontent.com/HL7/fhir-directory-exchange/67efd1672547be50b87209fe42e91faaad8f0ecc/input/fsh/cap-statements.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-exchange
# (node:17240) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17240) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-fhir-national-directory.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-exchange/67efd1672547be50b87209fe42e91faaad8f0ecc/input/fsh/cap-statements.fsh:
#
#
#
#
# //National Directory
#
# Instance: fhir-national-directory
# InstanceOf: Cap
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-exchange/67efd1672547be50b87209fe42e91faaad8f0ecc/input/fsh/cap-statements.fsh:
#  sd = None
# *************************************
# 69: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/907c96c943e0caf981d8b2681e0b04c1aff77e98/input/fsh/scripts/test.html
# *************************************
# *************************************
# 70: https://raw.githubusercontent.com/HL7/davinci-pas/b23807354a98fdd54ee9eab8e9a7cf5ecab341a3/input/fsh/Coverage.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pas
# (node:17253) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17253) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-profile-coverage.json
# (15) Type = Coverage
# sd.id = profile-coverage
# *************************************
# 71: https://raw.githubusercontent.com/HL7/davinci-dtr/bf03a58434227a80a566bdc56a36d0211ef6e332/input/fsh/DTRCoverageR4.fsh
# *************************************
# convert fsh to json
# project_code: davinci-dtr
# (node:17266) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17266) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-dtr-coverage-r4.json
# (16) Type = Coverage
# sd.id = dtr-coverage-r4
# *************************************
# 72: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/CoverageDental1.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17279) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17279) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/CoverageDental1.fsh:
#  sd = None
# *************************************
# 73: https://raw.githubusercontent.com/HL7/carin-bb/0759f4ee87cc738c312d9811d694fac6a3563b0d/input/fsh/Examples.fsh.old
# *************************************
# *************************************
# 74: https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/4b4cf1df351efe84b192905fb0af2b2b6f482a47/input/fsh/ExamplesGraphDefinition.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pdex-formulary
# (node:17292) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17292) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/4b4cf1df351efe84b192905fb0af2b2b6f482a47/input/fsh/ExamplesGraphDefinition.fsh:
#  sd = None
# *************************************
# 75: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/Coverage1.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17305) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17305) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/Coverage1.fsh:
#  sd = None
# *************************************
# 76: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/Coverage2.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17320) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17320) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/Coverage2.fsh:
#  sd = None
# *************************************
# 77: https://raw.githubusercontent.com/HL7/fhir-directory-exchange/67efd1672547be50b87209fe42e91faaad8f0ecc/input/fsh/cap-statement-rulesets.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-exchange
# (node:17337) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17337) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-exchange/67efd1672547be50b87209fe42e91faaad8f0ecc/input/fsh/cap-statement-rulesets.fsh:
#  sd = None
# *************************************
# 78: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/Coverage3.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17350) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17350) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/Coverage3.fsh:
#  sd = None
# *************************************
# 79: https://raw.githubusercontent.com/HL7/fhir-directory-query/b0d0b597bb619ed7da85cc8c17f2c78d2edff694/input/fsh/cap-statement-rulesets-complete.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17363) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17363) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/b0d0b597bb619ed7da85cc8c17f2c78d2edff694/input/fsh/cap-statement-rulesets-complete.fsh:
#  sd = None
# *************************************
# 80: https://raw.githubusercontent.com/HL7/davinci-pdex-plan-net/8e6f6ff02bad6481a26cbb3d58e094e2f609af8b/input/fsh/PlanNet.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pdex-plan-net
# (node:17376) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17376) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-plannet-Endpoint.json
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pdex-plan-net/8e6f6ff02bad6481a26cbb3d58e094e2f609af8b/input/fsh/PlanNet.fsh:
#
#
# Profile:        PlannetEndpoint
# Parent:         Endpoint
# Id:
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-plannet-InsurancePlan.json
# *************************************
# 81: https://raw.githubusercontent.com/HL7/fhir-directory-query/3a4ffab31a810e4ff28852fd4b63093e7032d91b/input/fsh/cap-statement-rulesets.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17395) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17395) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/3a4ffab31a810e4ff28852fd4b63093e7032d91b/input/fsh/cap-statement-rulesets.fsh:
#  sd = None
# *************************************
# 82: https://raw.githubusercontent.com/HL7/fhir-directory-exchange/5dd8c824bcb58a9e8cb41367544c411a6edc159b/input/fsh/cap-statement-rulesets-complete.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-exchange
# (node:17408) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17408) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-exchange/5dd8c824bcb58a9e8cb41367544c411a6edc159b/input/fsh/cap-statement-rulesets-complete.fsh:
#  sd = None
# *************************************
# 83: https://raw.githubusercontent.com/HL7/fhir-directory-query/b5ea4148a5a70f35608136f97e5a0ae1e5f71164/input/fsh/NatlDirectoryQueryCompleteProfiles.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17421) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17421) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/b5ea4148a5a70f35608136f97e5a0ae1e5f71164/input/fsh/NatlDirectoryQueryCompleteProfiles.fsh:
#  sd = None
# *************************************
# 84: https://raw.githubusercontent.com/HL7/davinci-epdx/d9d83d918cc146ffd151667411da731208fa2bec/input/fsh/HrexCoverageExample.fsh
# *************************************
# convert fsh to json
# project_code: davinci-epdx
# (node:17434) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17434) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/davinci-epdx/d9d83d918cc146ffd151667411da731208fa2bec/input/fsh/HrexCoverageExample.fsh:
#  sd = None
# *************************************
# 85: https://raw.githubusercontent.com/HL7/fhir-directory-query/79577607286dedd79a60cdaa20730ef4d6228ec3/input/fsh/NatlDirectoryQuery.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17447) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17447) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-NatlDirEndpointQry-OrganizationAffiliation.json
# *************************************
# 86: https://raw.githubusercontent.com/HL7/davinci-epdx/b3ac85bbf29ab434870133a5cddd2a420fd4015b/input/fsh/ProfilePdexPriorAuthorization.fsh
# *************************************
# convert fsh to json
# project_code: davinci-epdx
# (node:17460) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17460) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-pdex-priorauthorization.json
# *************************************
# 87: https://raw.githubusercontent.com/HL7/davinci-epdx/c5992799e6605d464d19f46b1eaceb38be23c833/input/fsh/ExamplePriorAuthEOB.fsh
# *************************************
# convert fsh to json
# project_code: davinci-epdx
# (node:17474) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17474) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/davinci-epdx/c5992799e6605d464d19f46b1eaceb38be23c833/input/fsh/ExamplePriorAuthEOB.fsh:
#  sd = None
# *************************************
# 88: https://raw.githubusercontent.com/HL7/davinci-epdx/f0a35f72e01cb9e6a807a60ee9dbacaf3ddc52e3/input/fsh/PdexCapabilityStatementClient.fsh.ignore
# *************************************
# *************************************
# 89: https://raw.githubusercontent.com/HL7/davinci-epdx/dccefcc4fc8fd812c4f3b0fab8e8f2bfaaf9a06e/input/fsh/OperationPatient-payer-member-match.fsh.ignore
# *************************************
# *************************************
# 90: https://raw.githubusercontent.com/HL7/genomics-reporting/aa820d53ffcd94885fcb3f0a6d6142b9cf7f38c5/input/fsh/CGFindings.fsh
# *************************************
# convert fsh to json
# project_code: genomics-reporting
# (node:17487) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17487) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/aa820d53ffcd94885fcb3f0a6d6142b9cf7f38c5/input/fsh/CGFindings.fsh:
#  sd = None
# *************************************
# 91: https://raw.githubusercontent.com/HL7/carin-bb/dd8738651f43a7c6faba6c4cff07524478c6a1ba/input/fsh/scripts/buildCPCDStables.rb
# *************************************
# *************************************
# 92: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/0829b565654d8dd55f31b85bb6fcdfa73481a523/input/fsh/scripts/buildCPCDStables.rb
# *************************************
# *************************************
# 93: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/57c635176d6aa8fef54b8f04758fcd124c833d3a/input/fsh/Examples.fsh
# *************************************
# convert fsh to json
# project_code: carin-digital-insurance-card
# (node:17500) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17500) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/57c635176d6aa8fef54b8f04758fcd124c833d3a/input/fsh/Examples.fsh:
#  sd = None
# *************************************
# 94: https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/4b4cf1df351efe84b192905fb0af2b2b6f482a47/input/fsh/scripts/Narrative-CapabilityStatement-usdf-server.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/4b4cf1df351efe84b192905fb0af2b2b6f482a47/input/fsh/scripts/Narrative-CapabilityStatement-usdf-server.json:
#  {
#     "id": "usdf-server",
#     "text": {
#         "div": "<div xmlns=\"http:
# *************************************
# 95: https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/4b4cf1df351efe84b192905fb0af2b2b6f482a47/input/fsh/scripts/CapabilityStatement-usdf-server.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/4b4cf1df351efe84b192905fb0af2b2b6f482a47/input/fsh/scripts/CapabilityStatement-usdf-server.json:
#  {
#     "id": "usdf-server",
#     "text": {
#         "div": "<div xmlns=\"http:
# *************************************
# 96: https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/c87eedae102163f9ee1b180fc43d26c6bd4b75ed/input/fsh/OrganizationProfile.fsh
# *************************************
# convert fsh to json
# project_code: carin-digital-insurance-card
# (node:17513) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17513) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-digital-insurance-card/c87eedae102163f9ee1b180fc43d26c6bd4b75ed/input/fsh/OrganizationProfile.fsh:
#  sd = None
# *************************************
# 97: https://raw.githubusercontent.com/HL7/davinci-epdx/f0a35f72e01cb9e6a807a60ee9dbacaf3ddc52e3/input/fsh/PdexCapabilityStatementServer.fsh.ignore
# *************************************
# *************************************
# 98: https://raw.githubusercontent.com/HL7/davinci-epdx/f1c284705b6d1897cb4395e82763edcd1f6f7836/input/fsh/ExamplePDexServerCapabilityStatement.fsh
# *************************************
# convert fsh to json
# project_code: davinci-epdx
# (node:17526) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17526) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/CapabilityStatement-PdexServerCapabilityStatement.json
# Error parsing https://raw.githubusercontent.com/HL7/davinci-epdx/f1c284705b6d1897cb4395e82763edcd1f6f7836/input/fsh/ExamplePDexServerCapabilityStatement.fsh:
#  Instance: PdexServerCapabilityStatement
# InstanceOf: CapabilityStatement
# Des
# Error parsing https://raw.githubusercontent.com/HL7/davinci-epdx/f1c284705b6d1897cb4395e82763edcd1f6f7836/input/fsh/ExamplePDexServerCapabilityStatement.fsh:
#  sd = None
# *************************************
# 99: https://raw.githubusercontent.com/HL7/fhir-directory-exchange/c889857f4bc07e60b0e2322d6bffaedb793df6f7/input/fsh/NatlDirectory.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-exchange
# (node:17539) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17539) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-exchange/c889857f4bc07e60b0e2322d6bffaedb793df6f7/input/fsh/NatlDirectory.fsh:
#  sd = None
# *************************************
# 100: https://raw.githubusercontent.com/HL7/davinci-pct/e6fd53b4d1395efdf09bf1ed5a6269d6eb936173/input/fsh/pct_gfe_professional.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pct
# (node:17552) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17552) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-davinci-pct-gfe-professional.json
# *************************************
# 101: https://raw.githubusercontent.com/HL7/fhir-directory-attestation/5302e6e0910502659902378a211bb1101f4bd027/input/fsh/examples/InsurancePlan-AcmeQHPBronze.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-attestation
# (node:17565) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17565) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-attestation/5302e6e0910502659902378a211bb1101f4bd027/input/fsh/examples/InsurancePlan-AcmeQHPBronze.fsh:
#  sd = None
# *************************************
# 102: https://raw.githubusercontent.com/HL7/fhir-directory-attestation/4771c5e6cb42849a23aa6b2b14952e98dbffc355/input/fsh/examples/InsurancePlan-AcmeQHPGold.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-attestation
# (node:17578) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17578) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/InsurancePlan-ipHFxNkt6vAvN7qEG.json
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-attestation/4771c5e6cb42849a23aa6b2b14952e98dbffc355/input/fsh/examples/InsurancePlan-AcmeQHPGold.fsh:
#  Instance: AcmeQHPGold
# InstanceOf: InsurancePlan
# Title: "InsurancePlan/ipHFx
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-attestation/4771c5e6cb42849a23aa6b2b14952e98dbffc355/input/fsh/examples/InsurancePlan-AcmeQHPGold.fsh:
#  sd = None
# *************************************
# 103: https://raw.githubusercontent.com/HL7/fhir-directory-attestation/4771c5e6cb42849a23aa6b2b14952e98dbffc355/input/fsh/examples/InsurancePlan-AcmeQHPSilver.fsh
# ...
#  sd = None
# *************************************
# 118: https://raw.githubusercontent.com/HL7/davinci-pdex-plan-net/ff0e2cc3e3189dbaf833ccf91f428cf7b380e583/input/fsh/ValueSets.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pdex-plan-net
# (node:17786) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17786) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pdex-plan-net/ff0e2cc3e3189dbaf833ccf91f428cf7b380e583/input/fsh/ValueSets.fsh:
#  sd = None
# *************************************
# 119: https://raw.githubusercontent.com/HL7/fhir-directory-attestation/5302e6e0910502659902378a211bb1101f4bd027/input/fsh/NatlDirectory.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-attestation
# (node:17799) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17799) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-NatlDirEx-restriction.json
# *************************************
# 120: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBOutpatient1.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17812) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17812) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBOutpatient1.fsh:
#  sd = None
# *************************************
# 121: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBPharmacy1.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17825) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17825) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBPharmacy1.fsh:
#  sd = None
# *************************************
# 122: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBInpatient1.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17838) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17838) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBInpatient1.fsh:
#  sd = None
# *************************************
# 123: https://raw.githubusercontent.com/HL7/fhir-directory-query/79577607286dedd79a60cdaa20730ef4d6228ec3/input/fsh/ValueSets.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17851) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17851) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-directory-query/79577607286dedd79a60cdaa20730ef4d6228ec3/input/fsh/ValueSets.fsh:
#  sd = None
# *************************************
# 124: https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh
# *************************************
# convert fsh to json
# project_code: genomics-reporting
# (node:17864) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17864) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/ServiceRequest-GenomicsServiceRequestExample01.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/RiskAssessment-GenRiskDiabetesT2.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Specimen-GenomicSpecimenExample02.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/ServiceRequest-eMERGEServiceRequest.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Observation-GrouperEx01.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Patient-CGPatientExample01.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Observation-GrouperEx03.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Observation-GrouperEx02.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Patient-HG00403.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Organization-ExampleOrg.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/Specimen-GenomicSpecimenExample01.json
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  Instance: HG00403
# InstanceOf: Patient
# Description: "Example for Patient. S
# Error parsing https://raw.githubusercontent.com/HL7/genomics-reporting/e3ce5350320ba252da5595bfe8e615067b0113d3/input/fsh/CGExamples.fsh:
#  sd = None
# *************************************
# 125: https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBInpatient2.fsh
# *************************************
# convert fsh to json
# project_code: carin-bb
# (node:17877) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17877) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/carin-bb/2191ed033bb0997762a9adc47496dfadffe94cdc/input/fsh/examples/EOBInpatient2.fsh:
#  sd = None
# *************************************
# 126: https://raw.githubusercontent.com/HL7/davinci-dtr/cdff17a9decd7ffcb236c2f410f7f05bb863fb1b/input/fsh/examples/HomeOxygenQuestionnaireResponse.fsh
# *************************************
# convert fsh to json
# project_code: davinci-dtr
# (node:17890) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17890) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/QuestionnaireResponse-home-o2-questionnaireresponse.json
# Error parsing https://raw.githubusercontent.com/HL7/davinci-dtr/cdff17a9decd7ffcb236c2f410f7f05bb863fb1b/input/fsh/examples/HomeOxygenQuestionnaireResponse.fsh:
#  Instance: referred-questionnaire
# InstanceOf: Questionnaire
# Usage: #inline
# D
# Error parsing https://raw.githubusercontent.com/HL7/davinci-dtr/cdff17a9decd7ffcb236c2f410f7f05bb863fb1b/input/fsh/examples/HomeOxygenQuestionnaireResponse.fsh:
#  sd = None
# *************************************
# 127: https://raw.githubusercontent.com/HL7/FHIR-IG-Human-Services-Directory/9be95bc6a434e4b6fd290add64f021440197da2e/input/fsh/hsdshealthcareservice.fsh
# *************************************
# convert fsh to json
# project_code: FHIR-IG-Human-Services-Directory
# (node:17903) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17903) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/FHIR-IG-Human-Services-Directory/9be95bc6a434e4b6fd290add64f021440197da2e/input/fsh/hsdshealthcareservice.fsh:
#  sd = None
# *************************************
# 128: https://raw.githubusercontent.com/HL7/fhir-registry-protocols-ig/3fdda7e0ddf35897f7fa2a93bea569b4dfb839ff/input/fsh/Cath-PCI-SD-Example.fsh
# *************************************
# convert fsh to json
# project_code: fhir-registry-protocols-ig
# (node:17916) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17916) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-ACCNCDRCathPCI.json
# *************************************
# 129: https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/23650112c612c2dbfa907dc44999a8af626b3d1f/input/fsh/Examples3004t.fsh
# *************************************
# convert fsh to json
# project_code: davinci-pdex-formulary
# (node:17929) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17929) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/davinci-pdex-formulary/23650112c612c2dbfa907dc44999a8af626b3d1f/input/fsh/Examples3004t.fsh:
#  sd = None
# *************************************
# 130: https://raw.githubusercontent.com/HL7/fhir-directory-query/1b3aa6f19191fb22a2a7cad8ce09a131b219c7a8/input/fsh/Extensions.fsh
# *************************************
# convert fsh to json
# project_code: fhir-directory-query
# (node:17942) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17942) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# /Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources/StructureDefinition-location-reference.json
# *************************************
# 131: https://raw.githubusercontent.com/HL7/fhir-registry-protocols-ig/9ddeef37a722d60e2808856bfb22c38e3388ecee/input/fsh/Cath-PCI-SD-Example-detailed.fsh
# *************************************
# convert fsh to json
# project_code: fhir-registry-protocols-ig
# (node:17967) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# (node:17967) Warning: Accessing non-existent property 'INVALID_ALT_NUMBER' of module exports inside circular dependency
# Error parsing https://raw.githubusercontent.com/HL7/fhir-registry-protocols-ig/9ddeef37a722d60e2808856bfb22c38e3388ecee/input/fsh/Cath-PCI-SD-Example-detailed.fsh:
#  sd = None
# Total Coverage Profiles = 14
# {'http://hl7.org/fhir/us/bfdr/StructureDefinition/Coverage-principal-payer-for-delivery',
#  'http://hl7.org/fhir/us/bser/StructureDefinition/BSeR-Coverage',
#  'http://hl7.org/fhir/us/carin-bb/StructureDefinition/C4BB-Coverage',
#  'http://hl7.org/fhir/us/carin-digital-insurance-card/StructureDefinition/C4DIC-Coverage',
#  'http://hl7.org/fhir/us/carin-rtpbc/StructureDefinition/rtpbc-coverage',
#  'http://hl7.org/fhir/us/davinci-alerts/StructureDefinition/adt-notification-coverage',
#  'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm',
#  'http://hl7.org/fhir/us/davinci-dtr/StructureDefinition/dtr-coverage-r4',
#  'http://hl7.org/fhir/us/davinci-epdx/StructureDefinition/hrex-coverage',
#  'http://hl7.org/fhir/us/davinci-hrex/StructureDefinition/hrex-coverage',
#  'http://hl7.org/fhir/us/davinci-pas/StructureDefinition/profile-coverage',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-coverage',
#  'http://hl7.org/fhir/us/phcp/StructureDefinition/PhCP-Coverage',
#  'http://hl7.org/fhir/us/specialty-rx/StructureDefinition/specialty-rx-coverage'}
# Total Coverage Profiles with ['Coverage.period'] in differential = 3
# {'http://hl7.org/fhir/us/bser/StructureDefinition/BSeR-Coverage',
#  'http://hl7.org/fhir/us/carin-bb/StructureDefinition/C4BB-Coverage',
#  'http://hl7.org/fhir/us/carin-digital-insurance-card/StructureDefinition/C4DIC-Coverage'}
# Total Files = 131
