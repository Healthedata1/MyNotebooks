# %% [markdown]
# ## Search through StructureDefinition properties
#
# *USE Python 3.7+ to maintain order of Json files*
#
# - Fetch URLs from excel file
# - Fetch published URl
# - search for SD elements

# %% [markdown]
# ### import python modules

# %%
from pathlib import Path
import pandas as pd
import csv
from json import loads, dumps
from requests import get,post
from fhir.resources.structuredefinition import StructureDefinition
from pprint import pprint

headers = {'Accept': 'application/fhir+json', 'Content-Type': 'application/fhir+json'}
in_path = Path(r'/Users/ehaas/Documents/FHIR/US-Core/my-notes/MedReq-MedDisp-profiles.csv')
in_path = Path(r'/Users/ehaas/Documents/FHIR/US-Core/my-notes/SD_URL.md.csv')
fsh_project = '/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project'
sushi_config_path = Path(r'/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/sushi-config.yml')
fsh_file_path = Path(r'/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/input/fsh/file.fsh')
fsh_gen_resource_path = Path('/Users/ehaas/Documents/Python/Jupyter/MyNotebooks/utils/test_files/my-project/fsh-generated/resources')

in_path
# Out:
# PosixPath('/Users/ehaas/Documents/FHIR/US-Core/my-notes/SD_URL.md.csv')

# %% [markdown]
# ### Loop through SDs
#  - read sheet as DF
#  - iterate through urls
#    - fetch SD as xml, json, or fsh
#    - convert all to python fhir object
#    - list id

# %%
test_type = 'MedicationRequest' #'ServiceRequest'
test_me =["MedicationRequest.reasonCode","MedicationRequest.reasonReference",]#["ServiceRequest.reasonCode","ServiceRequest.reasonReference",]
#test_me =["Coverage.period",]
count1 = 1
count2 = 1
list1 = []
list2 = []

def check_element(sd):
    global count1, count2, list1, list2
    if sd.type == test_type:
        print(f'({count1}) Type = {test_type}')
        count1 += 1
        list1.append(sd.url)
        print(f'sd.id = {sd.id}')
        element_paths = [e.path for e in sd.differential.element]
        if any(item in element_paths for item in test_me):
                print(f'>>>>>>>>>({count2}) reason[x] element found!!<<<<<<<<<<')
                list2.append(sd.url)
                count2 += 1

                
def update_sushi(my_file):
    '''update the sushi-config.yaml file'''
    project_code  = my_file.split('/')[4:5][0]
    print(f'project_code: {project_code}')
    sushi_config = f'''
FSHOnly: true
fhirVersion: 4.0.1
canonical: "http://hl7.org/fhir/us/{project_code}"
name: Temp
status: draft
''' 
    # print(sushi_config)
    # print(config_path)
    sushi_config_path.write_text(sushi_config)

def make_fhir_object():
    for file in fsh_gen_resource_path.glob('*.json'):
        print(file)
        try:
            sd = StructureDefinition.parse_file(file)
            file.unlink()
        except:
            print(f'Error parsing {my_file}:\n {response.text[:75]}')
            file.unlink()
        else:
            return sd


df = pd.read_csv(in_path, header=0, encoding='utf-8')
for i,my_file in enumerate(df.url):
    print(f'*************************************\n{i+1}: {my_file}\n*************************************')
    with get(my_file, headers=headers) as response:
        if response.status_code == 200:
            if my_file.split('.')[-1] == 'xml':
                data = response.text.replace('<?xml version="1.0" encoding="UTF-8"?>','',1) # check all spellings!!!
                try:       
                    sd = StructureDefinition.parse_raw(data, content_type="text/xml")
                except:
                    print(f'Error parsing {my_file}:\n {response.text[:75]}')
                else:
                    check_element(sd)
            if my_file.split('.')[-1]  == 'json':
                try:
                    sd = StructureDefinition.parse_obj(response.json())
                except:
                    print(f'Error parsing {my_file}:\n {response.text[:75]}')
                else:
                    check_element(sd)
            if my_file.split('.')[-1]  == 'fsh':
                print('convert fsh to json')
                update_sushi(my_file)
                fsh_file_path.write_text(response.text)
                #build json from fsh files using sushi
                # !sushi $fsh_project > "/Users/ehaas/Documents/Python/Jupyter/sushi.txt"
                sd = make_fhir_object()
                try:
                    check_element(sd)
                except AttributeError:
                    print(f'Error parsing {my_file}:\n sd = {sd}')

print(f'Total {test_type} Profiles = {count1-1}')
pprint(list1)
print(f'Total {test_type} Profiles with {test_me} in differential = {count2-1}')
pprint(list2)
print(f'Total Files = {i+1}')
# Out:
# *************************************
# 1: https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/structuredefinition/dental-servicerequest.xml
# *************************************
# (1) Type = ServiceRequest
# sd.id = dental-servicerequest
# >>>>>>>>>(1) reason[x] element found!!<<<<<<<<<<
# *************************************
# 2: https://raw.githubusercontent.com/HL7/case-reporting/23bdb08d27747fde62476b1f18b1f76bdfb97a94/input/resources/structuredefinition/eicr-servicerequest.xml
# *************************************
# (2) Type = ServiceRequest
# sd.id = eicr-servicerequest
# *************************************
# 3: https://raw.githubusercontent.com/HL7/sdc/f9c12c2eb322f3e97d4c9baf54d78fd17269baaa/input/resources/StructureDefinition-sdc-servicerequest.xml
# *************************************
# (3) Type = ServiceRequest
# sd.id = sdc-servicerequest
# >>>>>>>>>(2) reason[x] element found!!<<<<<<<<<<
# *************************************
# 4: https://raw.githubusercontent.com/HL7/fhir-us-mcc/33cdbe306011bd75d0994ab7e12e44b71a391ff1/input/resources/structuredefinition/MCCServiceRequest.xml
# *************************************
# (4) Type = ServiceRequest
# sd.id = MCCServiceRequest
# *************************************
# 5: https://raw.githubusercontent.com/HL7/PhCP-r4/285711544d07539241aa5cf33f99828be2c8bac1/input/resources/structuredefinition/PhCP-ServiceRequest.xml
# *************************************
# (5) Type = ServiceRequest
# sd.id = PhCP-ServiceRequest
# *************************************
# 6: https://raw.githubusercontent.com/HL7/sdc/f9c12c2eb322f3e97d4c9baf54d78fd17269baaa/input/resources/StructureDefinition-sdc-servicerequest-questionnaire.xml
# *************************************
# *************************************
# 7: https://raw.githubusercontent.com/HL7/cancer-reporting/ae576ddde353a54c6e438748ab830a1604598ee9/input/resources/structuredefinition/us-pathology-service-request.xml
# *************************************
# (6) Type = ServiceRequest
# sd.id = us-pathology-service-request
# *************************************
# 8: https://raw.githubusercontent.com/HL7/bser/413cf21b766d42531454321d475cfa06c0b7195d/input/resources/structuredefinition/BSeR-ReferralServiceRequest.xml
# *************************************
# (7) Type = ServiceRequest
# sd.id = BSeR-ReferralServiceRequest
# >>>>>>>>>(3) reason[x] element found!!<<<<<<<<<<
# *************************************
# 9: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-servicerequest.xml
# *************************************
# (8) Type = ServiceRequest
# sd.id = PAOX-servicerequest
# >>>>>>>>>(4) reason[x] element found!!<<<<<<<<<<
# *************************************
# 10: https://raw.githubusercontent.com/HL7/fhir-qi-core/21fc6f080d5588da7743be5cc529dd3c65549877/input/resources/structuredefinition-qicore-servicerequest-appropriatenessscore.xml
# *************************************
# *************************************
# 11: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/9c787dc3e767459828b9b3638dced8e16b9cfacc/input/resources/structuredefinition/SDOHCC-ServiceRequest.xml
# *************************************
# (9) Type = ServiceRequest
# sd.id = SDOHCC-ServiceRequest
# >>>>>>>>>(5) reason[x] element found!!<<<<<<<<<<
# *************************************
# 12: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-servicerequest.json
# *************************************
# (10) Type = ServiceRequest
# sd.id = PAOX-servicerequest
# >>>>>>>>>(6) reason[x] element found!!<<<<<<<<<<
# *************************************
# 13: https://raw.githubusercontent.com/HL7/sdc/f9c12c2eb322f3e97d4c9baf54d78fd17269baaa/input/resources/structuredefinition-sdc-task.xml
# *************************************
# *************************************
# 14: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/OrderExtension.xml
# *************************************
# *************************************
# 15: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/OrderExtension.xml
# *************************************
# *************************************
# 16: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-provenance.xml
# *************************************
# *************************************
# 17: https://raw.githubusercontent.com/HL7/fhir-qi-core/6d75b8d61e63dd83d1627be3ca8e411fe1ee37aa/input/resources/StructureDefinition-qicore-isElective.json
# *************************************
# *************************************
# 18: https://raw.githubusercontent.com/HL7/dental-data-exchange/d532d0a95713552dcc34baddfa22bd331ef13f38/input/resources/structuredefinition/dental-consult-note.xml
# *************************************
# *************************************
# 19: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-task.xml
# *************************************
# *************************************
# 20: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/9a09486553aba7160c7e5fa2602dba5193474e4c/input/resources/structuredefinition/SDOHCC-TaskForReferralManagement.xml
# *************************************
# *************************************
# 21: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-provenance.json
# *************************************
# *************************************
# 22: https://raw.githubusercontent.com/HL7/davinci-crd/f1ab653cba5278d190dc132d78407e75aa028e8c/input/resources/StructureDefinition-ext-coverage-information.xml
# *************************************
# *************************************
# 23: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-task.json
# *************************************
# *************************************
# 24: https://raw.githubusercontent.com/HL7/US-Core/f94b82cb109de6e0bb1f25621b882d82e4bbc620/input/resources/structuredefinition-us-core-servicerequest.json
# *************************************
# (11) Type = ServiceRequest
# sd.id = us-core-servicerequest
# *************************************
# 25: https://raw.githubusercontent.com/HL7/fhir-us-mcc/a16eb01e8981b8e107649f78d9c651a3fef8f79c/input/resources/structuredefinition/mccCarePlan.xml
# *************************************
# *************************************
# 26: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-messageheader.xml
# *************************************
# *************************************
# 27: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/9a09486553aba7160c7e5fa2602dba5193474e4c/input/resources/structuredefinition/SDOHCC-Procedure.xml
# *************************************
# *************************************
# 28: https://raw.githubusercontent.com/HL7/fhir-order-catalog/111f316d66f054e5b8f3fbb7a51d5b1ce93633ca/input/resources/LabProcedureDefinition.StructureDefinition.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-order-catalog/111f316d66f054e5b8f3fbb7a51d5b1ce93633ca/input/resources/LabProcedureDefinition.StructureDefinition.xml:
#  <?xml version="1.0" encoding="utf-8"?>
# <StructureDefinition xmlns="http://h
# *************************************
# 29: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-messageheader.json
# *************************************
# *************************************
# 30: https://raw.githubusercontent.com/HL7/davinci-ehrx/11f13256b312c2cf5b87cade68a413d0c7a68993/input/resources/structuredefinition-hrex-task-data-request.xml
# *************************************
# *************************************
# 31: https://raw.githubusercontent.com/HL7/us-odh/58747c031d2ea416622b3fdafb2b61a45051e302/input/resources/structuredefinition/odh-CombatZonePeriod.json
# *************************************
# *************************************
# 32: https://raw.githubusercontent.com/HL7/us-odh/58747c031d2ea416622b3fdafb2b61a45051e302/input/resources/structuredefinition/odh-RetirementDate.json
# *************************************
# *************************************
# 33: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Care-Plan-Document.xml
# *************************************
# *************************************
# 34: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Care-Plan-Document.xml
# *************************************
# *************************************
# 35: https://raw.githubusercontent.com/HL7/us-odh/58747c031d2ea416622b3fdafb2b61a45051e302/input/resources/structuredefinition/odh-EmploymentStatus.json
# *************************************
# *************************************
# 36: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Operative-Note.xml
# *************************************
# *************************************
# 37: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Operative-Note.xml
# *************************************
# *************************************
# 38: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Referral-Note.xml
# *************************************
# *************************************
# 39: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Progress-Note.xml
# *************************************
# *************************************
# 40: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Referral-Note.xml
# *************************************
# *************************************
# 41: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Progress-Note.xml
# *************************************
# *************************************
# 42: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Transfer-Summary.xml
# *************************************
# *************************************
# 43: https://raw.githubusercontent.com/HL7/us-odh/0150069be9e1e03ac51c96a194dfd7dec787e5d9/input/resources/structuredefinition/odh-UsualWork.json
# *************************************
# *************************************
# 44: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Transfer-Summary.xml
# *************************************
# *************************************
# 45: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/History-and-Physical.xml
# *************************************
# *************************************
# 46: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/History-and-Physical.xml
# *************************************
# *************************************
# 47: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Consultation-Note.xml
# *************************************
# *************************************
# 48: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Continuity-of-Care-Document.xml
# *************************************
# *************************************
# 49: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Consultation-Note.xml
# *************************************
# *************************************
# 50: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Continuity-of-Care-Document.xml
# *************************************
# *************************************
# 51: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Procedure-Note.xml
# *************************************
# *************************************
# 52: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Discharge-Summary.xml
# *************************************
# *************************************
# 53: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Procedure-Note.xml
# *************************************
# *************************************
# 54: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/Discharge-Summary.xml
# *************************************
# *************************************
# 55: https://raw.githubusercontent.com/HL7/us-odh/e3be5850b13e15d5d9102f54e231b821e4d0564f/input/resources/structuredefinition/odh-PastOrPresentJob.json
# *************************************
# *************************************
# 56: https://raw.githubusercontent.com/HL7/case-reporting/f101b1bb6b29680e7452530ab97b3cecb1462a04/input/resources/structuredefinition/eicr-composition.xml
# *************************************
# *************************************
# 57: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/9c787dc3e767459828b9b3638dced8e16b9cfacc/input/resources/structuredefinition/SDOHCC-ServiceRequest.xml
# *************************************
# (12) Type = ServiceRequest
# sd.id = SDOHCC-ServiceRequest
# >>>>>>>>>(7) reason[x] element found!!<<<<<<<<<<
# *************************************
# 58: https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/structuredefinition/dental-servicerequest.xml
# *************************************
# (13) Type = ServiceRequest
# sd.id = dental-servicerequest
# >>>>>>>>>(8) reason[x] element found!!<<<<<<<<<<
# *************************************
# 59: https://raw.githubusercontent.com/HL7/bser/413cf21b766d42531454321d475cfa06c0b7195d/input/resources/structuredefinition/BSeR-ReferralServiceRequest.xml
# *************************************
# (14) Type = ServiceRequest
# sd.id = BSeR-ReferralServiceRequest
# >>>>>>>>>(9) reason[x] element found!!<<<<<<<<<<
# *************************************
# 60: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-servicerequest.xml
# *************************************
# (15) Type = ServiceRequest
# sd.id = PAOX-servicerequest
# >>>>>>>>>(10) reason[x] element found!!<<<<<<<<<<
# *************************************
# 61: https://raw.githubusercontent.com/HL7/PhCP-r4/285711544d07539241aa5cf33f99828be2c8bac1/input/resources/structuredefinition/PhCP-ServiceRequest.xml
# *************************************
# (16) Type = ServiceRequest
# sd.id = PhCP-ServiceRequest
# *************************************
# 62: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-servicerequest.json
# *************************************
# (17) Type = ServiceRequest
# sd.id = PAOX-servicerequest
# >>>>>>>>>(11) reason[x] element found!!<<<<<<<<<<
# *************************************
# 63: https://raw.githubusercontent.com/HL7/case-reporting/23bdb08d27747fde62476b1f18b1f76bdfb97a94/input/resources/structuredefinition/eicr-servicerequest.xml
# *************************************
# (18) Type = ServiceRequest
# sd.id = eicr-servicerequest
# *************************************
# 64: https://raw.githubusercontent.com/HL7/fhir-us-mcc/33cdbe306011bd75d0994ab7e12e44b71a391ff1/input/resources/structuredefinition/MCCServiceRequest.xml
# *************************************
# (19) Type = ServiceRequest
# sd.id = MCCServiceRequest
# *************************************
# 65: https://raw.githubusercontent.com/HL7/cancer-reporting/ae576ddde353a54c6e438748ab830a1604598ee9/input/resources/structuredefinition/us-pathology-service-request.xml
# *************************************
# (20) Type = ServiceRequest
# sd.id = us-pathology-service-request
# *************************************
# 66: https://raw.githubusercontent.com/HL7/sdc/f9c12c2eb322f3e97d4c9baf54d78fd17269baaa/input/resources/StructureDefinition-sdc-servicerequest.xml
# *************************************
# (21) Type = ServiceRequest
# sd.id = sdc-servicerequest
# >>>>>>>>>(12) reason[x] element found!!<<<<<<<<<<
# *************************************
# 67: https://raw.githubusercontent.com/HL7/case-reporting/85aa33336a4afb51bbdb00a48336ee6d43909ac1/input/resources/capabilitystatement/capabilitystatement-ecr.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/85aa33336a4afb51bbdb00a48336ee6d43909ac1/input/resources/capabilitystatement/capabilitystatement-ecr.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement xmlns="http://h
# *************************************
# 68: https://raw.githubusercontent.com/HL7/fhir-us-mcc/29df311233e6e5dea66f49054d7ab36a9b257b20/input/resources/servicerequest/foodpantry-referral.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-us-mcc/29df311233e6e5dea66f49054d7ab36a9b257b20/input/resources/servicerequest/foodpantry-referral.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 69: https://raw.githubusercontent.com/HL7/cqf-measures/052f80bbd153edf919294965518adb14c3cfeb81/input/resources/Measure-HBPComponent.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cqf-measures/052f80bbd153edf919294965518adb14c3cfeb81/input/resources/Measure-HBPComponent.xml:
#  <Measure xmlns="http://hl7.org/fhir">
#    <id value="HBPComponent"></id>
#
# *************************************
# 70: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-ReferralRecipientLight.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-ReferralRecipientLight.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement xmlns="http://h
# *************************************
# 71: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-ReferralRecipient.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-ReferralRecipient.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement xmlns="http://h
# *************************************
# 72: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/aefb4c6569ca2b99a2339b5ae73cfa8fcd9650ee/input/resources/capabilitystatement/SDOHCC-PatientApp.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/aefb4c6569ca2b99a2339b5ae73cfa8fcd9650ee/input/resources/capabilitystatement/SDOHCC-PatientApp.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement xmlns="http://h
# *************************************
# 73: https://raw.githubusercontent.com/HL7/sdc/f9c12c2eb322f3e97d4c9baf54d78fd17269baaa/input/resources/StructureDefinition-sdc-servicerequest-questionnaire.xml
# *************************************
# *************************************
# 74: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-CoordinationPlatform.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-CoordinationPlatform.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement xmlns="http://h
# *************************************
# 75: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/Radiograph-survey.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/Radiograph-survey.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 76: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-ReferralSource.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/82798d0d17b55f26a7f47f6f0785e9104d67a795/input/resources/capabilitystatement/SDOHCC-ReferralSource.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement xmlns="http://h
# *************************************
# 77: https://raw.githubusercontent.com/HL7/davinci-ecdx/bf2f46f6a1a60fca52b82384ba4828b6c97a630f/input/resources/capabilitystatement-data-source-client.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/davinci-ecdx/bf2f46f6a1a60fca52b82384ba4828b6c97a630f/input/resources/capabilitystatement-data-source-client.json:
#  {
#   "resourceType": "CapabilityStatement",
#   "id": "data-source-client",
#
# *************************************
# 78: https://raw.githubusercontent.com/HL7/case-reporting/67d8d13917d309511949231b59bdccf5ac799c21/input/resources/servicerequest/servicerequest-eicr-zika.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/67d8d13917d309511949231b59bdccf5ac799c21/input/resources/servicerequest/servicerequest-eicr-zika.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest xmlns="http://hl7.or
# *************************************
# 79: https://raw.githubusercontent.com/HL7/case-reporting/67d8d13917d309511949231b59bdccf5ac799c21/input/resources/servicerequest/servicerequest-eicr-eve-everywoman-zika.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/67d8d13917d309511949231b59bdccf5ac799c21/input/resources/servicerequest/servicerequest-eicr-eve-everywoman-zika.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest xmlns="http://hl7.or
# *************************************
# 80: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/Resin-restore-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/Resin-restore-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 81: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/prophylaxis-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/prophylaxis-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 82: https://raw.githubusercontent.com/HL7/davinci-ecdx/bf2f46f6a1a60fca52b82384ba4828b6c97a630f/input/resources/capabilitystatement-data-consumer-server.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/davinci-ecdx/bf2f46f6a1a60fca52b82384ba4828b6c97a630f/input/resources/capabilitystatement-data-consumer-server.json:
#  {
#   "resourceType": "CapabilityStatement",
#   "id": "data-consumer-server",
#
# *************************************
# 83: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/Dental-extraction-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/servicerequest/Dental-extraction-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 84: https://raw.githubusercontent.com/HL7/dental-data-exchange/d532d0a95713552dcc34baddfa22bd331ef13f38/input/resources/servicerequest/example-dental-referral-1.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/d532d0a95713552dcc34baddfa22bd331ef13f38/input/resources/servicerequest/example-dental-referral-1.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 85: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/servicerequest/SDOHCC-ServiceRequestSubreferralSummerFoodProgramExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/servicerequest/SDOHCC-ServiceRequestSubreferralSummerFoodProgramExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 86: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/servicerequest/SDOHCC-ServiceRequestSubreferralGardenProgramExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/servicerequest/SDOHCC-ServiceRequestSubreferralGardenProgramExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 87: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/servicerequest/SDOHCC-ServiceRequestSubreferralGardenProgramExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/4af6153b65d95b73800d99df9f7ce3e3aec91e36/input/resources/servicerequest/SDOHCC-ServiceRequestSubreferralGardenProgramExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 88: https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/capabilitystatement/dental-client-capstat.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/capabilitystatement/dental-client-capstat.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement
#     xmlns="http
# *************************************
# 89: https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/capabilitystatement/dental-server-capstat.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/6bbcfe5f82492b1de0569d59490766b21c4b5119/input/resources/capabilitystatement/dental-server-capstat.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement
#     xmlns="http
# *************************************
# 90: https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/task/task-BSeR-ReferralTask.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/task/task-BSeR-ReferralTask.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 91: https://raw.githubusercontent.com/HL7/fhir-qi-core/07cc3d96f73c4ad828ddafb7f4f1702f5ef00d01/input/resources/servicerequest-myringotomy-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-qi-core/07cc3d96f73c4ad828ddafb7f4f1702f5ef00d01/input/resources/servicerequest-myringotomy-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest xmlns="http://hl7.or
# *************************************
# 92: https://raw.githubusercontent.com/HL7/fhir-qi-core/07cc3d96f73c4ad828ddafb7f4f1702f5ef00d01/input/resources/servicerequest-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-qi-core/07cc3d96f73c4ad828ddafb7f4f1702f5ef00d01/input/resources/servicerequest-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest xmlns="http://hl7.or
# *************************************
# 93: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/f7278ff5efc030a8ef93dbb4ebdcdbd632080b87/input/resources/servicerequest/SDOHCC-ServiceRequestActiveFoodPantryApplicationAssistExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/f7278ff5efc030a8ef93dbb4ebdcdbd632080b87/input/resources/servicerequest/SDOHCC-ServiceRequestActiveFoodPantryApplicationAssistExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 94: https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/bundle/bundle-bser-referral-message-bundle-eve-everywoman.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/bundle/bundle-bser-referral-message-bundle-eve-everywoman.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Bundle xmlns="http://hl7.org/fhir">
# *************************************
# 95: https://raw.githubusercontent.com/HL7/dental-data-exchange/d532d0a95713552dcc34baddfa22bd331ef13f38/input/resources/structuredefinition/dental-consult-note.xml
# *************************************
# *************************************
# 96: https://raw.githubusercontent.com/HL7/cancer-reporting/ae576ddde353a54c6e438748ab830a1604598ee9/input/resources/capabilitystatement/central-cancer-registry-reporting-ehr-pathology.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cancer-reporting/ae576ddde353a54c6e438748ab830a1604598ee9/input/resources/capabilitystatement/central-cancer-registry-reporting-ehr-pathology.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CapabilityStatement
#     xmlns="http
# *************************************
# 97: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/servicerequest/HomeHealth.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/servicerequest/HomeHealth.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 98: https://raw.githubusercontent.com/HL7/fhir-qi-core/21fc6f080d5588da7743be5cc529dd3c65549877/input/resources/structuredefinition-qicore-servicerequest-appropriatenessscore.xml
# *************************************
# *************************************
# 99: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/task/Home-Health.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/task/Home-Health.json:
#  {
# 	"resourceType": "Task",
# 	"id": "Home-Health",
# 	"meta": {
# 		"versionId":
# *************************************
# 100: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/task/Home-Health.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/task/Home-Health.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 101: https://raw.githubusercontent.com/HL7/fhir-qi-core/2517908330ca8fdf6f119df4f0aa2fcc628d38c2/input/resources/changes.txt
# *************************************
# *************************************
# 102: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-task.json
# *************************************
# *************************************
# 103: https://raw.githubusercontent.com/HL7/case-reporting/673407ed401ac3823115d10c76e4b93e160be6e3/input/resources/plandefinition/plandefinition-ersd-instance-relateddata-extension-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/673407ed401ac3823115d10c76e4b93e160be6e3/input/resources/plandefinition/plandefinition-ersd-instance-relateddata-extension-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <PlanDefinition xmlns="http://hl7.or
# *************************************
# 104: https://raw.githubusercontent.com/HL7/case-reporting/673407ed401ac3823115d10c76e4b93e160be6e3/input/resources/plandefinition/plandefinition-ersd-instance-simple-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/673407ed401ac3823115d10c76e4b93e160be6e3/input/resources/plandefinition/plandefinition-ersd-instance-simple-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <PlanDefinition xmlns="http://hl7.or
# *************************************
# 105: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/servicerequest/HomeHealth.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/servicerequest/HomeHealth.json:
#  {
# 	"resourceType": "ServiceRequest",
# 	"id": "HomeHealth",
# 	"meta": {
# 		"ver
# *************************************
# 106: https://raw.githubusercontent.com/HL7/fhir-qi-core/2517908330ca8fdf6f119df4f0aa2fcc628d38c2/input/resources/valueset-qicore-servicerequest-reason-rejected.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-qi-core/2517908330ca8fdf6f119df4f0aa2fcc628d38c2/input/resources/valueset-qicore-servicerequest-reason-rejected.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
#
# <ValueSet xmlns="http://hl7.org/fhi
# *************************************
# 107: https://raw.githubusercontent.com/HL7/sdc/f9c12c2eb322f3e97d4c9baf54d78fd17269baaa/input/resources/structuredefinition-sdc-task.xml
# *************************************
# *************************************
# 108: https://raw.githubusercontent.com/HL7/fhir-us-mcc/a16eb01e8981b8e107649f78d9c651a3fef8f79c/input/resources/structuredefinition/mccCarePlan.xml
# *************************************
# *************************************
# 109: https://raw.githubusercontent.com/HL7/cancer-reporting/63fc2af7fdb0cc3b5aa0b3995f9753be594a2f00/input/resources/servicerequest/cancer-path-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cancer-reporting/63fc2af7fdb0cc3b5aa0b3995f9753be594a2f00/input/resources/servicerequest/cancer-path-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest xmlns="http://hl7.or
# *************************************
# 110: https://raw.githubusercontent.com/HL7/case-reporting/673407ed401ac3823115d10c76e4b93e160be6e3/input/resources/plandefinition/plandefinition-ersd-instance-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/673407ed401ac3823115d10c76e4b93e160be6e3/input/resources/plandefinition/plandefinition-ersd-instance-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <PlanDefinition xmlns="http://hl7.or
# *************************************
# 111: https://raw.githubusercontent.com/HL7/US-Core/f94b82cb109de6e0bb1f25621b882d82e4bbc620/input/resources/structuredefinition-us-core-servicerequest.json
# *************************************
# (22) Type = ServiceRequest
# sd.id = us-core-servicerequest
# *************************************
# 112: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-task.xml
# *************************************
# *************************************
# 113: https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/servicerequest/servicerequest-BSeR-ReferralServiceRequest.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/servicerequest/servicerequest-BSeR-ReferralServiceRequest.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <ServiceRequest
#     xmlns="http://hl
# *************************************
# 114: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/9a09486553aba7160c7e5fa2602dba5193474e4c/input/resources/structuredefinition/SDOHCC-TaskForReferralManagement.xml
# *************************************
# *************************************
# 115: https://raw.githubusercontent.com/HL7/cqf-measures/052f80bbd153edf919294965518adb14c3cfeb81/input/resources/measure-vte-1-FHIR.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cqf-measures/052f80bbd153edf919294965518adb14c3cfeb81/input/resources/measure-vte-1-FHIR.json:
#  {
#   "resourceType": "Measure",
#   "id": "measure-vte-1-FHIR",
#   "meta": {
#
# *************************************
# 116: https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/composition/composition-bser-referral-feedback.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/bser/c6e5ec087522d6b5d90e21568f241d3da3a93ae0/input/resources/composition/composition-bser-referral-feedback.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Composition
#     xmlns="http://hl7.o
# *************************************
# 117: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-provenance.xml
# *************************************
# *************************************
# 118: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-provenance.json
# *************************************
# *************************************
# 119: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/91d04de61a6b62442d74544e895c04cc55304603/input/resources/task/SDOHCC-TaskReferralManagementOrderFulfillmentAcceptedExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/91d04de61a6b62442d74544e895c04cc55304603/input/resources/task/SDOHCC-TaskReferralManagementOrderFulfillmentAcceptedExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 120: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/procedure/SDOHCC-ProcedureFoodPantryApplicationAssistanceExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/procedure/SDOHCC-ProcedureFoodPantryApplicationAssistanceExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Procedure
#     xmlns="http://hl7.org
# *************************************
# 121: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/procedure/SDOHCC-ProcedureSummerFoodProgramApplicationAssistanceExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/procedure/SDOHCC-ProcedureSummerFoodProgramApplicationAssistanceExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Procedure
#     xmlns="http://hl7.org
# *************************************
# 122: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/task/SDOHCC-TaskReferralManagementOrderSubtaskAcceptedExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/task/SDOHCC-TaskReferralManagementOrderSubtaskAcceptedExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 123: https://raw.githubusercontent.com/HL7/case-reporting/d360bd2c79e055336c230e9e9ba8a22be9087699/input/resources/codesystem/us-ph-triggerdefinition-namedevents.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/d360bd2c79e055336c230e9e9ba8a22be9087699/input/resources/codesystem/us-ph-triggerdefinition-namedevents.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CodeSystem
#     xmlns="http://hl7.or
# *************************************
# 124: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/task/MedicationRequest.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/task/MedicationRequest.json:
#  {
# 	"resourceType": "Task",
# 	"id": "MedicationRequest",
# 	"meta": {
# 		"versio
# *************************************
# 125: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/OrderExtension.xml
# *************************************
# *************************************
# 126: https://raw.githubusercontent.com/HL7/fhir-us-ph-library/fe84a61ca4f1e8a6b0579c1e23885560b2e2b9ab/input/resources/plandefinition/us-ph-plandefinition-alt-expression-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-us-ph-library/fe84a61ca4f1e8a6b0579c1e23885560b2e2b9ab/input/resources/plandefinition/us-ph-plandefinition-alt-expression-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <PlanDefinition
#     xmlns="http://hl
# *************************************
# 127: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/task/SDOHCC-TaskReferralManagementOrderSubtaskCompletedExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/task/SDOHCC-TaskReferralManagementOrderSubtaskCompletedExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 128: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/task/SDOHCC-TaskReferralManagementOrderFulfillmentCompletedExample.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/cfd31cd4bbb9dc7dd6a29ae509c63b45651276f7/input/resources/task/SDOHCC-TaskReferralManagementOrderFulfillmentCompletedExample.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 129: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/task/MedicationRequest.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/task/MedicationRequest.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Task
#     xmlns="http://hl7.org/fhir
# *************************************
# 130: https://raw.githubusercontent.com/HL7/cancer-reporting/4cf770af9a2e2d7d99469c0f6d48a56c177808ec/input/resources/procedure/path-specimen.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cancer-reporting/4cf770af9a2e2d7d99469c0f6d48a56c177808ec/input/resources/procedure/path-specimen.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Procedure
#     xmlns="http://hl7.org
# *************************************
# 131: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/provenance/Home-Health-Order.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/provenance/Home-Health-Order.json:
#  {
# 	"resourceType": "Provenance",
# 	"id": "Home-Health-Order",
# 	"meta": {
# 		"
# *************************************
# 132: https://raw.githubusercontent.com/HL7/fhir-sdoh-clinicalcare/9a09486553aba7160c7e5fa2602dba5193474e4c/input/resources/structuredefinition/SDOHCC-Procedure.xml
# *************************************
# *************************************
# 133: https://raw.githubusercontent.com/HL7/cancer-reporting/4cf770af9a2e2d7d99469c0f6d48a56c177808ec/input/resources/specimen/adrenal-example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cancer-reporting/4cf770af9a2e2d7d99469c0f6d48a56c177808ec/input/resources/specimen/adrenal-example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Specimen
#     xmlns="http://hl7.org/
# *************************************
# 134: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/provenance/Home-Health-Order.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/provenance/Home-Health-Order.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Provenance
#     xmlns="http://hl7.or
# *************************************
# 135: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/composition/Dental-2-Med-Consult.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/composition/Dental-2-Med-Consult.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Composition
#     xmlns="http://hl7.o
# *************************************
# 136: https://raw.githubusercontent.com/HL7/ccda-on-fhir-r4/d1d3766a573195b583f849ae7ed9068b85d03518/input/resources/structuredefinition/OrderExtension.xml
# *************************************
# *************************************
# 137: https://raw.githubusercontent.com/HL7/dme-orders/ad88710d1d1e694e428f7c9ad83f6e815c1d6f99/input/resources/structuredefinition/PAOX-messageheader.json
# *************************************
# *************************************
# 138: https://raw.githubusercontent.com/HL7/fhir-us-ph-library/f3984581d41bfacba885329169ce64dee6fb3d1c/input/resources/codesystem/us-ph-triggerdefinition-namedevents.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-us-ph-library/f3984581d41bfacba885329169ce64dee6fb3d1c/input/resources/codesystem/us-ph-triggerdefinition-namedevents.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <CodeSystem
#     xmlns="http://hl7.or
# *************************************
# 139: https://raw.githubusercontent.com/HL7/case-reporting/ec6636318e04ccd697a5e2aec83ab558058656e4/input/resources/bundle/bundle-eicr-document-zika.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/ec6636318e04ccd697a5e2aec83ab558058656e4/input/resources/bundle/bundle-eicr-document-zika.xml:
#  <Bundle xmlns="http://hl7.org/fhir">
#   <id value="bundle-eicr-document-zika
# *************************************
# 140: https://raw.githubusercontent.com/HL7/dme-orders/b11211e5aa26ee2e1343f13e0f3cc088436026cf/input/resources/structuredefinition/PAOX-messageheader.xml
# *************************************
# *************************************
# 141: https://raw.githubusercontent.com/HL7/davinci-crd/f1ab653cba5278d190dc132d78407e75aa028e8c/input/resources/StructureDefinition-ext-coverage-information.xml
# *************************************
# *************************************
# 142: https://raw.githubusercontent.com/HL7/bser/2d0b7229c642c812eb8ab16924f88ccf3c4445e4/input/resources/bundle/bundle-bser-referral-feedback-document-bundle-eve-everywoman.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/bser/2d0b7229c642c812eb8ab16924f88ccf3c4445e4/input/resources/bundle/bundle-bser-referral-feedback-document-bundle-eve-everywoman.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Bundle xmlns="http://hl7.org/fhir">
# *************************************
# 143: https://raw.githubusercontent.com/HL7/case-reporting/ec6636318e04ccd697a5e2aec83ab558058656e4/input/resources/bundle/bundle-ecr-message-zika.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/ec6636318e04ccd697a5e2aec83ab558058656e4/input/resources/bundle/bundle-ecr-message-zika.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Bundle xmlns="http://hl7.org/fhir">
# *************************************
# 144: https://raw.githubusercontent.com/HL7/cqf-measures/c8e3f91e5ca0da4b8c0cd6c3c97fec54f2f3d8f1/input/resources/measure-BCS-FHIR-depends.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cqf-measures/c8e3f91e5ca0da4b8c0cd6c3c97fec54f2f3d8f1/input/resources/measure-BCS-FHIR-depends.json:
#  {
#   "resourceType": "Measure",
#   "id": "BreastCancerScreeningFHIR",
#   "meta
# *************************************
# 145: https://raw.githubusercontent.com/HL7/case-reporting/3552bb5688b856ef6b5d7cb22c1f1bd45b705696/input/resources/composition/composition-eicr-zika-manual-initiation.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/case-reporting/3552bb5688b856ef6b5d7cb22c1f1bd45b705696/input/resources/composition/composition-eicr-zika-manual-initiation.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Composition xmlns="http://hl7.org/f
# *************************************
# 146: https://raw.githubusercontent.com/HL7/fhir-order-catalog/111f316d66f054e5b8f3fbb7a51d5b1ce93633ca/input/resources/LabProcedureDefinition.StructureDefinition.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/fhir-order-catalog/111f316d66f054e5b8f3fbb7a51d5b1ce93633ca/input/resources/LabProcedureDefinition.StructureDefinition.xml:
#  <?xml version="1.0" encoding="utf-8"?>
# <StructureDefinition xmlns="http://h
# *************************************
# 147: https://raw.githubusercontent.com/HL7/cqf-measures/052f80bbd153edf919294965518adb14c3cfeb81/input/resources/Measure-PVSComponent.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cqf-measures/052f80bbd153edf919294965518adb14c3cfeb81/input/resources/Measure-PVSComponent.xml:
#  <Measure xmlns="http://hl7.org/fhir">
#    <id value="PVSComponent"></id>
#
# *************************************
# 148: https://raw.githubusercontent.com/HL7/us-odh/58747c031d2ea416622b3fdafb2b61a45051e302/input/resources/structuredefinition/odh-CombatZonePeriod.json
# *************************************
# *************************************
# 149: https://raw.githubusercontent.com/HL7/us-odh/58747c031d2ea416622b3fdafb2b61a45051e302/input/resources/structuredefinition/odh-RetirementDate.json
# *************************************
# *************************************
# 150: https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/bundle/Complete-Dental-Consult-Note-Document-Bundle-Example.xml
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/dental-data-exchange/244dde85c04fa0b6d76e45bd0f37f62328891b2c/input/resources/bundle/Complete-Dental-Consult-Note-Document-Bundle-Example.xml:
#  <?xml version="1.0" encoding="UTF-8"?>
# <Bundle
#     xmlns="http://hl7.org/fh
# *************************************
# 151: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Operative-Note.xml
# *************************************
# *************************************
# 152: https://raw.githubusercontent.com/HL7/cqf-measures/c8e3f91e5ca0da4b8c0cd6c3c97fec54f2f3d8f1/input/resources/measure-exm130-FHIR.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cqf-measures/c8e3f91e5ca0da4b8c0cd6c3c97fec54f2f3d8f1/input/resources/measure-exm130-FHIR.json:
#  {
#   "resourceType": "Measure",
#   "id": "measure-exm130-FHIR",
#   "meta": {
#
# *************************************
# 153: https://raw.githubusercontent.com/HL7/US-Core/240ca78bb533af445bceb6b39bbfe63a6e066124/input/resources/capabilitystatement-us-core-server.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/US-Core/240ca78bb533af445bceb6b39bbfe63a6e066124/input/resources/capabilitystatement-us-core-server.json:
#  {
#   "resourceType": "CapabilityStatement",
#   "id": "us-core-server",
#   "tex
# *************************************
# 154: https://raw.githubusercontent.com/HL7/US-Core/240ca78bb533af445bceb6b39bbfe63a6e066124/input/resources/capabilitystatement-us-core-client.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/US-Core/240ca78bb533af445bceb6b39bbfe63a6e066124/input/resources/capabilitystatement-us-core-client.json:
#  {
#   "resourceType": "CapabilityStatement",
#   "id": "us-core-client",
#   "tex
# *************************************
# 155: https://raw.githubusercontent.com/HL7/cqf-measures/c8e3f91e5ca0da4b8c0cd6c3c97fec54f2f3d8f1/input/resources/measure-exm124-FHIR.json
# *************************************
# Error parsing https://raw.githubusercontent.com/HL7/cqf-measures/c8e3f91e5ca0da4b8c0cd6c3c97fec54f2f3d8f1/input/resources/measure-exm124-FHIR.json:
#  {
#   "resourceType": "Measure",
#   "id": "measure-exm124-FHIR",
#   "meta": {
#
# *************************************
# 156: https://raw.githubusercontent.com/HL7/ccda-on-fhir/2f232ddaf90836f0abb70941c7989f2fd34e1cfa/input/resources/structuredefinition/Care-Plan-Document.xml
# *************************************
# Total ServiceRequest Profiles = 22
# ['http://hl7.org/fhir/us/dental-data-exchange/dental-servicerequest',
#  'http://hl7.org/fhir/us/ecr/StructureDefinition/eicr-servicerequest',
#  'http://hl7.org/fhir/uv/sdc/StructureDefinition/sdc-servicerequest',
#  'http://hl7.org/fhir/us/mcc/StructureDefinition/MCCServiceRequest',
#  'http://hl7.org/fhir/us/phcp/StructureDefinition/PhCP-ServiceRequest',
#  'http://hl7.org/fhir/us/cancer-reporting/StructureDefinition/us-pathology-service-request',
#  'http://hl7.org/fhir/us/bser/StructureDefinition/BSeR-ReferralServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/sdoh-clinicalcare/StructureDefinition/SDOHCC-ServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-servicerequest',
#  'http://hl7.org/fhir/us/sdoh-clinicalcare/StructureDefinition/SDOHCC-ServiceRequest',
#  'http://hl7.org/fhir/us/dental-data-exchange/dental-servicerequest',
#  'http://hl7.org/fhir/us/bser/StructureDefinition/BSeR-ReferralServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/phcp/StructureDefinition/PhCP-ServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/ecr/StructureDefinition/eicr-servicerequest',
#  'http://hl7.org/fhir/us/mcc/StructureDefinition/MCCServiceRequest',
#  'http://hl7.org/fhir/us/cancer-reporting/StructureDefinition/us-pathology-service-request',
#  'http://hl7.org/fhir/uv/sdc/StructureDefinition/sdc-servicerequest',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-servicerequest']
# Total ServiceRequest Profiles with ['ServiceRequest.reasonCode', 'ServiceRequest.reasonReference'] in differential = 12
# ['http://hl7.org/fhir/us/dental-data-exchange/dental-servicerequest',
#  'http://hl7.org/fhir/uv/sdc/StructureDefinition/sdc-servicerequest',
#  'http://hl7.org/fhir/us/bser/StructureDefinition/BSeR-ReferralServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/sdoh-clinicalcare/StructureDefinition/SDOHCC-ServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/sdoh-clinicalcare/StructureDefinition/SDOHCC-ServiceRequest',
#  'http://hl7.org/fhir/us/dental-data-exchange/dental-servicerequest',
#  'http://hl7.org/fhir/us/bser/StructureDefinition/BSeR-ReferralServiceRequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/us/dme-orders/StructureDefinition/PAOX-servicerequest',
#  'http://hl7.org/fhir/uv/sdc/StructureDefinition/sdc-servicerequest']
# Total Files = 156

# %%
    with get(i, headers=headers) as response:
        if response.status_code == 200:
     
            try:
                if response.json()['type'] == 'ServiceRequest':
                    r_json = response.json()
                    
            except JSONDecodeError:
                print(f'>>>>>>>>>>>>>>>>JSONDecodeError: {i}')
                print(response.text[:75])
                data = response.text.replace('<?xml version="1.0" encoding="UTF-8"?>','',1) # check all spellings
                print(data[:75])
                try:
                    r_json = StructureDefinition.parse_raw(data, content_type="text/xml")
                except:
                    print('XML Parse Failed')
                    print(response.text[:75])
                    break
                print(f'{r_json.id}\n <<<<<<<<<<<<<<<<<<<')
        
            except KeyError:
                    print(f'KeyError: {i}')
                    print(response.json()['resourceType'])
            else:
                print(f'{count}: {i}')
                count += 1
                element_paths = [e["path"] for e in r_json["differential"]["element"]]
                if any(item in element_paths for item in test_me):
                        print(f'indication element found!!')
                        # my_element = [e for e in response.json()["differential"]["element"] if e["path"] in test_me]
                        # print(f'my_element = {my_element}')
        else:
            print(f'{count}: {i} is not valid')
            count += 1
# Out:
#   Input In [6]
# SyntaxError: 'break' outside loop

# %% [markdown]
# loop through all sd and print out the element the element you want
#
# filter on the element properties you want

# %%
def open_file(in_path, f_name): # get files
    with open(f'{in_path}/{f_name}', encoding="utf8") as f:
        r = f.read()
        return(json.loads(r))
constraints = {}
sps = []
test_resources = [
"CareTeam",
"Condition",
"DiagnosticReport",
"Encounter",
"Goal",
"Location",
"Observation",
"Organization",
"Patient",
"Practitioner",
"PractitionerRole",
"Procedure",
"RelatedPerson",
"ServiceRequest",
]
for i in us_core_files: 
    
    sp_dict = open_file(us_core,i)
    
    try:
        assert sp_dict['base'][0] in test_resources
        #sps.append({"base":sp_dict['base'][0],"code":sp_dict['code']})
        sps.append(sp_dict['base'][0]  + " `" + sp_dict['code'] + "` search parameter ")
    except:
        pass

for sp in sorted(sps):
    print("   - "+sp)
