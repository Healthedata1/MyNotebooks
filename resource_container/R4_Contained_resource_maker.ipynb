# %% [markdown]
# ## Script to bundle all resources in folder as a batch, transaction, collection, or message
#
# - python version 3.6+
# - get data from folder
# - bundle
# - validate and save

# %%
from json import load, dumps, loads
from IPython import display as D
from requests import get, post, put
from IPython.display import display, Markdown, HTML
from fhir.resources.bundle import Bundle as B, BundleEntry as BE, BundleEntryRequest as BER, BundleEntryResponse as BERes, BundleEntrySearch as BES 
import os, uuid
from datetime import datetime
from pprint import pprint

# bundle_id = 'cdex-data-requirements-bundle-example1'
bundle_id = 'cdex-scenario1-load-transaction-bundle'
bundle_type = 'transaction'

# %% [markdown]
# ###  write to file

# %%
def write_file(r): # write file
    #out_path = '/Users/ehaas/Documents/FHIR/Davinci-DEQM/source/examples/'  # append forward slash
    out_path ='r4'
    with open(f'{out_path}/Bundle-{bundle_id}.json', 'w') as f:
        f.write(r)

# %% [markdown]
# ### open json file and return as dict

# %%
def open_file(f_name): # get files
    with open(f'{in_path}/{f_name}') as f:
        r = f.read()
        return(loads(r))

# %% [markdown]
# ### Get files in current path

# %%
in_path = 'r4'
files = [x for x in os.listdir(in_path) if x.endswith(".json") and not x.startswith("Bundle")]
pprint(files)
# Out:
# ['example-1-patient.json',
#  'example-1-imaging-study.json',
#  'example-1-progress-note.json',
#  'example-1-operative-note.json',
#  'example-1-surgical-note.json']

# %% [markdown]
# ### create Bundle 'b'  change the id for unique Bundles!!!

# %%
b = B(
    id = bundle_id,
    type = bundle_type,
    timestamp = datetime.now().astimezone().isoformat(),
)
b.json()
# Out:
# '{"resourceType":"Bundle","id":"cdex-scenario1-load-transaction-bundle","type":"transaction","timestamp":"2023-07-14T17:08:24.616959-07:00"}'

# %% [markdown]
# ### Add resources to bundle
#
# #### Create a mapping of ids to uuids
#
# - get id from resource
# - map to uuid (create a dict of {urn, (old_ref)})
# - remove id element
# - replace all old refs in bundle with new urns

# %%
b.entry = []
ref_map = {}
for i in files:
    r = open_file(i)
    # remove text adn id elements from Bundle
    r.pop('text', None) # remove id elements from Bundle
    old_id = r.pop('id',None) # remove text elements from Bundle
    try:
        print(r['url'])
        new_urn = r['url']
    except:
        new_urn = uuid.uuid1().urn # new urn for resource
    ref_map[new_urn] = f'{r["resourceType"]}/{old_id}'
    # print( id_map , '\n')
    e = dict( 
        fullUrl = new_urn,
        resource = r,
      )
    print(e)
    if bundle_type in ['transaction', 'batch']:
        e['request'] = dict(
                    method = 'POST',
                    url = r['resourceType']
                    )
                    
    
    b.entry.append(e)
b_json = b.json()
for new_ref, old_ref in ref_map.items():
    b_json = b_json.replace(old_ref,new_ref)
print(b_json)
write_file(b_json)
# Out:
# {'fullUrl': 'urn:uuid:b75f94a8-22a3-11ee-b00d-daaf18ab2cba', 'resource': {'resourceType': 'Patient', 'meta': {'profile': ['http://hl7.org/fhir/us/davinci-cdex/StructureDefinition/cdex-patient-demographics']}, 'identifier': [{'use': 'usual', 'type': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-hrex/CodeSystem/hrex-temp', 'code': 'UMB', 'display': 'Member Number'}], 'text': 'Member Number'}, 'system': 'http://example.org/cdex/payer/member-ids', 'value': 'Member123'}], 'name': [{'family': 'Shaw', 'given': ['Amy']}], 'birthDate': '1987-02-20'}}
# {'fullUrl': 'urn:uuid:b75fcf7c-22a3-11ee-b00d-daaf18ab2cba', 'resource': {'resourceType': 'DocumentReference', 'status': 'current', 'type': {'coding': [{'system': 'http://loinc.org', 'code': '18748-4', 'display': 'Diagnostic imaging study'}], 'text': 'Imaging Study'}, 'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category', 'code': 'clinical-note', 'display': 'Clinical Note'}], 'text': 'Clinical Note 2'}], 'subject': {'reference': 'Patient/example', 'identifier': {'system': 'http://example.org/cdex/payer/member-ids', 'value': 'Member123'}, 'display': 'Amy Shaw'}, 'date': '2023-07-14T16:21:44Z', 'content': [{'attachment': {'contentType': 'application/pdf', 'data': '... ...', 'title': 'Example Imaging Study'}}]}}
# {'fullUrl': 'urn:uuid:b7602760-22a3-11ee-b00d-daaf18ab2cba', 'resource': {'resourceType': 'DocumentReference', 'status': 'current', 'type': {'coding': [{'system': 'http://loinc.org', 'code': '11506-3', 'display': 'Progress note'}], 'text': 'Progress note'}, 'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category', 'code': 'clinical-note', 'display': 'Clinical Note'}], 'text': 'Clinical Note 1'}], 'subject': {'reference': 'urn:uuid:5807abe6-229c-11ee-b00d-daaf18ab2cba', 'identifier': {'system': 'http://example.org/cdex/payer/member-ids', 'value': 'Member123'}, 'display': 'Amy Shaw'}, 'date': '2021-12-03T18:30:56-08:00', 'content': [{'attachment': {'contentType': 'application/pdf', 'data': '...', 'title': 'Example Progress Note'}}]}}
# {'fullUrl': 'urn:uuid:b7607184-22a3-11ee-b00d-daaf18ab2cba', 'resource': {'resourceType': 'DocumentReference', 'status': 'current', 'type': {'coding': [{'system': 'http://loinc.org', 'code': '11504-8', 'display': 'Surgical operation note'}], 'text': 'Operative Note'}, 'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category', 'code': 'clinical-note', 'display': 'Clinical Note'}], 'text': 'Clinical Note 2'}], 'subject': {'reference': 'Patient/example', 'identifier': {'system': 'http://example.org/cdex/payer/member-ids', 'value': 'Member123'}, 'display': 'Amy Shaw'}, 'date': '2023-07-14T16:21:44Z', 'content': [{'attachment': {'contentType': 'text/xml', 'data': '...', 'hash': '026d568297832e6e083e96549041a72aa383bb23', 'title': 'Example CCDA'}}]}}
# {'fullUrl': 'urn:uuid:b760ae1a-22a3-11ee-b00d-daaf18ab2cba', 'resource': {'resourceType': 'DocumentReference', 'status': 'current', 'type': {'coding': [{'system': 'http://loinc.org', 'code': '11504-8', 'display': 'Surgical operation note'}], 'text': 'Surgical Note'}, 'category': [{'coding': [{'system': 'http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category', 'code': 'clinical-note', 'display': 'Clinical Note'}], 'text': 'Clinical Note 1'}], 'subject': {'reference': 'Patient/example', 'identifier': {'system': 'http://example.org/cdex/payer/member-ids', 'value': 'Member123'}, 'display': 'Amy Shaw'}, 'date': '2023-07-14T16:21:44Z', 'content': [{'attachment': {'contentType': 'application/pdf', 'data': '...', 'title': 'Example Surgical Note'}}]}}
# {"resourceType":"Bundle","id":"cdex-scenario1-load-transaction-bundle","type":"transaction","timestamp":"2023-07-14T17:08:24.616959-07:00","entry":[{"fullUrl":"urn:uuid:b75f94a8-22a3-11ee-b00d-daaf18ab2cba","resource":{"resourceType":"Patient","meta":{"profile":["http://hl7.org/fhir/us/davinci-cdex/StructureDefinition/cdex-patient-demographics"]},"identifier":[{"use":"usual","type":{"coding":[{"system":"http://hl7.org/fhir/us/davinci-hrex/CodeSystem/hrex-temp","code":"UMB","display":"Member Number"}],"text":"Member Number"},"system":"http://example.org/cdex/payer/member-ids","value":"Member123"}],"name":[{"family":"Shaw","given":["Amy"]}],"birthDate":"1987-02-20"},"request":{"method":"POST","url":"Patient"}},{"fullUrl":"urn:uuid:b75fcf7c-22a3-11ee-b00d-daaf18ab2cba","resource":{"resourceType":"DocumentReference","status":"current","type":{"coding":[{"system":"http://loinc.org","code":"18748-4","display":"Diagnostic imaging study"}],"text":"Imaging Study"},"category":[{"coding":[{"system":"http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category","code":"clinical-note","display":"Clinical Note"}],"text":"Clinical Note 2"}],"subject":{"reference":"urn:uuid:b75f94a8-22a3-11ee-b00d-daaf18ab2cba","identifier":{"system":"http://example.org/cdex/payer/member-ids","value":"Member123"},"display":"Amy Shaw"},"date":"2023-07-14T16:21:44Z","content":[{"attachment":{"contentType":"application/pdf","data":"... ...","title":"Example Imaging Study"}}]},"request":{"method":"POST","url":"DocumentReference"}},{"fullUrl":"urn:uuid:b7602760-22a3-11ee-b00d-daaf18ab2cba","resource":{"resourceType":"DocumentReference","status":"current","type":{"coding":[{"system":"http://loinc.org","code":"11506-3","display":"Progress note"}],"text":"Progress note"},"category":[{"coding":[{"system":"http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category","code":"clinical-note","display":"Clinical Note"}],"text":"Clinical Note 1"}],"subject":{"reference":"urn:uuid:5807abe6-229c-11ee-b00d-daaf18ab2cba","identifier":{"system":"http://example.org/cdex/payer/member-ids","value":"Member123"},"display":"Amy Shaw"},"date":"2021-12-03T18:30:56-08:00","content":[{"attachment":{"contentType":"application/pdf","data":"...","title":"Example Progress Note"}}]},"request":{"method":"POST","url":"DocumentReference"}},{"fullUrl":"urn:uuid:b7607184-22a3-11ee-b00d-daaf18ab2cba","resource":{"resourceType":"DocumentReference","status":"current","type":{"coding":[{"system":"http://loinc.org","code":"11504-8","display":"Surgical operation note"}],"text":"Operative Note"},"category":[{"coding":[{"system":"http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category","code":"clinical-note","display":"Clinical Note"}],"text":"Clinical Note 2"}],"subject":{"reference":"urn:uuid:b75f94a8-22a3-11ee-b00d-daaf18ab2cba","identifier":{"system":"http://example.org/cdex/payer/member-ids","value":"Member123"},"display":"Amy Shaw"},"date":"2023-07-14T16:21:44Z","content":[{"attachment":{"contentType":"text/xml","data":"...","hash":"026d568297832e6e083e96549041a72aa383bb23","title":"Example CCDA"}}]},"request":{"method":"POST","url":"DocumentReference"}},{"fullUrl":"urn:uuid:b760ae1a-22a3-11ee-b00d-daaf18ab2cba","resource":{"resourceType":"DocumentReference","status":"current","type":{"coding":[{"system":"http://loinc.org","code":"11504-8","display":"Surgical operation note"}],"text":"Surgical Note"},"category":[{"coding":[{"system":"http://hl7.org/fhir/us/core/CodeSystem/us-core-documentreference-category","code":"clinical-note","display":"Clinical Note"}],"text":"Clinical Note 1"}],"subject":{"reference":"urn:uuid:b75f94a8-22a3-11ee-b00d-daaf18ab2cba","identifier":{"system":"http://example.org/cdex/payer/member-ids","value":"Member123"},"display":"Amy Shaw"},"date":"2023-07-14T16:21:44Z","content":[{"attachment":{"contentType":"application/pdf","data":"...","title":"Example Surgical Note"}}]},"request":{"method":"POST","url":"DocumentReference"}}]}
