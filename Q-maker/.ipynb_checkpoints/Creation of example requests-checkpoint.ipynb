# %% [markdown]
#  ## Create examples for IGs
#
#  - format examples
#  - run requests to create examples
#  - capture requests and responses as string files

# %%
import textwrap
from json import load, dumps
from pprint import pprint 
from requests import get, post, put
from IPython.display import display, Markdown
from pandas import *
import openpyxl

# %%
def get_data(name):
    #path = '/Users/ehaas/Documents/FHIR/Argo-Questionnaire/source/examples/'
    path = ''

    with open(f'{path}{name}.json', 'r') as f:
        r_json = f.read()
        
    return r_json

# %% [markdown]
# ### write file to folder

# %%
def write_file(name, data): # write file
    
     out_path = '/Users/ehaas/Documents/FHIR/Argo-Questionnaire/source/pages/_includes/'
     #out_path = ''
     with open(f'{out_path}{name}.md', 'w') as f:
        f.write(data)

# %% [markdown]
# ### Read list of examples from excel using Pandas

# %%
#in_path = '/Users/ehaas/Documents/FHIR/Argo-Questionnaire/source/examples/'
in_path = ''
in_file = 'argo-q-search-examples'


xls = ExcelFile(f'{in_path}{in_file}.xlsx')
df = read_excel(xls,'Sheet1')
examples = df.to_dict('records')
df
# Out:
#                name  action r_type                                    id  \
# 0          create_q    POST      q                                   NaN
# 1          update_q     PUT      q          questionnaire-example-search
# 2          delete_q  DELETE      q          questionnaire-example-delete
# 3        fetch_q_id     GET      q                                   NaN
# 4       fetch_q_url     GET      q                                   NaN
# 5       fetch_q_tit     GET      q                                   NaN
# 6   fetch_q_tit_ver     GET      q                                   NaN
# 7    fetch_q_status     GET      q                                   NaN
# 8   fetch_q_context     GET      q                                   NaN
# 9         create_qr    POST     qr                                   NaN
# 10        update_qr     PUT     qr  questionnaireresponse-example-search
# 11        delete_qr  DELETE     qr  questionnaireresponse-example-delete
# 12         batch_qr    POST    NaN                                   NaN
#
#                                     data   parameter_1  \
# 0              questionnaire-example-new           NaN
# 1           questionnaire-example-search           NaN
# 2                                    NaN           NaN
# 3                                    NaN           _id
# 4                                    NaN           url
# 5                                    NaN         title
# 6                                    NaN         title
# 7                                    NaN        status
# 8                                    NaN  context-code
# 9      questionnaireresponse-example-new           NaN
# 10  questionnaireresponse-example-search           NaN
# 11                                   NaN           NaN
# 12                       qr_batch_bundle           NaN
#
#                                               value_1 parameter_2  value_2  \
# 0                                                 NaN         NaN      NaN
# 1                                                 NaN         NaN      NaN
# 2                                                 NaN         NaN      NaN
# 3                        questionnaire-example-search         NaN      NaN
# 4   http://fhir.org/guides/argonaut-questionnaire/...         NaN      NaN
# 5                      Argonaut Questionnaire Sampler         NaN      NaN
# 6                      Argonaut Questionnaire Sampler     version    3.0.0
# 7                                              active         NaN      NaN
# 8                                                task       value  example
# 9                                                 NaN         NaN      NaN
# 10                                                NaN         NaN      NaN
# 11                                                NaN         NaN      NaN
# 12                                                NaN         NaN      NaN
#
#     parameter_3  value_3
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# 5           NaN      NaN
# 6           NaN      NaN
# 7           NaN      NaN
# 8           NaN      NaN
# 9           NaN      NaN
# 10          NaN      NaN
# 11          NaN      NaN
# 12          NaN      NaN

# %%
for e in examples[12:]:
    print(e)
# Out:
# {'name': 'batch_qr', 'action': 'POST', 'r_type': nan, 'id': nan, 'data': 'qr_batch_bundle', 'parameter_1': nan, 'value_1': nan, 'parameter_2': nan, 'value_2': nan, 'parameter_3': nan, 'value_3': nan}

# %% [markdown]
# ### display first part of response json - find a nice place to stop

# %%
def get_snippet(s):
    delimiters = [',',']','}','\n']
    for i in range(750,850):
        #print(i,s[i])
        if s[i] in delimiters:
            break

    return f'''{s[:i+1]}'''

# %%
def get_md_string_del(r):
    return f'''

**Request**

~~~
{r.request.method} {r.url}

User-Agent: {r.request.headers["User-Agent"]}
Accept: {r.request.headers["Accept"]}
Content-Type: {r.request.headers["Content-Type"]}
[other headers]
~~~

**Response**

~~~
Response Code: {r.status_code} ({r.reason})
[other headers]
~~~
'''

# %%
def get_md_string(r):
    r_json = dumps(r.json(),indent=3)
    #print(r_json)
    return f'''

**Request**

~~~
{r.request.method} {r.url}

User-Agent: {r.request.headers["User-Agent"]}
Accept: {r.request.headers["Accept"]}
Content-Type: {r.request.headers["Content-Type"]}
[other headers]
~~~

**Response**

~~~
Response Code: {r.status_code} ({r.reason})
Content-Type: {r.headers["Content-Type"]}
Content-Location: {r.headers["Content-Location"]}
[other headers]

    
{get_snippet(r_json)}
        ...[snipped for brevity]....
      
~~~
'''

# %%
def fetch(action, id, params, r_type, data):
    fhir_test_server = 'http://sqlonfhir-stu3.azurewebsites.net/fhir'
    
    headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }
    f_url = f'{fhir_test_server}/{r_type}/{id}' if id==id else f'{fhir_test_server}/{r_type}'
    
    if r_type == None:
        f_url = f'{fhir_test_server}'
    
    r = requests.request(action, f_url, params = params, headers = headers,data=data)
    print(r.status_code)
    print(r.reason)
    print(f'{r.request.method} {r.url}')
    #for k,v in r.headers.items():
    #    print(f'{k} = {v}')
    #for k,v in r.json().items():
    #    print(f'{k} = {v}')
    return r

# %%
for e in examples[12:]:  # slice on the latest additions to spreadsheet
    if e['r_type'] == 'q':
        r_type = 'Questionnaire'
    elif e['r_type'] == 'qr':
        r_type = 'QuestionnaireResponse'
    elif e['r_type'] != e['r_type']:
        r_type = None
    
    data={}
    if e['data'] == e['data']:
        data = get_data(e['data'])
    #print(data)
       
    params={}
    for i in range(1,4):
        #print(i)
        if e[f'parameter_{i}'] == e[f'parameter_{i}']:  # not nan
            params[e[f'parameter_{i}']] = e[f'value_{i}']
    print(f'params={params}')
    #continue
    r = fetch(e['action'],id=e['id'],params=params,r_type=r_type, data=data)
    
    # print(r.text)
    

    #print(example_string)
    md_str = get_md_string(r) if e['action'] != "DELETE" else get_md_string_del(r) 
    # display(D.Markdown(f'<h4>Example</h4>{md_str}'))
    
    write_file(name = f'example-{e["name"]}',data = md_str)
# Out:
# params={}
# 404
# Not Found
# POST http://sqlonfhir-stu3.azurewebsites.net/fhir/None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-479-f0e829c85a2b> in <module>
#      25
#      26     #print(example_string)
# ---> 27     md_str = get_md_string(r) if e['action'] != "DELETE" else get_md_string_del(r)
#      28     # display(D.Markdown(f'<h4>Example</h4>{md_str}'))
#      29
#
# <ipython-input-456-9a5218dff02b> in get_md_string(r)
#      28
#      29 ~~~
# ---> 30 '''
#
# ~/Documents/Python/Venv/Flask36/lib/python3.6/site-packages/requests/structures.py in __getitem__(self, key)
#      50
#      51     def __getitem__(self, key):
# ---> 52         return self._store[key.lower()][1]
#      53
#      54     def __delitem__(self, key):
#
# KeyError: 'content-location'
