# %% [markdown]
# ## Script to update FHIR Questionnaires
#
# - python version 3.6+
#
# - upload example as python dict from file
# - add new extensions
# - write to FHIR server as json

# %%
from json import load, dumps
from flatten_json import flatten
import pandas as pd
from csv import writer
import openpyxl
from IPython import display as D
from fhirclient.models import questionnaire as Q
from fhirclient.models import extension as X
from requests import get, post, put

# %%
in_path = '/Users/ehaas/Documents/FHIR/Argo-Questionnaire/source/examples/'
in_file = ['ASQ3','AUDIT','DAST','Housing','PHQ9','Sampler']
out_path = ''
q_parts = ['contained','item','text']

fhir_test_server = 'http://fhirtest.uhn.ca/baseDstu3'

headers = {
'Accept':'application/fhir+json',
'Content-Type':'application/fhir+json'
}

profile = 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/q'

# %% [markdown]
# ### Open Questionnaires as DICT files

# %%
def open_file(name): # get files
    with open(f'{in_path}{name}.json') as f:
        q = load(f)
        return(Q.Questionnaire(q))

# %% [markdown]
# ### Instantiate itemorder extension and assign value

# %%
def get_itemorder_x(i):
    itemorder_x = X.Extension({
    'url':'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder',
    'valueUnsignedInt': i
    })

    return itemorder_x

# %% [markdown]
# ### Validate the Resource
# Using the $validate operation, the example is validated by a FHIR Reference Server. The results are displayed below in the human readable text as xhtml.

# %%
# *********************** validate Resource ********************************
def validate(rjson):
    params = {
    'profile': profile
    }
    #   r = requests.post('https://httpbin.org/post', data = {'key':'value'})
    r = post(f'{fhir_test_server}/Questionnaire/$validate', params = params, headers = headers, data = rjson)
    # print(r.status_code)
    # view  output
    return r.json()["text"]["div"]

# %% [markdown]
# ### Write to file

# %%
def write_file(name, data): # write file
    with open(f'{out_path}{name}.json', 'w') as f:
        f.write(data)

# %% [markdown]
# ### add item order to each group and to each choice type questions

# %%
for name in in_file:
    # create fhirmodel
    q = open_file(name)
    
    print(q.id)
    for i,i_item in enumerate(q.item):
        print(f'i={i}, i_item={i_item.linkId}')
        # print(f'i_item.extension = {i_item.extension}')
        
        try:
            i_item.extension.append(get_itemorder_x(i))
        except AttributeError:
            i_item.extension = [get_itemorder_x(i)]
        for y in i_item.extension:
            pass # print(y.as_json())
        for j,j_item in enumerate(i_item.item):
            print(f'j={j}, j_item={j_item.linkId}')
            
            try:
                j_item.extension.append(get_itemorder_x(j))
            except AttributeError:
                j_item.extension = [get_itemorder_x(j)]
            for z in i_item.extension:
                pass # print(z.as_json())
            try:
                for jj, jopt in enumerate(j_item.option):
                    
                    print(f'jj={jj}, iopt={jopt.as_json()}')
                    
                    try:
                        jopt.extension.append(get_itemorder_x(jj))
                    except AttributeError:
                        jopt.extension = [get_itemorder_x(jj)]
                    print(f'jj={jj}, iopt={jopt.as_json()}')   
            except TypeError:
                pass
            
        rjson = dumps(q.as_json())
        # write files as json
        write_file(name, rjson)
        
        # todo validate,  run in rendering-tool.
        
        #validate
        #remove the text attribute first
        q.text = None
        rjson = dumps(q.as_json())
        display(D.HTML(f'<h1>Validation output</h1>{validate(rjson)}'))
# Out:
# questionnaire-example-asq3
# i=0, i_item=G0
# j=0, j_item=G0.d
# <h1>Validation output</h1><div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Questionnaire.meta.profile[0]]</td><td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/q" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.jurisdiction]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/jurisdiction (http://hl7.org/fhir/ValueSet/jurisdiction, and a code should come from this value set unless it has no suitable code) (codes = urn:iso:std:iso:3166#US)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].item.extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[1].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[1].option[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[1].option[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[2].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[2].option[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[2].option[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[3].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[3].option[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[3].option[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 		</table>
# 	</div>
# i=1, i_item=G1
# j=0, j_item=G1.4
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 2}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# j=1, j_item=G1.5
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 2}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# j=2, j_item=G1.6
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 2}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# <h1>Validation output</h1><div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Questionnaire.meta.profile[0]]</td><td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/q" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.jurisdiction]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/jurisdiction (http://hl7.org/fhir/ValueSet/jurisdiction, and a code should come from this value set unless it has no suitable code) (codes = urn:iso:std:iso:3166#US)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].item.extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[1].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[2].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[2].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[3].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[3].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[1].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[2].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[2].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[3].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[3].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[1].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[2].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[2].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[3].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[3].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item[1].option[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</t
# i=2, i_item=G2
# j=0, j_item=G2.4
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 2}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# j=1, j_item=G2.5
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 2}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# j=2, j_item=G2.6
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 10}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'yes', 'display': 'YES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 5}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'sometimes', 'display': 'SOMETIMES', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# jj=2, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 2}], 'valueCoding': {'code': 'not-yet', 'display': 'NOT YET', 'system': 'http://fhir.org/guides/argonaut-questionnaire/ValueSet/example-answerlist2'}}
# <h1>Validation output</h1><div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Questionnaire.meta.profile[0]]</td><td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/q" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.jurisdiction]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/jurisdiction (http://hl7.org/fhir/ValueSet/jurisdiction, and a code should come from this value set unless it has no suitable code) (codes = urn:iso:std:iso:3166#US)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].item.extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[1].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[2].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[2].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[3].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[1].option[3].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[1].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[2].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[2].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[3].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[2].option[3].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[1].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[1].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[2].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[2].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[3].extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item[3].option[3].extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# questionnaire-example-audit
# i=0, i_item=g1
# j=0, j_item=g1.d
# j=1, j_item=g1.q1
# j=2, j_item=g1.q2
# j=3, j_item=g1.q3
# j=4, j_item=g1.q4
# j=5, j_item=g1.q5
# j=6, j_item=g1.q6
# j=7, j_item=g1.q7
# j=8, j_item=g1.q8
# j=9, j_item=g1.q9
# j=10, j_item=g1.q10
# j=11, j_item=g1.d2
# <h1>Validation output</h1><div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Questionnaire.meta.profile[0]]</td><td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/q" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.contained[1].meta.profile[0]]</td>
#
#
#
# 						<td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/qcvs" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.contained[1].expansion.timestamp]</td>
#
#
#
# 						<td><pre>if a date has a time, it must have a timezone</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.contained[2].meta.profile[0]]</td>
#
#
#
# 						<td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/qcvs" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.contained[2].expansion.timestamp]</td>
#
#
#
# 						<td><pre>if a date has a time, it must have a timezone</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.contained[3].meta.profile[0]]</td>
#
#
#
# 						<td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/qcvs" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.contained[3].expansion.timestamp]</td>
#
#
#
# 						<td><pre>if a date has a time, it must have a timezone</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.jurisdiction]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/jurisdiction (http://hl7.org/fhir/ValueSet/jurisdiction, and a code should come from this value set unless it has no suitable code) (codes = urn:iso:std:iso:3166#US)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.code]</td>
#
#
#
# 						<td><pre>The Coding references a value set, not a code system ("http://loinc.org")</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.code]</td>
#
#
#
# 						<td><pre>The Coding references a value set, not a code system ("http://loinc.org")</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[2].code]</td>
#
#
#
# 						<td><pre>The Coding references a value set, not a code system ("http://loinc.org")</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[2].code]</td>
#
#
#
# 						<td><pre>Error null validating Coding</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item.item[2].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[2].options.contained.expansion.timestamp]</td>
#
#
#
# 						<td><pre>if a date has a time, it must have a timezone</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[3].code]</td>
#
#
#
# 						<td><pre>The Coding references a value set, not a code system ("http://loinc.org")</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[3].options.contained.expansion.timestamp]</td>
#
#
#
# 						<td><pre>if a date has a time, it must have a timezone</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[4].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[4].code]</td>
#
#
#
# 						<td><pre>The Coding references a value set, not a code system ("http://loinc.org")</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[5].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[6].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[7].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[8].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[9].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[10].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Questionnaire.item.item[10].options.contained.expansion.timestamp]</td>
#
#
#
# 						<td><pre>if a date has a time, it must have a timezone</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item.item[11].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# questionnaire-example-dast
# i=0, i_item=g1
# j=0, j_item=g1.d
# j=1, j_item=g1.q1
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# j=2, j_item=g1.q2
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# j=3, j_item=g1.q3
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 1}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# j=4, j_item=g1.q4
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=0, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 0}, {'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder', 'valueUnsignedInt': 0}], 'valueCoding': {'code': 'LA 32-8 ', 'display': 'No', 'system': 'http://loinc.org'}}
# jj=1, iopt={'extension': [{'url': 'http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score', 'valueDecimal': 1}], 'valueCoding': {'code': 'LA33-6 ', 'display': 'Yes', 'system': 'http://loinc.org'}}
# ...
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.jurisdiction]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/jurisdiction (http://hl7.org/fhir/ValueSet/jurisdiction, and a code should come from this value set unless it has no suitable code) (codes = urn:iso:std:iso:3166#US)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].item.extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[1].item.text]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[2].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[3].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[4].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[4].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[4].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[4].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[5].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[5].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[5].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[5].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[6].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[6].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[6].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[6].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[7].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[7].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[7].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[7].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[8].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-qu
# i=12, i_item=g13
# j=0, j_item=g13.q1
# <h1>Validation output</h1><div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Questionnaire.meta.profile[0]]</td><td><pre>StructureDefinition reference "http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/q" could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.jurisdiction]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/jurisdiction (http://hl7.org/fhir/ValueSet/jurisdiction, and a code should come from this value set unless it has no suitable code) (codes = urn:iso:std:iso:3166#US)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[1].item.extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[1].item.text]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[2].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[2].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[3].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[3].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[4].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[4].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[4].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[4].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[5].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[5].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[5].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[5].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[6].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[6].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[6].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[6].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[7].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Questionnaire.item[7].prefix]</td>
#
#
#
# 						<td><pre>value should not start or finish with whitespace</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[7].item.extension[1]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-score</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[7].item.extension[2]]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-questionnaire/StructureDefinition/extension-itemOrder</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Questionnaire.item[8].extension]</td>
#
#
#
# 						<td><pre>Unknown extension http://fhir.org/guides/argonaut-qu

# %% [markdown]
# TODO:
#
# - run in rendering-tool
# - change to timelimit to timeLimit
# - not part of QR - edit this out
# - udpate comments change impossible to difficult
