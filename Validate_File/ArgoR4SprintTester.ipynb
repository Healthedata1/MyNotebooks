# %% [markdown]
# ## Validate ARGO R4 Resources from Servers
#
# - Get Resources
# - Load into R4 IG
# - Run IG
# - Review QA report for Examples
#
# (Python 3.7)

# %% [markdown]
# ### Import modules and asign globals

# %%
import os #os module imported here
from json import load, dumps, loads
from IPython import display as D
from requests import get, post, put
from IPython.display import display, Markdown, HTML
from pathlib import Path
from pandas import *
from collections import namedtuple

#Globals

source_path = '/Users/ehaas/Documents/FHIR/USCoreR4Validator'
examples_path = '/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples'


headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }

# US Core R4 Profiles
profiles ={
'CareTeam': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-careteam',
'MedicationStatement': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-medicationstatement',
'Device': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-device',
'Practitioner': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-practitioner',
'Patient': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient',
'Immunization': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-immunization',
'Observation1': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-smokingstatus',
'DocumentReference': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-documentreference',
'MedicationRequest': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-medicationrequest',
'Condition': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition',
'Encounter': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter',
'Organization': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-organization',
'Observation2': 'http://hl7.org/fhir/us/core/StructureDefinition/pediatric-weight-for-height',
'Procedure': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-procedure',
'Medication': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-medication',
'Observation3': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-lab',
'DiagnosticReport1': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note',
'PractitionerRole': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-practitionerrole',
'CarePlan': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-careplan',
'Goal': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-goal',
'Location': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-location',
'Observation4': 'http://hl7.org/fhir/us/core/StructureDefinition/pediatric-bmi-for-age',
'DiagnosticReport2': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab',
'AllergyIntolerance': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-allergyintolerance',
}

f_servers = dict(epic='https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/R4/')

# %% [markdown]
# ### Get examples from FHIR Server
#
# - import data from spreadsheet
# - convert to pandas df and access using dot notation

# %%
server = 'epic'  # sheet name = server
xls = ExcelFile('test_resources.xlsx')
df = read_excel(xls,server,na_false = False)

df
# Out:
#         resource_type                                                 id
# 0             Patient                           eroCd17NbCffM3E3WXi7eOQ3
# 1        Practitioner                           e7D.u41Zv3VPrLmUp-mWnrQ3
# 2        Organization                           enRyWnSP963FYDpoks4NHOA3
# 3  AllergyIntolerance                           eyHIVsZwhzaZhX9XvFesx5A3
# 4           Encounter  ehoN2kZnYuW5z0Di4Kkno5w3,eiSX3g2gt4tJIs7-6h7nJ...

# %% [markdown]
# ### Add meta profile to example
#
# - for each resource type fetching instance
#   - instance are comma separated list of ids
# - convert json to dict
# - insert profile
# - convert back to json
# - save as example in examples folder in ig publisher

# %%
for i in df.itertuples(index=True):
    for j in i.id.split(','):
        print(i.resource_type,j)
        params = dict(
            _id = j
            )
        # Open Server
        r = get(f'{f_servers[server]}{i.resource_type}/{j}', headers = headers)
        fhir_d = r.json() if r.status_code==200 else None
        print(r.status_code)

        if r.status_code!=200:
            print(f'Fetching of {f_servers[server]}{i.resource_type}/{j} failed: Status code= {r.status_code}')
            r = get(f'{f_servers[server]}{i.resource_type}',params = params, headers = headers ) # try other syntax

            fhir_d = r.json()['entry'][0]['resource'] if r.status_code==200 else None #unbundle
            # wait for error to do try pattern
            print(r.status_code)
        if r.status_code!=200:
            print(f'Seaching using {f_servers[server]}{i.resource_type}?_id={j} failed: Status code= {r.status_code}')     
        else: # r.status_code==200
            try:
                fhir_d['meta']['profile'].append(profiles[i.resource_type])
            except KeyError:
                fhir_d['meta']= dict(profile = [profiles[i.resource_type]])
            fhir_json = dumps(fhir_d, indent=4 )
            print(f'{"*"*10} {server}-{fhir_d["resourceType"].lower()}-{fhir_d["id"]}.json {"*"*10}')
            print(fhir_json)
            p = Path(examples_path) / f'{server}-{fhir_d["resourceType"].lower()}-{fhir_d["id"]}.json'
            #print(p)
            p.write_text(fhir_json, encoding='utf-8')
            print('writing to examples folder......')
# Out:
# Patient eroCd17NbCffM3E3WXi7eOQ3
# 200
# ********** epic-patient-eroCd17NbCffM3E3WXi7eOQ3.json **********
# {
#     "resourceType": "Patient",
#     "id": "eroCd17NbCffM3E3WXi7eOQ3",
#     "active": true,
#     "gender": "male",
#     "birthDate": "1978-12-11",
#     "deceasedBoolean": false,
#     "extension": [
#         {
#             "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#             "valueCode": "M"
#         },
#         {
#             "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#             "extension": [
#                 {
#                     "url": "ombCategory",
#                     "valueCoding": {
#                         "system": "http://hl7.org/fhir/us/core/ValueSet/omb-race-category",
#                         "code": "2028-9",
#                         "display": "Asian"
#                     }
#                 },
#                 {
#                     "url": "text",
#                     "valueString": "Asian"
#                 }
#             ]
#         },
#         {
#             "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#             "extension": [
#                 {
#                     "url": "ombCategory",
#                     "valueCoding": {
#                         "system": "http://hl7.org/fhir/us/core/ValueSet/omb-ethnicity-category",
#                         "code": "UNK",
#                         "display": "Unknown"
#                     }
#                 },
#                 {
#                     "url": "text",
#                     "valueString": "Unknown"
#                 }
#             ]
#         }
#     ],
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.5.737384.0",
#             "value": "E3948",
#             "type": {
#                 "text": "EPIC"
#             }
#         },
#         {
#             "use": "usual",
#             "value": "Z6073",
#             "type": {
#                 "text": "EXTERNAL"
#             }
#         },
#         {
#             "use": "usual",
#             "system": "urn:oid:2.16.840.1.113883.4.1",
#             "extension": [
#                 {
#                     "url": "http://hl7.org/fhir/StructureDefinition/rendered-value",
#                     "valueString": "xxx-xx-3601"
#                 }
#             ]
#         }
#     ],
#     "name": [
#         {
#             "use": "usual",
#             "text": "Jason Argonaut",
#             "family": "Argonaut",
#             "given": [
#                 "Jason"
#             ]
#         }
#     ],
#     "telecom": [
#         {
#             "system": "phone",
#             "value": "608-623-5250",
#             "use": "home"
#         },
#         {
#             "system": "phone",
#             "value": "608-777-7777",
#             "use": "work"
#         },
#         {
#             "system": "phone",
#             "value": "608-623-5250",
#             "use": "mobile"
#         }
#     ],
#     "address": [
#         {
#             "use": "home",
#             "line": [
#                 "2197 State Rd 89"
#             ],
#             "city": "Mt Horeb",
#             "district": "DANE",
#             "state": "WI",
#             "postalCode": "53572",
#             "country": "US",
#             "period": {
#                 "start": "2008-10-29"
#             }
#         }
#     ],
#     "communication": [
#         {
#             "preferred": true,
#             "language": {
#                 "text": "English",
#                 "coding": [
#                     {
#                         "system": "http://hl7.org/fhir/ValueSet/languages",
#                         "code": "en",
#                         "display": "English"
#                     }
#                 ]
#             }
#         }
#     ],
#     "generalPractitioner": [
#         {
#             "reference": "https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/STU3/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3",
#             "display": "Physician Champion, MD"
#         }
#     ],
#     "managingOrganization": {
#         "reference": "https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/STU3/Organization/enRyWnSP963FYDpoks4NHOA3",
#         "display": "Epic Hospital System"
#     },
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient"
#         ]
#     }
# }
# writing to examples folder......
# Practitioner e7D.u41Zv3VPrLmUp-mWnrQ3
# 400
# Fetching of https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/R4/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3 failed: Status code= 400
# 200
# ********** epic-practitioner-e7D.u41Zv3VPrLmUp-mWnrQ3.json **********
# {
#     "resourceType": "Practitioner",
#     "id": "e7D.u41Zv3VPrLmUp-mWnrQ3",
#     "active": true,
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "PROVID",
#             "value": "1054",
#             "type": {
#                 "text": "PROVID"
#             }
#         },
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.5.737384.7",
#             "value": "207Q00000X",
#             "type": {
#                 "text": "EPIC"
#             }
#         },
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.5.737384.60",
#             "value": "1105499994",
#             "type": {
#                 "text": "NPI"
#             }
#         },
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.5.737384.63",
#             "value": "TEMP1054",
#             "type": {
#                 "text": "Epic"
#             }
#         }
#     ],
#     "name": [
#         {
#             "use": "usual",
#             "text": "Physician Champion, MD",
#             "family": "Champion",
#             "given": [
#                 "Physician"
#             ]
#         }
#     ],
#     "qualification": [
#         {
#             "code": {
#                 "text": "MD",
#                 "coding": [
#                     {
#                         "system": "urn:oid:1.2.840.114350.1.13.0.1.7.4.836982.6000",
#                         "code": "11",
#                         "display": "MD"
#                     }
#                 ]
#             }
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-practitioner"
#         ]
#     }
# }
# writing to examples folder......
# Organization enRyWnSP963FYDpoks4NHOA3
# 404
# Fetching of https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/R4/Organization/enRyWnSP963FYDpoks4NHOA3 failed: Status code= 404
# 404
# Seaching using https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/R4/Organization?_id=enRyWnSP963FYDpoks4NHOA3 failed: Status code= 404
# AllergyIntolerance eyHIVsZwhzaZhX9XvFesx5A3
# 400
# Fetching of https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/R4/AllergyIntolerance/eyHIVsZwhzaZhX9XvFesx5A3 failed: Status code= 400
# 200
# ********** epic-allergyintolerance-eyHIVsZwhzaZhX9XvFesx5A3.json **********
# {
#     "resourceType": "AllergyIntolerance",
#     "id": "eyHIVsZwhzaZhX9XvFesx5A3",
#     "category": [
#         "medication"
#     ],
#     "clinicalStatus": {
#         "coding": [
#             {
#                 "system": "http://terminology.hl7.org/CodeSystem/allergyintolerance-clinical",
#                 "version": "4.0.0",
#                 "code": "active",
#                 "display": "Active"
#             }
#         ]
#     },
#     "verificationStatus": {
#         "coding": [
#             {
#                 "system": "http://terminology.hl7.org/CodeSystem/allergyintolerance-verification",
#                 "version": "4.0.0",
#                 "code": "confirmed",
#                 "display": "Confirmed"
#             }
#         ]
#     },
#     "code": {
#         "text": "LACTOSE INTOLERANCE (GI)",
#         "coding": [
#             {
#                 "system": "urn:oid:2.16.840.1.113883.3.26.1.5",
#                 "code": "N0000006627",
#                 "display": "LACTOSE INTOLERANCE (GI)"
#             }
#         ]
#     },
#     "patient": {
#         "reference": "https://connectathon.epic.com/Interconnect-Fhir-Unsecure/api/FHIR/R4/Patient/eroCd17NbCffM3E3WXi7eOQ3",
#         "display": "Argonaut, Jason"
#     },
#     "reaction": [
#         {
#             "description": "GI intolerance",
#             "severity": "mild",
#             "manifestation": [
#                 {
#                     "text": "GI intolerance"
#                 }
#             ]
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-allergyintolerance"
#         ]
#     }
# }
# writing to examples folder......
# Encounter ehoN2kZnYuW5z0Di4Kkno5w3
# 200
# ********** epic-encounter-ehoN2kZnYuW5z0Di4Kkno5w3.json **********
# {
#     "resourceType": "Encounter",
#     "id": "ehoN2kZnYuW5z0Di4Kkno5w3",
#     "status": "in-progress",
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.3.698084.8",
#             "value": "27382"
#         }
#     ],
#     "class": {
#         "system": "urn:oid:1.2.840.114350.1.72.1.7.7.10.696784.13260",
#         "code": "13",
#         "display": "Support OP Encounter"
#     },
#     "type": [
#         {
#             "text": "Telephone",
#             "coding": [
#                 {
#                     "system": "urn:oid:1.2.840.114350.1.13.0.1.7.10.698084.30",
#                     "code": "70",
#                     "display": "Telephone"
#                 }
#             ]
#         }
#     ],
#     "subject": {
#         "reference": "/Patient/eroCd17NbCffM3E3WXi7eOQ3",
#         "display": "Jason Argonaut"
#     },
#     "participant": [
#         {
#             "individual": {
#                 "reference": "/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3",
#                 "display": "Physician Champion, MD"
#             }
#         }
#     ],
#     "location": [
#         {
#             "location": {
#                 "reference": "/Location/e4W4rmGe9QzuGm2Dy4NBqVc0KDe6yGld6HW95UuN-Qd03",
#                 "display": "EMC Family Medicine"
#             }
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter"
#         ]
#     }
# }
# writing to examples folder......
# Encounter eiSX3g2gt4tJIs7-6h7nJjA3
# 200
# ********** epic-encounter-eiSX3g2gt4tJIs7-6h7nJjA3.json **********
# {
#     "resourceType": "Encounter",
#     "id": "eiSX3g2gt4tJIs7-6h7nJjA3",
#     "status": "in-progress",
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.3.698084.8",
#             "value": "27383"
#         }
#     ],
#     "class": {
#         "system": "urn:oid:1.2.840.114350.1.72.1.7.7.10.696784.13260",
#         "code": "13",
#         "display": "Support OP Encounter"
#     },
#     "type": [
#         {
#             "text": "Ancillary Orders",
#             "coding": [
#                 {
#                     "system": "urn:oid:1.2.840.114350.1.13.0.1.7.10.698084.30",
#                     "code": "117",
#                     "display": "Ancillary Orders"
#                 }
#             ]
#         }
#     ],
#     "subject": {
#         "reference": "/Patient/eroCd17NbCffM3E3WXi7eOQ3",
#         "display": "Jason Argonaut"
#     },
#     "participant": [
#         {
#             "individual": {
#                 "reference": "/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3",
#                 "display": "Physician Champion, MD"
#             }
#         }
#     ],
#     "location": [
#         {
#             "location": {
#                 "reference": "/Location/e4W4rmGe9QzuGm2Dy4NBqVc0KDe6yGld6HW95UuN-Qd03",
#                 "display": "EMC Family Medicine"
#             }
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter"
#         ]
#     }
# }
# writing to examples folder......
# Encounter e1Jw-ETrL1kZAPiXl3uSMWw3
# 200
# ********** epic-encounter-e1Jw-ETrL1kZAPiXl3uSMWw3.json **********
# {
#     "resourceType": "Encounter",
#     "id": "e1Jw-ETrL1kZAPiXl3uSMWw3",
#     "status": "in-progress",
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.3.698084.8",
#             "value": "27381"
#         }
#     ],
#     "class": {
#         "system": "urn:oid:1.2.840.114350.1.72.1.7.7.10.696784.13260",
#         "code": "13",
#         "display": "Support OP Encounter"
#     },
#     "type": [
#         {
#             "text": "Telemedicine",
#             "coding": [
#                 {
#                     "system": "urn:oid:1.2.840.114350.1.13.0.1.7.10.698084.30",
#                     "code": "76",
#                     "display": "Telemedicine"
#                 }
#             ]
#         }
#     ],
#     "subject": {
#         "reference": "/Patient/eroCd17NbCffM3E3WXi7eOQ3",
#         "display": "Jason Argonaut"
#     },
#     "participant": [
#         {
#             "individual": {
#                 "reference": "/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3",
#                 "display": "Physician Champion, MD"
#             }
#         }
#     ],
#     "location": [
#         {
#             "location": {
#                 "reference": "/Location/e4W4rmGe9QzuGm2Dy4NBqVc0KDe6yGld6HW95UuN-Qd03",
#                 "display": "EMC Family Medicine"
#             }
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter"
#         ]
#     }
# }
# writing to examples folder......
# Encounter eZAjx5sRd6AgpTlKjDh4b5w3
# 200
# ********** epic-encounter-eZAjx5sRd6AgpTlKjDh4b5w3.json **********
# {
#     "resourceType": "Encounter",
#     "id": "eZAjx5sRd6AgpTlKjDh4b5w3",
#     "status": "finished",
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.3.698084.8",
#             "value": "27380"
#         }
#     ],
#     "class": {
#         "system": "urn:oid:1.2.840.114350.1.72.1.7.7.10.696784.13260",
#         "code": "13",
#         "display": "Support OP Encounter"
#     },
#     "type": [
#         {
#             "text": "Refill",
#             "coding": [
#                 {
#                     "system": "urn:oid:1.2.840.114350.1.13.0.1.7.10.698084.30",
#                     "code": "107",
#                     "display": "Refill"
#                 }
#             ]
#         }
#     ],
#     "subject": {
#         "reference": "/Patient/eroCd17NbCffM3E3WXi7eOQ3",
#         "display": "Jason Argonaut"
#     },
#     "participant": [
#         {
#             "individual": {
#                 "reference": "/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3",
#                 "display": "Physician Champion, MD"
#             }
#         }
#     ],
#     "reasonCode": [
#         {
#             "text": "Med Refill",
#             "coding": [
#                 {
#                     "system": "urn:oid:1.2.840.114350.1.13.0.1.7.2.728286",
#                     "code": "160383",
#                     "display": "Med Refill"
#                 }
#             ]
#         }
#     ],
#     "location": [
#         {
#             "location": {
#                 "reference": "/Location/e4W4rmGe9QzuGm2Dy4NBqVc0KDe6yGld6HW95UuN-Qd03",
#                 "display": "EMC Family Medicine"
#             }
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter"
#         ]
#     }
# }
# writing to examples folder......
# Encounter ejPvGuBUqYJkCweOPRabvYg3
# 200
# ********** epic-encounter-ejPvGuBUqYJkCweOPRabvYg3.json **********
# {
#     "resourceType": "Encounter",
#     "id": "ejPvGuBUqYJkCweOPRabvYg3",
#     "status": "finished",
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:1.2.840.114350.1.13.0.1.7.3.698084.8",
#             "value": "27379"
#         }
#     ],
#     "class": {
#         "system": "urn:oid:1.2.840.114350.1.72.1.7.7.10.696784.13260",
#         "code": "13",
#         "display": "Support OP Encounter"
#     },
#     "type": [
#         {
#             "text": "Treatment",
#             "coding": [
#                 {
#                     "system": "urn:oid:1.2.840.114350.1.13.0.1.7.10.698084.30",
#                     "code": "210",
#                     "display": "Treatment"
#                 }
#             ]
#         }
#     ],
#     "subject": {
#         "reference": "/Patient/eroCd17NbCffM3E3WXi7eOQ3",
#         "display": "Jason Argonaut"
#     },
#     "participant": [
#         {
#             "individual": {
#                 "reference": "/Practitioner/e7D.u41Zv3VPrLmUp-mWnrQ3",
#                 "display": "Physician Champion, MD"
#             }
#         }
#     ],
#     "location": [
#         {
#             "location": {
#                 "reference": "/Location/e4W4rmGe9QzuGm2Dy4NBqVc0KDe6yGld6HW95UuN-Qd03",
#                 "display": "EMC Family Medicine"
#             }
#         }
#     ],
#     "meta": {
#         "profile": [
#             "http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter"
#         ]
#     }
# }
# writing to examples folder......

# %% [markdown]
# ### Validate using IG Build
#
# 1. run py script to update ig.json and ig.xml
# 1. run ig publisher to validate examples **it will take a couple of minutes to run** ( until I can use a more stripped down template )

# %%
# %%bash
# set -e
# cd /Users/ehaas/Documents/FHIR/IG-Template2
# path1=/Users/ehaas/Downloads/org.hl7.fhir.igpublisher.jar
# SOURCE=USCoreR4Validator
# source_path=/Users/ehaas/Documents/FHIR/USCoreR4Validator
# path3=/Users/ehaas/Documents/FHIR/IG-tools/
# echo "================================================================="
# echo === use definition files from relative path ../$SOURCE ===
# echo "================================================================="
# echo getting rid of .DS_Store files since they gum up the igpublisher....
# echo "================================================================="
# echo === run definitions maker with optional source directory name as first argument ===
# echo === create ig.json and ig.xml in $PWD and ../$SOURCE ===
# echo "================================================================="
# find . -name '.DS_Store' -type f -delete
# python3.5 ${path3}definitions.py $SOURCE
# java -jar ${path1} -ig ${PWD}/ig.json
# Out:
# =================================================================
# === use definition files from relative path ../USCoreR4Validator ===
# =================================================================
# getting rid of .DS_Store files since they gum up the igpublisher....
# =================================================================
# === run definitions maker with optional source directory name as first argument ===
# === create ig.json and ig.xml in /Users/ehaas/Documents/FHIR/IG-Template2 and ../USCoreR4Validator ===
# =================================================================
# FHIR Implementation Guide Publisher Version 3.7.29-SNAPSHOT - Built 2019-04-25T10:14:48.65+10:00 - Git 31e5adf40f19
# Detected Java version: 10.0.2 from /Library/Java/JavaVirtualMachines/jdk-10.0.2.jdk/Contents/Home on x86_64 (64bit). 2048MB available. Run time = Saturday, May 25, 2019, 5:00:58 PM
# [/Users/ehaas/Documents/FHIR/IG-Template2] -ig /Users/ehaas/Documents/FHIR/IG-Template2/ig.json
# Package Cache: /Users/ehaas/.fhir/packages
# Load Configuration from /Users/ehaas/Documents/FHIR/IG-Template2/ig.json         (00.0228sec)
# Logging progress
# Contacting Build Server...                                                       (00.0275sec)
#  ... done                                                                        (02.0127sec)
# Root directory: /Users/ehaas/Documents/FHIR/IG-Template2                         (02.0130sec)
# Terminology Cache is at /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/txCache. 32 files in cache (03.0127sec)
# Load hl7.fhir.core-4.0.0 package from /Users/ehaas/.fhir/packages/hl7.fhir.core#4.0.0 (03.0143sec)
# Unable to generate snapshot for http://hl7.org/fhir/StructureDefinition/example-section-library because null
# Unable to generate snapshot for http://hl7.org/fhir/StructureDefinition/example-composition because null
# -tx cache miss: $validate null before cache exists
# Load Terminology Cache from /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/txCache (39.0541sec)
# Connect to Terminology Server at http://tx.fhir.org                              (42.0948sec)
# 17:01:41.255 [main] DEBUG org.apache.http.impl.conn.BasicClientConnectionManager - Get connection for route {}->http://tx.fhir.org:80
# 17:01:41.312 [main] DEBUG org.apache.http.impl.conn.DefaultClientConnectionOperator - Connecting to tx.fhir.org:80
# 17:01:41.429 [main] DEBUG org.apache.http.client.protocol.RequestAddCookies - CookieSpec selected: default
# 17:01:41.430 [main] DEBUG org.apache.http.client.protocol.RequestAuthCache - Auth cache not set in the context
# 17:01:41.430 [main] DEBUG org.apache.http.client.protocol.RequestTargetAuthentication - Target auth state: UNCHALLENGED
# 17:01:41.431 [main] DEBUG org.apache.http.client.protocol.RequestProxyAuthentication - Proxy auth state: UNCHALLENGED
# 17:01:41.431 [main] DEBUG org.apache.http.impl.client.DefaultHttpClient - Attempt 1 to execute request
# 17:01:41.431 [main] DEBUG org.apache.http.impl.conn.DefaultClientConnection - Sending request: GET /r4/metadata?_summary=true HTTP/1.1
# 17:01:41.431 [main] DEBUG org.apache.http.wire -  >> "GET /r4/metadata?_summary=true HTTP/1.1[\r][\n]"
# 17:01:41.432 [main] DEBUG org.apache.http.wire -  >> "User-Agent: Java FHIR Client for FHIR[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.wire -  >> "Accept: application/fhir+xml[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.wire -  >> "Content-Type: application/fhir+xml;charset=UTF-8[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.wire -  >> "Accept-Charset: UTF-8[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.wire -  >> "Host: tx.fhir.org[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.wire -  >> "Connection: Keep-Alive[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.wire -  >> "[\r][\n]"
# 17:01:41.433 [main] DEBUG org.apache.http.headers - >> GET /r4/metadata?_summary=true HTTP/1.1
# 17:01:41.434 [main] DEBUG org.apache.http.headers - >> User-Agent: Java FHIR Client for FHIR
# 17:01:41.434 [main] DEBUG org.apache.http.headers - >> Accept: application/fhir+xml
# 17:01:41.434 [main] DEBUG org.apache.http.headers - >> Content-Type: application/fhir+xml;charset=UTF-8
# 17:01:41.434 [main] DEBUG org.apache.http.headers - >> Accept-Charset: UTF-8
# 17:01:41.434 [main] DEBUG org.apache.http.headers - >> Host: tx.fhir.org
# 17:01:41.434 [main] DEBUG org.apache.http.headers - >> Connection: Keep-Alive
# 17:01:41.890 [main] DEBUG org.apache.http.wire -  << "HTTP/1.1 200 OK[\r][\n]"
# 17:01:41.891 [main] DEBUG org.apache.http.wire -  << "Connection: close[\r][\n]"
# 17:01:41.891 [main] DEBUG org.apache.http.wire -  << "Content-Type: application/fhir+xml; charset=UTF-8[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Content-Length: 26281[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Cache-control: public, max-age=600[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Date: Sun, 26 May 2019 00:01:41 GMT[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Pragma: no-cache[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "X-Request-Id: 177-1180308[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Access-Control-Allow-Origin: *[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Access-Control-Expose-Headers: Content-Location, Location[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Access-Control-Allow-Methods: GET, POST, PUT, PATCH, DELETE[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "X-GDPR-Disclosure: All access to this server is logged as AuditEvent Resources, and these store your ip address (and logged in user, if one exists). Also, your IP address is logged with Google Analytics for building geomaps of server usage. Your continued use of the API constitutes agreement to these terms. See [link] for erasure requests[\r][\n]"
# 17:01:41.892 [main] DEBUG org.apache.http.wire -  << "Server: Health Intersections FHIR Server[\r][\n]"
# 17:01:41.893 [main] DEBUG org.apache.http.wire -  << "[\r][\n]"
# 17:01:41.893 [main] DEBUG org.apache.http.impl.conn.DefaultClientConnection - Receiving response: HTTP/1.1 200 OK
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << HTTP/1.1 200 OK
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << Connection: close
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << Content-Type: application/fhir+xml; charset=UTF-8
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << Content-Length: 26281
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << Cache-control: public, max-age=600
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << Date: Sun, 26 May 2019 00:01:41 GMT
# 17:01:41.893 [main] DEBUG org.apache.http.headers - << Pragma: no-cache
# 17:01:41.894 [main] DEBUG org.apache.http.headers - << X-Request-Id: 177-1180308
# 17:01:41.894 [main] DEBUG org.apache.http.headers - << Access-Control-Allow-Origin: *
# 17:01:41.894 [main] DEBUG org.apache.http.headers - << Access-Control-Expose-Headers: Content-Location, Location
# 17:01:41.894 [main] DEBUG org.apache.http.headers - << Access-Control-Allow-Methods: GET, POST, PUT, PATCH, DELETE
# 17:01:41.894 [main] DEBUG org.apache.http.headers - << X-GDPR-Disclosure: All access to this server is logged as AuditEvent Resources, and these store your ip address (and logged in user, if one exists). Also, your IP address is logged with Google Analytics for building geomaps of server usage. Your continued use of the API constitutes agreement to these terms. See [link] for erasure requests
# 17:01:41.894 [main] DEBUG org.apache.http.headers - << Server: Health Intersections FHIR Server
# 17:01:41.934 [main] DEBUG org.apache.http.wire -  << "<?xml version="1.0" encoding="UTF-8"?><CapabilityStatement xmlns="http://hl7.org/fhir"><id value="FhirServer"/><meta><tag><system value="http://hl7.org/fhir/v3/ObservationValue"/><code value="SUBSETTED"/><display value="Subsetted"/></tag></meta><url value="http://tx.fhir.org/r4/metadata"/><version value="4.0.0-1.0.280"/><name value="FHIR Reference Server Conformance Statement"/><status value="active"/><date value="2019-05-26T00:01:41.460Z"/><contact><telecom><system value="other"/><value value="http://healthintersections.com.au/"/></telecom></contact><instantiates value="http://hl7.org/fhir/Conformance/terminology-server"/><software><name value="Reference Server"/><version value="1.0.280"/><releaseDate value="2019-03-21"/></software><implementation><description value="FHIR Server running at http://tx.fhir.org/r4"/><url value="http://tx.fhir.org/r4"/></implementation><fhirVersion value="4.0.0"/><format value="application/fhir+xml"/><format value="application/fhir+json"/><rest><extension url="http://hl7.org/fhir/StructureDefinition/capabilitystatement-websocket"><valueString value="http://tx.fhir.org/r4/websockets"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/cds-activity"><extension url="name"><valueString value="Fetch Patient Alerts"/></extension><extension url="activity"><valueString value="patient-view"/></extension><extension url="preFetchOptional"><valueString value="Patient/{{Patient.id}}"/></extension></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/cds-activity"><extension url="name"><valueString value="Get Terminology Information"/></extension><extension url="activity"><valueString value="code-view"/></extension></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/cds-activity"><extension url="name"><valueString value="Get identifier Information"/></extension><extension url="activity"><valueString value="identifier-view"/></extension></extension><mode value="server"/><security><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/oauth-uris"><extension url="register"><valueString value="http://tx.fhir.org/r4/auth/register"/></extension><extension url="authorize"><valueString value="http://tx.fhir.org/r4/auth/auth"/></extension><extension url="token"><valueString value="http://tx.fhir.org/r4/auth/token"/></extension><extension url="manage"><valueString value="http://tx.fhir.org/r4/auth/manage"/></extension></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="launch-standalone"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="launch-ehr"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="client-public"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="client-confidential-symmetric"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="sso-openid-connect"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="permission-offline"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="permission-patient"/></extension><extension url="http://fhir-registry.smarthealthit.org/StructureDefinition/capabilities"><valueString value="permission-user"/></extension><cors value="true"/><service><coding><system value="http://hl7.org/fhir/restful-security-service"/><code value="SMART-on-FHIR"/><display value="SMART-on-FHIR"/></coding></service></security><resource><type value="Account"/><profile value="http://tx.fhir.org/r4/StructureDefinition/account"/></resource><resource>< ...
# 17:01:41.935 [main] DEBUG org.apache.http.wire -  << "rseEvent"/><profile value="http://tx.f"
# 17:01:41.973 [main] DEBUG org.apache.http.wire -  << "hir.org/r4/StructureDefinition/adverseevent"/></resource><resource><type value="AllergyIntolerance"/><profile value="http://tx.fhir.org/r4/StructureDefinition/allergyintolerance"/></resource><resource><type value="Appointment"/><profile value="http://tx.fhir.org/r4/StructureDefinition/appointment"/></resource><resource><type value="AppointmentResponse"/><profile value="http://tx.fhir.org/r4/StructureDefinition/appointmentresponse"/></resource><resource><type value="AuditEvent"/><profile value="http://tx.fhir.org/r4/StructureDefinition/auditevent"/></resource><resource><type value="Basic"/><profile value="http://tx.fhir.org/r4/StructureDefinition/basic"/></resource><resource><type value="Binary"/><profile value="http://tx.fhir.org/r4/StructureDefinition/binary"/></resource><resource><type value="BiologicallyDerivedProduct"/><profile value="http://tx.fhir.org/r4/StructureDefinition/biologicallyderivedproduct"/></resource><resource><type value="BodyStructure"/><profile value="http://tx.fhir.org/r4/StructureDefinition/bodystructure"/></resource><resource><type value="Bundle"/><profile value="http://tx.fhir.org/r4/StructureDefinition/bundle"/></resource><resource><type value="CapabilityStatement"/><profile value="http://tx.fhir.org/r4/StructureDefinition/capabilitystatement"/></resource><resource><type value="CarePlan"/><profile value="http://tx.fhir.org/r4/Str"
# 17:01:41.975 [main] DEBUG org.apache.http.wire -  << "uctureDefinition/careplan"/></resource><resource><type value="CareTeam"/><profile value="http://tx.fhir.org/r4/StructureDefinition/careteam"/></resource><resource><type value="CatalogEntry"/><profile value="http://tx.fhir.org/r4/StructureDefinition/catalogentry"/></resource><resource><type value="ChargeItem"/><profile value="http://tx.fhir.org/r4/StructureDefinition/chargeitem"/></resource><resource><type value="ChargeItemDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/chargeitemdefinition"/></resource><resource><type value="Claim"/><profile value="http://tx.fhir.org/r4/StructureDefinition/claim"/></resource><resource><type value="ClaimResponse"/><profile value="http://tx.fhir.org/r4/StructureDefinition/claimresponse"/></resource><resource><type value="ClinicalImpression"/><profile value="http://tx.fhir.org/r4/StructureDefinition/clinicalimpression"/></resource><resource><type value="CodeSystem"/><profile value="http://tx.fhir.org/r4/StructureDefinition/codesystem"/></resource><resource><type value="Communication"/><profile value="http://tx.fhir.org/r4/StructureDefinition/communication"/></resource><resource><type value="CommunicationRequest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/communicationrequest"/></resource><resource><type value="CompartmentDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/compartmentdefinition"/></resource><resource><type value="Composition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/composition"/></resource><resource><type value="ConceptMap"/><profile value="http://tx.fhir.org/r4/StructureDefinition/conceptmap"/></resource><resource><type value="Condition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/condition"/></resource><resource><type value="Consent"/><profile value="http://tx.fhir.org/r4/StructureDefinition/consent"/></resource><resource><type value="Contract"/><profile value="http://tx.fhir.org/r4/StructureDefinition/contract"/></resource><resource><type value="Coverage"/><profile value="http://tx.fhir.org/r4/StructureDefinition/coverage"/></resource><resource><type value="CoverageEligibilityRequest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/coverageeligibilityrequest"/></resource><resource><type value="CoverageEligibilityResponse"/><profile value="http://tx.fhir.org/r4/StructureDefinition/coverageeligibilityresponse"/></resource><resource><type value="DetectedIssue"/><profile value="http://tx.fhir.org/r4/StructureDefinition/detectedissue"/></resource><resource><type value="Device"/><profile value="http://tx.fhir.org/r4/StructureDefinition/device"/></resource><resource><type value="DeviceDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/devicedefinition"/></resource><resource><type value="DeviceMetric"/><profile value="http://tx.fhir.org/r4/StructureDefinition/devicemetric"/></resource><resource><type value="DeviceRequest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/devicerequest"/></resource><resource><type value="DeviceUseStatement"/><profile value="http://tx.fhir.org/r4/StructureDefinition/deviceusestatement"/></resource><resource><type value="DiagnosticReport"/><profile value="http://tx.fhir.org/r4/StructureDefinition/diagnosticreport"/></resource><resource><type value="DocumentManifest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/documentmanifest"/></resource><resource><type value="DocumentReference"/><profile value="http://tx.fhir.org/r4/StructureDefinition/documentreference"/></resource><resource><type value="EffectEvidenceSynthesis"/><profile value="http://tx.fhir.org/r4/StructureDefinition/effectevidencesynthesis"/></resource><resource><type value="Encounter"/><profile value="http://tx.fhir.org/r4/StructureDefinition/encounter"/></resource><resource><type value="Endpoint"/><profile value="http://tx.fhir.org/r4/StructureDefinition/endpoint"/></resource><resource><type value=" ...
# 17:01:41.975 [main] DEBUG org.apache.http.wire -  << ""/><profile value="http://tx.fhir.org/r4/StructureDefinition/enrollmentresponse"/></resource><resource><type value="EpisodeOfCare"/><profile value="http://tx.fhir.org/r4/StructureDefinition/episodeofcare"/></resource><resource><type value="EventDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/eventdefinition"/></resource><resource><type value="Evidence"/><profile value="http://tx.fhir.org/r4/StructureDefinition/evidence"/></resource><resource><type value="EvidenceVariable"/><profile value="http://tx.fhir.org/r4/StructureDefinition/evidencevariable"/></resource><resource><type value="ExampleScenario"/><profile value="http://tx.fhir.org/r4/StructureDefinition/examplescenario"/></resource><resource><type value="ExplanationOfBenefit"/><profile value="http://tx.fhir.org/r4/StructureDefinition/explanationofbenefit"/></resource><resource><type value="FamilyMemberHistory"/><profile value="http://tx.fhir.org/r4/StructureDefinition/familymemberhistory"/></resource><resource><type value="Flag"/><profile value="http://tx.fhir.org/r4/StructureDefinition/flag"/></resource><resource><type value="Goal"/><profile value="http://tx.fhir.org/r4/StructureDefinition/goal"/></resource><resource><type value="GraphDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/graphdefinition"/></resource><resource><type value="Group"/><profile value="http://tx.fhir.org/r4/StructureDefinit"
# 17:01:42.017 [main] DEBUG org.apache.http.wire -  << "ion/group"/></resource><resource><type value="GuidanceResponse"/><profile value="http://tx.fhir.org/r4/StructureDefinition/guidanceresponse"/></resource><resource><type value="HealthcareService"/><profile value="http://tx.fhir.org/r4/StructureDefinition/healthcareservice"/></resource><resource><type value="ImagingStudy"/><profile value="http://tx.fhir.org/r4/StructureDefinition/imagingstudy"/></resource><resource><type value="Immunization"/><profile value="http://tx.fhir.org/r4/StructureDefinition/immunization"/></resource><resource><type value="ImmunizationEvaluation"/><profile value="http://tx.fhir.org/r4/StructureDefinition/immunizationevaluation"/></resource><resource><type value="ImmunizationRecommendation"/><profile value="http://tx.fhir.org/r4/StructureDefinition/immunizationrecommendation"/></resource><resource><type value="ImplementationGuide"/><profile value="http://tx.fhir.org/r4/StructureDefinition/implementationguide"/></resource><resource><type value="InsurancePlan"/><profile value="http://tx.fhir.org/r4/StructureDefinition/insuranceplan"/></resource><resource><type value="Invoice"/><profile value="http://tx.fhir.org/r4/StructureDefinition/invoice"/></resource><resource><type value="Library"/><profile value="http://tx.fhir.org/r4/StructureDefinition/library"/></resource><resource><type value="Linkage"/><profile value="http://tx.fhir.org/r4/St"
# 17:01:42.017 [main] DEBUG org.apache.http.wire -  << "ructureDefinition/linkage"/></resource><resource><type value="List"/><profile value="http://tx.fhir.org/r4/StructureDefinition/list"/></resource><resource><type value="Location"/><profile value="http://tx.fhir.org/r4/StructureDefinition/location"/></resource><resource><type value="Measure"/><profile value="http://tx.fhir.org/r4/StructureDefinition/measure"/></resource><resource><type value="MeasureReport"/><profile value="http://tx.fhir.org/r4/StructureDefinition/measurereport"/></resource><resource><type value="Media"/><profile value="http://tx.fhir.org/r4/StructureDefinition/media"/></resource><resource><type value="Medication"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medication"/></resource><resource><type value="MedicationAdministration"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicationadministration"/></resource><resource><type value="MedicationDispense"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicationdispense"/></resource><resource><type value="MedicationKnowledge"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicationknowledge"/></resource><resource><type value="MedicationRequest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicationrequest"/></resource><resource><type value="MedicationStatement"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medica"
# 17:01:42.056 [main] DEBUG org.apache.http.wire -  << "tionstatement"/></resource><resource><type value="MedicinalProduct"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproduct"/></resource><resource><type value="MedicinalProductAuthorization"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductauthorization"/></resource><resource><type value="MedicinalProductContraindication"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductcontraindication"/></resource><resource><type value="MedicinalProductIndication"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductindication"/></resource><resource><type value="MedicinalProductIngredient"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductingredient"/></resource><resource><type value="MedicinalProductInteraction"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductinteraction"/></resource><resource><type value="MedicinalProductManufactured"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductmanufactured"/></resource><resource><type value="MedicinalProductPackaged"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductpackaged"/></resource><resource><type value="MedicinalProductPharmaceutical"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductpharmaceutical"/></re"
# 17:01:42.058 [main] DEBUG org.apache.http.wire -  << "source><resource><type value="MedicinalProductUndesirableEffect"/><profile value="http://tx.fhir.org/r4/StructureDefinition/medicinalproductundesirableeffect"/></resource><resource><type value="MessageDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/messagedefinition"/></resource><resource><type value="MolecularSequence"/><profile value="http://tx.fhir.org/r4/StructureDefinition/molecularsequence"/></resource><resource><type value="NamingSystem"/><profile value="http://tx.fhir.org/r4/StructureDefinition/namingsystem"/></resource><resource><type value="NutritionOrder"/><profile value="http://tx.fhir.org/r4/StructureDefinition/nutritionorder"/></resource><resource><type value="Observation"/><profile value="http://tx.fhir.org/r4/StructureDefinition/observation"/></resource><resource><type value="ObservationDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/observationdefinition"/></resource><resource><type value="OperationDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/operationdefinition"/></resource><resource><type value="OperationOutcome"/><profile value="http://tx.fhir.org/r4/StructureDefinition/operationoutcome"/></resource><resource><type value="Organization"/><profile value="http://tx.fhir.org/r4/StructureDefinition/organization"/></resource><resource><type value="OrganizationAffiliation"/><profile value="http://tx.fhir.org/r4/StructureDefinition/organizationaffiliation"/></resource><resource><type value="Parameters"/><profile value="http://tx.fhir.org/r4/StructureDefinition/parameters"/></resource><resource><type value="Patient"/><profile value="http://tx.fhir.org/r4/StructureDefinition/patient"/></resource><resource><type value="PaymentNotice"/><profile value="http://tx.fhir.org/r4/StructureDefinition/paymentnotice"/></resource><resource><type value="PaymentReconciliation"/><profile value="http://tx.fhir.org/r4/StructureDefinition/paymentreconciliation"/></resource><resource><type value="Person"/><profile value="http://tx.fhir.org/r4/StructureDefinition/person"/></resource><resource><type value="PlanDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/plandefinition"/></resource><resource><type value="Practitioner"/><profile value="http://tx.fhir.org/r4/StructureDefinition/practitioner"/></resource><resource><type value="PractitionerRole"/><profile value="http://tx.fhir.org/r4/StructureDefinition/practitionerrole"/></resource><resource><type value="Procedure"/><profile value="http://tx.fhir.org/r4/StructureDefinition/procedure"/></resource><resource><type value="Provenance"/><profile value="http://tx.fhir.org/r4/StructureDefinition/provenance"/></resource><resource><type value="Questionnaire"/><profile value="http://tx.fhir.org/r4/StructureDefinition/questionnaire"/></resource><resource><type value="QuestionnaireResponse"/><profile value="http://tx.fhir.org/r4/StructureDefinition/questionnaireresponse"/></resource><resource><type value="RelatedPerson"/><profile value="http://tx.fhir.org/r4/StructureDefinition/relatedperson"/></resource><resource><type value="RequestGroup"/><profile value="http://tx.fhir.org/r4/StructureDefinition/requestgroup"/></resource><resource><type value="ResearchDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/researchdefinition"/></resource><resource><type value="ResearchElementDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/researchelementdefinition"/></resource><resource><type value="ResearchStudy"/><profile value="http://tx.fhir.org/r4/StructureDefinition/researchstudy"/></resource><resource><type value="ResearchSubject"/><profile value="http://tx.fhir.org/r4/StructureDefinition/researchsubject"/></resource><resource><type value="RiskAssessment"/><profile value="http://tx.fhir.org/r4/StructureDefinition/riskassessment"/></resource><resource><type value="RiskEvidenceSynthesis"/><profile value="http://tx.fhir.org/r4/ ...
# 17:01:42.059 [main] DEBUG org.apache.http.wire -  << "edule"/></resource><resource><type value="SearchParameter"/><profile value="http://tx.fhir.org/r4/StructureDefinition/searchparameter"/></resource><resource><type value="ServiceRequest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/servicerequest"/></resource><resource><type value="Slot"/><profile value="http://tx.fhir.org/r4/StructureDefinition/slot"/></resource><resource><type value="Specimen"/><profile value="http://tx.fhir.org/r4/StructureDefinition/specimen"/></resource><resource><type value="SpecimenDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/specimendefinition"/></resource><resource><type value="StructureDefinition"/><profile value="http://tx.fhir.org/r4/StructureDefinition/structuredefinition"/></resource><resource><type value="StructureMap"/><profile value="http://tx.fhir.org/r4/StructureDefinition/structuremap"/></resource><resource><type value="Subscription"/><profile value="http://tx.fhir.org/r4/StructureDefinition/subscription"/></resource><resource><type value="Substance"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substance"/></resource><resource><type value="SubstanceNucleicAcid"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substancenucleicacid"/></resource><resource><type value="SubstancePolymer"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substancepolymer"/></resource><resource><type value="SubstanceProtein"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substanceprotein"/></resource><resource><type value="SubstanceReferenceInformation"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substancereferenceinformation"/></resource><resource><type value="SubstanceSourceMaterial"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substancesourcematerial"/></resource><resource><type value="SubstanceSpecification"/><profile value="http://tx.fhir.org/r4/StructureDefinition/substancespecification"/></resource><resource><type value="SupplyDelivery"/><profile value="http://tx.fhir.org/r4/StructureDefinition/supplydelivery"/></resource><resource><type value="SupplyRequest"/><profile value="http://tx.fhir.org/r4/StructureDefinition/supplyrequest"/></resource><resource><type value="Task"/><profile value="http://tx.fhir.org/r4/StructureDefinition/task"/></resource><resource><type value="TerminologyCapabilities"/><profile value="http://tx.fhir.org/r4/StructureDefinition/terminologycapabilities"/></resource><resource><type value="TestReport"/><profile value="http://tx.fhir.org/r4/StructureDefinition/testreport"/></resource><resource><type value="TestScript"/><profile value="http://tx.fhir.org/r4/StructureDefinition/testscript"/></resource><resource><type value="ValueSet"/><profile value="http://tx.fhir.org/r4/StructureDefinition/valueset"/></resource><resource><type value="VerificationResult"/><profile value="http://tx.fhir.org/r4/StructureDefinition/verificationresult"/></resource><resource><type value="VisionPrescription"/><profile value="http://tx.fhir.org/r4/StructureDefinition/visionprescription"/></resource><operation><name value="expand"/><definition value="http://hl7.org/fhir/OperationDefinition/ValueSet-expand"/></operation><operation><name value="lookup"/><definition value="http://hl7.org/fhir/OperationDefinition/ValueSet-lookup"/></operation><operation><name value="validate-code"/><definition value="http://hl7.org/fhir/OperationDefinition/Resource-validate"/></operation><operation><name value="translate"/><definition value="http://hl7.org/fhir/OperationDefinition/ConceptMap-translate"/></operation><operation><name value="closure"/><definition value="http://hl7.org/fhir/OperationDefinition/ConceptMap-closure"/></operation><operation><name value="validate"/><definition value="http://hl7.org/fhir/OperationDefinition/ValueSet-validate-code"/></operation><operation><name value="document"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-doc ...
# 17:01:42.060 [main] DEBUG org.apache.http.wire -  << "ation><name value="everything"/><definition value="http://hl7.org/fhir/OperationDefinition/Patient-everything"/></operation><operation><name value="everything"/><definition value="http://hl7.org/fhir/OperationDefinition/Encounter-everything"/></operation><operation><name value="everything"/><definition value="http://hl7.org/fhir/OperationDefinition/Group-everything"/></operation><operation><name value="qa-edit"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-qa-edit"/></operation><operation><name value="jwt"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-jwt"/></operation><operation><name value="codegen"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-codegen"/></operation><operation><name value="qa-post"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-qa-post"/></operation><operation><name value="questionnaire"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-questionnaire"/></operation><operation><name value="versions"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-versions"/></operation><operation><name value="process"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-process"/></operation><operation><name value="snapshot"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-snapshot"/></operation><operation><name value="generate-template"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-generate-template"/></operation><operation><name value="generate-narrative"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-generate-narrative"/></operation><operation><name value="suggest-keywords"/><definition value="http://tx.fhir.org/r4/OperationDefinition/fso-suggest-keywords"/></operation><operation><name value="meta"/><definition value="http://hl7.org/fhir/OperationDefinition/Resource-meta"/></operation><operation><name value="meta-add"/><definition value="http://hl7.org/fhir/OperationDefinition/Resource-meta-add"/></operation><operation><name value="meta-delete"/><definition value="http://hl7.org/fhir/OperationDefinition/Resource-meta-add"/></operation><operation><name value="diff"/><definition value="http://hl7.org/fhir/OperationDefinition/Resource-diff"/></operation><operation><name value="convert"/><definition value="http://hl7.org/fhir/OperationDefinition/Resource-Convert"/></operation><operation><name value="transform"/><definition value="http://hl7.org/fhir/OperationDefinition/StructureMap-transform"/></operation><operation><name value="subsumes"/><definition value="http://hl7.org/fhir/OperationDefinition/CodeSystem-subsumes"/></operation><operation><name value="stats"/><definition value="http://hl7.org/fhir/OperationDefinition/Observation-Stats"/></operation><operation><name value="lastn"/><definition value="http://hl7.org/fhir/OperationDefinition/Observation-lastn"/></operation></rest></CapabilityStatement>"
# 17:01:42.060 [main] DEBUG org.apache.http.impl.conn.BasicClientConnectionManager - Releasing connection org.apache.http.impl.conn.ManagedClientConnectionImpl@2a03d65c
# 17:01:42.061 [main] DEBUG org.apache.http.impl.conn.DefaultClientConnection - Connection 0.0.0.0:55788<->104.196.166.17:80 shut down
# -tx cache miss: Connect to http://tx.fhir.org//r4
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck1512.png (44.0608sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck1512.png (44.0609sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck01000.png (44.0611sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck01000.png (44.0613sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_profile.png (44.0616sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_profile.png (44.0618sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck01.png (44.0618sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck01.png (44.0623sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon-infrastructure.png (44.0625sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon-infrastructure.png (44.0628sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck11110.png (44.0629sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck11110.png (44.0632sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck010.png (44.0633sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck010.png (44.0636sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck1040.png (44.0637sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck1040.png (44.0639sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck001001.png (44.0643sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck001001.png (44.0647sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck00010.png (44.0649sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck00010.png (44.0652sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck0111.png (44.0652sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck0111.png (44.0653sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon-warning.png (44.0658sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon-warning.png (44.0660sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck041.png (44.0662sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck041.png (44.0664sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_element.gif (44.0667sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_element.gif (44.0669sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck0510.png (44.0669sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck0510.png (44.0674sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck10011.png (44.0674sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck10011.png (44.0676sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck150.png (44.0677sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck150.png (44.0680sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon-include.png (44.0681sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon-include.png (44.0684sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck0.png (44.0685sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck0.png (44.0687sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck05140.png (44.0688sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck05140.png (44.0691sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck101010.png (44.0692sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck101010.png (44.0695sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck0010010.png (44.0695sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck0010010.png (44.0698sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon-toc.png (44.0699sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon-toc.png (44.0702sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck1152.png (44.0703sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck1152.png (44.0706sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon-page.png (44.0707sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon-page.png (44.0710sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck0410.png (44.0710sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck0410.png (44.0714sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck101100.png (44.0715sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck101100.png (44.0717sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_modifier_extension_simple.png (44.0718sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_modifier_extension_simple.png (44.0721sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck011010.png (44.0721sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck011010.png (44.0724sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/mustsupport.png (44.0725sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/mustsupport.png (44.0728sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_page.gif (44.0729sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_page.gif (44.0732sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_resource.png (44.0732sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_resource.png (44.0735sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck1540.png (44.0736sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck1540.png (44.0739sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck01100.png (44.0740sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck01100.png (44.0743sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_vline_slice.png (44.0743sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_vline_slice.png (44.0746sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck110.png (44.0747sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck110.png (44.0750sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck111000.png (44.0751sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck111000.png (44.0753sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_blank.png (44.0754sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_blank.png (44.0757sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck12.png (44.0758sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck12.png (44.0761sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck0011.png (44.0761sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck0011.png (44.0764sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck15152.png (44.0765sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck15152.png (44.0768sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck010110.png (44.0769sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck010110.png (44.0772sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck10101.png (44.0772sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck10101.png (44.0773sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck000000.png (44.0773sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck000000.png (44.0774sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck00.png (44.0775sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck00.png (44.0776sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck001.png (44.0776sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck001.png (44.0778sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck11101.png (44.0778sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck11101.png (44.0779sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck05050.png (44.0779sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck05050.png (44.0780sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_vline_slicer.png (44.0780sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_vline_slicer.png (44.0781sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck10111.png (44.0781sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck10111.png (44.0784sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck000010.png (44.0785sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck000010.png (44.0788sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck10.png (44.0788sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck10.png (44.0791sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck00001.png (44.0792sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck00001.png (44.0793sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_modifier_extension_complex.png (44.0794sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_modifier_extension_complex.png (44.0795sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon-clinical.png (44.0795sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon-clinical.png (44.0800sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck05040.png (44.0801sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck05040.png (44.0803sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck011.png (44.0805sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck011.png (44.0807sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck050.png (44.0808sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck050.png (44.0811sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck100.png (44.0811sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck100.png (44.0814sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/icon_page_n.gif (44.0815sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/icon_page_n.gif (44.0818sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/target.png (44.0819sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/target.png (44.0822sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck10010.png (44.0823sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck10010.png (44.0825sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck101000.png (44.0826sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck101000.png (44.0829sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/qa/tbl_bck04.png (44.0830sec)
# Check Generate /Users/ehaas/Documents/FHIR/IG-Template2/generated_output/temp/tbl_bck04.png (44.0833sec)
# ...
#
#  2019-05-25 17:00:57,048 - INFO- appended this line to copy <!--  this could be a customizable include -->
#
#  2019-05-25 17:00:57,048 - INFO- appended this line to copy  <ul>
#
#  2019-05-25 17:00:57,048 - INFO- appended this line to copy   {% unless "{{[id]}}" contains "extension" %}<li><a href="#tabs-summ">Text Summary</a></li>{% endunless %}
#
#  2019-05-25 17:00:57,049 - INFO- appended this line to copy   <li><a href="#tabs-diff">Differential View</a></li>
#
#  2019-05-25 17:00:57,049 - INFO- appended this line to copy   <li><a href="#tabs-snap">Full View</a></li>
#
#  2019-05-25 17:00:57,049 - INFO- appended this line to copy   {% if site.showPsuedoXML %}<li><a href="#tabs-xml">XML Template</a></li>{% endif %}
#
#  2019-05-25 17:00:57,049 - INFO- appended this line to copy   {% if site.showPsuedoJson %}<li><a href="#tabs-json">JSON Template</a></li>{% endif %}
#
#  2019-05-25 17:00:57,049 - INFO- appended this line to copy   <li><a href="#tabs-all">All Views</a></li>
#
#  2019-05-25 17:00:57,049 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,050 - INFO- appended this line to copy  </ul>
#
#  2019-05-25 17:00:57,050 - INFO- appended this line to copy {% unless "{{[id]}}" contains "extension" %}
#
#  2019-05-25 17:00:57,050 - INFO- appended this line to copy  <div id="tabs-summ">
#
#  2019-05-25 17:00:57,050 - INFO- appended this line to copy   <div id="tbl-summ">
#
#  2019-05-25 17:00:57,050 - INFO- appended this line to copy    <div id="tbl-diff-inner">
#
#  2019-05-25 17:00:57,051 - INFO- appended this line to copy      <a name="summary"> </a>
#
#  2019-05-25 17:00:57,051 - INFO- appended this line to copy {% if site.summaries %}
#
#  2019-05-25 17:00:57,051 - INFO- appended this line to copy   {% capture my-include %}{% include {{[id]}}-summary.md id="{{[id]}}" %}{% endcapture %}{{ my-include | markdownify }}
#
#  2019-05-25 17:00:57,051 - INFO- appended this line to copy {% else %}
#
#  2019-05-25 17:00:57,051 - INFO- appended this line to copy   {% include {{[type]}}-{{[id]}}-summary.xhtml %}
#
#  2019-05-25 17:00:57,051 - INFO- appended this line to copy {% endif%}
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy  </div>
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy {% endunless %}
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy  <div id="tabs-diff">
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy   <div id="tbl-diff">
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy    <div id="tbl-diff-inner">
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy   {% include {{[type]}}-{{[id]}}-diff.xhtml %}
#
#  2019-05-25 17:00:57,052 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy  </div>
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy  <div id="tabs-snap">
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy   <div id="tbl-snap">
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy    <div id="tbl-snap-inner">
#
#  2019-05-25 17:00:57,053 - INFO- appended this line to copy {% include {{[type]}}-{{[id]}}-snapshot.xhtml %}
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy  </div>
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy <!-- =======XML and JSON ======== -->
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy {% if site.showPsuedoXML%}
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy  <div id="tabs-xml">
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy   <div id="xml">
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy    <div id="xml-inner">
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy {% include {{[type]}}-{{[id]}}-pseudo-xml.xhtml %}
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,054 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy  </div>
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy {% endif %}
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy {% if site.showPsuedoJson%}
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy  <div id="tabs-json">
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy   <div id="json">
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy    <div id="json-inner">
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy      <pre class="spec">
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy       {% include {{[type]}}-{{[id]}}-pseudo-json.xhtml %}
#
#  2019-05-25 17:00:57,055 - INFO- appended this line to copy      </pre>
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy  </div>
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy {% endif %}
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy {% endif %}
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy  <div id="tabs-all"  class = "no-external">
#
#  2019-05-25 17:00:57,056 - INFO- appended this line to copy <!-- =======Summary======== -->
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy {% unless "{{[id]}}" contains "extension"%}
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy   <div id="all-tbl-summ">
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy     <div id="all-tbl-summ-inner">
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy      <a name="summary"> </a>
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy    {% if site.summaries %}
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy      {% capture my-include %}{% include {{[id]}}-summary.md id="{{[id]}}" %}{% endcapture %}{{ my-include | markdownify }}
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy    {% else %}
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy      {% include {{[type]}}-{{[id]}}-summary.xhtml %}
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy    {% endif%}
#
#  2019-05-25 17:00:57,057 - INFO- appended this line to copy <!--{% raw %}
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy {% include {{[id]}}-summary.md id="{{[id]}}" %}
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy {% endraw %}-->
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy {% endunless %}
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy <!-- =======Differential level 1======== -->
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy  <div id="all-tbl-diff">
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy    <p><b>Differential View</b></p>
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy    <div id="all-tbl-diff-inner">
#
#  2019-05-25 17:00:57,058 - INFO- appended this line to copy      {% include {{[type]}}-{{[id]}}-diff.xhtml %}
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy    <!-- =======Differential level 2 ( if want to show an intermediate diff if profiling a profile) ========= -->
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy {% if site.diff2 %}
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy       <div id="all-tbl-diff2-inner">
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy         {% include {{[id]}}-diff2.md type="{{[type]}}" id="{{[id]}}" %}
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy       </div>
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy {% endif %}
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy </div>
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy <!-- =======Snapshot======== -->
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy {% unless site.data.structuredefinitions.{{[id]}}.kind == "logical" %}
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy   <div id="all-tbl-snap">
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy    <p><b>Snapshot View</b></p>
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy    <div id="all-tbl-snap-inner">
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy      {% include {{[type]}}-{{[id]}}-snapshot.xhtml %}
#
#  2019-05-25 17:00:57,059 - INFO- appended this line to copy    </div>
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy {% endunless %}
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy <!-- =======XML and JSON ======== -->
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy     {% if showPsuedoJson %}
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy         <div id="all-xml">
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy          <p><b>XML Template</b></p>
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy          <div id="all-xml-inner">
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy       {% include {{[type]}}-{{[id]}}-pseudo-xml.xhtml %}
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy          </div>
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy         </div>
#
#  2019-05-25 17:00:57,060 - INFO- appended this line to copy     {% endif %}
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy     {% if showPsuedoXML %}
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy         <div id="all-json">
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy          <p><b>JSON Template</b></p>
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy          <div id="all-json-inner">
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy             <pre class="spec">
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy              {% include {{[type]}}-{{[id]}}-pseudo-json.xhtml %}
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy             </pre>
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy         </div>
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy       </div>
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy     {% endif %}
#
#  2019-05-25 17:00:57,061 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy  </div>
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy </div>
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy <br />
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy {% if site.data.structuredefinitions.{{[id]}}.kind == "resource" %}
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy <a name="downloads"> </a>
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy <p>Downloads: StructureDefinition: (<a href="{{[type]}}-{{[id]}}.xml" download>XML</a>, <a href="{{[type]}}-{{[id]}}.json" download>JSON</a>), Schema:  <a href="{{[id]}}.sch" download>XML Schematron</a></p>
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy <br />
#
#  2019-05-25 17:00:57,062 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy   <!-- search text here-->
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy   <a name="search"> </a>
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy   <h3>Quick Start</h3>
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy   <p>Below is an overview of the required set of RESTful FHIR interactions - for example, search and read operations - for this profile.  See the <a href="capstatements.html">Conformance requirements</a> for a complete list of supported RESTful interactions for this IG.</p>
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy   {% capture my-include %}{% include {{[id]}}-search.md id="{{[id]}}" %}{% endcapture %}{{ my-include | markdownify }}
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy {% elsif site.data.structuredefinitions.{{[id]}}.kind == "logical" %}
#
#  2019-05-25 17:00:57,063 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy <br />
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy   <a name="mapping-tables"> </a>
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy   <h3>Mappings</h3>
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy   <p>Below are mappings for this model. These mappings are informative and are provided to help implementers of this specification understand the content and use it correctly.</p>
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy   <div markdown='0'>
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy       <!--reduce the header size -->
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy   {% capture mapping %}{% include StructureDefinition-{{id}}-maps.xhtml %}{% endcapture %}
#
#  2019-05-25 17:00:57,064 - INFO- appended this line to copy   {{ mapping| replace: 'h3', 'b' }}
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy   </div>
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy   <br />
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy {% else %}
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy   <hr/>
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy    See the <a href="capstatements.html">Conformance requirements</a> for a complete list of supported RESTful interactions for this IG.</p>
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy {% endif %}
#
#  2019-05-25 17:00:57,065 - INFO- appended this line to copy   <!-- ==============END CONTENT END CONTENT=================== -->
#
#  2019-05-25 17:00:57,069 - INFO- End of program

# %% [markdown]
# ### Get qa.html output and display
# (or alternatively go here: consider using autopublish to share)

# %%
p = Path(r'/Users/ehaas/Documents/FHIR/IG-Template2/docs/qa.html')

display(HTML(p.read_text()))
# Out:
# ﻿<!DOCTYPE HTML>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <!-- broken links = 820, errors = 292, warn = 11, info = 99 -->
# <head>
#   <title>USCoreR4 : Validation Results</title>
#   <link href="fhir.css" rel="stylesheet"/>
# </head>
# <body style="margin: 20px; background-color: #ffffff">
#  <h1>Validation Results for USCoreR4</h1>
#  <p>Generated Sat May 25 17:03:39 PDT 2019. FHIR version 4.0.0 for hl7.fhir.us.core.r4validator#0.0.0 (canonical = <a href="http://hl7.org/fhir/us/core">http://hl7.org/fhir/us/core</a> (<a href="http://hl7.org/fhir/us/core/history.html">history</a>))</p>
# <p>No Suppressed Errors</p>
#  <p>HL7 Publication check:</p> <ul>
#   <li>History Page 'history' is wrong (ig.json#paths/history) - must be 'http://hl7.org/fhir/us/core/history.html' or 'http://hl7.org/fhir/us/core/history.cfml'</li>
#   <li>package-list.json: file not found in /Users/ehaas/Documents/FHIR/IG-Template2</li>
# </ul>
#
#  <table class="grid">
#    <tr>
#      <td><b>Filename</b></td><td><b>Errors</b></td><td><b>Information messages &amp; Warnings</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#internal"><b>Build Errors</b></a></td><td><b>820</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-allergyintolerance-eyHIVsZwhzaZhX9XvFesx5A3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-allergyintolerance-eyHIVsZwhzaZhX9XvFesx5A3</b></a></td><td><b>1</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-encounter-e1Jw-ETrL1kZAPiXl3uSMWw3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-encounter-e1Jw-ETrL1kZAPiXl3uSMWw3</b></a></td><td><b>3</b></td><td><b>1</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-encounter-eZAjx5sRd6AgpTlKjDh4b5w3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-encounter-eZAjx5sRd6AgpTlKjDh4b5w3</b></a></td><td><b>3</b></td><td><b>2</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-encounter-ehoN2kZnYuW5z0Di4Kkno5w3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-encounter-ehoN2kZnYuW5z0Di4Kkno5w3</b></a></td><td><b>3</b></td><td><b>1</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-encounter-eiSX3g2gt4tJIs7-6h7nJjA3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-encounter-eiSX3g2gt4tJIs7-6h7nJjA3</b></a></td><td><b>3</b></td><td><b>1</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-encounter-ejPvGuBUqYJkCweOPRabvYg3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-encounter-ejPvGuBUqYJkCweOPRabvYg3</b></a></td><td><b>3</b></td><td><b>1</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-patient-eroCd17NbCffM3E3WXi7eOQ3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-patient-eroCd17NbCffM3E3WXi7eOQ3</b></a></td><td><b>11</b></td><td><b>2</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_examples_epic-practitioner-e7D.u41Zv3VPrLmUp-mWnrQ3"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/examples/epic-practitioner-e7D.u41Zv3VPrLmUp-mWnrQ3</b></a></td><td><b>1</b></td><td><b>8</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_capabilitystatement-us-core-client"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/capabilitystatement-us-core-client</b></a></td><td><b>90</b></td><td><b>47</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_capabilitystatement-us-core-server"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/capabilitystatement-us-core-server</b></a></td><td><b>90</b></td><td><b>47</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_codesystem-careplan-category"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/codesystem-careplan-category</b></a></td><td><b>1</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_codesystem-cdcrec"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/codesystem-cdcrec</b></a></td><td><b>1</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_codesystem-condition-category"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/codesystem-condition-category</b></a></td><td><b>1</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #EFFFEF">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_codesystem-us-core-documentreference-category"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/codesystem-us-core-documentreference-category</b></a></td><td><b>0</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #EFFFEF">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_conceptmap-ndc-cvx"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/conceptmap-ndc-cvx</b></a></td><td><b>0</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #EFFFEF">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_encounter-us-core-profile-spreadsheet"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/encounter-us-core-profile-spreadsheet</b></a></td><td><b>0</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #EFFFEF">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_ig"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/ig</b></a></td><td><b>0</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #EFFFEF">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_operationdefinition-docref"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/operationdefinition-docref</b></a></td><td><b>0</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #EFFFEF">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_practitionerrole-us-core-profile-spreadsheet"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/practitionerrole-us-core-profile-spreadsheet</b></a></td><td><b>0</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_searchparameter-us-core-allergyintolerance-clinical-status"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/searchparameter-us-core-allergyintolerance-clinical-status</b></a></td><td><b>1</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_Documents_FHIR_USCoreR4Validator_source_resources_searchparameter-us-core-allergyintolerance-patient"><b>/Users/ehaas/Documents/FHIR/USCoreR4Validator/source/resources/searchparameter-us-core-allergyintolerance-patient</b></a></td><td><b>1</b></td><td><b>0</b></td>
#    </tr>
#    <tr style="background-color: #ffcccc">
#      <td><a href="#_Users_ehaas_D
