# %%
ref_map = {
    "MessageHeader/messageheader-20200804054600.902959": "urn:uuid:cafd8476-d615-11ea-87a1-98ff6d06d9d0",
    "Encounter/02ba9ec6-0712-4715-8ba4-5485fc571403": "urn:uuid:cafdac9e-d615-11ea-ba88-98ff6d06d9d0",
    "Patient/aad0894e-47f4-4ffc-8fab-8fe5487110d2": "urn:uuid:cafdac9f-d615-11ea-88cc-98ff6d06d9d0",
    "Location/76ebe279-211e-493a-8318-4bc784129ac5": "urn:uuid:cafdaca0-d615-11ea-a851-98ff6d06d9d0",
    "Practitioner/0000016f-57cb-cdac-0000-00000000019a": "urn:uuid:cafdd28a-d615-11ea-ab2b-98ff6d06d9d0",
    "Organization/db0acede-4abe-3c01-8d03-5c68a190d8c7": "urn:uuid:cafdd28b-d615-11ea-aa5e-98ff6d06d9d0",
    "Condition/5e83a7b0-6ce9-48c0-aede-81ef3a12b69e": "urn:uuid:cafdd28c-d615-11ea-ae1a-98ff6d06d9d0",
    "Coverage/ccb4874a-2bf4-11ea-a5f5-a4d18ccf5172": "urn:uuid:cafdd28d-d615-11ea-a1b5-98ff6d06d9d0",
    "Organization/ccb48ab0-2bf4-11ea-a5f5-a4d18ccf5172": "urn:uuid:cafdd28e-d615-11ea-8222-98ff6d06d9d0",
    "Organization/sending-organization": "urn:uuid:cafdd28f-d615-11ea-a2ec-98ff6d06d9d0",
    "Provenance/messageheader-provenance-20200804054600.902959": "urn:uuid:cafdd290-d615-11ea-a7b7-98ff6d06d9d0",
    "Provenance/bundle-provenance-20200804054600.902959": "urn:uuid:cafdf954-d615-11ea-92db-98ff6d06d9d0"
}

# %%
B ='''
{
    "id": "davinci-notifications-bundle-20200804054607.644099",
    "entry": [
        {
            "fullUrl": "urn:uuid:cafd8476-d615-11ea-87a1-98ff6d06d9d0",
            "resource": {
                "id": "messageheader-20200804054600.902959",
                "author": {
                    "display": "Dr. Raina861 Willms744",
                    "reference": "urn:uuid:cafdd28a-d615-11ea-ab2b-98ff6d06d9d0"
                },
                "destination": [
                    {
                        "endpoint": "https://davinci-alerts-receiver.logicahealth.org/fhir",
                        "name": "Alerts-RI"
                    }
                ],
                "eventCoding": {
                    "code": "notification-transfer",
                    "display": "Notification Transfer",
                    "system": "http://hl7.org/fhir/us/davinci-alerts/CodeSystem/notification-event"
                },
                "focus": [
                    {
                        "display": "Notification Transfer(Examplotomy Encounter)",
                        "reference": "urn:uuid:cafdac9e-d615-11ea-ba88-98ff6d06d9d0"
                    }
                ],
                "responsible": {
                    "display": "SOUTH SHORE HOSPITAL",
                    "reference": "urn:uuid:cafdd28b-d615-11ea-aa5e-98ff6d06d9d0"
                },
                "sender": {
                    "display": "Acme Message Sender",
                    "reference": "urn:uuid:cafdd28f-d615-11ea-a2ec-98ff6d06d9d0"
                },
                "source": {
                    "contact": {
                        "system": "phone",
                        "value": "+1 (555) 123 4567"
                    },
                    "endpoint": "https://example.org/Endpoints/P456",
                    "name": "Acme Central Patient Registry",
                    "software": "FooBar Patient Manager",
                    "version": "3.1.45.AABB"
                },
                "resourceType": "MessageHeader"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdac9e-d615-11ea-ba88-98ff6d06d9d0",
            "resource": {
                "id": "02ba9ec6-0712-4715-8ba4-5485fc571403",
                "class": {
                    "code": "IMP",
                    "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode"
                },
                "hospitalization": {
                    "admitSource": {
                        "coding": [
                            {
                                "code": "transfer",
                                "display": "Transfer",
                                "system": "http://terminology.hl7.org/CodeSystem/admit-source"
                            }
                        ],
                        "text": "Transfer"
                    }
                },
                "identifier": [
                    {
                        "system": "http://example.org",
                        "value": "Jama227Corwin84620190706T1847440700"
                    }
                ],
                "location": [
                    {
                        "location": {
                            "display": "SOUTH SHORE HOSPITAL",
                            "reference": "urn:uuid:cafdaca0-d615-11ea-a851-98ff6d06d9d0"
                        }
                    }
                ],
                "participant": [
                    {
                        "individual": {
                            "display": "Dr. Raina861 Willms744",
                            "reference": "urn:uuid:cafdd28a-d615-11ea-ab2b-98ff6d06d9d0"
                        }
                    }
                ],
                "period": {
                    "end": "2019-07-06T19:47:44-07:00",
                    "start": "2019-07-06T18:47:44-07:00"
                },
                "serviceProvider": {
                    "display": "SOUTH SHORE HOSPITAL",
                    "reference": "urn:uuid:cafdd28b-d615-11ea-aa5e-98ff6d06d9d0"
                },
                "status": "in-progress",
                "subject": {
                    "display": "Ms. Jama227 Corwin846",
                    "reference": "urn:uuid:cafdac9f-d615-11ea-88cc-98ff6d06d9d0"
                },
                "type": [
                    {
                        "coding": [
                            {
                                "code": "1234",
                                "display": "Examplotomy Encounter",
                                "system": "http://snomed.info/sct"
                            }
                        ],
                        "text": "Examplotomy Encounter"
                    }
                ],
                "resourceType": "Encounter"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdac9f-d615-11ea-88cc-98ff6d06d9d0",
            "resource": {
                "id": "aad0894e-47f4-4ffc-8fab-8fe5487110d2",
                "extension": [
                    {
                        "extension": [
                            {
                                "url": "ombCategory",
                                "valueCoding": {
                                    "code": "2106-3",
                                    "display": "White",
                                    "system": "urn:oid:2.16.840.1.113883.6.238"
                                }
                            },
                            {
                                "url": "text",
                                "valueString": "White"
                            }
                        ],
                        "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race"
                    },
                    {
                        "extension": [
                            {
                                "url": "ombCategory",
                                "valueCoding": {
                                    "code": "2186-5",
                                    "display": "Not Hispanic or Latino",
                                    "system": "urn:oid:2.16.840.1.113883.6.238"
                                }
                            },
                            {
                                "url": "text",
                                "valueString": "Not Hispanic or Latino"
                            }
                        ],
                        "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity"
                    },
                    {
                        "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
                        "valueString": "Becky854 Crist667"
                    },
                    {
                        "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
                        "valueCode": "F"
                    },
                    {
                        "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
                        "valueAddress": {
                            "city": "Boston",
                            "country": "US",
                            "state": "Massachusetts"
                        }
                    }
                ],
                "address": [
                    {
                        "extension": [
                            {
                                "extension": [
                                    {
                                        "url": "latitude",
                                        "valueDecimal": 42.23059709875085
                                    },
                                    {
                                        "url": "longitude",
                                        "valueDecimal": -71.04894935227846
                                    }
                                ],
                                "url": "http://hl7.org/fhir/StructureDefinition/geolocation"
                            }
                        ],
                        "city": "Braintree",
                        "country": "US",
                        "line": [
                            "801 Wolf Quay Suite 61"
                        ],
                        "state": "MA"
                    }
                ],
                "birthDate": "2001-06-30",
                "communication": [
                    {
                        "language": {
                            "coding": [
                                {
                                    "code": "en-US",
                                    "display": "English (Region=United States)",
                                    "system": "urn:ietf:bcp:47"
                                }
                            ],
                            "text": "English"
                        }
                    }
                ],
                "gender": "female",
                "identifier": [
                    {
                        "system": "https://github.com/synthetichealth/synthea",
                        "value": "aad0894e-47f4-4ffc-8fab-8fe5487110d2"
                    },
                    {
                        "system": "http://hospital.smarthealthit.org",
                        "type": {
                            "coding": [
                                {
                                    "code": "MR",
                                    "display": "Medical Record Number",
                                    "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
                                }
                            ],
                            "text": "Medical Record Number"
                        },
                        "value": "aad0894e-47f4-4ffc-8fab-8fe5487110d2"
                    },
                    {
                        "system": "http://hl7.org/fhir/sid/us-ssn",
                        "type": {
                            "coding": [
                                {
                                    "code": "SS",
                                    "display": "Social Security Number",
                                    "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
                                }
                            ],
                            "text": "Social Security Number"
                        },
                        "value": "999-21-5963"
                    },
                    {
                        "system": "urn:oid:2.16.840.1.113883.4.3.25",
                        "type": {
                            "coding": [
                                {
                                    "code": "DL",
                                    "display": "Driver's license number",
                                    "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
                                }
                            ],
                            "text": "Driver's License"
                        },
                        "value": "S99984181"
                    }
                ],
                "maritalStatus": {
                    "coding": [
                        {
                            "code": "S",
                            "display": "Never Married",
                            "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus"
                        }
                    ],
                    "text": "Never Married"
                },
                "multipleBirthBoolean": false,
                "name": [
                    {
                        "family": "Corwin846",
                        "given": [
                            "Jama227"
                        ],
                        "prefix": [
                            "Ms."
                        ],
                        "use": "official"
                    }
                ],
                "telecom": [
                    {
                        "system": "phone",
                        "use": "home",
                        "value": "555-442-3071"
                    }
                ],
                "resourceType": "Patient"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdaca0-d615-11ea-a851-98ff6d06d9d0",
            "resource": {
                "id": "76ebe279-211e-493a-8318-4bc784129ac5",
                "address": {
                    "city": "SOUTH WEYMOUTH",
                    "country": "US",
                    "line": [
                        "55 FOGG ROAD"
                    ],
                    "postalCode": "02190",
                    "state": "MA"
                },
                "managingOrganization": {
                    "display": "SOUTH SHORE HOSPITAL",
                    "reference": "urn:uuid:cafdd28b-d615-11ea-aa5e-98ff6d06d9d0"
                },
                "name": "SOUTH SHORE HOSPITAL",
                "position": {
                    "latitude": 42.24158900000001,
                    "longitude": -71.082651
                },
                "status": "active",
                "telecom": [
                    {
                        "system": "phone",
                        "value": "7813408000"
                    }
                ],
                "resourceType": "Location"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd28a-d615-11ea-ab2b-98ff6d06d9d0",
            "resource": {
                "id": "0000016f-57cb-cdac-0000-00000000019a",
                "active": true,
                "address": [
                    {
                        "city": "SOUTH WEYMOUTH",
                        "country": "US",
                        "line": [
                            "55 FOGG ROAD"
                        ],
                        "postalCode": "02190",
                        "state": "MA"
                    }
                ],
                "gender": "female",
                "identifier": [
                    {
                        "system": "http://hl7.org/fhir/sid/us-npi",
                        "value": "410"
                    }
                ],
                "name": [
                    {
                        "family": "Willms744",
                        "given": [
                            "Raina861"
                        ],
                        "prefix": [
                            "Dr."
                        ]
                    }
                ],
                "telecom": [
                    {
                        "extension": [
                            {
                                "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-direct",
                                "valueBoolean": true
                            }
                        ],
                        "system": "email",
                        "use": "work",
                        "value": "Raina861.Willms744@example.com"
                    }
                ],
                "resourceType": "Practitioner"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd28b-d615-11ea-aa5e-98ff6d06d9d0",
            "resource": {
                "id": "db0acede-4abe-3c01-8d03-5c68a190d8c7",
                "active": true,
                "address": [
                    {
                        "city": "SOUTH WEYMOUTH",
                        "country": "US",
                        "line": [
                            "55 FOGG ROAD"
                        ],
                        "postalCode": "02190",
                        "state": "MA"
                    }
                ],
                "identifier": [
                    {
                        "system": "https://github.com/synthetichealth/synthea",
                        "value": "db0acede-4abe-3c01-8d03-5c68a190d8c7"
                    }
                ],
                "name": "SOUTH SHORE HOSPITAL",
                "telecom": [
                    {
                        "system": "phone",
                        "value": "7813408000"
                    }
                ],
                "type": [
                    {
                        "coding": [
                            {
                                "code": "prov",
                                "display": "Healthcare Provider",
                                "system": "http://terminology.hl7.org/CodeSystem/organization-type"
                            }
                        ],
                        "text": "Healthcare Provider"
                    }
                ],
                "resourceType": "Organization"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd28c-d615-11ea-ae1a-98ff6d06d9d0",
            "resource": {
                "id": "5e83a7b0-6ce9-48c0-aede-81ef3a12b69e",
                "category": [
                    {
                        "coding": [
                            {
                                "code": "encounter-diagnosis",
                                "display": "Encounter Diagnosis",
                                "system": "http://terminology.hl7.org/CodeSystem/condition-category"
                            }
                        ]
                    }
                ],
                "clinicalStatus": {
                    "coding": [
                        {
                            "code": "active",
                            "system": "http://terminology.hl7.org/CodeSystem/condition-clinical"
                        }
                    ]
                },
                "code": {
                    "coding": [
                        {
                            "code": "1234",
                            "display": "Examplitis",
                            "system": "http://snomed.info/sct"
                        }
                    ],
                    "text": "Examplitis"
                },
                "encounter": {
                    "reference": "urn:uuid:cafdac9e-d615-11ea-ba88-98ff6d06d9d0"
                },
                "onsetDateTime": "2019-07-06T18:47:44-07:00",
                "recordedDate": "2019-07-06T18:47:44-07:00",
                "subject": {
                    "reference": "urn:uuid:cafdac9f-d615-11ea-88cc-98ff6d06d9d0"
                },
                "verificationStatus": {
                    "coding": [
                        {
                            "code": "confirmed",
                            "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status"
                        }
                    ]
                },
                "resourceType": "Condition"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd28d-d615-11ea-a1b5-98ff6d06d9d0",
            "resource": {
                "id": "ccb4874a-2bf4-11ea-a5f5-a4d18ccf5172",
                "beneficiary": {
                    "reference": "urn:uuid:cafdac9f-d615-11ea-88cc-98ff6d06d9d0"
                },
                "payor": [
                    {
                        "display": "Anthem",
                        "reference": "urn:uuid:cafdd28e-d615-11ea-8222-98ff6d06d9d0"
                    }
                ],
                "status": "active",
                "subscriberId": "12345",
                "type": {
                    "text": "Anthem"
                },
                "resourceType": "Coverage"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd28e-d615-11ea-8222-98ff6d06d9d0",
            "resource": {
                "id": "ccb48ab0-2bf4-11ea-a5f5-a4d18ccf5172",
                "active": true,
                "address": [
                    {
                        "city": "Indianapolis",
                        "line": [
                            "220 Virginia Ave"
                        ],
                        "postalCode": "46204",
                        "state": "IN"
                    }
                ],
                "identifier": [
                    {
                        "system": "http://hl7.org/fhir/sid/us-npi",
                        "value": "0000010009"
                    }
                ],
                "name": "Anthem",
                "telecom": [
                    {
                        "system": "phone",
                        "use": "work",
                        "value": "1-800-331-1476"
                    }
                ],
                "resourceType": "Organization"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd28f-d615-11ea-a2ec-98ff6d06d9d0",
            "resource": {
                "id": "sending-organization",
                "active": true,
                "address": [
                    {
                        "city": "Chicago",
                        "line": [
                            "1 Main"
                        ],
                        "postalCode": "60007",
                        "state": "IL"
                    }
                ],
                "identifier": [
                    {
                        "system": "http://hl7.org/fhir/sid/us-npi",
                        "value": "0000010005"
                    }
                ],
                "name": "Acme Message Sender",
                "telecom": [
                    {
                        "system": "phone",
                        "use": "work",
                        "value": "1-800-555-5555"
                    }
                ],
                "resourceType": "Organization"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdd290-d615-11ea-a7b7-98ff6d06d9d0",
            "resource": {
                "id": "messageheader-provenance-20200804054600.902959",
                "agent": [
                    {
                        "type": {
                            "coding": [
                                {
                                    "code": "author",
                                    "display": "Author",
                                    "system": "http://terminology.hl7.org/CodeSystem/provenance-participant-type"
                                }
                            ]
                        },
                        "who": {
                            "reference": "urn:uuid:cafdd28f-d615-11ea-a2ec-98ff6d06d9d0"
                        }
                    }
                ],
                "recorded": "2020-08-04T05:46:00.902959Z",
                "target": [
                    {
                        "reference": "urn:uuid:cafd8476-d615-11ea-87a1-98ff6d06d9d0"
                    }
                ],
                "resourceType": "Provenance"
            }
        },
        {
            "fullUrl": "urn:uuid:cafdf954-d615-11ea-92db-98ff6d06d9d0",
            "resource": {
                "id": "bundle-provenance-20200804054600.902959",
                "agent": [
                    {
                        "type": {
                            "coding": [
                                {
                                    "code": "author",
                                    "display": "Author",
                                    "system": "http://terminology.hl7.org/CodeSystem/provenance-participant-type"
                                }
                            ]
                        },
                        "who": {
                            "reference": "urn:uuid:cafdd28f-d615-11ea-a2ec-98ff6d06d9d0"
                        }
                    }
                ],
                "recorded": "2020-08-04T05:46:00.902959Z",
                "target": [
                    {
                        "reference": "Bundle/davinci-notifications-bundle-20200804054607.644099"
                    }
                ],
                "resourceType": "Provenance"
            }
        }
    ],
    "timestamp": "2020-08-04T05:46:07.644099Z",
    "type": "message",
    "resourceType": "Bundle"
}
'''

# %%
for k,v in ref_map.items():
    print(f"{k.split('/')[-1]}={v.split(':')[-1]}")
# Out:
# messageheader-20200804054600.902959=cafd8476-d615-11ea-87a1-98ff6d06d9d0
# 02ba9ec6-0712-4715-8ba4-5485fc571403=cafdac9e-d615-11ea-ba88-98ff6d06d9d0
# aad0894e-47f4-4ffc-8fab-8fe5487110d2=cafdac9f-d615-11ea-88cc-98ff6d06d9d0
# 76ebe279-211e-493a-8318-4bc784129ac5=cafdaca0-d615-11ea-a851-98ff6d06d9d0
# 0000016f-57cb-cdac-0000-00000000019a=cafdd28a-d615-11ea-ab2b-98ff6d06d9d0
# db0acede-4abe-3c01-8d03-5c68a190d8c7=cafdd28b-d615-11ea-aa5e-98ff6d06d9d0
# 5e83a7b0-6ce9-48c0-aede-81ef3a12b69e=cafdd28c-d615-11ea-ae1a-98ff6d06d9d0
# ccb4874a-2bf4-11ea-a5f5-a4d18ccf5172=cafdd28d-d615-11ea-a1b5-98ff6d06d9d0
# ccb48ab0-2bf4-11ea-a5f5-a4d18ccf5172=cafdd28e-d615-11ea-8222-98ff6d06d9d0
# sending-organization=cafdd28f-d615-11ea-a2ec-98ff6d06d9d0
# messageheader-provenance-20200804054600.902959=cafdd290-d615-11ea-a7b7-98ff6d06d9d0
# bundle-provenance-20200804054600.902959=cafdf954-d615-11ea-92db-98ff6d06d9d0

# %%
from json import loads

D = loads(B)
for i in D['entry']:
    print(f"Type = {i['resource']['resourceType']}\n"
         f"  id = {i['resource']['id']}")
# Out:
# Type = MessageHeader
#   id = messageheader-20200804054600.902959
# Type = Encounter
#   id = 02ba9ec6-0712-4715-8ba4-5485fc571403
# Type = Patient
#   id = aad0894e-47f4-4ffc-8fab-8fe5487110d2
# Type = Location
#   id = 76ebe279-211e-493a-8318-4bc784129ac5
# Type = Practitioner
#   id = 0000016f-57cb-cdac-0000-00000000019a
# Type = Organization
#   id = db0acede-4abe-3c01-8d03-5c68a190d8c7
# Type = Condition
#   id = 5e83a7b0-6ce9-48c0-aede-81ef3a12b69e
# Type = Coverage
#   id = ccb4874a-2bf4-11ea-a5f5-a4d18ccf5172
# Type = Organization
#   id = ccb48ab0-2bf4-11ea-a5f5-a4d18ccf5172
# Type = Organization
#   id = sending-organization
# Type = Provenance
#   id = messageheader-provenance-20200804054600.902959
# Type = Provenance
#   id = bundle-provenance-20200804054600.902959

# %%
txt = "I like bananas"

txt = txt.replace("bananas", "apples")

print(txt)
# Out:
# I like apples

# %%
for k,v in ref_map.items():
    print(f'{v.split(':')[-1]} replaces {k}')
    B = B.replace('MessageHeader/messageheader-20200804054600.902959', 'foo')

D = loads(B)
for i in D['entry']:
    print(f"Type = {i['resource']['resourceType']}\n"
         f"  id = {i['resource']['id']}")
# Out:
# urn:uuid:cafd8476-d615-11ea-87a1-98ff6d06d9d0 replaces MessageHeader/messageheader-20200804054600.902959
# urn:uuid:cafdac9e-d615-11ea-ba88-98ff6d06d9d0 replaces Encounter/02ba9ec6-0712-4715-8ba4-5485fc571403
# urn:uuid:cafdac9f-d615-11ea-88cc-98ff6d06d9d0 replaces Patient/aad0894e-47f4-4ffc-8fab-8fe5487110d2
# urn:uuid:cafdaca0-d615-11ea-a851-98ff6d06d9d0 replaces Location/76ebe279-211e-493a-8318-4bc784129ac5
# urn:uuid:cafdd28a-d615-11ea-ab2b-98ff6d06d9d0 replaces Practitioner/0000016f-57cb-cdac-0000-00000000019a
# urn:uuid:cafdd28b-d615-11ea-aa5e-98ff6d06d9d0 replaces Organization/db0acede-4abe-3c01-8d03-5c68a190d8c7
# urn:uuid:cafdd28c-d615-11ea-ae1a-98ff6d06d9d0 replaces Condition/5e83a7b0-6ce9-48c0-aede-81ef3a12b69e
# urn:uuid:cafdd28d-d615-11ea-a1b5-98ff6d06d9d0 replaces Coverage/ccb4874a-2bf4-11ea-a5f5-a4d18ccf5172
# urn:uuid:cafdd28e-d615-11ea-8222-98ff6d06d9d0 replaces Organization/ccb48ab0-2bf4-11ea-a5f5-a4d18ccf5172
# ...
