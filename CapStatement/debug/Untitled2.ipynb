# %%
import sys, datetime, uuid

# %%
uri = uuid.uuid1()

dir(uri)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bytes',
#  'bytes_le',
#  'clock_seq',
#  'clock_seq_hi_variant',
#  'clock_seq_low',
#  'fields',
#  'hex',
#  'int',
#  'is_safe',
#  'node',
#  'time',
#  'time_hi_version',
#  'time_low',
#  'time_mid',
#  'urn',
#  'variant',
#  'version']

# %%
uuid.UUID('3c997af694-11ea-9a20-b5baa7182d44').urn
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-41c8d884680b> in <module>
# ----> 1 uuid.UUID('3c997af694-11ea-9a20-b5baa7182d44').urn
#
# c:\users\administrator\appdata\local\programs\python\python37-32\lib\uuid.py in __init__(self, hex, bytes, bytes_le, fields, int, version, is_safe)
#     158             hex = hex.strip('{}').replace('-', '')
#     159             if len(hex) != 32:
# --> 160                 raise ValueError('badly formed hexadecimal UUID string')
#     161             int = int_(hex, 16)
#     162         if bytes_le is not None:
#
# ValueError: badly formed hexadecimal UUID string

# %%
uri.urn, uri,hex, uri.int
# Out:
# ('urn:uuid:3c997af4-d694-11ea-9a20-b5baa7182d44',
#  UUID('3c997af4-d694-11ea-9a20-b5baa7182d44'),
#  <function hex(number, /)>,
#  80550595018502877716628892295903063364)

# %%
help(uuid)
# Out:
# Help on module uuid:
#
# NAME
#     uuid - UUID objects (universally unique identifiers) according to RFC 4122.
#
# DESCRIPTION
#     This module provides immutable UUID objects (class UUID) and the functions
#     uuid1(), uuid3(), uuid4(), uuid5() for generating version 1, 3, 4, and 5
#     UUIDs as specified in RFC 4122.
#
#     If all you want is a unique ID, you should probably call uuid1() or uuid4().
#     Note that uuid1() may compromise privacy since it creates a UUID containing
#     the computer's network address.  uuid4() creates a random UUID.
#
#     Typical usage:
#
#         >>> import uuid
#
#         # make a UUID based on the host ID and current time
#         >>> uuid.uuid1()    # doctest: +SKIP
#         UUID('a8098c1a-f86e-11da-bd1a-00112444be1e')
#
#         # make a UUID using an MD5 hash of a namespace UUID and a name
#         >>> uuid.uuid3(uuid.NAMESPACE_DNS, 'python.org')
#         UUID('6fa459ea-ee8a-3ca4-894e-db77e160355e')
#
# ...
