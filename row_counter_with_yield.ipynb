# %% [markdown]
# ## Search through Profile properties summaries using Jinja2 and Python Modele
#
# *USE Python 3.7 to maintain order of Json files*
#
# - Fetch SD file from IG
# - Spec_internals from IG Package.tgz
# - search for element properties
#
#
#
# *Note need a successful build to generate since based on ig output local file
# alternatively use package.files to generate*

# %% [markdown]
# ### import python modules including R4 fhirclient models

# %%
from fhirclient.r4models import structuredefinition as SD
import Summary_maker.title_map as tm
import os, json

# %% [markdown]
# ### Get file and return as dict

# %% [markdown]
# ### Write to file

# %% [markdown]
# ### Loop through profiles

# %%
us_core = '/Users/ehaas/.fhir/packages/hl7.fhir.us.core#dev/package'
fhir_r4 = '/Users/ehaas/.fhir/packages/hl7.fhir.r4.core#4.0.1/package'
#f_name = 'us-core-patient'
#n_path = '/Users/ehaas/.fhir/packages/hl7.fhir.us.core#dev' # package file keeps disappearing
#in_path = '//ERICS-AIR-2/ehaas/Documents/FHIR/US-Core-R4/output'  # use local build dir.
us_core_files = [x for x in os.listdir(us_core) if x.startswith("StructureDefinition") and x.endswith('json')]

# %%
fhir_r4_files = [x for x in os.listdir(fhir_r4) if x.startswith("StructureDefinition") and x.endswith('json')]
fhir_r4_files
# Out:
# ['StructureDefinition-cqf-strengthOfRecommendation.json',
#  'StructureDefinition-codesystem-alternate.json',
#  'StructureDefinition-relative-date.json',
#  'StructureDefinition-11179-objectClass.json',
#  'StructureDefinition-elementdefinition-equivalence.json',
#  'StructureDefinition-hdlcholesterol.json',
#  'StructureDefinition-SubstanceSpecification.json',
#  'StructureDefinition-oid.json',
#  'StructureDefinition-event-location.json',
#  'StructureDefinition-DeviceUseStatement.json',
#  'StructureDefinition-structuredefinition-explicit-type-name.json',
#  'StructureDefinition-diagnosticReport-summaryOf.json',
#  'StructureDefinition-BodyStructure.json',
#  'StructureDefinition-Attachment.json',
#  'StructureDefinition-communication-media.json',
#  'StructureDefinition-shareablelibrary.json',
#  'StructureDefinition-location-distance.json',
#  'StructureDefinition-ExampleScenario.json',
#  'StructureDefinition-Appointment.json',
#  'StructureDefinition-usagecontext-group.json',
#  'StructureDefinition-display.json',
#  'StructureDefinition-structuredefinition-ancestor.json',
#  'StructureDefinition-specimen-sequenceNumber.json',
#  'StructureDefinition-humanname-partner-name.json',
#  'StructureDefinition-elementdefinition-minValueSet.json',
#  'StructureDefinition-RelatedArtifact.json',
#  'StructureDefinition-Condition.json',
#  'StructureDefinition-codesystem-effectiveDate.json',
#  'StructureDefinition-valueset-sourceReference.json',
#  'StructureDefinition-List.json',
#  'StructureDefinition-elementdefinition-maxValueSet.json',
#  'StructureDefinition-patient-relatedPerson.json',
#  'StructureDefinition-questionnaire-supportLink.json',
#  'StructureDefinition-familymemberhistory-abatement.json',
#  'StructureDefinition-procedure-causedBy.json',
#  'StructureDefinition-ChargeItem.json',
#  'StructureDefinition-patient-citizenship.json',
#  'StructureDefinition-valueset-systemName.json',
#  'StructureDefinition-servicerequest-geneticsItem.json',
#  'StructureDefinition-elementdefinition-bestpractice.json',
#  'StructureDefinition-variable.json',
#  'StructureDefinition-Count.json',
#  'StructureDefinition-allergyintolerance-resolutionAge.json',
#  'StructureDefinition-VerificationResult.json',
#  'StructureDefinition-iso21090-ADXP-postBox.json',
#  'StructureDefinition-MedicinalProductUndesirableEffect.json',
#  'StructureDefinition-elementdefinition-bindingName.json',
#  'StructureDefinition-hla-genotyping-results-haploid.json',
#  'StructureDefinition-familymemberhistory-type.json',
#  'StructureDefinition-ContactDetail.json',
#  'StructureDefinition-patient-disability.json',
#  'StructureDefinition-uri.json',
#  'StructureDefinition-elementdefinition-de.json',
#  'StructureDefinition-observation-deviceCode.json',
#  'StructureDefinition-cqm-ValidityPeriod.json',
#  'StructureDefinition-iso21090-ADXP-deliveryMode.json',
#  'StructureDefinition-tz-code.json',
#  'StructureDefinition-codesystem-concept-comments.json',
#  'StructureDefinition-questionnaire-choiceOrientation.json',
#  'StructureDefinition-codesystem-otherName.json',
#  'StructureDefinition-Media.json',
#  'StructureDefinition-id.json',
#  'StructureDefinition-structuredefinition-normative-version.json',
#  'StructureDefinition-structuredefinition-wg.json',
#  'StructureDefinition-codesystem-warning.json',
#  'StructureDefinition-11179-objectClassProperty.json',
#  'StructureDefinition-SupplyDelivery.json',
#  'StructureDefinition-diagnosticreport-genetics.json',
#  'StructureDefinition-DiagnosticReport-geneticsFamilyMemberHistory.json',
#  'StructureDefinition-minValue.json',
#  'StructureDefinition-bodySite.json',
#  'StructureDefinition-http-response-header.json',
#  'StructureDefinition-computableplandefinition.json',
#  'StructureDefinition-Composition.json',
#  'StructureDefinition-observation-bodyPosition.json',
#  'StructureDefinition-rendering-xhtml.json',
#  'StructureDefinition-codesystem-usage.json',
#  'StructureDefinition-contactpoint-country.json',
#  'StructureDefinition-iso21090-ADXP-houseNumberNumeric.json',
#  'StructureDefinition-consent-NotificationEndpoint.json',
#  'StructureDefinition-goal-relationship.json',
#  'StructureDefinition-Encounter.json',
#  'StructureDefinition-MedicationAdministration.json',
#  'StructureDefinition-DocumentManifest.json',
#  'StructureDefinition-Claim.json',
#  'StructureDefinition-humanname-partner-prefix.json',
#  'StructureDefinition-DeviceMetric.json',
#  'StructureDefinition-patient-genderIdentity.json',
#  'StructureDefinition-codesystem-sourceReference.json',
#  'StructureDefinition-ElementDefinition.json',
#  'StructureDefinition-TriggerDefinition.json',
#  'StructureDefinition-synthesis.json',
#  'StructureDefinition-AuditEvent.json',
#  'StructureDefinition-ServiceRequest.json',
#  'StructureDefinition-patient-importance.json',
#  'StructureDefinition-EventDefinition.json',
#  'StructureDefinition-CarePlan.json',
#  'StructureDefinition-workflow-instantiatesUri.json',
#  'StructureDefinition-Linkage.json',
#  'StructureDefinition-device-implantStatus.json',
#  'StructureDefinition-CoverageEligibilityResponse.json',
#  'StructureDefinition-auditevent-Anonymized.json',
#  'StructureDefinition-iso21090-ADXP-streetAddressLine.json',
#  'StructureDefinition-data-absent-reason.json',
#  'StructureDefinition-workflow-relatedArtifact.json',
#  'StructureDefinition-time.json',
#  'StructureDefinition-base64Binary.json',
#  'StructureDefinition-QuestionnaireResponse.json',
#  'StructureDefinition-Location.json',
#  'StructureDefinition-InsurancePlan.json',
#  'StructureDefinition-originalText.json',
#  'StructureDefinition-Measure.json',
#  'StructureDefinition-condition-related.json',
#  'StructureDefinition-composition-section-subject.json',
#  'StructureDefinition-EffectEvidenceSynthesis.json',
#  'StructureDefinition-ActivityDefinition.json',
#  'StructureDefinition-shareablecodesystem.json',
#  'StructureDefinition-ldlcholesterol.json',
#  'StructureDefinition-iso21090-EN-qualifier.json',
#  'StructureDefinition-valueset-map.json',
#  'StructureDefinition-OrganizationAffiliation.json',
#  'StructureDefinition-patient-proficiency.json',
#  'StructureDefinition-cqf-systemUserType.json',
#  'StructureDefinition-questionnaireresponse-signature.json',
#  'StructureDefinition-EpisodeOfCare.json',
#  'StructureDefinition-observation-timeOffset.json',
#  'StructureDefinition-openEHR-test.json',
#  'StructureDefinition-string.json',
#  'StructureDefinition-questionnaireresponse-reviewer.json',
#  'StructureDefinition-goal-reasonRejected.json',
#  'StructureDefinition-event-basedOn.json',
#  'StructureDefinition-iso21090-preferred.json',
#  'StructureDefinition-event-statusReason.json',
#  'StructureDefinition-BackboneElement.json',
#  'StructureDefinition-DeviceRequest.json',
#  'StructureDefinition-patient-congregation.json',
#  'StructureDefinition-MedicinalProductManufactured.json',
#  'StructureDefinition-questionnaire-hidden.json',
#  'StructureDefinition-valueset-special-status.json',
#  'StructureDefinition-codesystem-author.json',
#  'StructureDefinition-allergyintolerance-assertedDate.json',
#  'StructureDefinition-procedure-targetBodyStructure.json',
#  'StructureDefinition-familymemberhistory-severity.json',
#  'StructureDefinition-valueset-expansionSource.json',
#  'StructureDefinition-humanname-assembly-order.json',
#  'StructureDefinition-markdown.json',
#  'StructureDefinition-CapabilityStatement.json',
#  'StructureDefinition-ContactPoint.json',
#  'StructureDefinition-Endpoint.json',
#  'StructureDefinition-cqf-recipientLanguage.json',
#  'StructureDefinition-structuredefinition-standards-status.json',
#  'StructureDefinition-SubstancePolymer.json',
#  'StructureDefinition-cqf-systemUserLanguage.json',
#  'StructureDefinition-structuredefinition-security-category.json',
#  'StructureDefinition-cdshooksguidanceresponse.json',
#  'StructureDefinition-resource-approvalDate.json',
#  'StructureDefinition-ordinalValue.json',
#  'StructureDefinition-questionnaire-usageMode.json',
#  'StructureDefinition-Annotation.json',
#  'StructureDefinition-Substance.json',
#  'StructureDefinition-oxygensat.json',
#  'StructureDefinition-observation-replaces.json',
#  'StructureDefinition-structuredefinition-xml-no-order.json',
#  'StructureDefinition-CatalogEntry.json',
#  'StructureDefinition-language.json',
#  'StructureDefinition-questionnaire-minOccurs.json',
#  'StructureDefinition-Meta.json',
#  'StructureDefinition-iso21090-SC-coding.json',
#  'StructureDefinition-Group.json',
#  'StructureDefinition-location-boundary-geojson.json',
#  'StructureDefinition-valueset-supplement.json',
#  'StructureDefinition-servicerequest-precondition.json',
#  'StructureDefinition-capabilitystatement-search-parameter-combination.json',
#  'StructureDefinition-structuredefinition-xml-type.json',
#  'StructureDefinition-request-performerOrder.json',
#  'StructureDefinition-observation-specimenCode.json',
#  'StructureDefinition-ImagingStudy.json',
#  'StructureDefinition-SubstanceAmount.json',
#  'StructureDefinition-valueset-steward.json',
#  'StructureDefinition-SubstanceNucleicAcid.json',
#  'StructureDefinition-observation-geneticsDNARegionName.json',
#  'StructureDefinition-questionnaire-signatureRequired.json',
#  'StructureDefinition-dateTime.json',
#  'StructureDefinition-valueset-warning.json',
#  'StructureDefinition-operationoutcome-detectedIssue.json',
#  'StructureDefinition-iso21090-ADXP-deliveryInstallationType.json',
#  'StructureDefinition-Organization.json',
#  'StructureDefinition-Contributor.json',
#  'StructureDefinition-MolecularSequence.json',
#  'StructureDefinition-valueset-usage.json',
#  'StructureDefinition-family-member-history-genetics-parent.json',
#  'StructureDefinition-organization-period.json',
#  'StructureDefinition-Population.json',
#  'StructureDefinition-boolean.json',
#  'StructureDefinition-identifier-validDate.json',
#  'StructureDefinition-openEHR-location.json',
#  'StructureDefinition-elementdefinition-inheritedExtensibleValueSet.json',
#  'StructureDefinition-match-grade.json',
#  'StructureDefinition-patient-adoptionInfo.json',
#  'StructureDefinition-cqf-receivingPerson.json',
#  'StructureDefinition-FiveWs.json',
#  'StructureDefinition-11179-permitted-value-conceptmap.json',
#  'StructureDefinition-shareableactivitydefinition.json',
#  'StructureDefinition-devicemetricobservation.json',
#  'StructureDefinition-quantity-precision.json',
#  'StructureDefinition-ChargeItemDefinition.json',
#  'StructureDefinition-openEHR-careplan.json',
#  'StructureDefinition-cqf-receivingOrganization.json',
#  'StructureDefinition-Questionnaire.json',
#  'StructureDefinition-actualgroup.json',
#  'StructureDefinition-Dosage.json',
#  'StructureDefinition-iso21090-EN-use.json',
#  'StructureDefinition-cqf-measureInfo.json',
#  'StructureDefinition-TestScript.json',
#  'StructureDefinition-elementdefinition-translatable.json',
#  'StructureDefinition-ResearchStudy.json',
#  'StructureDefinition-parameters-fullUrl.json',
#  'StructureDefinition-encounter-reasonCancelled.json',
#  'StructureDefinition-patient-animal.json',
#  'StructureDefinition-codesystem-conceptOrder.json',
#  'StructureDefinition-structuredefinition-hierarchy.json',
#  'StructureDefinition-condition-outcome.json',
#  'StructureDefinition-contactpoint-area.json',
#  'StructureDefinition-PractitionerRole.json',
#  'StructureDefinition-11179-permitted-value-valueset.json',
#  'StructureDefinition-TestReport.json',
#  'StructureDefinition-valueset-systemRef.json',
#  'StructureDefinition-resprate.json',
#  'StructureDefinition-Ratio.json',
#  'StructureDefinition-iso21090-ADXP-unitID.json',
#  'StructureDefinition-event-eventHistory.json',
#  'StructureDefinition-openEHR-exposureDate.json',
#  'StructureDefinition-consent-Transcriber.json',
#  'StructureDefinition-MeasureReport.json',
#  'StructureDefinition-auditevent-Instance.json',
#  'StructureDefinition-SubstanceSourceMaterial.json',
#  'StructureDefinition-mimeType.json',
#  'StructureDefinition-contactpoint-local.json',
#  'StructureDefinition-rendering-style.json',
#  'StructureDefinition-patient-preferenceType.json',
#  'StructureDefinition-SupplyRequest.json',
#  'StructureDefinition-structuredefinition-json-type.json',
#  'StructureDefinition-auditevent-Accession.json',
#  'StructureDefinition-regex.json',
#  'StructureDefinition-Coding.json',
#  'StructureDefinition-questionnaire-displayCategory.json',
#  'StructureDefinition-cqf-systemUserTaskContext.json',
#  'StructureDefinition-observation-geneticsAminoAcidChange.json',
#  'StructureDefinition-diagnosticReport-addendumOf.json',
#  'StructureDefinition-valueset-trusted-expansion.json',
#  'StructureDefinition-openEHR-exposureDescription.json',
#  'StructureDefinition-shareableplandefinition.json',
#  'StructureDefinition-valueset-conceptOrder.json',
#  'StructureDefinition-valueset-reference.json',
#  'StructureDefinition-questionnaireresponse-author.json',
#  'StructureDefinition-cqf-recipientType.json',
#  'StructureDefinition-valueset-toocostly.json',
#  'StructureDefinition-positiveInt.json',
#  'StructureDefinition-DataRequirement.json',
#  'StructureDefinition-task-replaces.json',
#  'StructureDefinition-tz-offset.json',
#  'StructureDefinition-translation.json',
#  'StructureDefinition-capabilitystatement-websocket.json',
#  'StructureDefinition-Provenance.json',
#  'StructureDefinition-Binary.json',
#  'StructureDefinition-RiskAssessment.json',
#  'StructureDefinition-DiagnosticReport-geneticsReferences.json',
#  'StructureDefinition-Parameters.json',
#  'StructureDefinition-HealthcareService.json',
#  'StructureDefinition-RelatedPerson.json',
#  'StructureDefinition-Evidence.json',
#  'StructureDefinition-observation-geneticsAllele.json',
#  'StructureDefinition-maxSize.json',
#  'StructureDefinition-questionnaire-itemControl.json',
#  'StructureDefinition-goal-acceptance.json',
#  'StructureDefinition-Basic.json',
#  'StructureDefinition-questionnaireresponse-completionMode.json',
#  'StructureDefinition-NamingSystem.json',
#  'StructureDefinition-codesystem-replacedby.json',
#  'StructureDefinition-VisionPrescription.json',
#  'StructureDefinition-EnrollmentRequest.json',
#  'StructureDefinition-hla-genotyping-results-method.json',
#  'StructureDefinition-Flag.json',
#  'StructureDefinition-Request.json',
#  'StructureDefinition-ParameterDefinition.json',
#  'StructureDefinition-humanname-mothers-family.json',
#  'StructureDefinition-patient-cadavericDonor.json',
#  'StructureDefinition-iso21090-ADXP-deliveryModeIdentifier.json',
#  'StructureDefinition-ExplanationOfBenefit.json',
#  'StructureDefinition-narrativeLink.json',
#  'StructureDefinition-Patient.json',
#  'StructureDefinition-cdshooksserviceplandefinition.json',
#  'StructureDefinition-uuid.json',
#  'StructureDefinition-servicerequest-genetics.json',
#  'StructureDefinition-iso21090-EN-representation.json',
#  'StructureDefinition-clinicaldocument.json',
#  'StructureDefinition-code.json',
#  'StructureDefinition-elementdefinition-identifier.json',
#  'StructureDefinition-MedicinalProduct.json',
#  'StructureDefinition-list-changeBase.json',
#  'StructureDefinition-workflow-episodeOfCare.json',
#  'StructureDefinition-Specimen.json',
#  'StructureDefinition-FamilyMemberHistory.json',
#  'StructureDefinition-example-section-library.json',
#  'StructureDefinition-observation-geneticsAncestry.json',
#  'StructureDefinition-triglyceride.json',
#  'StructureDefinition-iso21090-ADXP-buildingNumberSuffix.json',
#  'StructureDefinition-ResearchElementDefinition.json',
#  'StructureDefinition-structuredefinition-applicable-version.json',
#  'StructureDefinition-organization-preferredContact.json',
#  'StructureDefinition-OperationDefinition.json',
#  'StructureDefinition-MedicinalProductIndication.json',
#  'StructureDefinition-shareablevalueset.json',
#  'StructureDefinition-MarketingStatus.json',
#  'StructureDefinition-auditevent-ParticipantObjectContainsStudy.json',
#  'StructureDefinition-questionnaire-unit.json',
#  'StructureDefinition-elementdefinition-question.json',
#  'StructureDefinition-bmi.json',
#  'StructureDefinition-GraphDefinition.json',
#  'StructureDefinition-Medication.json',
#  'StructureDefinition-bodyweight.json',
#  'StructureDefinition-flag-detail.json',
#  'StructureDefinition-SimpleQuantity.json',
#  'StructureDefinition-valueset-keyWord.json',
#  'StructureDefinition-workflow-instantiatesCanonical.json',
#  'StructureDefinition-DiagnosticReport.json',
#  'StructureDefinition-valueset-label.json',
#  'StructureDefinition-AppointmentResponse.json',
#  'StructureDefinition-cqf-cdsHooksEndpoint.json',
#  'StructureDefinition-workflow-supportingInfo.json',
#  'StructureDefinition-nutritionorder-adaptiveFeedingDevice.json',
#  'StructureDefinition-composition-clinicaldocument-otherConfidentiality.json',
#  'StructureDefinition-hlaresult.json',
#  'StructureDefinition-cqf-expression.json',
#  'StructureDefinition-auditevent-Encrypted.json',
#  'StructureDefinition-auditevent-SOPClass.json',
#  'StructureDefinition-iso21090-nullFlavor.json',
#  'StructureDefinition-elementdefinition-allowedUnits.json',
#  'StructureDefinition-valueset-expand-group.json',
#  'StructureDefinition-rendering-markdown.json',
#  'StructureDefinition-RequestGroup.json',
#  'StructureDefinition-elementdefinition-isCommonBinding.json',
#  'StructureDefinition-observation-secondaryFinding.json',
#  'StructureDefinition-MessageHeader.json',
#  'StructureDefinition-bodytemp.json',
#  'StructureDefinition-resource-lastReviewDate.json',
#  'StructureDefinition-cqf-encounterClass.json',
#  'StructureDefinition-iso21090-PQ-translation.json',
#  'StructureDefinition-integer.json',
#  'StructureDefinition-xhtml.json',
#  'StructureDefinition-DeviceDefinition.json',
#  'StructureDefinition-Goal.json',
#  'StructureDefinition-questionnaire-referenceProfile.json',
#  'StructureDefinition-ObservationDefinition.json',
#  'StructureDefinition-Timing.json',
#  'StructureDefinition-valueset-concept-comments.json',
#  'StructureDefinition-auditevent-MPPS.json',
#  'StructureDefinition-valueset-parameterSource.json',
#  'StructureDefinition-familymemberhistory-patient-record.json',
#  'StructureDefinition-diagnosticReport-replaces.json',
#  'StructureDefinition-valueset-caseSensitive.json',
#  'StructureDefinition-operationoutcome-authority.json',
#  'StructureDefinition-observation-geneticsInterpretation.json',
#  'StructureDefinition-practitionerrole-primaryInd.json',
#  'StructureDefinition-Immunization.json',
#  'StructureDefinition-condition-occurredFollowing.json',
#  'StructureDefinition-capabilitystatement-expectation.json',
#  'StructureDefinition-diagnosticReport-risk.json',
#  'StructureDefinition-valueset-unclosed.json',
#  'StructureDefinition-valueset-system.json',
#  'StructureDefinition-heartrate.json',
#  'StructureDefinition-designNote.json',
#  'StructureDefinition-humanname-own-name.json',
#  'StructureDefinition-ValueSet.json',
#  'StructureDefinition-iso21090-ADXP-unitType.json',
#  'StructureDefinition-questionnaire-optionPrefix.json',
#  'StructureDefinition-ClaimResponse.json',
#  'StructureDefinition-structuredefinition-display-hint.json',
#  'StructureDefinition-contactpoint-extension.json',
#  'StructureDefinition-patient-religion.json',
#  'StructureDefinition-Contract.json',
#  'StructureDefinition-Element.json',
#  'StructureDefinition-BiologicallyDerivedProduct.json',
#  'StructureDefinition-observation-reagent.json',
#  'StructureDefinition-Period.json',
#  'StructureDefinition-flag-priority.json',
#  'StructureDefinition-replaces.json',
#  'StructureDefinition-date.json',
#  'StructureDefinition-codesystem-history.json',
#  'StructureDefinition-questionnaireresponse-reason.json',
#  'StructureDefinition-iso21090-ADXP-delimiter.json',
#  'StructureDefinition-valueset-deprecated.json',
#  'StructureDefinition-allergyintolerance-substanceExposureRisk.json',
#  'StructureDefinition-Extension.json',
#  'StructureDefinition-encounter-modeOfArrival.json',
#  'StructureDefinition-iso21090-ADXP-direction.json',
#  'StructureDefinition-TerminologyCapabilities.json',
#  'StructureDefinition-coding-sctdescid.json',
#  'StructureDefinition-ehrsrle-auditevent.json',
#  'StructureDefinition-bp.json',
#  'StructureDefinition-iso21090-ADXP-streetNameBase.json',
#  'StructureDefinition-SpecimenDefinition.json',
#  'StructureDefinition-picoelement.json',
#  'StructureDefinition-valueset-rules-text.json',
#  'StructureDefinition-ProductShelfLife.json',
#  'StructureDefinition-consent-location.json',
#  'StructureDefinition-entryFormat.json',
#  'StructureDefinition-minLength.json',
#  'StructureDefinition-MedicinalProductIngredient.json',
#  'StructureDefinition-ConceptMap.json',
#  'StructureDefinition-Signature.json',
#  'StructureDefinition-allergyintolerance-duration.json',
#  'StructureDefinition-humanname-fathers-family.json',
#  'StructureDefinition-timing-daysOfCycle.json',
#  'StructureDefinition-encounter-associatedEncounter.json',
#  'StructureDefinition-structuredefinition-template-status.json',
#  'StructureDefinition-Duration.json',
#  'StructureDefinition-elementdefinition-selector.json',
#  'StructureDefinition-devicerequest-patientInstruction.json',
#  'StructureDefinition-Definition.json',
#  'StructureDefinition-Invoice.json',
#  'StructureDefinition-vitalspanel.json',
#  'StructureDefinition-url.json',
#  'StructureDefinition-StructureDefinition.json',
#  'StructureDefinition-elementdefinition-profile-element.json',
#  'StructureDefinition-cqf-library.json',
#  'StructureDefinition-CommunicationRequest.json',
#  'StructureDefinition-MedicinalProductInteraction.json',
#  'StructureDefinition-iso21090-uncertaintyType.json',
#  'StructureDefinition-cqf-qualityOfEvidence.json',
#  'StructureDefinition-Identifier.json',
#  'StructureDefinition-patient-nationality.json',
#  'StructureDefinition-PaymentNotice.json',
#  'StructureDefinition-workflow-reasonReference.json',
#  'StructureDefinition-GuidanceResponse.json',
#  'StructureDefinition-RiskEvidenceSynthesis.json',
#  'StructureDefinition-MedicinalProductPackaged.json',
#  'StructureDefinition-patient-birthPlace.json',
#  'StructureDefinition-valueset-expression.json',
#  'StructureDefinition-family-member-history-genetics-observation.json',
#  'StructureDefinition-concept-bidirectional.json',
#  'StructureDefinition-iso21090-ADXP-deliveryAddressLine.json',
#  'StructureDefinition-task-candidateList.json',
#  'StructureDefinition-timing-dayOfMonth.json',
#  'StructureDefinition-resource-pertainsToGoal.json',
#  'StructureDefinition-DetectedIssue.json',
#  'StructureDefinition-ResearchDefinition.json',
#  'StructureDefinition-procedure-approachBodyStructure.json',
#  'StructureDefinition-cqf-calculatedValue.json',
#  'StructureDefinition-HumanName.json',
#  'StructureDefinition-cqf-citation.json',
#  'StructureDefinition-MedicinalProductPharmaceutical.json',
#  'StructureDefinition-iso21090-ADXP-streetNameType.json',
#  'StructureDefinition-observation-delta.json',
#  'StructureDefinition-timing-exact.json',
#  'StructureDefinition-condition-assertedDate.json',
#  'StructureDefinition-questionnaire-constraint.json',
#  'StructureDefinition-cdshooksrequestgroup.json',
#  'StructureDefinition-groupdefinition.json',
#  'StructureDefinition-familymemberhistory-genetic.json',
#  'StructureDefinition-EvidenceVariable.json',
#  'StructureDefinition-valueset-otherName.json',
#  'StructureDefinition-catalog.json',
#  'StructureDefinition-instant.json',
#  'StructureDefinition-event-partOf.json',
#  'StructureDefinition-messageheader-response-request.json',
#  'StructureDefinition-iso21090-ADXP-houseNumber.json',
#  'StructureDefinition-headcircum.json',
#  'StructureDefinition-allergyintolerance-certainty.json',
#  'StructureDefinition-capabilities.json',
#  'StructureDefinition-shareablemeasure.json',
#  'StructureDefinition-codesystem-trusted-expansion.json',
#  'StructureDefinition-valueset-concept-definition.json',
#  'StructureDefinition-Bundle.json',
#  'StructureDefinition-MessageDefinition.json',
#  'StructureDefinition-ImplementationGuide.json',
#  'StructureDefinition-NutritionOrder.json',
#  'StructureDefinition-procedure-method.json',
#  'StructureDefinition-Expression.json',
#  'StructureDefinition-EnrollmentResponse.json',
#  'StructureDefinition-questionnaire-maxOccurs.json',
#  'StructureDefinition-CoverageEligibilityRequest.json',
#  'StructureDefinition-allergyintolerance-reasonRefuted.json',
#  'StructureDefinition-structuredefinition-summary.json',
#  'StructureDefinition-Range.json',
#  'StructureDefinition-iso21090-ADXP-careOf.json',
#  'StructureDefinition-Reference.json',
#  'StructureDefinition-valueset-extensible.json',
#  'StructureDefinition-iso21090-ADXP-censusTract.json',
#  'StructureDefinition-request-relevantHistory.json',
#  'StructureDefinition-CodeSystem.json',
#  'StructureDefinition-MedicationRequest.json',
#  'StructureDefinition-iso21090-ADXP-deliveryInstallationQualifier.json',
#  'StructureDefinition-openEHR-administration.json',
#  'StructureDefinition-specimen-processingTime.json',
#  'StructureDefinition-hla-genotyping-results-glstring.json',
#  'StructureDefinition-cqf-initialValue.json',
#  'StructureDefinition-valueset-expirationDate.json',
#  'StructureDefinition-elementdefinition-namespace.json',
#  'StructureDefinition-provenance-relevant-history.json',
#  'StructureDefinition-valueset-effectiveDate.json',
#  'StructureDefinition-cqllibrary.json',
#  'StructureDefinition-ImmunizationRecommendation.json',
#  'StructureDefinition-oauth-uris.json',
#  'StructureDefinition-observation-genetics.json',
#  'StructureDefinition-Resource.json',
#  'StructureDefinition-DomainResource.json',
#  'StructureDefinition-specimen-specialHandling.json',
#  'StructureDefinition-Slot.json',
#  'StructureDefinition-workflow-reasonCode.json',
#  'StructureDefinition-CompartmentDefinition.json',
#  'StructureDefinition-vitalsigns.json',
#  'StructureDefinition-organizationaffiliation-primaryInd.json',
#  'StructureDefinition-Coverage.json',
#  'StructureDefinition-PaymentReconciliation.json',
#  'StructureDefinition-structuredefinition-rdf-type.json',
#  'StructureDefinition-cqf-questionnaire.json',
#  'StructureDefinition-MedicationKnowledge.json',
#  'StructureDefinition-questionnaire-optionExclusive.json',
#  'StructureDefinition-operationdefinition-allowed-type.json',
#  'StructureDefinition-procedure-progressStatus.json',
#  'StructureDefinition-SubstanceReferenceInformation.json',
#  'StructureDefinition-humanname-own-prefix.json',
#  'StructureDefinition-questionnaire-referenceResource.json',
#  'StructureDefinition-iso21090-uncertainty.json',
#  'StructureDefinition-lipidprofile.json',
#  'StructureDefinition-structuredefinition-fhir-type.json',
#  'StructureDefinition-ImmunizationEvaluation.json',
#  'StructureDefinition-SearchParameter.json',
#  'StructureDefinition-diagnosticReport-extends.json',
#  'StructureDefinition-Narrative.json',
#  'StructureDefinition-capabilitystatement-supported-system.json',
#  'StructureDefinition-MedicationStatement.json',
#  'StructureDefinition-Money.json',
#  'StructureDefinition-condition-ruledOut.json',
#  'StructureDefinition-Schedule.json',
#  'StructureDefinition-iso21090-ADXP-streetName.json',
#  'StructureDefinition-codesystem-keyWord.json',
#  'StructureDefinition-DiagnosticReport-geneticsAssessedCondition.json',
#  'StructureDefinition-valueset-workflowStatus.json',
#  'StructureDefinition-ProdCharacteristic.json',
#  'StructureDefinition-Distance.json',
#  'StructureDefinition-event-performerFunction.json',
#  'StructureDefinition-operationoutcome-issue-source.json',
#  'StructureDefinition-practitioner-animalSpecies.json',
#  'StructureDefinition-Person.json',
#  'StructureDefinition-careplan-activity-title.json',
#  'StructureDefinition-iso21090-ADXP-additionalLocator.json',
#  'StructureDefinition-observation-precondition.json',
#  'StructureDefinition-procedure-directedBy.json',
#  'StructureDefinition-openEHR-exposureDuration.json',
#  'StructureDefinition-structuredefinition-category.json',
#  'StructureDefinition-cqf-initiatingOrganization.json',
#  'StructureDefinition-AllergyIntolerance.json',
#  'StructureDefinition-cqf-initiatingPerson.json',
#  'StructureDefinition-structuredefinition-dependencies.json',
#  'StructureDefinition-decimal.json',
#  'StructureDefinition-PlanDefinition.json',
#  'StructureDefinition-observation-focusCode.json',
#  'StructureDefinition-composition-clinicaldocument-versionNumber.json',
#  'StructureDefinition-codesystem-label.json',
#  'StructureDefinition-specimen-isDryWeight.json',
#  'StructureDefinition-request-insurance.json',
#  'StructureDefinition-auditevent-NumberOfInstances.json',
#  'StructureDefinition-ResearchSubject.json',
#  'StructureDefinition-canonical.json',
#  'StructureDefinition-resource-effectivePeriod.json',
#  'StructureDefinition-codesystem-workflowStatus.json',
#  'StructureDefinition-geolocation.json',
#  'StructureDefinition-ClinicalImpression.json',
#  'StructureDefinition-Subscription.json',
#  'StructureDefinition-valueset-author.json',
#  'StructureDefinition-rendered-value.json',
#  'StructureDefinition-procedure-incisionDateTime.json',
#  'StructureDefinition-request-doNotPerform.json',
#  'StructureDefinition-observation-geneticsPhaseSet.json',
#  'StructureDefinition-iso21090-TEL-address.json',
#  'StructureDefinition-CareTeam.json',
#  'StructureDefinition-observation-sequelTo.json',
#  'StructureDefinition-questionnaire-baseType.json',
#  'StructureDefinition-ehrsrle-provenance.json',
#  'StructureDefinition-observation-geneticsGene.json',
#  'StructureDefinition-procedure-schedule.json',
#  'StructureDefinition-structuredefinition-table-name.json',
#  'StructureDefinition-questionnaire-fhirType.json',
#  'StructureDefinition-observation-geneticsGenomicSourceClass.json',
#  'StructureDefinition-Device.json',
#  'StructureDefinition-valueset-authoritativeSource.json',
#  'StructureDefinition-codesystem-map.json',
#  'StructureDefinition-unsignedInt.json',
#  'StructureDefinition-DiagnosticReport-geneticsAnalysis.json',
#  'StructureDefinition-Consent.json',
#  'StructureDefinition-observation-geneticsVariant.json',
#  'StructureDefinition-SampledData.json',
#  'StructureDefinition-questionnaire-sliderStepValue.json',
#  'StructureDefinition-questionnaire-unitOption.json',
#  'StructureDefinition-Communication.json',
#  'StructureDefinition-Library.json',
#  'StructureDefinition-Age.json',
#  'StructureDefinition-capabilitystatement-prohibited.json',
#  'StructureDefinition-observation-gatewayDevice.json',
#  'StructureDefinition-iso21090-AD-use.json',
#  'StructureDefinition-CodeableConcept.json',
#  'StructureDefinition-elementdefinition-bestpractice-explanation.json',
#  'StructureDefinition-structuredefinition-fmm-no-warnings.json',
#  'StructureDefinition-request-statusReason.json',
#  'StructureDefinition-workflow-researchStudy.json',
#  'StructureDefinition-StructureMap.json',
#  'StructureDefinition-Task.json',
#  'StructureDefinition-observation-geneticsCopyNumberEvent.json',
#  'StructureDefinition-cqf-encounterType.json',
#  'StructureDefinition-MetadataResource.json',
#  'StructureDefinition-Practitioner.json',
#  'StructureDefinition-valueset-expand-rules.json',
#  'StructureDefinition-Quantity.json',
#  'StructureDefinition-MedicinalProductContraindication.json',
#  'StructureDefinition-MoneyQuantity.json',
#  'StructureDefinition-iso21090-ADXP-deliveryInstallationArea.json',
#  'StructureDefinition-operationdefinition-profile.json',
#  'StructureDefinition-Observation.json',
#  'StructureDefinition-DocumentReference.json',
#  'StructureDefinition-OperationOutcome.json',
#  'StructureDefinition-codesystem-expirationDate.json',
#  'StructureDefinition-Address.json',
#  'StructureDefinition-cholesterol.json',
#  'StructureDefinition-servicerequest-questionnaireRequest.json',
#  'StructureDefinition-specimen-collectionPriority.json',
#  'StructureDefinition-questionnaire-unitValueSet.json',
#  'StructureDefinition-iso21090-ADXP-precinct.json',
#  'StructureDefinition-hla-genotyping-results-allele-database.json',
#  'StructureDefinition-questionnaire-referenceFilter.json',
#  'StructureDefinition-MedicationDispense.json',
#  'StructureDefinition-Account.json',
#  'StructureDefinition-consent-Witness.json',
#  'StructureDefinition-patient-interpreterRequired.json',
#  'StructureDefinition-Procedure.json',
#  'StructureDefinition-SubstanceProtein.json',
#  'StructureDefinition-condition-dueTo.json',
#  'StructureDefinition-UsageContext.json',
#  'StructureDefinition-structuredefinition-codegen-super.json',
#  'StructureDefinition-diagnosticReport-locationPerformed.json',
#  'StructureDefinition-cqf-relativeDateTime.json',
#  'StructureDefinition-patient-birthTime.json',
#  'StructureDefinition-request-replaces.json',
#  'StructureDefinition-MedicinalProductAuthorization.json',
#  'StructureDefinition-communicationrequest-initiatingLocation.json',
#  'StructureDefinition-example-composition.json',
#  'StructureDefinition-structuredefinition-fmm.json',
#  'StructureDefinition-maxValue.json',
#  'StructureDefinition-Event.json',
#  'StructureDefinition-maxDecimalPlaces.json',
#  'StructureDefinition-openEHR-management.json',
#  'StructureDefinition-rendering-styleSensitive.json',
#  'StructureDefinition-patient-mothersMaidenName.json',
#  'StructureDefinition-bodyheight.json',
#  'StructureDefinition-family-member-history-genetics-sibling.json',
#  'StructureDefinition-AdverseEvent.json',
#  'StructureDefinition-valueset-activityStatusDate.json']

# %% [markdown]
# loop through all sd and print out the element the element you want
#
# filter on the element properties you want

# %%
def open_file(in_path, f_name): # get files
    with open(f'{in_path}/{f_name}', encoding="utf8") as f:
        #print(f.read())
        result = f.read().split(",")
        return result

my_file = open_file(fhir_r4, 'StructureDefinition-ExampleScenario.json')
row_count = 0

for row in my_file:
    row_count += 1


row_count
# Out:
# 2668

# %%
def infinite_sequence():
    num = 0
    while True:
        yield num
        num += 1
