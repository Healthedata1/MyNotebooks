# %% [markdown]
# #  Compare Dataframes by key using pandas
#
# Compare dataframes by a key:
#
# 1. "normalize both dataframe to same shape to compare with the df compare function
#       - merge dataframe key columns together and indicate where they came from
#       - concat unique rows from one data frame to the other so the number of rows is the same
#       - sort based on key
# 1. use data frame compare function to compare rows

# %%
import pandas as pd
import itertools 

'''
df1 = pd.DataFrame({'key': ['foo', 'bar','fizz'],
                    'value': [1, 2,11]})
df2 = pd.DataFrame({'key': ['foo', 'bar', 'baz'],
                    'value': [5, 6, 7]})

df1 = pd.read_excel(r'test_files/Book1.xlsx')
df2 = pd.read_excel(r'test_files/Book2.xlsx')

'''

df1 = pd.read_csv(r'test_files/StructureDefinition-C4BB-Coverage.csv')
df2 = pd.read_csv(r'test_files/StructureDefinition-hrex-coverage.csv')

my_key = ['Path',"Slice Name']

df1.shape
# Out:
# (66, 41)

# %%
df2.shape
# Out:
# (58, 41)

# %%
df_all = df1[[my_key]].merge(df2[[my_key]], on=my_key,], 
                   how='outer', indicator=True)
df_all
# Out:
#                             Path      _merge
# 0                       Coverage        both
# 1                    Coverage.id        both
# 2                  Coverage.meta        both
# 3               Coverage.meta.id   left_only
# 4        Coverage.meta.extension   left_only
# ..                           ...         ...
# 90      Coverage.identifier.type  right_only
# 91    Coverage.identifier.system  right_only
# 92     Coverage.identifier.value  right_only
# 93    Coverage.identifier.period  right_only
# 94  Coverage.identifier.assigner  right_only
#
# [95 rows x 2 columns]

# %%
df_all.query('_merge == "both"').shape
# Out:
# (78, 2)

# %%
left_only  = df_all.query('_merge == "left_only"')
left_only.shape
# Out:
# (9, 2)

# %%
right_only  = df_all.query('_merge == "right_only"')
right_only.shape
# Out:
# (8, 2)

# %%
df1_new = pd.concat([df1,right_only], ignore_index=True)
df1_new.shape
# Out:
# (74, 42)

# %%
df1_new = df1_new.set_index(my_key)
df1_new.head()
# Out:
#                         Slice Name                  Alias(s)  Label  Min Max  \
# Path
# Coverage                       NaN                       NaN    NaN  0.0   *
# Coverage.id                    NaN                       NaN    NaN  0.0   1
# Coverage.meta                  NaN                       NaN    NaN  1.0   1
# Coverage.meta.id               NaN                       NaN    NaN  0.0   1
# Coverage.meta.extension        NaN  extensions\nuser content    NaN  0.0   *
#
#                         Must Support? Is Modifier? Is Summary?  \
# Path
# Coverage                          NaN          NaN         NaN
# Coverage.id                       NaN          NaN           Y
# Coverage.meta                       Y          NaN           Y
# Coverage.meta.id                  NaN          NaN         NaN
# Coverage.meta.extension           NaN          NaN         NaN
#
#                                        Type(s)  \
# Path
# Coverage                                   NaN
# Coverage.id                 string {[]} {[]}\n
# Coverage.meta                 Meta {[]} {[]}\n
# Coverage.meta.id            string {[]} {[]}\n
# Coverage.meta.extension  Extension {[]} {[]}\n
#
#                                                                     Short  \
# Path
# Coverage                 Insurance or medical plan or a payment agreement
# Coverage.id                                   Logical id of this artifact
# Coverage.meta                                 Metadata about the resource
# Coverage.meta.id                  Unique id for inter-element referencing
# Coverage.meta.extension     Additional content defined by implementations
#
#                          ... Base Max  \
# Path                     ...
# Coverage                 ...      NaN
# Coverage.id              ...      NaN
# Coverage.meta            ...      NaN
# Coverage.meta.id         ...      NaN
# Coverage.meta.extension  ...        *
#
#                                                               Condition(s)  \
# Path
# Coverage                 dom-2:If the resource is contained in another ...
# Coverage.id                                                            NaN
# Coverage.meta            ele-1:All FHIR elements must have a @value or ...
# Coverage.meta.id                                                       NaN
# Coverage.meta.extension                                                NaN
#
#                                                              Constraint(s)  \
# Path
# Coverage                                                             Event
# Coverage.id                                                            NaN
# Coverage.meta                                                          NaN
# Coverage.meta.id                                                       NaN
# Coverage.meta.extension  ele-1:All FHIR elements must have a @value or ...
#
#                          Mapping: Workflow Pattern  Mapping: RIM Mapping  \
# Path
# Coverage                      Entity. Role, or Act              Coverage
# Coverage.id                                    NaN                   NaN
# Coverage.meta                                  NaN                   NaN
# Coverage.meta.id                               NaN                   NaN
# Coverage.meta.extension                        NaN                   NaN
#
#                          Mapping: FiveWs Pattern Mapping  \
# Path
# Coverage                                             NaN
# Coverage.id                                          NaN
# Coverage.meta                                        NaN
# Coverage.meta.id                                     NaN
# Coverage.meta.extension                              NaN
#
#                         Mapping: Canadian Dental Association eclaims standard  \
# Path
# Coverage                                                               NaN
# Coverage.id                                                            NaN
# Coverage.meta                                                          NaN
# Coverage.meta.id                                                       NaN
# Coverage.meta.extension                                                NaN
#
#                          Mapping: HL7 v2 Mapping  \
# Path
# Coverage                                     NaN
# Coverage.id                                  NaN
# Coverage.meta                                NaN
# Coverage.meta.id                             NaN
# Coverage.meta.extension                      NaN
#
#                          Mapping: Canadian Pharmacy Associaiton eclaims standard  \
# Path
# Coverage                                                               NaN
# Coverage.id                                                            NaN
# Coverage.meta                                                          NaN
# Coverage.meta.id                                                       NaN
# Coverage.meta.extension                                                NaN
#
#                          _merge
# Path
# Coverage                    NaN
# Coverage.id                 NaN
# Coverage.meta               NaN
# Coverage.meta.id            NaN
# Coverage.meta.extension     NaN
#
# [5 rows x 41 columns]

# %%
df1_new = df1_new.sort_index()
df1_new.head()
# Out:
#                      Slice Name Alias(s)  Label  Min Max Must Support?  \
# Path
# Coverage                    NaN      NaN    NaN  0.0   *           NaN
# Coverage.beneficiary        NaN      NaN    NaN  1.0   1             Y
# Coverage.class             plan      NaN    NaN  0.0   1             Y
# Coverage.class              NaN      NaN    NaN  0.0   *             Y
# Coverage.class            group      NaN    NaN  0.0   1             Y
#
#                      Is Modifier? Is Summary?  \
# Path
# Coverage                      NaN         NaN
# Coverage.beneficiary          NaN           Y
# Coverage.class                NaN         NaN
# Coverage.class                NaN         NaN
# Coverage.class                NaN         NaN
#
#                                                                 Type(s)  \
# Path
# Coverage                                                            NaN
# Coverage.beneficiary  Reference {[]} {[CanonicalType[http://hl7.org/...
# Coverage.class                              BackboneElement {[]} {[]}\n
# Coverage.class                              BackboneElement {[]} {[]}\n
# Coverage.class                              BackboneElement {[]} {[]}\n
#
#                                                                  Short  ...  \
# Path                                                                    ...
# Coverage              Insurance or medical plan or a payment agreement  ...
# Coverage.beneficiary                                  Plan beneficiary  ...
# Coverage.class                                                    Plan  ...
# Coverage.class                     Additional coverage classifications  ...
# Coverage.class                                                   Group  ...
#
#                      Base Max  \
# Path
# Coverage                  NaN
# Coverage.beneficiary      NaN
# Coverage.class            NaN
# Coverage.class              *
# Coverage.class            NaN
#
#                                                            Condition(s)  \
# Path
# Coverage              dom-2:If the resource is contained in another ...
# Coverage.beneficiary  ele-1:All FHIR elements must have a @value or ...
# Coverage.class        ele-1:All FHIR elements must have a @value or ...
# Coverage.class                                                      NaN
# Coverage.class        ele-1:All FHIR elements must have a @value or ...
#
#                                                           Constraint(s)  \
# Path
# Coverage                                                          Event
# Coverage.beneficiary                                      Event.subject
# Coverage.class                                                      NaN
# Coverage.class        ele-1:All FHIR elements must have a @value or ...
# Coverage.class                                                      NaN
#
#                       Mapping: Workflow Pattern  Mapping: RIM Mapping  \
# Path
# Coverage                   Entity. Role, or Act              Coverage
# Coverage.beneficiary          FiveWs.subject[x]        FiveWs.subject
# Coverage.class                              NaN                   NaN
# Coverage.class                              NaN                   NaN
# Coverage.class                              NaN                   NaN
#
#                       Mapping: FiveWs Pattern Mapping  \
# Path
# Coverage                                          NaN
# Coverage.beneficiary                  D01 through D09
# Coverage.class                                    NaN
# Coverage.class                                    NaN
# Coverage.class                                    NaN
#
#                      Mapping: Canadian Dental Association eclaims standard  \
# Path
# Coverage                                                            NaN
# Coverage.beneficiary  IN1-16, 18,  19-name of insured, address, date...
# Coverage.class                                                      NaN
# Coverage.class                                                      NaN
# Coverage.class                                                      NaN
#
#                       Mapping: HL7 v2 Mapping  \
# Path
# Coverage                                  NaN
# Coverage.beneficiary                     C.35
# Coverage.class                            NaN
# Coverage.class                            NaN
# Coverage.class                            NaN
#
#                       Mapping: Canadian Pharmacy Associaiton eclaims standard  \
# Path
# Coverage                                                            NaN
# Coverage.beneficiary                                                NaN
# Coverage.class                                                      NaN
# Coverage.class                                                      NaN
# Coverage.class                                                      NaN
#
#                       _merge
# Path
# Coverage                 NaN
# Coverage.beneficiary     NaN
# Coverage.class           NaN
# Coverage.class           NaN
# Coverage.class           NaN
#
# [5 rows x 41 columns]

# %%
df2_new = pd.concat([df2,left_only], ignore_index=True)
df2_new = df2_new.set_index(my_key)
df2_new = df2_new.sort_index()
df2_new.shape
# Out:
# (67, 41)

# %%
df1_new.compare(df2_new, align_axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 df1_new.compare(df2_new, align_axis = 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:7195, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    7082 @doc(
#    7083     _shared_docs["compare"],
#    7084     """
#    (...)
#    7193     keep_equal: bool = False,
#    7194 ) -> DataFrame:
# -> 7195     return super().compare(
#    7196         other=other,
#    7197         align_axis=align_axis,
#    7198         keep_shape=keep_shape,
#    7199         keep_equal=keep_equal,
#    7200     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:8646, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    8641     cls_self, cls_other = type(self).__name__, type(other).__name__
#    8642     raise TypeError(
#    8643         f"can only compare '{cls_self}' (not '{cls_other}') with '{cls_self}'"
#    8644     )
# -> 8646 mask = ~((self == other) | (self.isna() & other.isna()))
#    8647 keys = ["self", "other"]
#    8649 if not keep_equal:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:6933, in DataFrame._cmp_method(self, other, op)
#    6930 def _cmp_method(self, other, op):
#    6931     axis = 1  # only relevant for Series other case
# -> 6933     self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    6935     # See GH#4537 for discussion of scalar op behavior
#    6936     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/__init__.py:289, in align_method_FRAME(left, right, axis, flex, level)
#     287             left, right = left.align(right, join="outer", level=level, copy=False)
#     288         else:
# --> 289             raise ValueError(
#     290                 "Can only compare identically-labeled DataFrame objects"
#     291             )
#     292 elif isinstance(right, ABCSeries):
#     293     # axis=1 is default for DataFrame-with-Series op
#     294     axis = left._get_axis_number(axis) if axis is not None else 1
#
# ValueError: Can only compare identically-labeled DataFrame objects
