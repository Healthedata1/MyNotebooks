# %% [markdown]
# **\*\*\*\*\*\*\*Remember to restart Kerne
# l for new run since the template are not refreshed\*\*\*\*\*\*\***
#
# ## Script to create a transaction bundle of multiple indiv and summary Reports

# %%
from json import load, dumps, loads
from IPython import display as D
from requests import get, post, put
from IPython.display import display, Markdown, HTML
import fhirclient.r4models.bundle as B
import fhirclient.r4models.parameters as P
import fhirclient.r4models.fhirdate as D
from fhirclient.models.fhirabstractbase import FHIRValidationError 
import os, uuid
from datetime import datetime
from pprint import pprint
from pathlib import Path
#******* select for ind or summ reports ******
import ind_resource_templates_new as t 
#import summ_resource_templates as t

# %% [markdown]
# ### Fetch MeasureReports create List
#
# -  *******changed to fetching mr from source using pathlib********

# %%
print(t.out_path, t.base, t.source)
out_path = t.out_path
#print(out_path)

b_ref_list = {x for i in t.mrs for x in i } # unique set of core-references
#print(b_ref_list)
b_url_list = [f'{i.replace("/","-")}.json' for i in b_ref_list]
#print(b_url_list)
ref_map = dict(zip(b_ref_list,b_ref_list))
br_list = []
for i in b_url_list:
    path = Path() / t.base / t.source / i
    print(path)
    #print( path.read_text() )
    try:          
        br_list.append(loads(path.read_text()))
    except FileNotFoundError:  # PC to Mac
       path = Path() / t.base.replace('/Users','//ERICS-AIR-2') / t.source / i
       print(path)
       br_list.append(loads(path.read_text()))
            
#source/examples/MeasureReport-summ-measurereport02.json
b_ref_list, b_url_list, ref_map, br_list,
# Out:
# r4 /Users/ehaas/Documents/FHIR/Davinci-DEQM input/examples
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Practitioner-practitioner01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Practitioner-practitioner01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Organization-organization02.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Organization-organization02.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Coverage-coverage02.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Coverage-coverage02.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\MeasureReport-indv-measurereport02.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\MeasureReport-indv-measurereport02.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Coverage-coverage03.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Coverage-coverage03.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Coverage-coverage01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Coverage-coverage01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Organization-organization01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Organization-organization01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Organization-organization04.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Organization-organization04.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Observation-observation01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Observation-observation01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\MeasureReport-indv-measurereport03.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\MeasureReport-indv-measurereport03.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Encounter-encounter01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Encounter-encounter01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Observation-observation03.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Observation-observation03.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Patient-patient01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Patient-patient01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Patient-patient02.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Patient-patient02.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\MeasureReport-indv-measurereport01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\MeasureReport-indv-measurereport01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Task-task01.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Task-task01.json
# \Users\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Patient-patient03.json
# \\ERICS-AIR-2\ehaas\Documents\FHIR\Davinci-DEQM\input\examples\Patient-patient03.json
# ({'Coverage/coverage01',
#   'Coverage/coverage02',
#   'Coverage/coverage03',
#   'Encounter/encounter01',
#   'MeasureReport/indv-measurereport01',
#   'MeasureReport/indv-measurereport02',
#   'MeasureReport/indv-measurereport03',
#   'Observation/observation01',
#   'Observation/observation03',
#   'Organization/organization01',
#   'Organization/organization02',
#   'Organization/organization04',
#   'Patient/patient01',
#   'Patient/patient02',
#   'Patient/patient03',
#   'Practitioner/practitioner01',
#   'Task/task01'},
#  ['Practitioner-practitioner01.json',
#   'Organization-organization02.json',
#   'Coverage-coverage02.json',
#   'MeasureReport-indv-measurereport02.json',
#   'Coverage-coverage03.json',
#   'Coverage-coverage01.json',
#   'Organization-organization01.json',
#   'Organization-organization04.json',
#   'Observation-observation01.json',
#   'MeasureReport-indv-measurereport03.json',
#   'Encounter-encounter01.json',
#   'Observation-observation03.json',
#   'Patient-patient01.json',
#   'Patient-patient02.json',
#   'MeasureReport-indv-measurereport01.json',
#   'Task-task01.json',
#   'Patient-patient03.json'],
#  {'Practitioner/practitioner01': 'Practitioner/practitioner01',
#   'Organization/organization02': 'Organization/organization02',
#   'Coverage/coverage02': 'Coverage/coverage02',
#   'MeasureReport/indv-measurereport02': 'MeasureReport/indv-measurereport02',
#   'Coverage/coverage03': 'Coverage/coverage03',
#   'Coverage/coverage01': 'Coverage/coverage01',
#   'Organization/organization01': 'Organization/organization01',
#   'Organization/organization04': 'Organization/organization04',
#   'Observation/observation01': 'Observation/observation01',
#   'MeasureReport/indv-measurereport03': 'MeasureReport/indv-measurereport03',
#   'Encounter/encounter01': 'Encounter/encounter01',
#   'Observation/observation03': 'Observation/observation03',
#   'Patient/patient01': 'Patient/patient01',
#   'Patient/patient02': 'Patient/patient02',
#   'MeasureReport/indv-measurereport01': 'MeasureReport/indv-measurereport01',
#   'Task/task01': 'Task/task01',
#   'Patient/patient03': 'Patient/patient03'},
#  [{'resourceType': 'Practitioner',
#    'id': 'practitioner01',
#    'meta': {'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/practitioner-deqm']},
#    'identifier': [{'assigner': {'display': 'www.cms.gov'},
#      'system': 'http://hl7.org/fhir/sid/us-npi',
#      'type': {'coding': [{'code': 'PRN',
#         'display': 'Provider number',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203'}]},
#      'use': 'official',
#      'value': '345678912'},
#     {'assigner': {'display': 'www.cms.gov'},
#      'system': 'urn:oid:2.16.840.1.113883.4.336',
#      'type': {'coding': [{'code': 'PRN',
#         'display': 'Provider number',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203'}]},
#      'use': 'secondary',
#      'value': '082583'}],
#    'name': [{'family': 'Bone', 'given': ['Ronald'], 'prefix': ['Dr']}],
#    'address': [{'use': 'home',
#      'line': ['1003 Healthcare Drive'],
#      'city': 'Amherst',
#      'state': 'MA',
#      'postalCode': '01002'}]},
#   {'id': 'organization02',
#    'meta': {'lastUpdated': '2019-03-06T19:03:03.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm'],
#     'versionId': '3'},
#    'active': True,
#    'address': [{'city': 'Englewood',
#      'country': 'USA',
#      'line': ['3 Sherwood St.'],
#      'postalCode': '07631',
#      'state': 'NJ'}],
#    'identifier': [{'assigner': {'display': 'www.irs.gov'},
#      'system': 'urn:oid:2.16.840.1.113883.4.4',
#      'type': {'coding': [{'code': 'TAX',
#         'display': 'Tax ID number',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203'}]},
#      'use': 'official',
#      'value': '234567891'}],
#    'name': 'DaVinciHospital02',
#    'telecom': [{'system': 'phone', 'value': '(+1) 551-555-1212'}],
#    'type': [{'coding': [{'code': 'prov',
#        'display': 'Healthcare Provider',
#        'system': 'http://terminology.hl7.org/CodeSystem/organization-type'}]}],
#    'resourceType': 'Organization'},
#   {'id': 'coverage02',
#    'meta': {'lastUpdated': '2019-03-06T19:03:03.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm'],
#     'versionId': '2'},
#    'status': 'active',
#    'beneficiary': {'reference': 'Patient/patient02'},
#    'payor': [{'reference': 'Organization/organization04'}],
#    'policyHolder': {'reference': 'Patient/patient02'},
#    'relationship': {'coding': [{'code': 'self'}]},
#    'subscriber': {'reference': 'Patient/patient02'},
#    'subscriberId': 'B123456789',
#    'resourceType': 'Coverage'},
#   {'resourceType': 'MeasureReport',
#    'id': 'indv-measurereport02',
#    'meta': {'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring',
#      'valueCodeableConcept': {'coding': [{'code': 'proportion',
#         'system': 'http://terminology.hl7.org/CodeSystem/measure-scoring'}]}},
#     {'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-certificationIdentifier',
#      'valueIdentifier': {'system': 'urn:oid:2.16.840.1.113883.3.2074.1',
#       'value': '0015HQN9BD3304E'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-reportingVendor',
#      'valueReference': {'reference': 'Organization/organization02'}}],
#    'status': 'complete',
#    'type': 'individual',
#    'measure': 'http://hl7.org/fhir/us/davinci-deqm/Measure/measure-mrp-example',
#    'subject': {'reference': 'Patient/patient01'},
#    'date': '2018-09-05T16:59:52.404Z',
#    'reporter': {'reference': 'Organization/organization01'},
#    'period': {'start': '2018-08-01', 'end': '2018-09-01'},
#    'improvementNotation': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-improvement-notation',
#       'code': 'increase',
#       'display': 'Increased score indicates improvement'}]},
#    'group': [{'code': {'coding': [{'system': 'http://example.org',
#         'code': 'mrp-group',
#         'display': 'MRP Group'}],
#       'text': 'MRP Group'},
#      'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'initial-population',
#           'display': 'Initial Population'}]},
#        'id': 'initial-population',
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'numerator',
#           'display': 'Numerator'}]},
#        'id': 'numerator',
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'denominator',
#           'display': 'Denominator'}]},
#        'id': 'denominator',
#        'count': 1}],
#      'measureScore': {'value': 1}}],
#    'evaluatedResource': [{'reference': 'Observation/observation01'}]},
#   {'id': 'coverage03',
#    'meta': {'lastUpdated': '2019-02-07T18:47:34.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm'],
#     'versionId': '2'},
#    'status': 'active',
#    'beneficiary': {'reference': 'Patient/patient03'},
#    'payor': [{'reference': 'Organization/organization04'}],
#    'policyHolder': {'reference': 'Patient/patient03'},
#    'relationship': {'coding': [{'code': 'self'}]},
#    'subscriber': {'reference': 'Patient/patient03'},
#    'subscriberId': 'C123456789',
#    'resourceType': 'Coverage'},
#   {'id': 'coverage01',
#    'meta': {'lastUpdated': '2019-02-11T14:19:25.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm'],
#     'versionId': '2'},
#    'status': 'active',
#    'beneficiary': {'reference': 'Patient/patient01'},
#    'payor': [{'reference': 'Organization/organization04'}],
#    'policyHolder': {'reference': 'Patient/patient01'},
#    'relationship': {'coding': [{'code': 'self'}]},
#    'subscriber': {'reference': 'Patient/patient01'},
#    'subscriberId': 'A123456789',
#    'resourceType': 'Coverage'},
#   {'id': 'organization01',
#    'meta': {'lastUpdated': '2019-02-21T01:47:54.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm'],
#     'versionId': '4'},
#    'active': True,
#    'address': [{'city': 'Warwick',
#      'country': 'USA',
#      'line': ['73 Lakewood Street'],
#      'postalCode': '02886',
#      'state': 'RI'}],
#    'identifier': [{'assigner': {'display': 'www.irs.gov'},
#      'system': 'urn:oid:2.16.840.1.113883.4.4',
#      'type': {'coding': [{'code': 'TAX',
#         'display': 'Tax ID number',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203'}]},
#      'use': 'official',
#      'value': '123456789'}],
#    'name': 'DaVinciHospital01',
#    'telecom': [{'system': 'phone', 'value': '(+1) 401-555-1212'}],
#    'type': [{'coding': [{'code': 'prov',
#        'display': 'Healthcare Provider',
#        'system': 'http://terminology.hl7.org/CodeSystem/organization-type'}]}],
#    'resourceType': 'Organization'},
#   {'id': 'organization04',
#    'meta': {'lastUpdated': '2019-03-06T19:03:03.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm'],
#     'versionId': '4'},
#    'active': True,
#    'address': [{'city': 'Grand Rapids',
#      'country': 'USA',
#      'line': ['160 Glen Eagles Road'],
#      'postalCode': '49503',
#      'state': 'MI'}],
#    'identifier': [{'assigner': {'display': 'www.irs.gov'},
#      'system': 'urn:oid:2.16.840.1.113883.4.4',
#      'type': {'coding': [{'code': 'TAX',
#         'display': 'Tax ID number',
#         'system': 'http://terminology.hl7.org/CodeSystem/v2-0203'}]},
#      'use': 'official',
#      'value': '456789123'}],
#    'name': 'DVPayer04',
#    'telecom': [{'system': 'phone', 'value': '(+1) 616-555-1212'}],
#    'type': [{'coding': [{'code': 'ins',
#        'display': 'Insurance Company',
#        'system': 'http://terminology.hl7.org/CodeSystem/organization-type'}]}],
#    'resourceType': 'Organization'},
#   {'resourceType': 'Observation',
#    'id': 'observation01',
#    'meta': {'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-observation']},
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://acme.org/observation-category',
#        'code': 'measure',
#        'display': 'Measure'}]}],
#    'code': {'coding': [{'system': 'http://www.ama-assn.org/go/cpt',
#       'code': '1111F',
#       'display': 'Medication Reconciliation'}]},
#    'subject': {'reference': 'Patient/patient01'},
#    'encounter': {'reference': 'Encounter/Encounter01'},
#    'effectiveDateTime': '2018-09-29T14:15:04.424Z',
#    'issued': '2018-09-29T14:15:04.424Z',
#    'performer': [{'reference': 'Practitioner/practitioner01'}],
#    'valueBoolean': True},
#   {'resourceType': 'MeasureReport',
#    'id': 'indv-measurereport03',
#    'meta': {'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring',
#      'valueCodeableConcept': {'coding': [{'code': 'proportion',
#         'system': 'http://terminology.hl7.org/CodeSystem/measure-scoring'}]}}],
#    'status': 'complete',
#    'type': 'individual',
#    'measure': 'http://hl7.org/fhir/us/cqfmeasures/Measure/measure-exm130-FHIR',
#    'subject': {'reference': 'Patient/patient01'},
#    'date': '2019-03-14',
#    'reporter': {'reference': 'Organization/organization01'},
#    'period': {'end': '2019-01-01', 'start': '2018-12-31'},
#    'improvementNotation': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-improvement-notation',
#       'code': 'increase',
#       'display': 'Increased score indicates improvement'}]},
#    'group': [{'measureScore': {'value': 1},
#      'code': {'coding': [{'system': 'http://fhir/example.org',
#         'code': 'group-1',
#         'display': 'group-1'}]},
#      'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'initial-population',
#           'display': 'Initial Population'}]},
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'numerator',
#           'display': 'Numerator'}]},
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'denominator',
#           'display': 'Denominator'}]},
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'denominator-exclusion',
#           'display': 'Denominator Exclusion'}]},
#        'count': 0}],
#      'stratifier': [{'code': [{'coding': [{'system': 'http://fhir/example.org',
#            'code': 'sde-ethnicity',
#            'display': 'SDE Ethnicity'}]}],
#        'stratum': [{'value': {'coding': [{'system': 'urn:oid:2.16.840.1.113883.6.238',
#             'code': '2135-2',
#             'display': 'Hispanic or Latino'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'urn:oid:2.16.840.1.113883.6.238',
#             'code': '2186-5',
#             'display': 'Not Hispanic or Latino'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]}]},
#       {'code': [{'coding': [{'system': 'http://fhir/example.org',
#            'code': 'sde-payer',
#            'display': 'SDE Payer'}]}],
#        'stratum': [{'value': {'coding': [{'system': 'http://fhir/example.org',
#             'code': 'Payer123',
#             'display': 'King HMO'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'http://fhir/example.org',
#             'code': 'Payer456',
#             'display': 'Green Circle'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'http://fhir/example.org',
#             'code': 'Payer789',
#             'display': 'GoodHealth of California'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]}]},
#       {'code': [{'coding': [{'system': 'http://fhir/example.org',
#            'code': 'sde-race',
#            'display': 'SDE Race'}]}],
#        'stratum': [{'value': {'coding': [{'system': 'urn:oid:2.16.840.1.113883.6.238',
#             'code': '2054-5',
#             'display': 'Black or African American'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'urn:oid:2.16.840.1.113883.6.238',
#             'code': '2106-3',
#             'display': 'White'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'urn:oid:2.16.840.1.113883.6.238',
#             'code': '2028-9',
#             'display': 'Asian'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]}]},
#       {'code': [{'coding': [{'system': 'http://fhir/example.org',
#            'code': 'sde-sex',
#            'display': 'SDE Sex'}]}],
#        'stratum': [{'value': {'coding': [{'system': 'http://hl7.org/fhir/administrative-gender',
#             'code': 'male',
#             'display': 'Male'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 1},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'http://hl7.org/fhir/administrative-gender',
#             'code': 'female',
#             'display': 'Female'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]},
#         {'value': {'coding': [{'system': 'http://hl7.org/fhir/administrative-gender',
#             'code': 'other',
#             'display': 'Other'}]},
#          'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'initial-population',
#               'display': 'Initial Population'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'numerator',
#               'display': 'Numerator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator',
#               'display': 'Denominator'}]},
#            'count': 0},
#           {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#               'code': 'denominator-exclusion',
#               'display': 'Denominator Exclusion'}]},
#            'count': 0}]}]}]}]},
#   {'resourceType': 'Encounter',
#    'id': 'Encounter01',
#    'meta': {'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-encounter']},
#    'status': 'finished',
#    'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode',
#     'code': 'IMP',
#     'display': 'inpatient encounter'},
#    'type': [{'coding': [{'system': 'http://snomed.info/sct',
#        'code': '56876005',
#        'display': 'Drug rehabilitation and detoxification'}]}],
#    'subject': {'reference': 'Patient/patient01', 'display': 'Jairo Webster'},
#    'period': {'start': '2018-05-29T11:00:00-04:00',
#     'end': '2018-05-29T11:00:00-04:00'},
#    'hospitalization': {'dischargeDisposition': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/discharge-disposition',
#        'code': 'home',
#        'display': 'Home'}]}}},
#   {'resourceType': 'Observation',
#    'id': 'observation03',
#    'meta': {'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-observation']},
#    'status': 'final',
#    'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category',
#        'code': 'laboratory',
#        'display': 'Laboratory'}]}],
#    'code': {'coding': [{'system': 'http://loinc.org',
#       'code': '77353-1',
#       'display': 'Noninvasive colorectal cancer DNA and occult blood screening [Interpretation] in Stool Narrative'}]},
#    'subject': {'reference': 'Patient/patient03'},
#    'effectiveDateTime': '2018-06-22',
#    'performer': [{'reference': 'Practitioner/practitioner01'}]},
#   {'resourceType': 'Patient',
#    'id': 'patient01',
#    'meta': {'versionId': '5',
#     'lastUpdated': '2019-02-11T14:19:25.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-patient']},
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">Jairo <b>WEBSTER </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>12345</td></tr><tr><td>Address</td><td><span>7496 Beaver Ridge Ave </span><br/><span>Thornton </span><span>NJ </span><span>USA </span></td></tr><tr><td>Date of birth</td><td><span>16 December 1946</span></td></tr></tbody></table></div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex',
#      'valueCode': 'M'},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2106-3',
#         'display': 'White'}},
#       {'url': 'text', 'valueString': 'White'}]},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2186-5',
#         'display': 'Not Hispanic or Latino'}},
#       {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]}],
#    'identifier': [{'use': 'usual',
#      'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical record number'}]},
#      'system': 'http://hospital.davinci.org',
#      'value': '12345'}],
#    'active': True,
#    'name': [{'use': 'official', 'family': 'Webster', 'given': ['Jairo']}],
#    'gender': 'male',
#    'birthDate': '1946-12-16',
#    'deceasedBoolean': False,
#    'address': [{'use': 'home',
#      'line': ['7496 Beaver Ridge Ave'],
#      'city': 'Thornton',
#      'state': 'NJ',
#      'postalCode': '07003',
#      'country': 'USA'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'M',
#       'display': 'Married'}]},
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English (Region=United States)'}]},
#      'preferred': True}],
#    'managingOrganization': {'reference': 'Organization/organization01'}},
#   {'resourceType': 'Patient',
#    'id': 'patient02',
#    'meta': {'versionId': '4',
#     'lastUpdated': '2019-03-06T19:03:03.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-patient']},
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">Darien <b>BERNARD </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>23456</td></tr><tr><td>Address</td><td><span>6 Rockwell Street </span><br/><span>Lynnwood </span><span>NJ </span><span>USA </span></td></tr><tr><td>Date of birth</td><td><span>13 June 1967</span></td></tr></tbody></table></div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex',
#      'valueCode': 'M'},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2028-9',
#         'display': 'Asian'}},
#       {'url': 'text', 'valueString': 'Asian'}]},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2186-5',
#         'display': 'Not Hispanic or Latino'}},
#       {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]}],
#    'identifier': [{'use': 'usual',
#      'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical record number'}]},
#      'system': 'http://hospital.davinci.org',
#      'value': '23456'}],
#    'active': True,
#    'name': [{'use': 'official', 'family': 'Bernard', 'given': ['Darien']}],
#    'gender': 'male',
#    'birthDate': '1967-06-13',
#    'deceasedBoolean': False,
#    'address': [{'use': 'home',
#      'line': ['6 Rockwell Street'],
#      'city': 'Lynnwood',
#      'state': 'NJ',
#      'postalCode': '07420',
#      'country': 'USA'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'M',
#       'display': 'Married'}]},
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English (Region=United States)'}]},
#      'preferred': True}],
#    'managingOrganization': {'reference': 'Organization/organization02'}},
#   {'resourceType': 'MeasureReport',
#    'id': 'indv-measurereport01',
#    'meta': {'profile': ['http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring',
#      'valueCodeableConcept': {'coding': [{'code': 'proportion',
#         'system': 'http://terminology.hl7.org/CodeSystem/measure-scoring'}]}},
#     {'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-certificationIdentifier',
#      'valueIdentifier': {'system': 'urn:oid:2.16.840.1.113883.3.2074.1',
#       'value': '0015HQN9BD3304E'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-reportingVendor',
#      'valueReference': {'reference': 'Organization/organization02'}}],
#    'status': 'complete',
#    'type': 'individual',
#    'measure': 'http://hl7.org/fhir/us/davinci-deqm/Measure/measure-mrp-example',
#    'subject': {'reference': 'Patient/patient01'},
#    'date': '2018-09-05T16:59:52.404Z',
#    'reporter': {'reference': 'Organization/organization01'},
#    'period': {'start': '2018-08-01', 'end': '2018-09-01'},
#    'improvementNotation': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-improvement-notation',
#       'code': 'increase',
#       'display': 'Increased score indicates improvement'}]},
#    'group': [{'code': {'coding': [{'system': 'http://example.org',
#         'code': 'mrp-group',
#         'display': 'MRP Group'}],
#       'text': 'MRP Group'},
#      'population': [{'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'initial-population',
#           'display': 'Initial Population'}]},
#        'id': 'initial-population',
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'numerator',
#           'display': 'Numerator'}]},
#        'id': 'numerator',
#        'count': 1},
#       {'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#           'code': 'denominator',
#           'display': 'Denominator'}]},
#        'id': 'denominator',
#        'count': 1}],
#      'measureScore': {'value': 1}}],
#    'evaluatedResource': [{'reference': 'Task/Task01'}]},
#   {'resourceType': 'Task',
#    'id': 'Task01',
#    'meta': {'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-task']},
#    'identifier': [{'system': 'http://example.org/tasks', 'value': '19009'}],
#    'status': 'completed',
#    'intent': 'plan',
#    'priority': 'routine',
#    'code': {'coding': [{'system': 'http://www.ama-assn.org/go/cpt',
#       'code': '1111F',
#       'display': 'Medication Reconciliation'}]},
#    'for': {'reference': 'Patient/patient01'},
#    'encounter': {'reference': 'Encounter/Encounter01'},
#    'executionPeriod': {'start': '2017-06-11', 'end': '2017-06-11'},
#    'authoredOn': '2018-09-25T14:24:23.584Z',
#    'owner': {'reference': 'Practitioner/practitioner01'}},
#   {'resourceType': 'Patient',
#    'id': 'patient03',
#    'meta': {'versionId': '4',
#     'lastUpdated': '2019-02-07T18:47:34.000+00:00',
#     'profile': ['http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-patient']},
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">Virginia <b>HARTMAN </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>34567</td></tr><tr><td>Address</td><td><span>213 Lilac Ave. </span><br/><span>Freehold </span><span>MI </span><span>USA </span></td></tr><tr><td>Date of birth</td><td><span>12 September 1983</span></td></tr></tbody></table></div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex',
#      'valueCode': 'F'},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2054-5',
#         'display': 'Black or African American'}},
#       {'url': 'text', 'valueString': 'Black or African American'}]},
#     {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#      'extension': [{'url': 'ombCategory',
#        'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#         'code': '2186-5',
#         'display': 'Not Hispanic or Latino'}},
#       {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]}],
#    'identifier': [{'use': 'usual',
#      'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical record number'}]},
#      'system': 'http://hospital.davinci.org',
#      'value': '34567'}],
#    'active': True,
#    'name': [{'use': 'official', 'family': 'Hartman', 'given': ['Virginia']}],
#    'gender': 'female',
#    'birthDate': '1983-09-12',
#    'deceasedBoolean': False,
#    'address': [{'use': 'home',
#      'line': ['213 Lilac Ave.'],
#      'city': 'Freehold',
#      'state': 'MI',
#      'postalCode': '48099',
#      'country': 'USA'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'U',
#       'display': 'unmarried'}]},
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English (Region=United States)'}]},
#      'preferred': True}],
#    'managingOrganization': {'reference': 'Organization/organization03'}}])

# %% [markdown]
# ### global variables

# %%
"""summ = True
use_bundle=True
single_patient = False
use_task = False
uc = ''#'mrp"""


bundle_id = (f'{"single" if t.single_patient else "multiple"}-{"summ" if t.summ else "indv"}-{t.uc}'
            f'{"" if t.summ else ("-task-" if t.use_task else "-obs-")}report')
print(bundle_id)
# Out:
# multiple-ind-mrp-task-report

# %%
bundle_type = 'transaction'

# %%
'''
if single_patient:
    ref_map = dict(zip(t.mrp1_core_references,t.mrp1_core_references)) # init the ref with old:new=old
    my_resources = t.mrp1  # get all core resource templates from use case list

else: # mult patients or summ
    mult_ref_mrp = (i['core_references'] for i in t.mrs)
    # mult_ref_mrp =  set(t.mrp1_core_references + t.mrp2_core_references + t.mrp3_core_references)
    #ref_map = dict(zip(mult_ref_mrp,mult_ref_mrp))

    #mult_mrp = t.mrp1 + t.mrp2 + t.mrp3  # take three list and combine
    my_resources = [i['id'] for i in t.mrs]
    
mult_ref_mrp, my_resources'''
# Out:
# "\nif single_patient:\n    ref_map = dict(zip(t.mrp1_core_references,t.mrp1_core_references)) # init the ref with old:new=old\n    my_resources = t.mrp1  # get all core resource templates from use case list\n\nelse: # mult patients or summ\n    mult_ref_mrp = (i['core_references'] for i in t.mrs)\n    # mult_ref_mrp =  set(t.mrp1_core_references + t.mrp2_core_references + t.mrp3_core_references)\n    #ref_map = dict(zip(mult_ref_mrp,mult_ref_mrp))\n\n    #mult_mrp = t.mrp1 + t.mrp2 + t.mrp3  # take three list and combine\n    my_resources = [i['id'] for i in t.mrs]\n    \nmult_ref_mrp, my_resources"

# %% [markdown]
# ## Some Functions

# %% [markdown]
# ###  write to file

# %%
def write_file(r): # write file
    with open(f'{out_path}/Bundle-{bundle_id}.json', 'w', encoding='utf-8') as f:
        f.write(r)

# %% [markdown]
# ### validate

# %%
# *********************** validate Resource ********************************

def validate(r):

    #fhir_test_server = 'http://test.fhir.org/r4'
    #fhir_test_server = 'http://hapi.fhir.org/baseR4'
    fhir_test_server ='http://wildfhir4.aegis.net/fhir4-0-1'
    headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }

    # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
 
    params = dict(
      # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
        )
    
    #   r = requests.post('https://httpbin.org/post', data = {'key':'value'})
    r = post(f'{fhir_test_server}/{r.resource_type}/$validate', params = params, headers = headers, data = dumps(r.as_json()))
    # return r.status_code
    # view  output
    # return (r.json()["text"]["div"])
    return r

# %% [markdown]
# ### parse out patient url from Synthea bundle object

# %%
def get_resource_url(b, type):
    my_url = [e.fullUrl for e in b.entry if e.resource.resource_type ==type]
    return(my_url[0])

# %% [markdown]
# ### get resource from Synthea bundle object by id
#
# -  return as dict
# -  make generic later

# %%
def get_resource_by_url(b,my_url):
    '''my_encounters = [e.resource for e in b.entry
        if e.resource.resource_type == 'Encounter']
    for my_encounter in my_encounters:
        print( my_encounter.id, my_encounter.type[0].coding[0].as_json() )
        #return(my_encounter[0].as_json())# assume only one / Bundle'''
    my_resource = [e.resource for e in b.entry
        if e.fullUrl == my_url]
    print(my_url, my_resource)
    return(my_resource[0].as_json())# assume only one / Bundle

# %% [markdown]
# ### update my_resources list and reference map

# %%
def add_resource_by_url(my_patient_data,my_url,r_type,num=0):
    ref_map[f'{r_type}/{r_type.lower()}0{num+1}'] = my_url
    my_resource = get_resource_by_url(my_patient_data,my_url)
    # if organization make sure has an NPI
    if my_resource["resourceType"] == "Organization":
        my_resource["identifier"] = t.org_npi
    # if encoounter make an inpatient encounter
    elif my_resource["resourceType"] == "Encounter":
        my_resource["class"]['code'] == "AMB"
        my_resource["type"] = t.enc_type
        # use the same organization for all the reports in the bundle
        if num != 0:
            my_resource["serviceProvider"] = {"reference":ref_map["Organization/organization01"]}
            my_resource["location"][0]["location"] = {"reference":ref_map["Location/location01"]}
    elif my_resource["resourceType"] == "Patient": 
        my_resource.pop('deceasedDateTime', None) # make sure is alive...
        # remove illegal extensions
        my_resource['extension'].pop()
        my_resource['extension'].pop() 
    my_resources.append(my_resource)
return

# %% [markdown]
# ### Get files in current path
#
# - get only 1
# - convert the files to FHIR Bundle object

# %%
def get_synth_patient_data(num=1):
    pyfhir = []
    my_patient_files = [x for i,x in enumerate(os.listdir(in_path)) if i < num]
    pprint(my_patient_files)
    for my_patient_file in my_patient_files:
        with open(f'{in_path}/{my_patient_file}', encoding='utf-8') as f:
            r = f.read()
            pyfhir.append(B.Bundle(loads(r)))
    return(pyfhir)

# %% [markdown]
# ## Main part of Code

# %% [markdown]
# ### 1. create Bundle 'b'  change the id for unique Bundles!!!

# %%
b = B.Bundle()
b.id =  bundle_id
b.type = bundle_type
b.timestamp = D.FHIRDate(f'{datetime.utcnow().isoformat()}Z')
b.as_json()
# Out:
# {'id': 'multiple-ind-mrp-task-report',
#  'timestamp': '2020-07-06T04:38:32.238514Z',
#  'type': 'transaction',
#  'resourceType': 'Bundle'}

# %% [markdown]
# ### 1. create Parameters resource 'p'  change the id for unique Bundles!!!

# %%
p = P.Parameters()
p.id =  bundle_id
p.as_json()
# Out:
# {'id': 'multiple-ind-mrp-task-report', 'resourceType': 'Parameters'}

# %% [markdown]
# ### 2.  Add Core resources to resource bundle list
#
# - get all core resource templates from use case list
#
# ### 3.  Add Patient resources to resource bundle list
#
# - first get synthea patient bundle for 1 patient
# - parse out patient resource
# - add to list as patient01
# - make alive if deceased
#
# ### 3.  Add Encounter resources to resource bundle list
#
# - use synthea patient bundle for same patient as above
# - parse out encounter resources and look at type
# - choose id for inpatient encounter
# - use id to:
#     - add to list as encounter
#     - replace all references id
#
# ### based upon the Encounter add in the organization01, Location and patient01
#
# - use the uuid to add in these resources
# - update the ref_map
#
# ### Create a mapping of ids to uuids
#
# - get id from resource
# - map to uuid (create a dict of {urn:old_ref})
# - remove id element
# - replace all old refs in bundle with new urns

# %%
first = True
b.entry = []
'''
num = 1 if single_patient else 3

# get patient data as fhir object
my_patient_data_list = get_synth_patient_data(num)


for i,my_patient_data in enumerate(my_patient_data_list):
    # get patient0n as dict
    r_type = 'Patient'
    print(f'i={i}')
    
    
    my_url = get_resource_url(my_patient_data, r_type)
    add_resource_by_url(my_patient_data,my_url,r_type,i)

    # get encounter as dict
    r_type = 'Encounter'
    my_url = get_resource_url(my_patient_data, r_type)
    add_resource_by_url(my_patient_data,my_url,r_type,i)

    my_encounter = my_resources[-1]
    # get practitioner01 from encounter
    my_url = my_encounter['participant'][0]['individual']['reference']
    r_type = 'Practitioner'
    add_resource_by_url(my_patient_data,my_url,r_type,i)

    if i == 0:
        # get organization01 from encounter
        my_url = my_encounter['serviceProvider']['reference']
        r_type = 'Organization'
        add_resource_by_url(my_patient_data,my_url,r_type)
        # get location01 from encounter
        my_url = my_encounter['location'][0]['location']['reference']
        r_type = 'Location'
        add_resource_by_url(my_patient_data,my_url,r_type)
'''   
#if use_bundle:


'''
variables=
b_id_list, 
b_mrref_list, 
b_ref_list, 
b_ref_list, 
b_url_list, 
ref_map, 
br_list, 
'''

for resource in br_list:  # look at each dict in list and bundle
    resource_type= resource["resourceType"]
    
    # make sure that evaluatedResource is aligned
    if resource_type == 'MeasureReport' and not t.use_task:
        try:
            er = resource['evaluatedResource'][0]['reference']
        except KeyError:
            pass
        else:
            er = er.replace('Task', 'Observation')
            er = er.replace('task', 'observation')
            resource['evaluatedResource'][0]['reference'] = er


    # remove text from resource
    resource.pop('text', None)       
    # remove id from resource if not a uuid and replace with uuid
    #print(template["id"])
    old_id =  resource.pop('id',None)
    try: # check if a valid UUID
        val = uuid.UUID(old_id, version=4)
        new_urn = f'urn:uuid:{old_id}'
    except ValueError:
        # If it's a value error, then the string 
        # is not a valid hex code for a UUID.
        # print('invalid')
        new_urn = uuid.uuid1().urn # new urn for resource
        ref_map[f'{resource_type}/{old_id}'] = new_urn #update the maps to uuid
    #print(ref_map , '\n')
    e = B.BundleEntry(dict
        (
        resource = resource,
        fullUrl = new_urn,
        )
      )
    if bundle_type in ['transaction', 'batch']:
        e.request = B.BundleEntryRequest(dict
                    (
                    method = 'POST',
                    url =  resource['resourceType']
                    )
                    )

    if( (resource_type != 'Observation' and t.use_task)
        or (resource_type != 'Task' and not t.use_task) ): 
        b.entry.append(e)
pprint(ref_map)
b_json = dumps(b.as_json(),indent =3)
# print(b_json)
for old_ref, new_ref in ref_map.items():
    b_json = b_json.replace(old_ref,new_ref)
"""for bad, good in t.qa_issues.items():
    b_json = b_json.replace(bad,good)"""
print(b_json)
print('.......validating')
r = validate(b)
display(HTML(f'<h1>Validation output</h1><h3>Status Code = {r.status_code}</h3> {r.json()["text"]["div"]}'))
write_file(b_json)
                 
'''else:  # use parameters
    p = P.Parameters()
    p.id =  bundle_id
    pprint(ref_map)             

    for resource in my_resources:  # all templates as dict in mrp
        resource_type= resource["resourceType"]
'''
# Out:
# {'Coverage/coverage01': 'urn:uuid:8be4a69f-bf42-11ea-81d8-4ccc6a181ed3',
#  'Coverage/coverage02': 'urn:uuid:8be431e2-bf42-11ea-8e67-4ccc6a181ed3',
#  'Coverage/coverage03': 'urn:uuid:8be4a69e-bf42-11ea-91ae-4ccc6a181ed3',
#  'Encounter/Encounter01': 'urn:uuid:8be5905c-bf42-11ea-b2cd-4ccc6a181ed3',
#  'Encounter/encounter01': 'Encounter/encounter01',
#  'MeasureReport/indv-measurereport01': 'urn:uuid:8be62b48-bf42-11ea-98b1-4ccc6a181ed3',
#  'MeasureReport/indv-measurereport02': 'urn:uuid:8be47fde-bf42-11ea-a085-4ccc6a181ed3',
#  'MeasureReport/indv-measurereport03': 'urn:uuid:8be4f48a-bf42-11ea-8fac-4ccc6a181ed3',
#  'Observation/observation01': 'urn:uuid:8be4cdda-bf42-11ea-b8d3-4ccc6a181ed3',
#  'Observation/observation03': 'urn:uuid:8be5b666-bf42-11ea-9ebd-4ccc6a181ed3',
#  'Organization/organization01': 'urn:uuid:8be4cdd8-bf42-11ea-bb36-4ccc6a181ed3',
#  'Organization/organization02': 'urn:uuid:8be409e4-bf42-11ea-90af-4ccc6a181ed3',
#  'Organization/organization04': 'urn:uuid:8be4cdd9-bf42-11ea-be37-4ccc6a181ed3',
#  'Patient/patient01': 'urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3',
#  'Patient/patient02': 'urn:uuid:8be60454-bf42-11ea-9038-4ccc6a181ed3',
#  'Patient/patient03': 'urn:uuid:8be67a34-bf42-11ea-834f-4ccc6a181ed3',
#  'Practitioner/practitioner01': 'urn:uuid:8be3bd12-bf42-11ea-823a-4ccc6a181ed3',
#  'Task/Task01': 'urn:uuid:8be62b49-bf42-11ea-8987-4ccc6a181ed3',
#  'Task/task01': 'Task/task01'}
# {
#    "id": "multiple-ind-mrp-task-report",
#    "entry": [
#       {
#          "fullUrl": "urn:uuid:8be3bd12-bf42-11ea-823a-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Practitioner"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/practitioner-deqm"
#                ]
#             },
#             "address": [
#                {
#                   "city": "Amherst",
#                   "line": [
#                      "1003 Healthcare Drive"
#                   ],
#                   "postalCode": "01002",
#                   "state": "MA",
#                   "use": "home"
#                }
#             ],
#             "identifier": [
#                {
#                   "assigner": {
#                      "display": "www.cms.gov"
#                   },
#                   "system": "http://hl7.org/fhir/sid/us-npi",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "PRN",
#                            "display": "Provider number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "345678912"
#                },
#                {
#                   "assigner": {
#                      "display": "www.cms.gov"
#                   },
#                   "system": "urn:oid:2.16.840.1.113883.4.336",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "PRN",
#                            "display": "Provider number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "secondary",
#                   "value": "082583"
#                }
#             ],
#             "name": [
#                {
#                   "family": "Bone",
#                   "given": [
#                      "Ronald"
#                   ],
#                   "prefix": [
#                      "Dr"
#                   ]
#                }
#             ],
#             "resourceType": "Practitioner"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be409e4-bf42-11ea-90af-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Organization"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-03-06T19:03:03.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm"
#                ],
#                "versionId": "3"
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "Englewood",
#                   "country": "USA",
#                   "line": [
#                      "3 Sherwood St."
#                   ],
#                   "postalCode": "07631",
#                   "state": "NJ"
#                }
#             ],
#             "identifier": [
#                {
#                   "assigner": {
#                      "display": "www.irs.gov"
#                   },
#                   "system": "urn:oid:2.16.840.1.113883.4.4",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "TAX",
#                            "display": "Tax ID number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "234567891"
#                }
#             ],
#             "name": "DaVinciHospital02",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "(+1) 551-555-1212"
#                }
#             ],
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "prov",
#                         "display": "Healthcare Provider",
#                         "system": "http://terminology.hl7.org/CodeSystem/organization-type"
#                      }
#                   ]
#                }
#             ],
#             "resourceType": "Organization"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be431e2-bf42-11ea-8e67-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Coverage"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-03-06T19:03:03.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm"
#                ],
#                "versionId": "2"
#             },
#             "beneficiary": {
#                "reference": "urn:uuid:8be60454-bf42-11ea-9038-4ccc6a181ed3"
#             },
#             "payor": [
#                {
#                   "reference": "urn:uuid:8be4cdd9-bf42-11ea-be37-4ccc6a181ed3"
#                }
#             ],
#             "policyHolder": {
#                "reference": "urn:uuid:8be60454-bf42-11ea-9038-4ccc6a181ed3"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "status": "active",
#             "subscriber": {
#                "reference": "urn:uuid:8be60454-bf42-11ea-9038-4ccc6a181ed3"
#             },
#             "subscriberId": "B123456789",
#             "resourceType": "Coverage"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be47fde-bf42-11ea-a085-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "MeasureReport"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm"
#                ]
#             },
#             "extension": [
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring",
#                   "valueCodeableConcept": {
#                      "coding": [
#                         {
#                            "code": "proportion",
#                            "system": "http://terminology.hl7.org/CodeSystem/measure-scoring"
#                         }
#                      ]
#                   }
#                },
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-certificationIdentifier",
#                   "valueIdentifier": {
#                      "system": "urn:oid:2.16.840.1.113883.3.2074.1",
#                      "value": "0015HQN9BD3304E"
#                   }
#                },
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-reportingVendor",
#                   "valueReference": {
#                      "reference": "urn:uuid:8be409e4-bf42-11ea-90af-4ccc6a181ed3"
#                   }
#                }
#             ],
#             "date": "2018-09-05T16:59:52.404Z",
#             "evaluatedResource": [
#                {
#                   "reference": "urn:uuid:8be4cdda-bf42-11ea-b8d3-4ccc6a181ed3"
#                }
#             ],
#             "group": [
#                {
#                   "code": {
#                      "coding": [
#                         {
#                            "code": "mrp-group",
#                            "display": "MRP Group",
#                            "system": "http://example.org"
#                         }
#                      ],
#                      "text": "MRP Group"
#                   },
#                   "measureScore": {
#                      "value": 1
#                   },
#                   "population": [
#                      {
#                         "id": "initial-population",
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "initial-population",
#                                  "display": "Initial Population",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "id": "numerator",
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "numerator",
#                                  "display": "Numerator",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "id": "denominator",
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "denominator",
#                                  "display": "Denominator",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      }
#                   ]
#                }
#             ],
#             "improvementNotation": {
#                "coding": [
#                   {
#                      "code": "increase",
#                      "display": "Increased score indicates improvement",
#                      "system": "http://terminology.hl7.org/CodeSystem/measure-improvement-notation"
#                   }
#                ]
#             },
#             "measure": "http://hl7.org/fhir/us/davinci-deqm/Measure/measure-mrp-example",
#             "period": {
#                "end": "2018-09-01",
#                "start": "2018-08-01"
#             },
#             "reporter": {
#                "reference": "urn:uuid:8be4cdd8-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "status": "complete",
#             "subject": {
#                "reference": "urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "type": "individual",
#             "resourceType": "MeasureReport"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be4a69e-bf42-11ea-91ae-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Coverage"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-02-07T18:47:34.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm"
#                ],
#                "versionId": "2"
#             },
#             "beneficiary": {
#                "reference": "urn:uuid:8be67a34-bf42-11ea-834f-4ccc6a181ed3"
#             },
#             "payor": [
#                {
#                   "reference": "urn:uuid:8be4cdd9-bf42-11ea-be37-4ccc6a181ed3"
#                }
#             ],
#             "policyHolder": {
#                "reference": "urn:uuid:8be67a34-bf42-11ea-834f-4ccc6a181ed3"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "status": "active",
#             "subscriber": {
#                "reference": "urn:uuid:8be67a34-bf42-11ea-834f-4ccc6a181ed3"
#             },
#             "subscriberId": "C123456789",
#             "resourceType": "Coverage"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be4a69f-bf42-11ea-81d8-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Coverage"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-02-11T14:19:25.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm"
#                ],
#                "versionId": "2"
#             },
#             "beneficiary": {
#                "reference": "urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "payor": [
#                {
#                   "reference": "urn:uuid:8be4cdd9-bf42-11ea-be37-4ccc6a181ed3"
#                }
#             ],
#             "policyHolder": {
#                "reference": "urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "status": "active",
#             "subscriber": {
#                "reference": "urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "subscriberId": "A123456789",
#             "resourceType": "Coverage"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be4cdd8-bf42-11ea-bb36-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Organization"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-02-21T01:47:54.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm"
#                ],
#                "versionId": "4"
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "Warwick",
#                   "country": "USA",
#                   "line": [
#                      "73 Lakewood Street"
#                   ],
#                   "postalCode": "02886",
#                   "state": "RI"
#                }
#             ],
#             "identifier": [
#                {
#                   "assigner": {
#                      "display": "www.irs.gov"
#                   },
#                   "system": "urn:oid:2.16.840.1.113883.4.4",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "TAX",
#                            "display": "Tax ID number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "123456789"
#                }
#             ],
#             "name": "DaVinciHospital01",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "(+1) 401-555-1212"
#                }
#             ],
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "prov",
#                         "display": "Healthcare Provider",
#                         "system": "http://terminology.hl7.org/CodeSystem/organization-type"
#                      }
#                   ]
#                }
#             ],
#             "resourceType": "Organization"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be4cdd9-bf42-11ea-be37-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Organization"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-03-06T19:03:03.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm"
#                ],
#                "versionId": "4"
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "Grand Rapids",
#                   "country": "USA",
#                   "line": [
#                      "160 Glen Eagles Road"
#                   ],
#                   "postalCode": "49503",
#                   "state": "MI"
#                }
#             ],
#             "identifier": [
#                {
#                   "assigner": {
#                      "display": "www.irs.gov"
#                   },
#                   "system": "urn:oid:2.16.840.1.113883.4.4",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "TAX",
#                            "display": "Tax ID number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "456789123"
#                }
#             ],
#             "name": "DVPayer04",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "(+1) 616-555-1212"
#                }
#             ],
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "ins",
#                         "display": "Insurance Company",
#                         "system": "http://terminology.hl7.org/CodeSystem/organization-type"
#                      }
#                   ]
#                }
#             ],
#             "resourceType": "Organization"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be4f48a-bf42-11ea-8fac-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "MeasureReport"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm"
#                ]
#             },
#             "extension": [
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring",
#                   "valueCodeableConcept": {
#                      "coding": [
#                         {
#                            "code": "proportion",
#                            "system": "http://terminology.hl7.org/CodeSystem/measure-scoring"
#                         }
#                      ]
#                   }
#                }
#             ],
#             "date": "2019-03-14",
#             "group": [
#                {
#                   "code": {
#                      "coding": [
#                         {
#                            "code": "group-1",
#                            "display": "group-1",
#                            "system": "http://fhir/example.org"
#                         }
#                      ]
#                   },
#                   "measureScore": {
#                      "value": 1
#                   },
#                   "population": [
#                      {
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "initial-population",
#                                  "display": "Initial Population",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "numerator",
#                                  "display": "Numerator",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "denominator",
#                                  "display": "Denominator",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "denominator-exclusion",
#                                  "display": "Denominator Exclusion",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 0
#                      }
#                   ],
#                   "stratifier": [
#                      {
#                         "code": [
#                            {
#                               "coding": [
#                                  {
#                                     "code": "sde-ethnicity",
#                                     "display": "SDE Ethnicity",
#                                     "system": "http://fhir/example.org"
#                                  }
#                               ]
#                            }
#                         ],
#                         "stratum": [
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "2135-2",
#                                        "display": "Hispanic or Latino",
#                                        "system": "urn:oid:2.16.840.1.113883.6.238"
#                                     }
#                                  ]
#                               }
#                            },
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "2186-5",
#                                        "display": "Not Hispanic or Latino",
#                                        "system": "urn:oid:2.16.840.1.113883.6.238"
#                                     }
#                                  ]
#                               }
#                            }
#                         ]
#                      },
#                      {
#                         "code": [
#                            {
#                               "coding": [
#                                  {
#                                     "code": "sde-payer",
#                                     "display": "SDE Payer",
#                                     "system": "http://fhir/example.org"
#                                  }
#                               ]
#                            }
#                         ],
#                         "stratum": [
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "Payer123",
#                                        "display": "King HMO",
#                                        "system": "http://fhir/example.org"
#                                     }
#                                  ]
#                               }
#                            },
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "Payer456",
#                                        "display": "Green Circle",
#                                        "system": "http://fhir/example.org"
#                                     }
#                                  ]
#                               }
#                            },
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "Payer789",
#                                        "display": "GoodHealth of California",
#                                        "system": "http://fhir/example.org"
#                                     }
#                                  ]
#                               }
#                            }
#                         ]
#                      },
#                      {
#                         "code": [
#                            {
#                               "coding": [
#                                  {
#                                     "code": "sde-race",
#                                     "display": "SDE Race",
#                                     "system": "http://fhir/example.org"
#                                  }
#                               ]
#                            }
#                         ],
#                         "stratum": [
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "2054-5",
#                                        "display": "Black or African American",
#                                        "system": "urn:oid:2.16.840.1.113883.6.238"
#                                     }
#                                  ]
#                               }
#                            },
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 1
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
#                                              "display": "Denominator Exclusion",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  }
#                               ],
#                               "value": {
#                                  "coding": [
#                                     {
#                                        "code": "2106-3",
#                                        "display": "White",
#                                        "system": "urn:oid:2.16.840.1.113883.6.238"
#                                     }
#                                  ]
#                               }
#                            },
#                            {
#                               "population": [
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "initial-population",
#                                              "display": "Initial Population",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "numerator",
#                                              "display": "Numerator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator",
#                                              "display": "Denominator",
#                                              "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                                           }
#                                        ]
#                                     },
#                                     "count": 0
#                                  },
#                                  {
#                                     "code": {
#                                        "coding": [
#                                           {
#                                              "code": "denominator-exclusion",
# ...
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "MR",
#                            "display": "Medical record number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "usual",
#                   "value": "23456"
#                }
#             ],
#             "managingOrganization": {
#                "reference": "urn:uuid:8be409e4-bf42-11ea-90af-4ccc6a181ed3"
#             },
#             "maritalStatus": {
#                "coding": [
#                   {
#                      "code": "M",
#                      "display": "Married",
#                      "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus"
#                   }
#                ]
#             },
#             "name": [
#                {
#                   "family": "Bernard",
#                   "given": [
#                      "Darien"
#                   ],
#                   "use": "official"
#                }
#             ],
#             "resourceType": "Patient"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be62b48-bf42-11ea-98b1-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "MeasureReport"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm"
#                ]
#             },
#             "extension": [
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring",
#                   "valueCodeableConcept": {
#                      "coding": [
#                         {
#                            "code": "proportion",
#                            "system": "http://terminology.hl7.org/CodeSystem/measure-scoring"
#                         }
#                      ]
#                   }
#                },
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-certificationIdentifier",
#                   "valueIdentifier": {
#                      "system": "urn:oid:2.16.840.1.113883.3.2074.1",
#                      "value": "0015HQN9BD3304E"
#                   }
#                },
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-reportingVendor",
#                   "valueReference": {
#                      "reference": "urn:uuid:8be409e4-bf42-11ea-90af-4ccc6a181ed3"
#                   }
#                }
#             ],
#             "date": "2018-09-05T16:59:52.404Z",
#             "evaluatedResource": [
#                {
#                   "reference": "urn:uuid:8be62b49-bf42-11ea-8987-4ccc6a181ed3"
#                }
#             ],
#             "group": [
#                {
#                   "code": {
#                      "coding": [
#                         {
#                            "code": "mrp-group",
#                            "display": "MRP Group",
#                            "system": "http://example.org"
#                         }
#                      ],
#                      "text": "MRP Group"
#                   },
#                   "measureScore": {
#                      "value": 1
#                   },
#                   "population": [
#                      {
#                         "id": "initial-population",
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "initial-population",
#                                  "display": "Initial Population",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "id": "numerator",
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "numerator",
#                                  "display": "Numerator",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      },
#                      {
#                         "id": "denominator",
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "denominator",
#                                  "display": "Denominator",
#                                  "system": "http://terminology.hl7.org/CodeSystem/measure-population"
#                               }
#                            ]
#                         },
#                         "count": 1
#                      }
#                   ]
#                }
#             ],
#             "improvementNotation": {
#                "coding": [
#                   {
#                      "code": "increase",
#                      "display": "Increased score indicates improvement",
#                      "system": "http://terminology.hl7.org/CodeSystem/measure-improvement-notation"
#                   }
#                ]
#             },
#             "measure": "http://hl7.org/fhir/us/davinci-deqm/Measure/measure-mrp-example",
#             "period": {
#                "end": "2018-09-01",
#                "start": "2018-08-01"
#             },
#             "reporter": {
#                "reference": "urn:uuid:8be4cdd8-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "status": "complete",
#             "subject": {
#                "reference": "urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "type": "individual",
#             "resourceType": "MeasureReport"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be62b49-bf42-11ea-8987-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Task"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-task"
#                ]
#             },
#             "authoredOn": "2018-09-25T14:24:23.584Z",
#             "code": {
#                "coding": [
#                   {
#                      "code": "1111F",
#                      "display": "Medication Reconciliation",
#                      "system": "http://www.ama-assn.org/go/cpt"
#                   }
#                ]
#             },
#             "encounter": {
#                "reference": "urn:uuid:8be5905c-bf42-11ea-b2cd-4ccc6a181ed3"
#             },
#             "executionPeriod": {
#                "end": "2017-06-11",
#                "start": "2017-06-11"
#             },
#             "for": {
#                "reference": "urn:uuid:8be5b667-bf42-11ea-bb36-4ccc6a181ed3"
#             },
#             "identifier": [
#                {
#                   "system": "http://example.org/tasks",
#                   "value": "19009"
#                }
#             ],
#             "intent": "plan",
#             "owner": {
#                "reference": "urn:uuid:8be3bd12-bf42-11ea-823a-4ccc6a181ed3"
#             },
#             "priority": "routine",
#             "status": "completed",
#             "resourceType": "Task"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8be67a34-bf42-11ea-834f-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Patient"
#          },
#          "resource": {
#             "meta": {
#                "lastUpdated": "2019-02-07T18:47:34.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-patient"
#                ],
#                "versionId": "4"
#             },
#             "extension": [
#                {
#                   "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#                   "valueCode": "F"
#                },
#                {
#                   "extension": [
#                      {
#                         "url": "ombCategory",
#                         "valueCoding": {
#                            "code": "2054-5",
#                            "display": "Black or African American",
#                            "system": "urn:oid:2.16.840.1.113883.6.238"
#                         }
#                      },
#                      {
#                         "url": "text",
#                         "valueString": "Black or African American"
#                      }
#                   ],
#                   "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race"
#                },
#                {
#                   "extension": [
#                      {
#                         "url": "ombCategory",
#                         "valueCoding": {
#                            "code": "2186-5",
#                            "display": "Not Hispanic or Latino",
#                            "system": "urn:oid:2.16.840.1.113883.6.238"
#                         }
#                      },
#                      {
#                         "url": "text",
#                         "valueString": "Not Hispanic or Latino"
#                      }
#                   ],
#                   "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity"
#                }
#             ],
#             "active": true,
#             "address": [
#                {
#                   "city": "Freehold",
#                   "country": "USA",
#                   "line": [
#                      "213 Lilac Ave."
#                   ],
#                   "postalCode": "48099",
#                   "state": "MI",
#                   "use": "home"
#                }
#             ],
#             "birthDate": "1983-09-12",
#             "communication": [
#                {
#                   "language": {
#                      "coding": [
#                         {
#                            "code": "en-US",
#                            "display": "English (Region=United States)",
#                            "system": "urn:ietf:bcp:47"
#                         }
#                      ]
#                   },
#                   "preferred": true
#                }
#             ],
#             "deceasedBoolean": false,
#             "gender": "female",
#             "identifier": [
#                {
#                   "system": "http://hospital.davinci.org",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "MR",
#                            "display": "Medical record number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "usual",
#                   "value": "34567"
#                }
#             ],
#             "managingOrganization": {
#                "reference": "Organization/organization03"
#             },
#             "maritalStatus": {
#                "coding": [
#                   {
#                      "code": "U",
#                      "display": "unmarried",
#                      "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus"
#                   }
#                ]
#             },
#             "name": [
#                {
#                   "family": "Hartman",
#                   "given": [
#                      "Virginia"
#                   ],
#                   "use": "official"
#                }
#             ],
#             "resourceType": "Patient"
#          }
#       }
#    ],
#    "timestamp": "2020-07-06T04:38:32.238514Z",
#    "type": "transaction",
#    "resourceType": "Bundle"
# }
# .......validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div xmlns="http://www.w3.org/1999/xhtml"><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Code</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Source</b></td></tr><tr><td>ERROR</td><td>Bundle.entry[1].resource.identifier[0] (line 1, col 1474), Bundle.entry[1].resource.identifier[0] (line 1, col 1474)</td><td>Validation rule failed</td><td>Either an NPI or EIN (TIN) identifier SHALL be present [(identifier.system = 'urn:oid:2.16.840.1.113883.4.2') or (identifier.system = 'http://hl7.org/fhir/sid/us-npi')]</td><td/><td>InstanceValidator</td></tr><tr><td>ERROR</td><td>Bundle.entry[6].resource.identifier[0] (line 1, col 6489), Bundle.entry[6].resource.identifier[0] (line 1, col 6489)</td><td>Validation rule failed</td><td>Either an NPI or EIN (TIN) identifier SHALL be present [(identifier.system = 'urn:oid:2.16.840.1.113883.4.2') or (identifier.system = 'http://hl7.org/fhir/sid/us-npi')]</td><td/><td>InstanceValidator</td></tr><tr><td>ERROR</td><td>Bundle.entry[7].resource.identifier[0] (line 1, col 7468), Bundle.entry[7].resource.identifier[0] (line 1, col 7468)</td><td>Validation rule failed</td><td>Either an NPI or EIN (TIN) identifier SHALL be present [(identifier.system = 'urn:oid:2.16.840.1.113883.4.2') or (identifier.system = 'http://hl7.org/fhir/sid/us-npi')]</td><td/><td>InstanceValidator</td></tr><tr><td>INFORMATION</td><td>Bundle.entry[3].resource.extension[0] (line 1, col 2872), Bundle.entry[3].resource.extension[0] (line 1, col 2872)</td><td>Structural Issue</td><td>Unknown extension http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring</td><td/><td>InstanceValidator</td></tr><tr><td>INFORMATION</td><td>Bundle.entry[8].resource.extension[0] (line 1, col 8231), Bundle.entry[8].resource.extension[0] (line 1, col 8231)</td><td>Structural Issue</td><td>Unknown extension http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring</td><td/><td>InstanceValidator</td></tr><tr><td>INFORMATION</td><td>Bundle.entry[12].resource.extension[0] (line 1, col 23839), Bundle.entry[12].resource.extension[0] (line 1, col 23839)</td><td>Structural Issue</td><td>Unknown extension http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-measureScoring</td><td/><td>InstanceValidator</td></tr><tr><td>WARNING</td><td>Bundle.entry[2].resource.relationship (line 1, col 2472), Bundle.entry[2].resource.relationship (line 1, col 2472)</td><td>Invalid Code</td><td>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/subscriber-relationship (http://hl7.org/fhir/ValueSet/subscriber-relationship, and a code should come from this value set unless it has no suitable code) (codes = null#self)</td><td/><td>TerminologyEngine</td></tr><tr><td>WARNING</td><td>Bundle.entry[4].resource.relationship (line 1, col 5267), Bundle.entry[4].resource.relationship (line 1, col 5267)</td><td>Invalid Code</td><td>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/subscriber-relationship (http://hl7.org/fhir/ValueSet/subscriber-relationship, and a code should come from this value set unless it has no suitable code) (codes = null#self)</td><td/><td>TerminologyEngine</td></tr><tr><td>WARNING</td><td>Bundle.entry[5].resource.relationship (line 1, col 5891), Bundle.entry[5].resource.relationship (line 1, col 5891)</td><td>Invalid Code</td><td>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/subscriber-relationship (http://hl7.org/fhir/ValueSet/subscriber-relationship, and a code should come from this value set unless it has no suitable code) (codes = null#self)</td><td/><td>TerminologyEngine</td></tr><tr><td>WARNING</td><td>Bundle.entry[0].resource.meta.profile[0] (line 1, col 187), Bundle.entry[0].resource.meta.profile[0] (line 1, col 187)</td><td>Structural Issue</td><td>StructureDefinition reference &quot;http://hl7.org/fhir/us/davinci-deqm/S ...
# 'else:  # use parameters\n    p = P.Parameters()\n    p.id =  bundle_id\n    pprint(ref_map)             \n\n    for resource in my_resources:  # all templates as dict in mrp\n        resource_type= resource["resourceType"]\n'
