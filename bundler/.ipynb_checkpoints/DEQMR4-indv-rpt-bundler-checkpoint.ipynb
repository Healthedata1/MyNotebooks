# %% [markdown]
# **\*\*\*\*\*\*\*Remember to restart Kerne
# l for new run since the template are not refreshed\*\*\*\*\*\*\***
#
# ## Script to create a transaction bundle of multiple indiv Reports
#
# - python version 3.6+
# - multiple measures per patient
# - create for each patient       [
#         'MeasureReport',
#         'Task',
#         'Coverage'
#         ]
#       - using dictionary templates
# - Build Bundle stepwise....
#   - Create Empty Bundle
#        - POST method
#        - unique id (increment for now)
#   - fullURL= uuid
#   - Add Core resources from templates
#   - Add patient
#   - Create a dict of uuid to resource id
#   - remove id elements
#   - replace the relative refs with uuids
#   - Get encounter
#   - Get referenced Organizations, Practitioners, Locations
#     - check if in dict - if not addscxaz
#   - replace the relative refs with uuids
#
#
#
#   - multiple US Core Synthea patient bundle in folder
#     - cycle through entries to get patient resource
#
#   - multiple reports per patient
#     - MRP
#       - Resources:
#         [
#         'MeasureReport',
#         'Task',
#         'Encounter',
#         'Location',
#         'Organization',
#         'Practititioner',
#         'Patient',
#         'Coverage',
#         ]
#     - Col
#       - Resources:
#     - VTE
#       - Resources:
#   - reuse encounters, practitioner and organizations and patients where possible!!!
# - bundle
#   - POST method
#   - replace all references with uuids
# - validate and save

# %%
from json import load, dumps, loads
from IPython import display as D
from requests import get, post, put
from IPython.display import display, Markdown, HTML
import fhirclient.r4models.bundle as B
import fhirclient.r4models.parameters as P
import fhirclient.r4models.fhirdate as D
from fhirclient.models.fhirabstractbase import FHIRValidationError 
import os, uuid
from datetime import datetime
from pprint import pprint
import mrp_resource_templates as t

for i in t.mrp1:
    print(i['resourceType'])
# Out:
# MeasureReport
# Task
# Coverage
# Organization
# Organization
# Observation

# %% [markdown]
# ### global variables

# %%
use_bundle=True
single_patient = False
use_task = False
uc = 'mrp'

bundle_id = (f'{"single" if single_patient else "multiple"}-indv-{uc}-'
            f'{"task" if use_task else "obs"}-report')
print(bundle_id)
bundle_type = 'transaction'
                         
parameter_id = f'{uc}-submit-data-example'
print(parameter_id)

in_path =  "//ERICS-AIR-2/ehaas/Documents/FHIR/synthea/output/us_core_r4/fhir_10yr_hx" # local source of Synthea bundles from PC to Mac
#out_path = '/Users/ehaas/Documents/FHIR/Davinci-DEQM/source/examples/'  # append forward slash
out_path ='r4'  #local output dir
out_path = "//ERICS-AIR-2/ehaas/Documents/FHIR/Davinci-DEQM/source/examples"  # DEqm source



if single_patient:
    ref_map = dict(zip(t.mrp1_core_references,t.mrp1_core_references)) # init the ref with old:new=old
    my_resources = t.mrp1  # get all core resource templates from use case list

else: # mult patients
    mult_ref_mrp =  set(t.mrp1_core_references + t.mrp2_core_references + t.mrp3_core_references)
    ref_map = dict(zip(mult_ref_mrp,mult_ref_mrp))

    mult_mrp = t.mrp1 + t.mrp2 + t.mrp3  # take three list and combine
    my_resources = list({v['id']:v for v in mult_mrp}.values())
# Out:
# single-indv-mrp-obs-report
# mrp-submit-data-example

# %% [markdown]
# ###  write to file

# %%
def write_file(r): # write file
    with open(f'{out_path}/Bundle-{bundle_id}.json', 'w', encoding='utf-8') as f:
        f.write(r)

# %% [markdown]
# ### validate

# %%
# *********************** validate Resource ********************************

def validate(r):

    #fhir_test_server = 'http://test.fhir.org/r4'
    fhir_test_server = 'http://hapi.fhir.org/baseR4'
    headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }

    # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
 
    params = dict(
      # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
        )
    
    #   r = requests.post('https://httpbin.org/post', data = {'key':'value'})
    r = post(f'{fhir_test_server}/{r.resource_type}/$validate', params = params, headers = headers, data = dumps(r.as_json()))
    # return r.status_code
    # view  output
    # return (r.json()["text"]["div"])
    return r

# %% [markdown]
# ### parse out patient url from Synthea bundle object

# %%
def get_resource_url(b, type):
    my_url = [e.fullUrl for e in b.entry if e.resource.resource_type ==type]
    return(my_url[0])

# %% [markdown]
# ### get resource from Synthea bundle object by id
#
# -  return as dict
# -  make generic later

# %%
def get_resource_by_url(b,my_url):
    '''my_encounters = [e.resource for e in b.entry
        if e.resource.resource_type == 'Encounter']
    for my_encounter in my_encounters:
        print( my_encounter.id, my_encounter.type[0].coding[0].as_json() )
        #return(my_encounter[0].as_json())# assume only one / Bundle'''
    my_resource = [e.resource for e in b.entry
        if e.fullUrl == my_url]
    print(my_url, my_resource)
    return(my_resource[0].as_json())# assume only one / Bundle

# %% [markdown]
# ### update my_resources list and reference map

# %%
def add_resource_by_url(my_patient_data,my_url,r_type,num=0):
    ref_map[f'{r_type}/{r_type.lower()}0{num+1}'] = my_url
    my_resource = get_resource_by_url(my_patient_data,my_url)
    # if organization make sure has an NPI
    if my_resource["resourceType"] == "Organization":
        my_resource["identifier"] = t.org_npi
    # if encoounter make an inpatient encounter
    elif my_resource["resourceType"] == "Encounter":
        my_resource["class"]['code'] == "AMB"
        my_resource["type"] = t.enc_type
        # use the same organization for all the reports in the bundle
        if num != 0:
            my_resource["serviceProvider"] = {"reference":ref_map["Organization/organization01"]}
            my_resource["location"][0]["location"] = {"reference":ref_map["Location/location01"]}
    elif my_resource["resourceType"] == "Patient": 
        my_resource.pop('deceasedDateTime', None) # make sure is alive...
        # remove illegal extensions
        my_resource['extension'].pop()
        my_resource['extension'].pop() 
    my_resources.append(my_resource)
return

# %% [markdown]
# ### Get files in current path
#
# - get only 1
# - convert the files to FHIR Bundle object

# %%
def get_synth_patient_data(num=1):
    pyfhir = []
    my_patient_files = [x for i,x in enumerate(os.listdir(in_path)) if i < num]
    pprint(my_patient_files)
    for my_patient_file in my_patient_files:
        with open(f'{in_path}/{my_patient_file}', encoding='utf-8') as f:
            r = f.read()
            pyfhir.append(B.Bundle(loads(r)))
    return(pyfhir)

# %% [markdown]
# ### 1. create Bundle 'b'  change the id for unique Bundles!!!

# %%
b = B.Bundle()
b.id =  bundle_id
b.type = bundle_type
b.timestamp = D.FHIRDate(f'{datetime.utcnow().isoformat()}Z')
b.as_json()
# Out:
# {'id': 'single-indv-mrp-obs-report',
#  'timestamp': '2019-12-06T06:28:44.902388Z',
#  'type': 'transaction',
#  'resourceType': 'Bundle'}

# %% [markdown]
# ### 1. create Parameters resource 'p'  change the id for unique Bundles!!!

# %%
p = P.Parameters()
p.id =  bundle_id
p.as_json()
# Out:
# {'id': 'single-indv-mrp-obs-report', 'resourceType': 'Parameters'}

# %% [markdown]
# ### 2.  Add Core resources to resource bundle list
#
# - get all core resource templates from use case list
#
# ### 3.  Add Patient resources to resource bundle list
#
# - first get synthea patient bundle for 1 patient
# - parse out patient resource
# - add to list as patient01
# - make alive if deceased
#
# ### 3.  Add Encounter resources to resource bundle list
#
# - use synthea patient bundle for same patient as above
# - parse out encounter resources and look at type
# - choose id for inpatient encounter
# - use id to:
#     - add to list as encounter
#     - replace all references id
#
# ### based upon the Encounter add in the organization01, Location and patient01
#
# - use the uuid to add in these resources
# - update the ref_map
#
# ### Create a mapping of ids to uuids
#
# - get id from resource
# - map to uuid (create a dict of {urn:old_ref})
# - remove id element
# - replace all old refs in bundle with new urns

# %%
first = True
b.entry = []

num = 1 if single_patient else 3

# get patient data as fhir object
my_patient_data_list = get_synth_patient_data(num)


for i,my_patient_data in enumerate(my_patient_data_list):
    # get patient0n as dict
    r_type = 'Patient'
    print(f'i={i}')
    
    
    my_url = get_resource_url(my_patient_data, r_type)
    add_resource_by_url(my_patient_data,my_url,r_type,i)

    # get encounter as dict
    r_type = 'Encounter'
    my_url = get_resource_url(my_patient_data, r_type)
    add_resource_by_url(my_patient_data,my_url,r_type,i)

    my_encounter = my_resources[-1]
    # get practitioner01 from encounter
    my_url = my_encounter['participant'][0]['individual']['reference']
    r_type = 'Practitioner'
    add_resource_by_url(my_patient_data,my_url,r_type,i)

    if i == 0:
        # get organization01 from encounter
        my_url = my_encounter['serviceProvider']['reference']
        r_type = 'Organization'
        add_resource_by_url(my_patient_data,my_url,r_type)
        # get location01 from encounter
        my_url = my_encounter['location'][0]['location']['reference']
        r_type = 'Location'
        add_resource_by_url(my_patient_data,my_url,r_type)
    
if use_bundle:
    for resource in my_resources:  # all templates as dict in mrp
        resource_type= resource["resourceType"]
        # make sure that evaluatedResource is aligned
        if resource_type == 'MeasureReport' and not use_task:
            er = resource['evaluatedResource'][0]['reference']
            er = er.replace('Task', 'Observation')
            er = er.replace('task', 'observation')
            resource['evaluatedResource'][0]['reference'] = er


        # remove text from resource
        resource.pop('text', None)       
        # remove id from resource if not a uuid and replace with uuid
        #print(template["id"])
        old_id =  resource.pop('id',None)
        try: # check if a valid UUID
            val = uuid.UUID(old_id, version=4)
            new_urn = f'urn:uuid:{old_id}'
        except ValueError:
            # If it's a value error, then the string 
            # is not a valid hex code for a UUID.
            # print('invalid')
            new_urn = uuid.uuid1().urn # new urn for resource
            ref_map[f'{resource_type}/{old_id}'] = new_urn #update the maps to uuid
        #print(ref_map , '\n')
        e = B.BundleEntry(dict
            (
            resource = resource,
            fullUrl = new_urn,
            )
          )
        if bundle_type in ['transaction', 'batch']:
            e.request = B.BundleEntryRequest(dict
                        (
                        method = 'POST',
                        url =  resource['resourceType']
                        )
                        )

        if( (resource_type != 'Observation' and use_task)
            or (resource_type != 'Task' and not use_task) ): 
            b.entry.append(e)
    pprint(ref_map)
    b_json = dumps(b.as_json(),indent =3)
    # print(b_json)
    for old_ref, new_ref in ref_map.items():
        b_json = b_json.replace(old_ref,new_ref)
    for bad, good in t.qa_issues.items():
        b_json = b_json.replace(bad,good)
    print(b_json)
    print('.......validating')
    r = validate(b)
    display(HTML(f'<h1>Validation output</h1><h3>Status Code = {r.status_code}</h3> {r.json()["text"]["div"]}'))
    write_file(b_json)
                 
else:  # use parameters
    p = P.Parameters()
    p.id =  bundle_id

    for resource in my_resources:  # all templates as dict in mrp
        resource_type= resource["resourceType"]
# Out:
# ['Debbie941_McDermott739_0156e3a9-c4e1-4c0a-a53e-03ce3984ac65.json']
# i=0
# urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8 [<fhirclient.r4models.patient.Patient object at 0x064BFD10>]
# urn:uuid:1f33ae07-0891-4c2a-a376-fcd18800cb71 [<fhirclient.r4models.encounter.Encounter object at 0x0650C990>]
# urn:uuid:0000016d-235f-39b3-0000-0000000000fa [<fhirclient.r4models.practitioner.Practitioner object at 0x064FFEB0>]
# urn:uuid:ebc3f5c4-6700-34af-8323-85621c313726 [<fhirclient.r4models.organization.Organization object at 0x064FFAD0>]
# urn:uuid:8938e769-59f7-40ff-a541-50b0bfcd6742 [<fhirclient.r4models.location.Location object at 0x064FFAB0>]
# {'Coverage/coverage01': 'urn:uuid:a8fa147a-17f1-11ea-91ce-4ccc6a181ed3',
#  'Encounter/encounter01': 'urn:uuid:1f33ae07-0891-4c2a-a376-fcd18800cb71',
#  'Location/location01': 'urn:uuid:8938e769-59f7-40ff-a541-50b0bfcd6742',
#  'MeasureReport/measurereport01': 'urn:uuid:a8f9c686-17f1-11ea-a072-4ccc6a181ed3',
#  'Observation/observation01': 'urn:uuid:a8fa3b69-17f1-11ea-bd75-4ccc6a181ed3',
#  'Organization/organization01': 'urn:uuid:ebc3f5c4-6700-34af-8323-85621c313726',
#  'Organization/organization02': 'urn:uuid:a8fa147b-17f1-11ea-9ba7-4ccc6a181ed3',
#  'Organization/organization04': 'urn:uuid:a8fa3b68-17f1-11ea-93ae-4ccc6a181ed3',
#  'Patient/patient01': 'urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8',
#  'Practitioner/practitioner01': 'urn:uuid:0000016d-235f-39b3-0000-0000000000fa',
#  'Task/task01': 'urn:uuid:a8f9ed80-17f1-11ea-b47c-4ccc6a181ed3'}
# {
#    "id": "single-indv-mrp-obs-report",
#    "entry": [
#       {
#          "fullUrl": "urn:uuid:a8f9c686-17f1-11ea-a072-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "MeasureReport"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm"
#                ]
#             },
#             "extension": [
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-certificationIdentifier",
#                   "valueIdentifier": {
#                      "system": "urn:oid:2.16.840.1.113883.3.2074.1",
#                      "value": "0015HQN9BD3304E"
#                   }
#                },
#                {
#                   "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-reportingVendor",
#                   "valueReference": {
#                      "reference": "urn:uuid:a8fa147b-17f1-11ea-9ba7-4ccc6a181ed3"
#                   }
#                }
#             ],
#             "date": "2018-09-05T16:59:52.404Z",
#             "evaluatedResource": [
#                {
#                   "reference": "urn:uuid:a8fa3b69-17f1-11ea-bd75-4ccc6a181ed3"
#                }
#             ],
#             "group": [
#                {
#                   "code": {
#                      "coding": [
#                         {
#                            "code": "112",
#                            "display": "112",
#                            "system": "http://hl7/example.org"
#                         }
#                      ]
#                   },
#                   "measureScore": {
#                      "value": 100
#                   },
#                   "population": [
#                      {
#                         "code": {
#                            "coding": [
#                               {
#                                  "code": "initial-population",
#                                  "display": "Initial Population",
#                                  "system": "http://hl7/example.org"
#                               }
#                            ]
#                         }
#                      }
#                   ]
#                }
#             ],
#             "measure": "http://hl7.org/fhir/us/davinci-deqm/Measure/measure-mrp-example",
#             "period": {
#                "end": "2018-09-01",
#                "start": "2018-08-01"
#             },
#             "reporter": {
#                "reference": "urn:uuid:ebc3f5c4-6700-34af-8323-85621c313726"
#             },
#             "status": "complete",
#             "subject": {
#                "reference": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8"
#             },
#             "type": "individual",
#             "resourceType": "MeasureReport"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:a8fa147a-17f1-11ea-91ce-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Coverage"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm"
#                ]
#             },
#             "beneficiary": {
#                "reference": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8"
#             },
#             "payor": [
#                {
#                   "reference": "urn:uuid:a8fa3b68-17f1-11ea-93ae-4ccc6a181ed3"
#                }
#             ],
#             "policyHolder": {
#                "reference": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "status": "active",
#             "subscriber": {
#                "reference": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8"
#             },
#             "subscriberId": "A123456789",
#             "resourceType": "Coverage"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:a8fa147b-17f1-11ea-9ba7-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Organization"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm"
#                ]
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "Grand Rapids",
#                   "country": "USA",
#                   "line": [
#                      "160 Glen Eagles Road"
#                   ],
#                   "postalCode": "49503",
#                   "state": "MI"
#                }
#             ],
#             "identifier": [
#                {
#                   "assigner": {
#                      "display": "www.irs.gov"
#                   },
#                   "system": "urn:oid:2.16.840.1.113883.4.2",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "TAX",
#                            "display": "Tax ID number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "456789124"
#                }
#             ],
#             "name": "DV Quality Measure Data Reporter",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "(+1) 616-555-1212"
#                }
#             ],
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "other",
#                         "display": "Other",
#                         "system": "http://terminology.hl7.org/CodeSystem/organization-type"
#                      }
#                   ]
#                }
#             ],
#             "resourceType": "Organization"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:a8fa3b68-17f1-11ea-93ae-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Organization"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm"
#                ]
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "Grand Rapids",
#                   "country": "USA",
#                   "line": [
#                      "160 Glen Eagles Road"
#                   ],
#                   "postalCode": "49503",
#                   "state": "MI"
#                }
#             ],
#             "identifier": [
#                {
#                   "assigner": {
#                      "display": "www.irs.gov"
#                   },
#                   "system": "urn:oid:2.16.840.1.113883.4.2",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "TAX",
#                            "display": "Tax ID number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "456789125"
#                }
#             ],
#             "name": "DVPayer04",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "(+1) 616-555-1212"
#                }
#             ],
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "ins",
#                         "display": "Insurance Company",
#                         "system": "http://terminology.hl7.org/CodeSystem/organization-type"
#                      }
#                   ]
#                }
#             ],
#             "resourceType": "Organization"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:a8fa3b69-17f1-11ea-bd75-4ccc6a181ed3",
#          "request": {
#             "method": "POST",
#             "url": "Observation"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-observation"
#                ]
#             },
#             "category": [
#                {
#                   "coding": [
#                      {
#                         "code": "measure",
#                         "display": "Measure",
#                         "system": "http://hl7/example.org"
#                      }
#                   ]
#                }
#             ],
#             "code": {
#                "coding": [
#                   {
#                      "code": "1111F",
#                      "display": "Medication Reconciliation",
#                      "system": "http://www.ama-assn.org/go/cpt"
#                   }
#                ]
#             },
#             "effectiveDateTime": "2018-09-29T14:15:04.424Z",
#             "encounter": {
#                "reference": "urn:uuid:1f33ae07-0891-4c2a-a376-fcd18800cb71"
#             },
#             "issued": "2018-09-29T14:15:04.424Z",
#             "performer": [
#                {
#                   "reference": "urn:uuid:0000016d-235f-39b3-0000-0000000000fa"
#                }
#             ],
#             "status": "final",
#             "subject": {
#                "reference": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8"
#             },
#             "valueBoolean": true,
#             "resourceType": "Observation"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8",
#          "request": {
#             "method": "POST",
#             "url": "Patient"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient"
#                ]
#             },
#             "extension": [
#                {
#                   "extension": [
#                      {
#                         "url": "ombCategory",
#                         "valueCoding": {
#                            "code": "2106-3",
#                            "display": "White",
#                            "system": "urn:oid:2.16.840.1.113883.6.238"
#                         }
#                      },
#                      {
#                         "url": "text",
#                         "valueString": "White"
#                      }
#                   ],
#                   "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race"
#                },
#                {
#                   "extension": [
#                      {
#                         "url": "ombCategory",
#                         "valueCoding": {
#                            "code": "2186-5",
#                            "display": "Not Hispanic or Latino",
#                            "system": "urn:oid:2.16.840.1.113883.6.238"
#                         }
#                      },
#                      {
#                         "url": "text",
#                         "valueString": "Not Hispanic or Latino"
#                      }
#                   ],
#                   "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity"
#                },
#                {
#                   "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#                   "valueString": "Freda902 Tillman293"
#                },
#                {
#                   "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#                   "valueCode": "F"
#                },
#                {
#                   "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#                   "valueAddress": {
#                      "city": "Faro",
#                      "country": "PT",
#                      "state": "Algarve"
#                   }
#                }
#             ],
#             "address": [
#                {
#                   "extension": [
#                      {
#                         "extension": [
#                            {
#                               "url": "latitude",
#                               "valueDecimal": 42.21379047108309
#                            },
#                            {
#                               "url": "longitude",
#                               "valueDecimal": -72.73951315911818
#                            }
#                         ],
#                         "url": "http://hl7.org/fhir/StructureDefinition/geolocation"
#                      }
#                   ],
#                   "city": "Westfield",
#                   "country": "US",
#                   "line": [
#                      "903 Wolff Ville"
#                   ],
#                   "postalCode": "01085",
#                   "state": "MA"
#                }
#             ],
#             "birthDate": "1961-02-26",
#             "communication": [
#                {
#                   "language": {
#                      "coding": [
#                         {
#                            "code": "pt",
#                            "display": "Portuguese",
#                            "system": "urn:ietf:bcp:47"
#                         }
#                      ],
#                      "text": "Portuguese"
#                   }
#                }
#             ],
#             "gender": "female",
#             "identifier": [
#                {
#                   "system": "https://github.com/synthetichealth/synthea",
#                   "value": "0156e3a9-c4e1-4c0a-a53e-03ce3984ac65"
#                },
#                {
#                   "system": "http://hospital.smarthealthit.org",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "MR",
#                            "display": "Medical Record Number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ],
#                      "text": "Medical Record Number"
#                   },
#                   "value": "0156e3a9-c4e1-4c0a-a53e-03ce3984ac65"
#                },
#                {
#                   "system": "http://hl7.org/fhir/sid/us-ssn",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "SS",
#                            "display": "Social Security Number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ],
#                      "text": "Social Security Number"
#                   },
#                   "value": "999-61-8566"
#                },
#                {
#                   "system": "urn:oid:2.16.840.1.113883.4.3.25",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "DL",
#                            "display": "Driver's license Number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ],
#                      "text": "Driver's license Number"
#                   },
#                   "value": "S99966861"
#                },
#                {
#                   "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "PPN",
#                            "display": "Passport Number",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ],
#                      "text": "Passport Number"
#                   },
#                   "value": "X52208740X"
#                }
#             ],
#             "maritalStatus": {
#                "coding": [
#                   {
#                      "code": "M",
#                      "display": "Married",
#                      "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus"
#                   }
#                ],
#                "text": "M"
#             },
#             "multipleBirthBoolean": false,
#             "name": [
#                {
#                   "family": "McDermott739",
#                   "given": [
#                      "Debbie941"
#                   ],
#                   "prefix": [
#                      "Mrs."
#                   ],
#                   "use": "official"
#                },
#                {
#                   "family": "Funk324",
#                   "given": [
#                      "Debbie941"
#                   ],
#                   "prefix": [
#                      "Mrs."
#                   ],
#                   "use": "maiden"
#                }
#             ],
#             "telecom": [
#                {
#                   "system": "phone",
#                   "use": "home",
#                   "value": "555-755-4280"
#                }
#             ],
#             "resourceType": "Patient"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:1f33ae07-0891-4c2a-a376-fcd18800cb71",
#          "request": {
#             "method": "POST",
#             "url": "Encounter"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter"
#                ]
#             },
#             "class": {
#                "code": "AMB",
#                "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode"
#             },
#             "location": [
#                {
#                   "location": {
#                      "display": "NOBLE HOSPITAL",
#                      "reference": "urn:uuid:8938e769-59f7-40ff-a541-50b0bfcd6742"
#                   }
#                }
#             ],
#             "participant": [
#                {
#                   "individual": {
#                      "display": "Dr. Manuel446 Granados71",
#                      "reference": "urn:uuid:0000016d-235f-39b3-0000-0000000000fa"
#                   }
#                }
#             ],
#             "period": {
#                "end": "2018-04-29T10:41:49-07:00",
#                "start": "1976-06-20T10:41:49-07:00"
#             },
#             "serviceProvider": {
#                "display": "NOBLE HOSPITAL",
#                "reference": "urn:uuid:ebc3f5c4-6700-34af-8323-85621c313726"
#             },
#             "status": "finished",
#             "subject": {
#                "display": "Mrs. Debbie941 McDermott739",
#                "reference": "urn:uuid:6f0cef31-2235-4d66-82e2-fa861fc909a8"
#             },
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "99221",
#                         "display": "Initial hospital care",
#                         "system": "http://www.ama-assn.org/go/cpt"
#                      }
#                   ],
#                   "text": "Initial hospital care"
#                }
#             ],
#             "resourceType": "Encounter"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:0000016d-235f-39b3-0000-0000000000fa",
#          "request": {
#             "method": "POST",
#             "url": "Practitioner"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/core/StructureDefinition/us-core-practitioner"
#                ]
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "WESTFIELD",
#                   "country": "US",
#                   "line": [
#                      "115 WEST SILVER STREET"
#                   ],
#                   "postalCode": "01085",
#                   "state": "MA"
#                }
#             ],
#             "gender": "male",
#             "identifier": [
#                {
#                   "system": "http://hl7.org/fhir/sid/us-npi",
#                   "value": "250"
#                }
#             ],
#             "name": [
#                {
#                   "family": "Granados71",
#                   "given": [
#                      "Manuel446"
#                   ],
#                   "prefix": [
#                      "Dr."
#                   ]
#                }
#             ],
#             "telecom": [
#                {
#                   "extension": [
#                      {
#                         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-direct",
#                         "valueBoolean": true
#                      }
#                   ],
#                   "system": "email",
#                   "use": "work",
#                   "value": "Manuel446.Granados71@example.com"
#                }
#             ],
#             "resourceType": "Practitioner"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:ebc3f5c4-6700-34af-8323-85621c313726",
#          "request": {
#             "method": "POST",
#             "url": "Organization"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/core/StructureDefinition/us-core-organization"
#                ]
#             },
#             "active": true,
#             "address": [
#                {
#                   "city": "WESTFIELD",
#                   "country": "US",
#                   "line": [
#                      "115 WEST SILVER STREET"
#                   ],
#                   "postalCode": "01085",
#                   "state": "MA"
#                }
#             ],
#             "identifier": [
#                {
#                   "system": "http://hl7.org/fhir/sid/us-npi",
#                   "type": {
#                      "coding": [
#                         {
#                            "code": "PRN",
#                            "system": "http://terminology.hl7.org/CodeSystem/v2-0203"
#                         }
#                      ]
#                   },
#                   "use": "official",
#                   "value": "9999999999"
#                }
#             ],
#             "name": "NOBLE HOSPITAL",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "4135682811"
#                }
#             ],
#             "type": [
#                {
#                   "coding": [
#                      {
#                         "code": "prov",
#                         "display": "Healthcare Provider",
#                         "system": "http://terminology.hl7.org/CodeSystem/organization-type"
#                      }
#                   ],
#                   "text": "Healthcare Provider"
#                }
#             ],
#             "resourceType": "Organization"
#          }
#       },
#       {
#          "fullUrl": "urn:uuid:8938e769-59f7-40ff-a541-50b0bfcd6742",
#          "request": {
#             "method": "POST",
#             "url": "Location"
#          },
#          "resource": {
#             "meta": {
#                "profile": [
#                   "http://hl7.org/fhir/us/core/StructureDefinition/us-core-location"
#                ]
#             },
#             "address": {
#                "city": "WESTFIELD",
#                "country": "US",
#                "line": [
#                   "115 WEST SILVER STREET"
#                ],
#                "postalCode": "01085",
#                "state": "MA"
#             },
#             "managingOrganization": {
#                "display": "NOBLE HOSPITAL",
#                "reference": "urn:uuid:ebc3f5c4-6700-34af-8323-85621c313726"
#             },
#             "name": "NOBLE HOSPITAL",
#             "position": {
#                "latitude": 42.138838,
#                "longitude": -72.755911
#             },
#             "status": "active",
#             "telecom": [
#                {
#                   "system": "phone",
#                   "value": "4135682811"
#                }
#             ],
#             "resourceType": "Location"
#          }
#       }
#    ],
#    "timestamp": "2019-12-06T06:28:44.902388Z",
#    "type": "transaction",
#    "resourceType": "Bundle"
# }
# .......validating
# <h1>Validation output</h1><h3>Status Code = 412</h3> <div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Bundle.entry[0].resource.meta.profile[0], Line 1, Col 1263]</td><td><pre>StructureDefinition reference &quot;http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/indv-measurereport-deqm&quot; could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[0].resource, Line 1, Col 1263]</td>
#
#
#
# 						<td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Bundle.entry[0].resource.extension[0], Line 1, Col 298]</td>
#
#
#
# 						<td><pre>Unknown extension http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-certificationIdentifier</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Bundle.entry[0].resource.extension[1], Line 1, Col 497]</td>
#
#
#
# 						<td><pre>Unknown extension http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-reportingVendor</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[0].resource.group[0].population[0].code, Line 1, Col 930]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/measure-population (http://hl7.org/fhir/ValueSet/measure-population, and a code should come from this value set unless it has no suitable code) (codes = http://hl7/example.org#initial-population)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[1].resource.meta.profile[0], Line 1, Col 1818]</td>
#
#
#
# 						<td><pre>StructureDefinition reference &quot;http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/coverage-deqm&quot; could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[1].resource, Line 1, Col 1818]</td>
#
#
#
# 						<td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[1].resource.relationship, Line 1, Col 1763]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/subscriber-relationship (http://hl7.org/fhir/ValueSet/subscriber-relationship, and a code should come from this value set unless it has no suitable code) (codes = null#self)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[2].resource.meta.profile[0], Line 1, Col 2050]</td>
#
#
#
# 						<td><pre>StructureDefinition reference &quot;http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm&quot; could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[2].resource, Line 1, Col 2050]</td>
#
#
#
# 						<td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[3].resource.meta.profile[0], Line 1, Col 2965]</td>
#
#
#
# 						<td><pre>StructureDefinition reference &quot;http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/organization-deqm&quot; could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[3].resource, Line 1, Col 2965]</td>
#
#
#
# 						<td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[4].resource.meta.profile[0], Line 1, Col 4416]</td>
#
#
#
# 						<td><pre>StructureDefinition reference &quot;http://hl7.org/fhir/us/qicore/StructureDefinition/qicore-observation&quot; could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[4].resource, Line 1, Col 4416]</td>
#
#
#
# 						<td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">INFORMATION</td>
# 				<td>[Bundle.entry[4].resource.category[0], Line 1, Col 3966]</td>
#
#
#
# 						<td><pre>None of the codes provided are in the value set http://hl7.org/fhir/ValueSet/observation-category (http://hl7.org/fhir/ValueSet/observation-category, and a code is recommended to come from this value set) (codes = http://hl7/example.org#measure)</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">WARNING</td>
# 				<td>[Bundle.entry[5].resource, Line 1, Col 7280]</td>
#
#
#
# 						<td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[0], Line 1, Col 4734]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-race]]' on Patient.extension:race could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[1], Line 1, Col 4987]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-race]]' on Patient.extension:race could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[2], Line 1, Col 5279]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-race]]' on Patient.extension:race could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[3], Line 1, Col 5395]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-race]]' on Patient.extension:race could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[4], Line 1, Col 5490]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-race]]' on Patient.extension:race could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[0], Line 1, Col 4734]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity]]' on Patient.extension:ethnicity could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[1], Line 1, Col 4987]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity]]' on Patient.extension:ethnicity could not be resolved</pre></td>
#
#
# 			</tr>
# 			<tr>
# 				<td style="font-weight: bold;">ERROR</td>
# 				<td>[Bundle.entry[5].resource.extension[2], Line 1, Col 5279]</td>
#
#
#
# 						<td><pre>Problem with use of resolve() - profile '[CanonicalType[http://hl7.org/f
