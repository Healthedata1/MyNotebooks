# %% [markdown]
# ### Read all FHIR SD and find all binding strengths
#
# - load package data to inspect
# - read SDs
# - print binding by strength

# %%
from pathlib import Path
from json import load, dumps, loads
from IPython.display import display, Markdown, HTML 
table_header = '|Profile|Element|Value Set|Inherited from base?|\n|---|---|---|---|'
bindings = {
    'required':table_header,
    'extensible':table_header,
    'preferred':table_header,
    'example':table_header,
    'no_strength':table_header,
    
}

# %% [markdown]
# ### get package

# %%
uscore_path = Path(r'/Users/ehaas/.fhir/packages/hl7.fhir.us.core#dev/package')
fhir_path = Path(r'/Users/ehaas/.fhir/packages/hl7.fhir.r4.core#4.0.1/package')
print(uscore_path,fhir_path)
# Out:
# /Users/ehaas/.fhir/packages/hl7.fhir.us.core#dev/package /Users/ehaas/.fhir/packages/hl7.fhir.r4.core#4.0.1/package

# %% [markdown]
# ### Get SDs

# %%
def inherited(strength,element_path,sd_type):
    print(strength,element_path,sd_type)
    for f in fhir_path.iterdir():
        if str(f.name)==f'StructureDefinition-{sd_type}.json':
            print(f'### {f.name}')
            sd_dict=loads(f.read_text())
            for element in sd_dict['differential']['element']:
                if element.get('path')==element_path:
                    try:
                        base_strength=element['binding'].get('strength','no_strength')  
                    except KeyError:
                        base_strength="no binding!"
                    print(base_strength)
    try:
        return base_strength==strength
    except UnboundLocalError:
        return False

# %%
for f in uscore_path.iterdir():
    if str(f.name).startswith('StructureDefinition'):
        #print(f'### {f.name}')
        sd_dict=loads(f.read_text())
        #print(sd_dict['type'])
        for element in sd_dict['differential']['element']:
            if element.get('binding'):
                vs = element['binding'].get('valueSet','No ValueSet')
                vs = vs.split('|')[0] #strip version
                strength = element['binding'].get('strength','no_strength')
                print('foo')
                is_inherited = inherited(strength=strength,element_path=element["path"],sd_type=sd_dict['type'])
                bindings[strength]= f'{bindings[strength]}\n|{sd_dict["title"]}|{element["path"]}|{vs}|{f"**{is_inherited}**" if is_inherited == False else is_inherited}|'
# Out:
# foo
# required Observation.status Observation
# ### StructureDefinition-Observation.json
# required
# foo
# extensible Observation.code Observation
# ### StructureDefinition-Observation.json
# example
# foo
# extensible Observation.dataAbsentReason Observation
# ### StructureDefinition-Observation.json
# extensible
# foo
# required CareTeam.status CareTeam
# ### StructureDefinition-CareTeam.json
# required
# foo
# extensible CareTeam.participant.role CareTeam
# ### StructureDefinition-CareTeam.json
# example
# foo
# required Observation.valueQuantity.code Observation
# ### StructureDefinition-Observation.json
# foo
# required Patient.telecom.system Patient
# ### StructureDefinition-Patient.json
# foo
# required Patient.telecom.use Patient
# ### StructureDefinition-Patient.json
# foo
# required Patient.gender Patient
# ### StructureDefinition-Patient.json
# required
# foo
# extensible Patient.address.state Patient
# ### StructureDefinition-Patient.json
# foo
# extensible Patient.communication.language Patient
# ### StructureDefinition-Patient.json
# preferred
# foo
# required Immunization.status Immunization
# ### StructureDefinition-Immunization.json
# required
# foo
# example Immunization.statusReason Immunization
# ### StructureDefinition-Immunization.json
# example
# foo
# extensible Immunization.vaccineCode Immunization
# ### StructureDefinition-Immunization.json
# example
# foo
# extensible Provenance.agent.type Provenance
# ### StructureDefinition-Provenance.json
# extensible
# foo
# required Observation.status Observation
# ### StructureDefinition-Observation.json
# required
# foo
# extensible Observation.code Observation
# ### StructureDefinition-Observation.json
# example
# foo
# preferred Observation.valueCodeableConcept Observation
# ### StructureDefinition-Observation.json
# foo
# required DocumentReference.status DocumentReference
# ### StructureDefinition-DocumentReference.json
# required
# foo
# required DocumentReference.type DocumentReference
# ### StructureDefinition-DocumentReference.json
# preferred
# foo
# extensible DocumentReference.category DocumentReference
# ### StructureDefinition-DocumentReference.json
# example
# foo
# extensible DocumentReference.content.format DocumentReference
# ### StructureDefinition-DocumentReference.json
# preferred
# foo
# required Observation.valueQuantity.code Observation
# ### StructureDefinition-Observation.json
# foo
# required Extension.extension.valueCoding Extension
# ### StructureDefinition-Extension.json
# foo
# required Extension.extension.valueCoding Extension
# ### StructureDefinition-Extension.json
# foo
# required MedicationRequest.status MedicationRequest
# ### StructureDefinition-MedicationRequest.json
# required
# foo
# required MedicationRequest.intent MedicationRequest
# ### StructureDefinition-MedicationRequest.json
# required
# foo
# extensible MedicationRequest.medication[x] MedicationRequest
# ### StructureDefinition-MedicationRequest.json
# example
# foo
# required Condition.clinicalStatus Condition
# ### StructureDefinition-Condition.json
# required
# foo
# required Condition.verificationStatus Condition
# ### StructureDefinition-Condition.json
# required
# foo
# extensible Condition.category Condition
# ### StructureDefinition-Condition.json
# extensible
# foo
# required Condition.code.coding Condition
# ### StructureDefinition-Condition.json
# foo
# required Condition.code.coding Condition
# ### StructureDefinition-Condition.json
# foo
# required Condition.code.coding Condition
# ### StructureDefinition-Condition.json
# foo
# required Extension.valueCode Extension
# ### StructureDefinition-Extension.json
# foo
# extensible Encounter.type Encounter
# ### StructureDefinition-Encounter.json
# example
# foo
# required Observation.valueQuantity.code Observation
# ### StructureDefinition-Observation.json
# foo
# extensible Organization.address.state Organization
# ### StructureDefinition-Organization.json
# foo
# required Procedure.status Procedure
# ### StructureDefinition-Procedure.json
# required
# foo
# required Procedure.code Procedure
# ### StructureDefinition-Procedure.json
# example
# foo
# extensible Medication.code Medication
# ### StructureDefinition-Medication.json
# example
# foo
# required DiagnosticReport.status DiagnosticReport
# ### StructureDefinition-DiagnosticReport.json
# required
# foo
# extensible DiagnosticReport.category DiagnosticReport
# ### StructureDefinition-DiagnosticReport.json
# example
# foo
# extensible DiagnosticReport.code DiagnosticReport
# ### StructureDefinition-DiagnosticReport.json
# preferred
# foo
# extensible PractitionerRole.code PractitionerRole
# ### StructureDefinition-PractitionerRole.json
# example
# foo
# extensible PractitionerRole.specialty PractitionerRole
# ### StructureDefinition-PractitionerRole.json
# preferred
# foo
# required CarePlan.text.div CarePlan
# ### StructureDefinition-CarePlan.json
# foo
# required CarePlan.status CarePlan
# ### StructureDefinition-CarePlan.json
# required
# foo
# required CarePlan.intent CarePlan
# ### StructureDefinition-CarePlan.json
# required
# foo
# required Goal.lifecycleStatus Goal
# ### StructureDefinition-Goal.json
# required
# foo
# required Extension.extension.value[x] Extension
# ### StructureDefinition-Extension.json
# foo
# required Extension.extension.value[x] Extension
# ### StructureDefinition-Extension.json
# foo
# extensible Location.address.state Location
# ### StructureDefinition-Location.json
# foo
# required DiagnosticReport.status DiagnosticReport
# ### StructureDefinition-DiagnosticReport.json
# required
# foo
# extensible DiagnosticReport.code DiagnosticReport
# ### StructureDefinition-DiagnosticReport.json
# preferred
# foo
# extensible Device.type Device
# ### StructureDefinition-Device.json
# example
# foo
# required AllergyIntolerance.clinicalStatus AllergyIntolerance
# ### StructureDefinition-AllergyIntolerance.json
# required
# foo
# required AllergyIntolerance.verificationStatus AllergyIntolerance
# ### StructureDefinition-AllergyIntolerance.json
# required
# foo
# extensible AllergyIntolerance.code AllergyIntolerance
# ### StructureDefinition-AllergyIntolerance.json
# example
# foo
# extensible AllergyIntolerance.reaction.manifestation AllergyIntolerance
# ### StructureDefinition-AllergyIntolerance.json
# example
# foo
# required Observation.valueQuantity.code Observation
# ### StructureDefinition-Observation.json
# foo
# extensible Observation.code Observation
# ### StructureDefinition-Observation.json
# example
# foo
# extensible Observation.value[x] Observation
# ### StructureDefinition-Observation.json
# no binding!
# foo
# extensible Observation.component.code Observation
# ### StructureDefinition-Observation.json
# example
# foo
# extensible Observation.component.value[x] Observation
# ### StructureDefinition-Observation.json
# no binding!

# %%
for strength,binding in bindings.items():
    print(f'### {strength.upper()}')
    print(bindings[strength])
    #display(Markdown(f'### {strength.upper()}'))
    #display(Markdown(bindings[strength]))
# Out:
# ### REQUIRED
# |Profile|Element|Value Set|Inherited from base?|
# |---|---|---|---|
# |US Core Laboratory Result Observation Profile|Observation.status|http://hl7.org/fhir/ValueSet/observation-status|True|
# |US Core CareTeam Profile|CareTeam.status|http://hl7.org/fhir/ValueSet/care-team-status|True|
# |US Core Body Temperature Profile|Observation.valueQuantity.code|http://hl7.org/fhir/ValueSet/ucum-bodytemp|**False**|
# |US Core Patient Profile|Patient.telecom.system|http://hl7.org/fhir/ValueSet/contact-point-system|**False**|
# |US Core Patient Profile|Patient.telecom.use|http://hl7.org/fhir/ValueSet/contact-point-use|**False**|
# |US Core Patient Profile|Patient.gender|http://hl7.org/fhir/ValueSet/administrative-gender|True|
# |US Core Immunization Profile|Immunization.status|http://hl7.org/fhir/ValueSet/immunization-status|True|
# |US Core Smoking Status Observation Profile|Observation.status|http://hl7.org/fhir/us/core/ValueSet/us-core-observation-smoking-status-status|True|
# |US Core DocumentReference Profile|DocumentReference.status|http://hl7.org/fhir/ValueSet/document-reference-status|True|
# |US Core DocumentReference Profile|DocumentReference.type|http://hl7.org/fhir/us/core/ValueSet/us-core-documentreference-type|**False**|
# |US Core Head Circumference Profile|Observation.valueQuantity.code|http://hl7.org/fhir/ValueSet/ucum-bodylength|**False**|
# |US Core Race Extension|Extension.extension.valueCoding|http://hl7.org/fhir/us/core/ValueSet/omb-race-category|**False**|
# |US Core Race Extension|Extension.extension.valueCoding|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113883.1.11.14914|**False**|
# |US Core MedicationRequest Profile|MedicationRequest.status|http://hl7.org/fhir/ValueSet/medicationrequest-status|True|
# |US Core MedicationRequest Profile|MedicationRequest.intent|http://hl7.org/fhir/ValueSet/medicationrequest-intent|True|
# |US Core Condition Profile|Condition.clinicalStatus|http://hl7.org/fhir/ValueSet/condition-clinical|True|
# |US Core Condition Profile|Condition.verificationStatus|http://hl7.org/fhir/ValueSet/condition-ver-status|True|
# |US Core Condition Profile|Condition.code.coding|http://hl7.org/fhir/us/core/ValueSet/us-core-condition-code|**False**|
# |US Core Condition Profile|Condition.code.coding|http://hl7.org/fhir/us/core/ValueSet/us-core-condition-code|**False**|
# |US Core Condition Profile|Condition.code.coding|http://hl7.org/fhir/us/core/ValueSet/us-core-condition-code|**False**|
# |US Core Birth Sex Extension|Extension.valueCode|http://hl7.org/fhir/us/core/ValueSet/birthsex|**False**|
# |US Core Body Height Profile|Observation.valueQuantity.code|http://hl7.org/fhir/ValueSet/ucum-bodylength|**False**|
# |US Core Procedure Profile|Procedure.status|http://hl7.org/fhir/ValueSet/event-status|True|
# |US Core Procedure Profile|Procedure.code|http://hl7.org/fhir/us/core/ValueSet/us-core-procedure-code|**False**|
# |US Core DiagnosticReport Profile for Report and Note exchange|DiagnosticReport.status|http://hl7.org/fhir/ValueSet/diagnostic-report-status|True|
# |US Core CarePlan Profile|CarePlan.text.div|http://hl7.org/fhir/us/core/ValueSet/us-core-narrative-status|**False**|
# |US Core CarePlan Profile|CarePlan.status|http://hl7.org/fhir/ValueSet/request-status|True|
# |US Core CarePlan Profile|CarePlan.intent|http://hl7.org/fhir/ValueSet/care-plan-intent|True|
# |US Core Goal Profile|Goal.lifecycleStatus|http://hl7.org/fhir/ValueSet/goal-status|True|
# |US Core Ethnicity Extension|Extension.extension.value[x]|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.114222.4.11.837|**False**|
# |US Core Ethnicity Extension|Extension.extension.value[x]|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.114222.4.11.877|**False**|
# |US Core DiagnosticReport Profile for Laboratory Results Reporting|DiagnosticReport.status|http://hl7.org/fhir/ValueSet/diagnostic-report-status|True|
# |US Core AllergyIntolerance Profile|AllergyIntolerance.clinicalStatus|http://hl7.org/fhir/ValueSet/allergyintolerance-clinical|True|
# |US Core AllergyIntolerance Profile|AllergyIntolerance.verificationStatus|http://hl7.org/fhir/ValueSet/allergyintolerance-verification|True|
# |US Core Body Weight Profile|Observation.valueQuantity.code|http://hl7.org/fhir/ValueSet/ucum-bodyweight|**False**|
# ### EXTENSIBLE
# |Profile|Element|Value Set|Inherited from base?|
# |---|---|---|---|
# |US Core Laboratory Result Observation Profile|Observation.code|http://hl7.org/fhir/ValueSet/observation-codes|**False**|
# |US Core Laboratory Result Observation Profile|Observation.dataAbsentReason|http://hl7.org/fhir/ValueSet/data-absent-reason|True|
# |US Core CareTeam Profile|CareTeam.participant.role|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113762.1.4.1099.30|**False**|
# |US Core Patient Profile|Patient.address.state|http://hl7.org/fhir/us/core/ValueSet/us-core-usps-state|**False**|
# |US Core Patient Profile|Patient.communication.language|http://hl7.org/fhir/us/core/ValueSet/simple-language|**False**|
# |US Core Immunization Profile|Immunization.vaccineCode|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113762.1.4.1010.6|**False**|
# |US Core Provenance Profile|Provenance.agent.type|http://hl7.org/fhir/us/core/ValueSet/us-core-provenance-participant-type|True|
# |US Core Smoking Status Observation Profile|Observation.code|http://hl7.org/fhir/us/core/ValueSet/us-core-smoking-status-observation-codes|**False**|
# |US Core DocumentReference Profile|DocumentReference.category|http://hl7.org/fhir/us/core/ValueSet/us-core-documentreference-category|**False**|
# |US Core DocumentReference Profile|DocumentReference.content.format|http://hl7.org/fhir/ValueSet/formatcodes|**False**|
# |US Core MedicationRequest Profile|MedicationRequest.medication[x]|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113762.1.4.1010.4|**False**|
# |US Core Condition Profile|Condition.category|http://hl7.org/fhir/us/core/ValueSet/us-core-condition-category|True|
# |US Core Encounter Profile|Encounter.type|http://hl7.org/fhir/us/core/ValueSet/us-core-encounter-type|**False**|
# |US Core Organization Profile|Organization.address.state|http://hl7.org/fhir/us/core/ValueSet/us-core-usps-state|**False**|
# |US Core Medication Profile|Medication.code|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113762.1.4.1010.4|**False**|
# |US Core DiagnosticReport Profile for Report and Note exchange|DiagnosticReport.category|http://hl7.org/fhir/us/core/ValueSet/us-core-diagnosticreport-category|**False**|
# |US Core DiagnosticReport Profile for Report and Note exchange|DiagnosticReport.code|http://hl7.org/fhir/us/core/ValueSet/us-core-diagnosticreport-report-and-note-codes|**False**|
# |US Core PractitionerRole Profile|PractitionerRole.code|http://hl7.org/fhir/us/core/ValueSet/us-core-provider-role|**False**|
# |US Core PractitionerRole Profile|PractitionerRole.specialty|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.114222.4.11.1066|**False**|
# |US Core Location Profile|Location.address.state|http://hl7.org/fhir/us/core/ValueSet/us-core-usps-state|**False**|
# |US Core DiagnosticReport Profile for Laboratory Results Reporting|DiagnosticReport.code|http://hl7.org/fhir/us/core/ValueSet/us-core-diagnosticreport-lab-codes|**False**|
# |US Core Implantable Device Profile|Device.type|http://hl7.org/fhir/ValueSet/device-kind|**False**|
# |US Core AllergyIntolerance Profile|AllergyIntolerance.code|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113762.1.4.1186.8|**False**|
# |US Core AllergyIntolerance Profile|AllergyIntolerance.reaction.manifestation|http://hl7.org/fhir/ValueSet/clinical-findings|**False**|
# |US Core Vital Signs Profile|Observation.code|http://hl7.org/fhir/us/core/ValueSet/us-core-vital-signs|**False**|
# |US Core Vital Signs Profile|Observation.value[x]|http://hl7.org/fhir/ValueSet/ucum-vitals-common|**False**|
# |US Core Vital Signs Profile|Observation.component.code|http://hl7.org/fhir/us/core/ValueSet/us-core-vital-signs|**False**|
# |US Core Vital Signs Profile|Observation.component.value[x]|http://hl7.org/fhir/ValueSet/ucum-vitals-common|**False**|
# ### PREFERRED
# |Profile|Element|Value Set|Inherited from base?|
# |---|---|---|---|
# |US Core Smoking Status Observation Profile|Observation.valueCodeableConcept|http://cts.nlm.nih.gov/fhir/ValueSet/2.16.840.1.113883.11.20.9.38|**False**|
# ### EXAMPLE
# |Profile|Element|Value Set|Inherited from base?|
# |---|---|---|---|
# |US Core Immunization Profile|Immunization.statusReason|http://hl7.org/fhir/ValueSet/immunization-status-reason|True|
# ### NO_STRENGTH
# |Profile|Element|Value Set|Inherited from base?|
# |---|---|---|---|
