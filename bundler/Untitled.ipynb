# %%
from json import load, dumps, loads

r= {
    "resourceType": "Goal",
    "id": "53c3a997-68a5-4c62-8702-d3e2ad3b0ee5",
    "meta": {
        "profile": [
            "http://hl7.org/fhir/us/core/StructureDefinition/us-core-goal"
        ]
    },
    "lifecycleStatus": "accepted",
    "achievementStatus": {
        "coding": [
            {
                "system": "http://terminology.hl7.org/CodeSystem/goal-achievement",
                "code": "in-progress"
            }
        ]
    },
    "description": {
        "text": "Improve and maintenance of optimal foot health: aim at early detection of peripheral vascular problems and neuropathy presumed due to diabetes; and prevention of diabetic foot ulcer, gangrene"
    },
    "subject": {
        "reference": "urn:uuid:8b42051b-e45b-4032-926a-747affe4e09d"
    }
}

r_string = dumps(r, indent=2)
print(r_string)
new_string = r_string.replace("urn:uuid:8b42051b-e45b-4032-926a-747affe4e09d","foo")
print(new_string)

string = "geeks for geeks geeks geeks geeks" 
   
# Prints the string by replacing geeks by Geeks  
print(string.replace("geeks", "Geeks"))
# Out:
# {
#   "resourceType": "Goal",
#   "id": "53c3a997-68a5-4c62-8702-d3e2ad3b0ee5",
#   "meta": {
#     "profile": [
#       "http://hl7.org/fhir/us/core/StructureDefinition/us-core-goal"
#     ]
#   },
#   "lifecycleStatus": "accepted",
#   "achievementStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/goal-achievement",
#         "code": "in-progress"
#       }
#     ]
#   },
#   "description": {
#     "text": "Improve and maintenance of optimal foot health: aim at early detection of peripheral vascular problems and neuropathy presumed due to diabetes; and prevention of diabetic foot ulcer, gangrene"
#   },
#   "subject": {
#     "reference": "urn:uuid:8b42051b-e45b-4032-926a-747affe4e09d"
#   }
# }
# {
#   "resourceType": "Goal",
#   "id": "53c3a997-68a5-4c62-8702-d3e2ad3b0ee5",
#   "meta": {
#     "profile": [
#       "http://hl7.org/fhir/us/core/StructureDefinition/us-core-goal"
#     ]
#   },
#   "lifecycleStatus": "accepted",
# ...
