# %% [markdown]
# # Get wt data from csv using Pandas
#
# - loop through rows and create observations for each one and validate and save

# %%
import pandas as pd

df = pd.read_csv('wt_data.csv', skip_blank_lines=True)
df.dropna(how="all", inplace=True)
df.head(3)
# Out:
#                    instance_name  \
# 0  Patient Supplied WT Example 1
# 1  Patient Supplied WT Example 2
# 2  Patient Supplied WT Example 3
#
#                                 instance_description source identifier  \
# 0  This is a simple patient entered weight exampl...    NaN        NaN
# 1  This is a simple patient entered weight exampl...    NaN        NaN
# 2  This is a simple patient entered weight exampl...    NaN        NaN
#
#   assigner  value    Unnamed: 6    effective_datetime  \
# 0      NaN  165.0  7/5/21 21:50  2021-07-05T21:50:26Z
# 1      NaN  165.0   7/6/21 9:50  2021-07-06T09:50:26Z
# 2      NaN  160.0  7/6/21 21:50  2021-07-06T21:50:26Z
#
#                                  patient_fhirid  patient_identifier  ...  \
# 0  Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b                 NaN  ...
# 1  Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b                 NaN  ...
# 2  Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b                 NaN  ...
#
#   encounter_fhirid  encounter_identifier  encounter_display device_fhirid  \
# 0              NaN                   NaN                NaN           NaN
# 1              NaN                   NaN                NaN           NaN
# 2              NaN                   NaN                NaN    Device/123
#
#   device_identifier                 device_display servicerequest_fhirid  \
# 0               NaN                            NaN                   NaN
# 1               NaN                            NaN    ServiceRequest/123
# 2         Dev123456  WiTscale S200 Bluetooth scale                   NaN
#
#   servicerequest_identifier             servicerequest_display modality
# 0                       NaN                                NaN      NaN
# 1                  SR123456  Provider X Home weight monitoring      NaN
# 2                       NaN                                NaN      NaN
#
# [3 rows x 21 columns]

# %%
df.dtypes
# Out:
# instance_name                 object
# instance_description          object
# source                        object
# identifier                    object
# assigner                      object
# value                        float64
# Unnamed: 6                    object
# effective_datetime            object
# patient_fhirid                object
# patient_identifier           float64
# patient_display               object
# encounter_fhirid             float64
# encounter_identifier         float64
# encounter_display             object
# device_fhirid                 object
# device_identifier             object
# device_display                object
# servicerequest_fhirid         object
# servicerequest_identifier     object
# servicerequest_display        object
# modality                      object
# dtype: object

# %%
for i,row in df[0:].iterrows():
    print(row)
    # %run ./obs_maker.ipynb
# Out:
# instance_name                                    Patient Supplied WT Example 1
# instance_description         This is a simple patient entered weight exampl...
# source                                                                     NaN
# identifier                                                                 NaN
# assigner                                                                   NaN
# value                                                                      165
# Unnamed: 6                                                        7/5/21 21:50
# effective_datetime                                        2021-07-05T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                                          NaN
# device_fhirid                                                              NaN
# device_identifier                                                          NaN
# device_display                                                             NaN
# servicerequest_fhirid                                                      NaN
# servicerequest_identifier                                                  NaN
# servicerequest_display                                                     NaN
# modality                                                                   NaN
# Name: 0, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 1
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 1
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project without any identifier, service key, sensed/entered modality, or encounter
#       data
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# effectiveDateTime: 2021-07-05 21:50:26+00:00
# valueQuantity:
#   value: 165.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 1.yaml............
# instance_name                                    Patient Supplied WT Example 2
# instance_description         This is a simple patient entered weight exampl...
# source                                                                     NaN
# identifier                                                                 NaN
# assigner                                                                   NaN
# value                                                                      165
# Unnamed: 6                                                         7/6/21 9:50
# effective_datetime                                        2021-07-06T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                                          NaN
# device_fhirid                                                              NaN
# device_identifier                                                          NaN
# device_display                                                             NaN
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                   NaN
# Name: 1, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 2
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 2
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with a service key
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# effectiveDateTime: 2021-07-06 09:50:26+00:00
# valueQuantity:
#   value: 165.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 2.yaml............
# instance_name                                    Patient Supplied WT Example 3
# instance_description         This is a simple patient entered weight exampl...
# source                                                                     NaN
# identifier                                                                 NaN
# assigner                                                                   NaN
# value                                                                      160
# Unnamed: 6                                                        7/6/21 21:50
# effective_datetime                                        2021-07-06T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                                          NaN
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                                      NaN
# servicerequest_identifier                                                  NaN
# servicerequest_display                                                     NaN
# modality                                                                   NaN
# Name: 2, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 3
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 3
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with a device provided for simple provenance
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# effectiveDateTime: 2021-07-06 21:50:26+00:00
# valueQuantity:
#   value: 160.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 3.yaml............
# instance_name                                    Patient Supplied WT Example 4
# instance_description         This is a simple patient entered weight exampl...
# source                                    18c749f9-31ba-920c-1a86-caad8ce861d6
# identifier                                                                 NaN
# assigner                                                                   NaN
# value                                                                      163
# Unnamed: 6                                                         7/7/21 9:50
# effective_datetime                                        2021-07-07T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                                          NaN
# device_fhirid                                                              NaN
# device_identifier                                                          NaN
# device_display                                                             NaN
# servicerequest_fhirid                                                      NaN
# servicerequest_identifier                                                  NaN
# servicerequest_display                                                     NaN
# modality                                                                   NaN
# Name: 3, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 4
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 4
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with a meta.source identifier/string provided for simple provenance
#   source: 18c749f9-31ba-920c-1a86-caad8ce861d6
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# effectiveDateTime: 2021-07-07 09:50:26+00:00
# valueQuantity:
#   value: 163.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 4.yaml............
# instance_name                                    Patient Supplied WT Example 5
# instance_description         This is a simple patient entered weight exampl...
# source                                                                     NaN
# identifier                                d236f4b3-91b5-8d1d-29f1-801af2ac1696
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      164
# Unnamed: 6                                                        7/7/21 21:50
# effective_datetime                                        2021-07-07T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                                          NaN
# device_fhirid                                                              NaN
# device_identifier                                                          NaN
# device_display                                                             NaN
# servicerequest_fhirid                                                      NaN
# servicerequest_identifier                                                  NaN
# servicerequest_display                                                     NaN
# modality                                                                   NaN
# Name: 4, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 5
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 5
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with an identifier provided for simple provenance
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# identifier:
# - value: d236f4b3-91b5-8d1d-29f1-801af2ac1696
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# effectiveDateTime: 2021-07-07 21:50:26+00:00
# valueQuantity:
#   value: 164.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 5.yaml............
# instance_name                                    Patient Supplied WT Example 6
# instance_description         This is a simple patient entered weight exampl...
# source                                                                     NaN
# identifier                                                                 NaN
# assigner                                                                   NaN
# value                                                                      160
# Unnamed: 6                                                         7/8/21 9:50
# effective_datetime                                        2021-07-08T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                              NaN
# device_identifier                                                          NaN
# device_display                                                             NaN
# servicerequest_fhirid                                                      NaN
# servicerequest_identifier                                                  NaN
# servicerequest_display                                                     NaN
# modality                                                                   NaN
# Name: 5, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 6
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 6
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with encounter data provided
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-08 09:50:26+00:00
# valueQuantity:
#   value: 160.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 6.yaml............
# instance_name                                    Patient Supplied WT Example 7
# instance_description         This is a simple patient entered weight exampl...
# source                                                                     NaN
# identifier                                                                 NaN
# assigner                                                                   NaN
# value                                                                      160
# Unnamed: 6                                                        7/8/21 21:50
# effective_datetime                                        2021-07-08T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                                          NaN
# device_fhirid                                                              NaN
# device_identifier                                                          NaN
# device_display                                                             NaN
# servicerequest_fhirid                                                      NaN
# servicerequest_identifier                                                  NaN
# servicerequest_display                                                     NaN
# modality                                                                sensed
# Name: 6, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 7
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 7
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with modality = sensed|entered by patient data
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# effectiveDateTime: 2021-07-08 21:50:26+00:00
# valueQuantity:
#   value: 160.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 7.yaml............
# instance_name                                    Patient Supplied WT Example 8
# instance_description         This is a simple patient entered weight exampl...
# source                                    0e23a054-4246-806c-1db4-1629fc030475
# identifier                                7051c783-4e4d-7a63-56f0-7f2a13654d06
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      161
# Unnamed: 6                                                         7/9/21 9:50
# effective_datetime                                        2021-07-09T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 7, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 8
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 8
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: 0e23a054-4246-806c-1db4-1629fc030475
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 7051c783-4e4d-7a63-56f0-7f2a13654d06
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-09 09:50:26+00:00
# valueQuantity:
#   value: 161.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 8.yaml............
# instance_name                                    Patient Supplied WT Example 9
# instance_description         This is a simple patient entered weight exampl...
# source                                    2fad2b0e-50e3-509b-171f-523083941fdf
# identifier                                da4e8b2b-8ab1-97be-45dc-cb6c16520f1f
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      166
# Unnamed: 6                                                        7/9/21 21:50
# effective_datetime                                        2021-07-09T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 8, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 9
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 9
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: 2fad2b0e-50e3-509b-171f-523083941fdf
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: da4e8b2b-8ab1-97be-45dc-cb6c16520f1f
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-09 21:50:26+00:00
# valueQuantity:
#   value: 166.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 9.yaml............
# instance_name                                   Patient Supplied WT Example 10
# instance_description         This is a simple patient entered weight exampl...
# source                                    dd19bdf0-0997-0a68-039d-e354fb7b8bcb
# identifier                                9544da8f-447a-a692-7ab5-df767ae61b69
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      165
# Unnamed: 6                                                        7/10/21 9:50
# effective_datetime                                        2021-07-10T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 9, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 10
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 10
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: dd19bdf0-0997-0a68-039d-e354fb7b8bcb
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 9544da8f-447a-a692-7ab5-df767ae61b69
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-10 09:50:26+00:00
# valueQuantity:
#   value: 165.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 10.yaml............
# instance_name                                   Patient Supplied WT Example 11
# instance_description         This is a simple patient entered weight exampl...
# source                                    fb396a1b-0baf-1b70-2eea-047b4f7b4c0d
# identifier                                97051f62-8dab-4bd9-276c-3cd88b2f5599
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      167
# Unnamed: 6                                                       7/10/21 21:50
# effective_datetime                                        2021-07-10T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 10, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 11
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 11
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: fb396a1b-0baf-1b70-2eea-047b4f7b4c0d
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 97051f62-8dab-4bd9-276c-3cd88b2f5599
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-10 21:50:26+00:00
# valueQuantity:
#   value: 167.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 11.yaml............
# instance_name                                   Patient Supplied WT Example 12
# instance_description         This is a simple patient entered weight exampl...
# source                                    da4912b6-55e5-0b20-5ef2-fbcbe9659723
# identifier                                8581ad94-486d-98c5-a437-fbb20e6005ee
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      161
# Unnamed: 6                                                        7/11/21 9:50
# effective_datetime                                        2021-07-11T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# ...
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: b8530aea-7768-4dd2-1778-9863d5dc17f5
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: a224318d-596b-004d-9295-8eb1a7bb0f28
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-11 21:50:26+00:00
# valueQuantity:
#   value: 168.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 13.yaml............
# instance_name                                   Patient Supplied WT Example 14
# instance_description         This is a simple patient entered weight exampl...
# source                                    635a72a7-7425-32ba-3d3e-4c0916374ec7
# identifier                                c80b63dd-575d-646a-a5aa-38e947736ab1
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      160
# Unnamed: 6                                                        7/12/21 9:50
# effective_datetime                                        2021-07-12T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 13, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 14
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 14
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: 635a72a7-7425-32ba-3d3e-4c0916374ec7
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: c80b63dd-575d-646a-a5aa-38e947736ab1
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-12 09:50:26+00:00
# valueQuantity:
#   value: 160.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 14.yaml............
# instance_name                                   Patient Supplied WT Example 15
# instance_description         This is a simple patient entered weight exampl...
# source                                    4fe4a25e-51f1-4645-2f7a-4a2efdc93c90
# identifier                                8e175ea0-017a-90d7-96d6-f259d76d9be3
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      162
# Unnamed: 6                                                       7/12/21 21:50
# effective_datetime                                        2021-07-12T21:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 14, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 15
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 15
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: 4fe4a25e-51f1-4645-2f7a-4a2efdc93c90
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 8e175ea0-017a-90d7-96d6-f259d76d9be3
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-12 21:50:26+00:00
# valueQuantity:
#   value: 162.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 15.yaml............
# instance_name                                   Patient Supplied WT Example 16
# instance_description         This is a simple patient entered weight exampl...
# source                                    5dba2571-3a32-20b0-0332-c45f037ca0b7
# identifier                                ac7f522d-44e6-447a-8f68-44eec9125fa2
# assigner                                         WiTscale S200 Bluetooth scale
# value                                                                      167
# Unnamed: 6                                                        7/13/21 9:50
# effective_datetime                                        2021-07-13T09:50:26Z
# patient_fhirid                    Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
# patient_identifier                                                         NaN
# patient_display                                          Eldon718 Halvorson124
# encounter_fhirid                                                           NaN
# encounter_identifier                                                       NaN
# encounter_display                                           At Home Monitoring
# device_fhirid                                                       Device/123
# device_identifier                                                    Dev123456
# device_display                                   WiTscale S200 Bluetooth scale
# servicerequest_fhirid                                       ServiceRequest/123
# servicerequest_identifier                                             SR123456
# servicerequest_display                       Provider X Home weight monitoring
# modality                                                                sensed
# Name: 15, dtype: object
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 16
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 16
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project with source, identifier, service key, sensed/entered modality, and encounter
#       data
#   source: 5dba2571-3a32-20b0-0332-c45f037ca0b7
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: ac7f522d-44e6-447a-8f68-44eec9125fa2
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-13 09:50:26+00:00
# valueQuantity:
#   value: 167.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 16.yaml............
