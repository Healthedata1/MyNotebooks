# %% [markdown]
# # Get wt data from csv using Pandas
#
# - loop through rows and create observations for each one and validate and save

# %%
import pandas as pd

df = pd.read_csv('wt_data.csv', skip_blank_lines=True)
df.dropna(how="all", inplace=True)
df.head(3)
# Out:
#                    instance_name  \
# 0  Patient Supplied WT Example 1
# 1  Patient Supplied WT Example 2
# 2  Patient Supplied WT Example 3
#
#                                 instance_description  \
# 0  This is a simple patient entered weight exampl...
# 1  This is a simple patient entered weight exampl...
# 2  This is a simple patient entered weight exampl...
#
#                       source_identifier                    source_name  value  \
# 0  08dc6f12-31c3-0275-068a-6b36af564241  WiTscale S200 Bluetooth scale  165.0
# 1  c1b882ea-6e8e-48d6-0b6e-9edf9f6b4b67  WiTscale S200 Bluetooth scale  166.0
# 2  ecbc121a-6eb4-546c-a2a2-3c15dad344fd  WiTscale S200 Bluetooth scale  164.0
#
#      Unnamed: 5    effective_datetime  \
# 0  7/5/21 18:48  2021-07-05T18:48:54Z
# 1   7/6/21 6:48  2021-07-06T06:48:54Z
# 2  7/6/21 18:48  2021-07-06T18:48:54Z
#
#                                  patient_fhirid  patient_identifier  \
# 0  Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b                 NaN
# 1  Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b                 NaN
# 2  Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b                 NaN
#
#          patient_display  encounter_fhirid  encounter_identifier  \
# 0  Eldon718 Halvorson124               NaN                   NaN
# 1  Eldon718 Halvorson124               NaN                   NaN
# 2  Eldon718 Halvorson124               NaN                   NaN
#
#     encounter_display device_fhirid device_identifier  \
# 0  At Home Monitoring    Device/123         Dev123456
# 1  At Home Monitoring    Device/123         Dev123456
# 2  At Home Monitoring    Device/123         Dev123456
#
#                   device_display servicerequest_fhirid  \
# 0  WiTscale S200 Bluetooth scale    ServiceRequest/123
# 1  WiTscale S200 Bluetooth scale    ServiceRequest/123
# 2  WiTscale S200 Bluetooth scale    ServiceRequest/123
#
#   servicerequest_identifier             servicerequest_display modality
# 0                  SR123456  Provider X Home weight monitoring   sensed
# 1                  SR123456  Provider X Home weight monitoring   sensed
# 2                  SR123456  Provider X Home weight monitoring   sensed

# %%
df.dtypes
# Out:
# instance_name                 object
# instance_description          object
# source_identifier             object
# source_name                   object
# value                        float64
# Unnamed: 5                    object
# effective_datetime            object
# patient_fhirid                object
# patient_identifier           float64
# patient_display               object
# encounter_fhirid             float64
# encounter_identifier         float64
# encounter_display             object
# device_fhirid                 object
# device_identifier             object
# device_display                object
# servicerequest_fhirid         object
# servicerequest_identifier     object
# servicerequest_display        object
# modality                      object
# dtype: object

# %%
for i,row in df.iterrows():
    #print(row.instance_name)
    # %run ./obs_maker.ipynb
# Out:
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 1
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 1
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 08dc6f12-31c3-0275-068a-6b36af564241
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-05 18:48:54+00:00
# valueQuantity:
#   value: 165.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 1.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 2
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 2
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: c1b882ea-6e8e-48d6-0b6e-9edf9f6b4b67
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-06 06:48:54+00:00
# valueQuantity:
#   value: 166.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 2.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 3
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 3
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: ecbc121a-6eb4-546c-a2a2-3c15dad344fd
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-06 18:48:54+00:00
# valueQuantity:
#   value: 164.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 3.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 4
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 4
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 19fb03bf-2ea0-1815-1f7e-5ac2739f4dad
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-07 06:48:54+00:00
# valueQuantity:
#   value: 168.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 4.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 5
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 5
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: af9288de-4a7b-8eaa-2fcc-584791482229
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-07 18:48:54+00:00
# valueQuantity:
#   value: 164.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 5.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 6
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 6
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 0770c26d-5560-875e-7806-f5b976528824
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-08 06:48:54+00:00
# valueQuantity:
#   value: 166.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 6.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 7
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 7
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: bfca744b-2fdd-02ad-0231-db15b0b219c8
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-08 18:48:54+00:00
# valueQuantity:
#   value: 160.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 7.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 8
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 8
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 3840fc4f-799e-7666-4fed-6a52bfa854a4
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-09 06:48:54+00:00
# valueQuantity:
#   value: 164.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 8.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 9
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 9
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: c8e7666c-2298-8c01-72a5-130e8cc808df
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-09 18:48:54+00:00
# valueQuantity:
#   value: 168.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 9.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 10
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 10
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: a1038d20-249a-3a55-30f6-c1ed128916d3
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-10 06:48:54+00:00
# valueQuantity:
#   value: 165.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 10.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 11
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 11
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 517447b9-6c6e-9665-3d0f-56f7d4a6a14b
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-10 18:48:54+00:00
# valueQuantity:
#   value: 168.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 11.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 12
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 12
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 29b36014-2ec6-626b-7f11-a31b1b9a46bf
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-11 06:48:54+00:00
# valueQuantity:
#   value: 167.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 12.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 13
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 13
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: b2a252c7-38b3-3209-4a14-b2bcc05c9ed4
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-11 18:48:54+00:00
# valueQuantity:
#   value: 161.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 13.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 14
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 14
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: bd029988-a769-175d-88f2-bce95c0a59cf
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-12 06:48:54+00:00
# valueQuantity:
#   value: 164.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 14.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 15
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 15
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: cac94aa3-2741-50d3-73f7-420868db83d2
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-12 18:48:54+00:00
# valueQuantity:
#   value: 168.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 15.yaml............
# /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker
# *******************************************************************************
# Patient Supplied WT Example 16
# *******************************************************************************
# resourceType: Observation
# meta:
#   extension:
#   - url: http://hl7.org/fhir/StructureDefinition/instance-name
#     valueString: Patient Supplied WT Example 16
#   - url: http://hl7.org/fhir/StructureDefinition/instance-description
#     valueMarkdown: This is a simple patient entered weight example for the Argo Write
#       project
#   profile:
#   - http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight
# extension:
# - url: http://www.fhir.org/guides/omhtofhir/StructureDefinition/extension-modality
#   valueCode: sensed
# identifier:
# - value: 27789855-3476-96ac-956c-0857847f0668
#   assigner:
#     display: WiTscale S200 Bluetooth scale
# basedOn:
# - reference: ServiceRequest/123
#   identifier:
#     value: SR123456
#   display: Provider X Home weight monitoring
# status: final
# category:
# - coding:
#   - system: http://terminology.hl7.org/CodeSystem/observation-category
#     code: vital-signs
#     display: Vital Signs
#   text: Vital Signs
# code:
#   coding:
#   - system: http://loinc.org
#     code: 29463-7
#     display: Body Weight
#   text: weight
# subject:
#   reference: Patient/06e1f0dd-5fbe-4480-9bb4-6b54ec02d31b
#   display: Eldon718 Halvorson124
# encounter:
#   display: At Home Monitoring
# effectiveDateTime: 2021-07-13 06:48:54+00:00
# valueQuantity:
#   value: 168.0
#   unit: pounds
#   system: http://unitsofmeasure.org
#   code: '[lb_av]'
# device:
#   reference: Device/123
#   identifier:
#     value: Dev123456
#   display: WiTscale S200 Bluetooth scale
#
# ...validating
# <h1>Validation output</h1><h3>Status Code = 200</h3> <div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>StructureDefinition reference "http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight" could not be resolved</td><td/><td>invalid</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr><tr><td>information</td><td/><td>Could not verify slice for profile for profile http://hl7.org/fhir/StructureDefinition/Meta</td><td/><td>not-supported</td></tr></table></div>
# ...........saving to file /Users/ehaas/Documents/Python/MyNotebooks/Obs_maker/examples/Patient Supplied WT Example 16.yaml............
