# %% [markdown]
# # Using pathlib to read files

# %%
from pathlib import Path


p = Path('C:/Users/Administrator/Desktop')
help(p)
# Out:
# Help on WindowsPath in module pathlib object:
#
# class WindowsPath(Path, PureWindowsPath)
#  |  WindowsPath(*args, **kwargs)
#  |
#  |  Path subclass for Windows systems.
#  |
#  |  On a Windows system, instantiating a Path should return this object.
#  |
#  |  Method resolution order:
#  |      WindowsPath
#  |      Path
#  |      PureWindowsPath
#  |      PurePath
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  group(self)
#  |      Return the group name of the file gid.
#  |
#  |  is_mount(self)
#  |      Check if this path is a POSIX mount point
#  |
#  |  owner(self)
#  |      Return the login name of the file owner.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Path:
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, t, v, tb)
#  |
#  |  absolute(self)
#  |      Return an absolute version of this path.  This function works
#  |      even if the path doesn't point to anything.
#  |
# ...

# %%
print(p.name)
for i in p.glob('**/*'):
     print(type(i),i, i.name)
     if i.name == 'test.py':
        print(i.read_text())
# Out:
# Desktop
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\Atom.lnk Atom.lnk
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\Capture.PNG Capture.PNG
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\Copy of profile-summary-measurereport-deqm-spreadsheet.xml Copy of profile-summary-measurereport-deqm-spreadsheet.xml
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\desktop.ini desktop.ini
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\F1.PNG F1.PNG
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\FCC.lnk FCC.lnk
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\Microsoft Edge.lnk Microsoft Edge.lnk
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\Postman.lnk Postman.lnk
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\ReedTech_IntroToFHIR.pptx ReedTech_IntroToFHIR.pptx
# <class 'pathlib.WindowsPath'> C:\Users\Administrator\Desktop\test test
# ...
