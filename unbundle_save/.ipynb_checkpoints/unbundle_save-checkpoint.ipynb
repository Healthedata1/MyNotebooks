# %% [markdown]
# ## Script to fetch bundle from server unbundle and save
#
# - python version 3.6+
# - get data from from Server
# - unbundle
# - save each resource to file

# %%
from json import load, dumps, loads
from IPython import display as D
from requests import get, post, put
from IPython.display import display, Markdown, HTML
from fhirclient.models import bundle as B

# %% [markdown]
# ### get bundle from FHIR Server

# %%
type = ['Coverage']

def fetch(type):
    # fhir_test_server = 'http://fhirtest.uhn.ca/baseDstu3'
    fhir_test_server = 'https://api-v5-stu3.hspconsortium.org/DaVinciEHRDemo2/open/'

    headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }


    params = dict(
      # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
        )
    
    #   r = requests.post('https://httpbin.org/post', data = {'key':'value'})
    r = get(f'{fhir_test_server}/{type}', params = params, headers = headers )
    # view  output
    # return (r.json()["text"]["div"])
    return r

for t in type:
    print(f'...getting bundle for {t} resources')
    r = fetch(t)
    display(HTML(f'<h1>Validation output</h1><h3>Status Code = {r.status_code}</h3>'))
    print(dumps(r.json(),indent=3))
# Out:
# ...getting bundle for Coverage resources
# <h1>Validation output</h1><h3>Status Code = 200</h3>
# {
#    "resourceType": "Bundle",
#    "id": "aaecc4c6-6688-46c3-85c4-1b26b357b126",
#    "meta": {
#       "lastUpdated": "2019-03-06T22:54:14.982+00:00"
#    },
#    "type": "searchset",
#    "total": 4,
#    "link": [
#       {
#          "relation": "self",
#          "url": "https://api-v5-stu3.hspconsor/Coverage"
#       }
#    ],
#    "entry": [
#       {
#          "fullUrl": "https://api-v5-stu3.hspconsor/Coverage/coverage01",
#          "resource": {
#             "resourceType": "Coverage",
#             "id": "coverage01",
#             "meta": {
#                "versionId": "2",
#                "lastUpdated": "2018-12-12T17:05:44.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/STU3/StructureDefinition/coverage-deqm"
#                ]
#             },
#             "policyHolder": {
#                "reference": "Patient/patient01"
#             },
#             "subscriber": {
#                "reference": "Patient/patient01"
#             },
#             "subscriberId": "A123456789",
#             "beneficiary": {
#                "reference": "Patient/patient01"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "payor": [
#                {
#                   "reference": "Organization/organization04"
#                }
#             ]
#          },
#          "search": {
#             "mode": "match"
#          }
#       },
#       {
#          "fullUrl": "https://api-v5-stu3.hspconsor/Coverage/coverage02",
#          "resource": {
#             "resourceType": "Coverage",
#             "id": "coverage02",
#             "meta": {
#                "versionId": "2",
#                "lastUpdated": "2018-12-12T17:05:44.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/STU3/StructureDefinition/coverage-deqm"
#                ]
#             },
#             "policyHolder": {
#                "reference": "Patient/patient02"
#             },
#             "subscriber": {
#                "reference": "Patient/patient02"
#             },
#             "subscriberId": "B123456789",
#             "beneficiary": {
#                "reference": "Patient/patient02"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "payor": [
#                {
#                   "reference": "Organization/organization04"
#                }
#             ]
#          },
#          "search": {
#             "mode": "match"
#          }
#       },
#       {
#          "fullUrl": "https://api-v5-stu3.hspconsor/Coverage/coverage03",
#          "resource": {
#             "resourceType": "Coverage",
#             "id": "coverage03",
#             "meta": {
#                "versionId": "2",
#                "lastUpdated": "2018-12-12T17:05:44.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/STU3/StructureDefinition/coverage-deqm"
#                ]
#             },
#             "policyHolder": {
#                "reference": "Patient/patient03"
#             },
#             "subscriber": {
#                "reference": "Patient/patient03"
#             },
#             "subscriberId": "C123456789",
#             "beneficiary": {
#                "reference": "Patient/patient03"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "payor": [
#                {
#                   "reference": "Organization/organization04"
#                }
#             ]
#          },
#          "search": {
#             "mode": "match"
#          }
#       },
#       {
#          "fullUrl": "https://api-v5-stu3.hspconsor/Coverage/cf-1549031394388",
#          "resource": {
#             "resourceType": "Coverage",
#             "id": "cf-1549031394388",
#             "meta": {
#                "versionId": "2",
#                "lastUpdated": "2019-02-01T14:33:46.000+00:00",
#                "profile": [
#                   "http://hl7.org/fhir/us/davinci-deqm/STU3/StructureDefinition/coverage-deqm"
#                ]
#             },
#             "policyHolder": {
#                "reference": "Patient/cf-1548845717752"
#             },
#             "subscriber": {
#                "reference": "Patient/cf-1548845717752"
#             },
#             "subscriberId": "C123456709",
#             "beneficiary": {
#                "reference": "Patient/cf-1548845717752"
#             },
#             "relationship": {
#                "coding": [
#                   {
#                      "code": "self"
#                   }
#                ]
#             },
#             "payor": [
#                {
#                   "reference": "Organization/organization01"
#                }
#             ]
#          },
#          "search": {
#             "mode": "match"
#          }
#       }
#    ]
# }

# %% [markdown]
# ### Unbundle and Write Resources to file

# %%
b = B.Bundle(r.json())
b.resource_type

def write_file(r): # write file
    out_path = '/Users/ehaas/Documents/FHIR/Davinci-DEQM/source/examples/'  # append forward slash
    with open(f'{out_path}{r.resource_type}-{r.id}.json', 'w') as f:
        f.write(dumps(r.as_json(), indent=3))
    
for i,e in enumerate(b.entry):
    r = e.resource
    print(f'''entry item = {i}
            r.resource_type={r.resource_type}
            r.id={r.id}
          ''')
    
    
    write_file(r)
    #save file
# Out:
# entry item = 0
#             r.resource_type=Coverage
#             r.id=coverage01
#
# entry item = 1
#             r.resource_type=Coverage
#             r.id=coverage02
#
# entry item = 2
#             r.resource_type=Coverage
#             r.id=coverage03
#
# entry item = 3
#             r.resource_type=Coverage
#             r.id=cf-1549031394388
