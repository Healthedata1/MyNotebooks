# %% [markdown]
# ## Search through Profile properties summaries using Jinja2 and Python Modele
#
# *USE Python 3.7 to maintain order of Json files*
#
# - Fetch SD file from IG
# - Spec_internals from IG Package.tgz
# - search for element properties
#
#
#
# *Note need a successful build to generate since based on ig output local file
# alternatively use package.files to generate*

# %% [markdown]
# ### import python modules including R4 fhirclient models

# %%
#from fhirclient.r4models import structuredefinition as SD
from fhir.resources import construct_fhir_element

from json import loads, dumps
from yaml import dump, load
from pathlib import Path
import copy
import pandas as pd

profile_map = {'http://hl7.org/fhir/StructureDefinition/Observation': 'Observation', 'http://hl7.org/fhir/StructureDefinition/vitalsigns':'FHIR Vital Signs Profile' }
ucum = 'http://unitsofmeasure.org'
out_path_csv = 'out/compare_obs_csv' 
out_path_excel = 'out/compare_obs_excel'
image_path = '/Users/ehaas/Documents/FHIR/US-Core/input/images'
#image_path = 'out/image'

# %% [markdown]
# ### Create New DataFrame with My Custom Column Headers

# %%
empty_row = {
    'Profile Title': None,
    'Based On': None,  #US Core Profile or FHIR Observation Resource
    'Category Slice Codes': [], # URI|Code  
    'Code Binding': None,  #list patternCodeableConcept or binding with strength
    'Code Fixed Value': None, # list patternCodeableConcept or binding with strength
    'Effective Time Types': [], # list MS types
    'Value Types': [], # list MS types or slice by types
    'ValueQuantity Code Binding': None,  #binding with strength
    'ValueQuantity Code Fixed Value': None, # URI|fixedCode - always UCUM by value
    'Is Data Absent Reason': False, #True if MS
    'Is Component': False, #True if MS
    'Component Slice Codes': [], # URI|Code 
    'Component Slice Value Types': [], # list MS types
    #'Component Slice ValueQuantity Code Binding': None,  #binding with strength
    'Component Slice ValueQuantity Codes': [], # URI|fixedCode - always UCUM by value
    'Has Member References': [], #list if MS
    'Derived From References': [], #list if MS    
    }



df = pd.DataFrame(data={}, columns=empty_row.keys())
df
# Out:
# Empty DataFrame
# Columns: [Profile Title, Based On, Category Slice Codes, Code Binding, Code Fixed Value, Effective Time Types, Value Types, ValueQuantity Code Binding, ValueQuantity Code Fixed Value, Is Data Absent Reason, Is Component, Component Slice Codes, Component Slice Value Types, Component Slice ValueQuantity Codes, Has Member References, Derived From References]
# Index: []

# %% [markdown]
# ### Get file and return as dict

# %% [markdown]
# ### Write to file

# %%
def save_new(f_name,data): # save in resources folder

    print('writing to file .......')
    #write_path = '/Users/ehaas/Documents/FHIR/US-Core-R4/input/examples'
    write_path = 'test_resources'
    path = Path.cwd() / write_path  / f_name
    path.write_text(json.dumps(data, indent=2))

# %% [markdown]
# ### Get all Profile from package file
#
#   - create url:title mapping table

# %%
us_core_path = Path(r'/Users/ehaas/.fhir/packages/hl7.fhir.us.core#dev/package')
us_core_files = sorted(us_core_path.glob('StructureDefinition-*'))
for i in us_core_files:
    print(i.name)
    sd_dict = loads(i.read_text())
    profile_map[sd_dict['url']] = sd_dict['title']
profile_map
# Out:
# StructureDefinition-head-occipital-frontal-circumference-percentile.json
# StructureDefinition-pediatric-bmi-for-age.json
# StructureDefinition-pediatric-weight-for-height.json
# StructureDefinition-us-core-allergyintolerance.json
# StructureDefinition-us-core-birthsex.json
# StructureDefinition-us-core-blood-pressure.json
# StructureDefinition-us-core-bmi.json
# StructureDefinition-us-core-body-height.json
# StructureDefinition-us-core-body-temperature.json
# StructureDefinition-us-core-body-weight.json
# StructureDefinition-us-core-careplan.json
# StructureDefinition-us-core-careteam.json
# StructureDefinition-us-core-condition-encounter-diagnosis.json
# StructureDefinition-us-core-condition-problems-health-concerns.json
# StructureDefinition-us-core-diagnosticreport-lab.json
# StructureDefinition-us-core-diagnosticreport-note.json
# StructureDefinition-us-core-direct.json
# StructureDefinition-us-core-documentreference.json
# StructureDefinition-us-core-encounter.json
# StructureDefinition-us-core-ethnicity.json
# StructureDefinition-us-core-extension-questionnaire-uri.json
# StructureDefinition-us-core-genderIdentity.json
# StructureDefinition-us-core-goal.json
# StructureDefinition-us-core-head-circumference.json
# StructureDefinition-us-core-heart-rate.json
# StructureDefinition-us-core-immunization.json
# StructureDefinition-us-core-implantable-device.json
# StructureDefinition-us-core-location.json
# StructureDefinition-us-core-medication.json
# StructureDefinition-us-core-medicationrequest.json
# StructureDefinition-us-core-observation-clinical-test.json
# StructureDefinition-us-core-observation-imaging.json
# StructureDefinition-us-core-observation-lab.json
# StructureDefinition-us-core-observation-sdoh-assessment.json
# StructureDefinition-us-core-observation-sexual-orientation.json
# StructureDefinition-us-core-observation-social-history.json
# StructureDefinition-us-core-observation-survey.json
# StructureDefinition-us-core-organization.json
# StructureDefinition-us-core-patient.json
# StructureDefinition-us-core-practitioner.json
# StructureDefinition-us-core-practitionerrole.json
# StructureDefinition-us-core-procedure.json
# StructureDefinition-us-core-provenance.json
# StructureDefinition-us-core-pulse-oximetry.json
# StructureDefinition-us-core-questionnaireresponse.json
# StructureDefinition-us-core-race.json
# StructureDefinition-us-core-relatedperson.json
# StructureDefinition-us-core-respiratory-rate.json
# StructureDefinition-us-core-servicerequest.json
# StructureDefinition-us-core-smokingstatus.json
# StructureDefinition-us-core-vital-signs.json
# {'http://hl7.org/fhir/StructureDefinition/Observation': 'Observation',
#  'http://hl7.org/fhir/StructureDefinition/vitalsigns': 'FHIR Vital Signs Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/head-occipital-frontal-circumference-percentile': 'US Core Pediatric Head Occipital-frontal Circumference Percentile Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/pediatric-bmi-for-age': 'US Core Pediatric BMI for Age Observation Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/pediatric-weight-for-height': 'US Core Pediatric Weight for Height Observation Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-allergyintolerance': 'US Core AllergyIntolerance Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex': 'US Core Birth Sex Extension',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-blood-pressure': 'US Core Blood Pressure Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-bmi': 'US Core BMI Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-height': 'US Core Body Height Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-temperature': 'US Core Body Temperature Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-body-weight': 'US Core Body Weight Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-careplan': 'US Core CarePlan Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-careteam': 'US Core CareTeam Profile',
#  'http://hl7.org/fhir/us/core//StructureDefinition/us-core-condition-encounter-diagnosis': 'US Core Condition Encounter Diagnosis Profile',
#  'http://hl7.org/fhir/us/core//StructureDefinition/us-core-condition-problems-health-concerns': 'US Core Condition Problems and Health Concerns Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab': 'US Core DiagnosticReport Profile for Laboratory Results Reporting',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note': 'US Core DiagnosticReport Profile for Report and Note Exchange',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-direct': 'US Core Direct email Extension',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-documentreference': 'US Core DocumentReference Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter': 'US Core Encounter Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity': 'US Core Ethnicity Extension',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-extension-questionnaire-uri': 'US Core Extension Questionnaire URI',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-genderIdentity': 'US Core Gender Identity Extension',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-goal': 'US Core Goal Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-head-circumference': 'US Core Head Circumference Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-heart-rate': 'US Core Heart Rate Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-immunization': 'US Core Immunization Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-implantable-device': 'US Core Implantable Device Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-location': 'US Core Location Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-medication': 'US Core Medication Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-medicationrequest': 'US Core MedicationRequest Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-clinical-test': 'US Core Observation Clinical Test Result Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-imaging': 'US Core Observation Imaging Result Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-lab': 'US Core Laboratory Result Observation Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-sdoh-assessment': 'US Core Observation SDOH Assessment Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-sexual-orientation': 'US Core Observation Sexual Orientation Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-social-history': 'US Core Observation Social History Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-observation-survey': 'US Core Observation Survey Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-organization': 'US Core Organization Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient': 'US Core Patient Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-practitioner': 'US Core Practitioner Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-practitionerrole': 'US Core PractitionerRole Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-procedure': 'US Core Procedure Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-provenance': 'US Core Provenance Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-pulse-oximetry': 'US Core Pulse Oximetry Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-questionnaireresponse': 'US Core QuestionnaireResponse Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race': 'US Core Race Extension',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-relatedperson': 'US Core RelatedPerson Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-respiratory-rate': 'US Core Respiratory Rate Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-servicerequest': 'US Core ServiceRequest Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-smokingstatus': 'US Core Smoking Status Observation Profile',
#  'http://hl7.org/fhir/us/core/StructureDefinition/us-core-vital-signs': 'US Core Vital Signs Profile'}

# %% [markdown]
# ### Loop through all sd and loop through all the elemenst and print out the element the element you want
#
# filter on the element properties you want

# %%
for i in us_core_files:
    #print(i.name)
    sd_dict = loads(i.read_text())
    #print(sd_dict['type'])
    
    if sd_dict['type'] =="Observation":
        new_row = copy.deepcopy(empty_row)
        #print('='*80)
        #print(sd_dict['title'])
                
        #==== Title and BaseDefinition ====
        new_row['Profile Title'] = sd_dict['title']
        new_row['Based On'] = profile_map[sd_dict['baseDefinition']]
        # convert elemnt to hash
        ed_dict = {list(j.values())[0]:j for j in sd_dict['snapshot']['element']}
        # print(dump(ed_dict,sort_keys=False))
        
        #==== Category ====
        category_slices = [j for j in ed_dict if "category:" in j.split('.')[-1]]
        category_names = [ed_dict[k]['sliceName'] for k in category_slices]
        
        for k in category_slices:
            
            try:
              cat_system = ed_dict[k]['patternCodeableConcept']['coding'][0]['system']
              cat_code = ed_dict[k]['patternCodeableConcept']['coding'][0]['code']
            except KeyError:
              pass
            else:
              new_row['Category Slice Codes'].append(f'{cat_system}|{cat_code}')
            
            system_key = f'{k}.coding.system'
            code_key = f'{k}.coding.code'               
            try:
              cat_system = ed_dict[system_key]['fixedUri']
              cat_code = ed_dict[code_key]['fixedCode']
            except KeyError:
              pass
            else:
              new_row['Category Slice Codes'].append(f'{cat_system}|{cat_code}')

        #==== Code ====
        #pattern
        o_code = ed_dict['Observation.code']
        try:
            code_system = o_code['patternCodeableConcept']['coding'][0]['system']
            code_code = o_code['patternCodeableConcept']['coding'][0]['code']
        except KeyError:
            #binding
            binding = o_code['binding']['valueSet']
            strength = o_code['binding']['strength']
            new_row['Code Binding'] = f'{binding}({strength})'
        else:
            new_row['Code Fixed Value'] = f'{code_system}|{code_code}'
        
        #==== time types ====

        try:
            o_eff = ed_dict['Observation.effective[x]']
        except KeyError:
            pass
        else:
            for eff_type in o_eff['type']:
                try:
                    eff_type['extension'][0]['valueBoolean']==True
                except KeyError:
                    continue             
                else: 
                    new_row['Effective Time Types'].append(eff_type['code'])
       #==== values types  ====
    
        
       # MS by type
        try:
            val = ed_dict['Observation.value[x]']
        except KeyError:
            pass
        else:
            for val_type in val['type']:
                try:
                    assert val_type['extension'][0]['valueBoolean']==True
                except (KeyError, AssertionError):
                    continue             
                else: 
                    new_row['Value Types'].append(val_type['code']) 
                    
        # ===slice by type ===
        
        value_slices = [v for v in ed_dict if "value[x]:" in v.split('.')[-1]] 
        for k in value_slices:           
            try:
              val_type = ed_dict[k]['type'][0]['code']
            except KeyError:
              pass
            else:
              new_row['Value Types'].append(val_type)
              
            
        # ===Unit Codes ===
        # either binding or fixed or none       
        # 'ValueQuantity Code Binding': None,  #binding with strength
        # 'ValueQuantity Code Fixed Value': None, # URI|fixedCode - always UCUM by value
        try: 
            vq_code = ed_dict['Observation.value[x]:valueQuantity.code']
        except KeyError:
            pass
        else:
            try: 
                binding = vq_code['binding']['valueSet']
                strength = vq_code['binding']['strength']                         
            except KeyError:
                try:
                    new_row['ValueQuantity Code Fixed Value']=f'{ucum}|{vq_code["fixedCode"]}'
                except KeyError:
                    pass # no code          
            else:
                new_row['ValueQuantity Code Binding'] = f'{binding}({strength})'    
 
        # ===DAR a MS ===
        try:
            new_row['Is Data Absent Reason'] = ed_dict["Observation.dataAbsentReason"]["mustSupport"]
        except KeyError:
            pass
        
        # ===Component is MS ===
        try:
            new_row['Is Component'] = ed_dict["Observation.component"]["mustSupport"]
        except KeyError:
            pass
        else:
            
 
            # loop through all slices and find patterns
            comp_slices = [j for j in ed_dict if "component:" in j.split('.')[-1]]
            comp_names = [ed_dict[k]['sliceName'] for k in category_slices]

            for k in comp_slices:
                # 'Component Slice Codes': [], # URI|Code 
  
                comp_code_id = f'{k}.code'
                try:
                  comp_system = ed_dict[comp_code_id]['patternCodeableConcept']['coding'][0]['system']
                  comp_code = ed_dict[comp_code_id]['patternCodeableConcept']['coding'][0]['code']
                except KeyError:
                  pass
                else:
                  new_row['Component Slice Codes'].append(f'{cat_system}|{cat_code}')
                
                # 'Component Slice Value Types': None, # list MS types assume just first one for now
                # 'Component Slice ValueQuantity Codes': None, # URI|fixedCode - always UCUM by value
                comp_value_id = f'{k}.value[x].code'
                try:
                  val_type = ed_dict[comp_value_id]['type'][0]['code']
                  vq_code = ed_dict[comp_value_id]['fixedCode']
                except KeyError:
                  pass
                else:
                  new_row['Component Slice Value Types'].append(val_type)
                  new_row['Component Slice ValueQuantity Codes'].append(f'{ucum}|{vq_code}')
                            
                
        #  === Has Member refs ====

        try:
            has_m = ed_dict['Observation.hasMember']
        except KeyError:
            pass
        else:
            for i, ref in enumerate(has_m['type'][0]['targetProfile']):
                try:
                    assert has_m['type'][0]['_targetProfile'][i]['extension'][0]['valueBoolean']==True
                except (KeyError, AssertionError):
                    continue             
                else: 
                    new_row['Has Member References'].append(ref)
              
        
        # === derivedFrom refs ===
        
        try:
            der_from = ed_dict['Observation.derivedFrom']
        except KeyError:
            pass
        else:
            for i, ref in enumerate(der_from['type'][0]['targetProfile']):
                try:
                    assert der_from['type'][0]['_targetProfile'][i]['extension'][0]['valueBoolean']==True
                except (KeyError, AssertionError):
                    continue             
                else: 
                    new_row['Has Member References'].append(ref)
        

        # =====print(new_row) =====
        # print('='*80)
        df_length = len(df)
        df.loc[df_length] = new_row

    
df = df.mask(df.applymap(type).eq(list) & ~df.astype(bool))
df
# Out:
#                                         Profile Title  \
# 0   US Core Pediatric Head Occipital-frontal Circu...
# 1   US Core Pediatric BMI for Age Observation Profile
# 2   US Core Pediatric Weight for Height Observatio...
# 3                      US Core Blood Pressure Profile
# 4                                 US Core BMI Profile
# 5                         US Core Body Height Profile
# 6                    US Core Body Temperature Profile
# 7                         US Core Body Weight Profile
# 8                  US Core Head Circumference Profile
# 9                          US Core Heart Rate Profile
# 10   US Core Observation Clinical Test Result Profile
# 11         US Core Observation Imaging Result Profile
# 12      US Core Laboratory Result Observation Profile
# 13        US Core Observation SDOH Assessment Profile
# 14     US Core Observation Sexual Orientation Profile
# 15         US Core Observation Social History Profile
# 16                 US Core Observation Survey Profile
# 17                     US Core Pulse Oximetry Profile
# 18                   US Core Respiratory Rate Profile
# 19         US Core Smoking Status Observation Profile
# 20                        US Core Vital Signs Profile
#
#                               Based On  \
# 0          US Core Vital Signs Profile
# 1          US Core Vital Signs Profile
# 2          US Core Vital Signs Profile
# 3          US Core Vital Signs Profile
# 4          US Core Vital Signs Profile
# 5          US Core Vital Signs Profile
# 6          US Core Vital Signs Profile
# 7          US Core Vital Signs Profile
# 8          US Core Vital Signs Profile
# 9          US Core Vital Signs Profile
# 10                         Observation
# 11                         Observation
# 12                         Observation
# 13  US Core Observation Survey Profile
# 14                         Observation
# 15                         Observation
# 16                         Observation
# 17         US Core Vital Signs Profile
# 18         US Core Vital Signs Profile
# 19                         Observation
# 20            FHIR Vital Signs Profile
#
#                                  Category Slice Codes  \
# 0   [http://terminology.hl7.org/CodeSystem/observa...
# 1   [http://terminology.hl7.org/CodeSystem/observa...
# 2   [http://terminology.hl7.org/CodeSystem/observa...
# 3   [http://terminology.hl7.org/CodeSystem/observa...
# 4   [http://terminology.hl7.org/CodeSystem/observa...
# 5   [http://terminology.hl7.org/CodeSystem/observa...
# 6   [http://terminology.hl7.org/CodeSystem/observa...
# 7   [http://terminology.hl7.org/CodeSystem/observa...
# 8   [http://terminology.hl7.org/CodeSystem/observa...
# 9   [http://terminology.hl7.org/CodeSystem/observa...
# 10  [http://hl7.org/fhir/us/core/CodeSystem/us-cor...
# 11  [http://terminology.hl7.org/CodeSystem/observa...
# 12  [http://terminology.hl7.org/CodeSystem/observa...
# 13  [http://terminology.hl7.org/CodeSystem/observa...
# 14                                                NaN
# 15  [http://terminology.hl7.org/CodeSystem/observa...
# 16  [http://terminology.hl7.org/CodeSystem/observa...
# 17  [http://terminology.hl7.org/CodeSystem/observa...
# 18  [http://terminology.hl7.org/CodeSystem/observa...
# 19  [http://terminology.hl7.org/CodeSystem/observa...
# 20  [http://terminology.hl7.org/CodeSystem/observa...
#
#                                          Code Binding  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10  http://hl7.org/fhir/us/core/ValueSet/us-core-c...
# 11  http://hl7.org/fhir/us/core/ValueSet/us-core-d...
# 12  http://hl7.org/fhir/ValueSet/observation-codes...
# 13  http://hl7.org/fhir/us/core/ValueSet/us-core-c...
# 14                                               None
# 15  http://hl7.org/fhir/ValueSet/observation-codes...
# 16  http://hl7.org/fhir/us/core/ValueSet/us-core-s...
# 17  http://hl7.org/fhir/us/core/ValueSet/us-core-v...
# 18                                               None
# 19  http://hl7.org/fhir/us/core/ValueSet/us-core-s...
# 20  http://hl7.org/fhir/us/core/ValueSet/us-core-v...
#
#             Code Fixed Value Effective Time Types  \
# 0    http://loinc.org|8289-1           [dateTime]
# 1   http://loinc.org|59576-9           [dateTime]
# 2   http://loinc.org|77606-2           [dateTime]
# 3   http://loinc.org|85354-9           [dateTime]
# 4   http://loinc.org|39156-5           [dateTime]
# 5    http://loinc.org|8302-2           [dateTime]
# 6    http://loinc.org|8310-5           [dateTime]
# 7   http://loinc.org|29463-7           [dateTime]
# 8    http://loinc.org|9843-4           [dateTime]
# 9    http://loinc.org|8867-4           [dateTime]
# 10                      None           [dateTime]
# 11                      None           [dateTime]
# 12                      None           [dateTime]
# 13                      None           [dateTime]
# 14  http://loinc.org|76690-7           [dateTime]
# 15                      None           [dateTime]
# 16                      None           [dateTime]
# 17                      None           [dateTime]
# 18   http://loinc.org|9279-1           [dateTime]
# 19                      None                  NaN
# 20                      None           [dateTime]
#
#                                      Value Types  \
# 0                                     [Quantity]
# 1                                     [Quantity]
# 2                                     [Quantity]
# 3                                     [Quantity]
# 4                                     [Quantity]
# 5                                     [Quantity]
# 6                                     [Quantity]
# 7                                     [Quantity]
# 8                                     [Quantity]
# 9                                     [Quantity]
# 10           [Quantity, CodeableConcept, string]
# 11           [Quantity, CodeableConcept, string]
# 12           [Quantity, CodeableConcept, string]
# 13           [Quantity, CodeableConcept, string]
# 14                             [CodeableConcept]
# 15  [Quantity, CodeableConcept, string, boolean]
# 16           [Quantity, CodeableConcept, string]
# 17                                    [Quantity]
# 18                                    [Quantity]
# 19                             [CodeableConcept]
# 20                                    [Quantity]
#
#                            ValueQuantity Code Binding  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   http://hl7.org/fhir/ValueSet/ucum-bodylength|4...
# 6   http://hl7.org/fhir/ValueSet/ucum-bodytemp|4.0...
# 7   http://hl7.org/fhir/ValueSet/ucum-bodyweight|4...
# 8   http://hl7.org/fhir/ValueSet/ucum-bodylength|4...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
#
#      ValueQuantity Code Fixed Value  Is Data Absent Reason  Is Component  \
# 0       http://unitsofmeasure.org|%                   True          True
# 1       http://unitsofmeasure.org|%                   True          True
# 2       http://unitsofmeasure.org|%                   True          True
# 3                              None                   True          True
# 4   http://unitsofmeasure.org|kg/m2                   True          True
# 5                              None                   True          True
# 6                              None                   True          True
# 7                              None                   True          True
# 8                              None                   True          True
# 9    http://unitsofmeasure.org|/min                   True          True
# 10                             None                   True         False
# 11                             None                   True         False
# 12                             None                   True         False
# 13                             None                   True         False
# 14                             None                  False         False
# 15                             None                  False         False
# 16                             None                   True         False
# 17                             None                   True          True
# 18   http://unitsofmeasure.org|/min                   True          True
# 19                             None                  False         False
# 20                             None                   True          True
#
#                                 Component Slice Codes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [http://terminology.hl7.org/CodeSystem/observa...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  [http://terminology.hl7.org/CodeSystem/observa...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#    Component Slice Value Types  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                 [code, code]
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                [code, code]
# 18                         NaN
# 19                         NaN
# 20                         NaN
#
#                   Component Slice ValueQuantity Codes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [http://unitsofmeasure.org|mm[Hg], http://unit...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  [http://unitsofmeasure.org|L/min, http://units...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                 Has Member References Derived From References
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                                                NaN                     NaN
# 11                                                NaN                     NaN
# 12                                                NaN                     NaN
# 13  [http://hl7.org/fhir/us/core/StructureDefiniti...                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16  [http://hl7.org/fhir/us/core/StructureDefiniti...                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN

# %%
print(f"printing {out_path_excel}/USCore_Obs_Compare.xlsx ....")
df.to_excel(f"{out_path_excel}/USCore_Obs_Compare.xlsx")
print(f"printing {out_path_csv}/USCore_Obs_Compare.csv ....")
df.to_csv(f"{out_path_csv}/USCore_Obs_Compare.csv")
# Out:
# printing out/compare_obs_excel/USCore_Obs_Compare.xlsx ....
# printing out/compare_obs_csv/USCore_Obs_Compare.csv ....

# %%
# %%bash -s "$out_path_excel" "$out_path_csv" "$image_path"
# echo "================================================================="
# echo "===zip up csv and excel files and put in==="
# echo "===$3/argo-compare.zips file for downloads==="
# echo "================================================================="
# zip -j $3/argo-obs-compare-excel.zip $1/*.*
# zip -j $3/argo-obs-compare-csv.zip $2/*.*
# Out:
# =================================================================
# ===zip up csv and excel files and put in===
# ===/Users/ehaas/Documents/FHIR/US-Core/input/images/argo-compare.zips file for downloads===
# =================================================================
#   adding: README.md (deflated 60%)
#   adding: USCore_Obs_Compare.xlsx (deflated 8%)
#   adding: README.md (deflated 60%)
#   adding: USCore_Obs_Compare.csv (deflated 83%)
