# %% [markdown]
# ## Create FHIRSTU3 SearchParameter Resource, CababilityStatement and Quick start text, and Searchparameter list. Using the Python FHIRClient Module and SearchParameter CSV file with source data.
#
# ### Prerequisites:
#
# - Python 3.6 or greater
#
#
# ### Import FHIRClient and other libraries

# %%
# %config IPCompleter.greedy=True

# %%
from fhirclient.models import searchparameter as SP
from fhirclient.models import capabilitystatement as CS
from fhirclient.models import bundle as B
import fhirclient.models.identifier as I
import fhirclient.models.coding as C
import fhirclient.models.codeableconcept as CC
import fhirclient.models.fhirdate as D
import fhirclient.models.extension as X
import fhirclient.models.contactdetail as CD
from json import dumps, loads, load
from requests import get, post, put
import os
from pathlib import Path
from csv import reader as csvreader
from IPython import display as Display
from pprint import pprint
from collections import namedtuple
from pandas import read_csv
from datetime import datetime
from jinja2 import Environment, FileSystemLoader, select_autoescape

# %% [markdown]
# #### Inspect ElementProperties as reference

# %% [markdown]
# ####  Assign Global Variables
#
#
# Here is where we assign all the global variables for this example such as the local paths for file input and output

# %%
#in_path = '/Users/ehaas/Documents/FHIR/pyfhir/test/'
in_path =''
#out_path = '/Users/ehaas/Documents/FHIR/pyfhir/test/'
out_path=''
#out_path = "C:/Users/Eric/Documents/Jan_2019_FHIR_Experience"
#sp_csv = 'SearchParams.csv'
sp_csv = 'Q_SearchParam.csv'
md_template = ['search_narrative.j2', 'sp_list_page.j2', 'cs_search_documentation.j2']

env = Environment(
    loader=FileSystemLoader(searchpath = in_path),
    autoescape=select_autoescape(['html','xml','xhtml','j2','md'])
    )

fhir_term_server = 'http://test.fhir.org/r3'
fhir_test_server = 'http://test.fhir.org/r3'

headers = {
'Accept':'application/fhir+json',
'Content-Type':'application/fhir+json'
}

# profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
fhir_base_url = 'http://hl7.org/fhir/'
base_id = "argo-q"
canon_base = "http://fhir.org/guides/argonaut-questionnaire/"
publisher = 'The Argonaut Project'
publisher_endpoint = dict(
                        system = 'url',
                        value = 'https://github.com/argonautproject/questionnaire/issues'
                        )
none_list = ['', ' ', 'none', 'n/a', 'N/A', 'N', 'False']
sep_list = (',', ';', ' ', ', ', '; ')
search_type = dict(
    token = '{[system]}|[code]',
    id = '[id]',
    reference = '[url]',
    string = '[string]'
    )

# %% [markdown]
# ### validate

# %%
# *********************** validate Resource ********************************

def validate(r):
    fhir_test_server = 'http://fhirtest.uhn.ca/baseDstu3'
    #fhir_test_server = 'http://test.fhir.org/r3'

    headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }
    
    params = {
  
    }
    #   r = requests.post('https://httpbin.org/post', data = {'key':'value'})
    r = post(f'{fhir_test_server}/Questionnaire/$validate', params = params, headers = headers, data = dumps(r.as_json()))
    # return r.status_code
    # view  output
    # return (r.json()["text"]["div"])
    return r

# %% [markdown]
# ### Write to File

# %%
 def write_file(name, data): # write file
    # out_path = ''
    out_path = '//ERICS-AIR-2/ehaas/Documents/FHIR/Argo-Questionnaire/source/resources/'
    with open(f'{Path(out_path)}/{name}.json', 'w') as f:
        f.write(data)

# %% [markdown]
# ### Get Search Parameter input data

# %%
data = read_csv(f'{in_path}{sp_csv}')
data
# Out:
#                  Resource Conformance Server           Parameter Exists  \
# 0       HealthcareService              SHALL              active      Y
# 1           Questionnaire              SHALL                 _id      Y
# 2           Questionnaire              SHALL                 url      Y
# 3           Questionnaire              SHALL              status      Y
# 4           Questionnaire              SHALL               title      Y
# 5           Questionnaire              SHALL           publisher      Y
# 6           Questionnaire             SHOULD             version      Y
# 7           Questionnaire             SHOULD  context-type-value      N
# 8   QuestionnaireResponse              SHALL                 _id      Y
# 9   QuestionnaireResponse              SHALL       questionnaire      Y
# 10  QuestionnaireResponse              SHALL             patient      Y
# 11  QuestionnaireResponse              SHALL             context      Y
# 12  QuestionnaireResponse              SHALL              status      Y
# 13  QuestionnaireResponse             SHOULD              author      Y
# 14  QuestionnaireResponse             SHOULD              source      Y
# 15             individual              SHALL           birthdate      Y
#
#    Update       Type                           Expression ands ors  \
# 0       N      token             HealthcareService.active    Y   Y
# 1       N      token                     Questionnaire.id    N   N
# 2       N        uri                    Questionnaire.url    N   N
# 3       Y      token                 Questionnaire.status    Y   Y
# 4       Y     string                  Questionnaire.title    Y   Y
# 5       Y     string              Questionnaire.publisher    Y   Y
# 6       Y      token                Questionnaire.version    Y   Y
# 7       N  composite     Questionnaire.context-type-value    N   N
# 8       N      token             QuestionnaireResponse.id    N   N
# 9       Y  reference  QuestionnaireResponse.questionnaire    Y   Y
# 10      Y  reference        QuestionnaireResponse.patient    Y   Y
# 11      Y  reference        QuestionnaireResponse.context    Y   Y
# 12      Y      token         QuestionnaireResponse.status    Y   Y
# 13      Y  reference         QuestionnaireResponse.author    Y   Y
# 14      Y  reference         QuestionnaireResponse.source    Y   Y
# 15      Y       date                 individual.birthdate    N   N
#
#       Modifiers  Comparators   References  \
# 0   foo,bar,baz  foo,bar,baz  foo,bar,baz
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4      contains          NaN          NaN
# 5      contains          NaN          NaN
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN
# 11          NaN          NaN          NaN
# 12          NaN          NaN          NaN
# 13          NaN          NaN          NaN
# 14          NaN          NaN          NaN
# 15          NaN        le,ge          NaN
#
#                                                Chains  \
# 0                                         foo,bar,baz
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  patient.gender,patient.birthdate,patient.race,...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                           Description  \
# 0   The Healthcare Service is currently marked as ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                  Example Query  foo
# 0   GET [base]/HealthcareService?active=[code]  NaN
# 1                                          NaN  NaN
# 2                                          NaN  NaN
# 3                                          NaN  NaN
# 4                                          NaN  NaN
# 5                                          NaN  NaN
# 6                                          NaN  NaN
# 7                                          NaN  NaN
# 8                                          NaN  NaN
# 9                                          NaN  NaN
# 10                                         NaN  NaN
# 11                                         NaN  NaN
# 12                                         NaN  NaN
# 13                                         NaN  NaN
# 14                                         NaN  NaN
# 15                                         NaN  NaN

# %%
with open(f'{in_path}{sp_csv}') as f:
    reader = csvreader(f)
    top_row = next(reader)
    top_row = [t.lower().split(' ') for t in top_row]
    top_row = ['_'.join(t) for t in top_row]

    Data = namedtuple("Data", top_row)
    data = [Data(*r) for r in reader]
    
for d in data:
    print(f'Resource = {d.resource}, Search Parameter = {d.parameter}, Exists = {d.exists}')
# Out:
# Resource = HealthcareService, Search Parameter = active, Exists = Y
# Resource = Questionnaire, Search Parameter = _id, Exists = Y
# Resource = Questionnaire, Search Parameter = url, Exists = Y
# Resource = Questionnaire, Search Parameter = status, Exists = Y
# Resource = Questionnaire, Search Parameter = title, Exists = Y
# Resource = Questionnaire, Search Parameter = publisher, Exists = Y
# Resource = Questionnaire, Search Parameter = version, Exists = Y
# Resource = Questionnaire, Search Parameter = context-type-value, Exists = N
# Resource = QuestionnaireResponse, Search Parameter = _id, Exists = Y
# Resource = QuestionnaireResponse, Search Parameter = questionnaire, Exists = Y
# Resource = QuestionnaireResponse, Search Parameter = patient, Exists = Y
# Resource = QuestionnaireResponse, Search Parameter = context, Exists = Y
# Resource = QuestionnaireResponse, Search Parameter = status, Exists = Y
# Resource = QuestionnaireResponse, Search Parameter = author, Exists = Y
# Resource = QuestionnaireResponse, Search Parameter = source, Exists = Y
# Resource = individual, Search Parameter = birthdate, Exists = Y

# %% [markdown]
# ### update core SP with additional capabiliities

# %% [markdown]
# #### Get core SP (d.exists == 'Y')
#
# - Get definitions bundle
# - If need to update SP Extract the SP based on the csv file

# %%
def_path = 'C:/Users/Eric/Documents/HL7/FHIR/BUILD_EDIT_FILES/STU3_Definitions/search-parameters.json'  # use '/' !

print(Path(def_path))

with open(Path(def_path)) as f:
    b = B.Bundle(load(f))

b.id
# Out:
# C:\Users\Eric\Documents\HL7\FHIR\BUILD_EDIT_FILES\STU3_Definitions\search-parameters.json
# 'searchParams'

# %%
def sp_multipleAnd(sp):
    x = X.Extension(dict(
    url = f'{canon_base}multipleAnd',
    valueBoolean = True
    ))
    try:
        sp.extension.append(x)
    except AttributeError:
        sp.extension = [x]
    # print('add adds extension')
    return sp
    
  
def sp_multipleOr(sp):
    x = X.Extension(dict(
    url = f'{canon_base}multipleOr',
    valueBoolean = True
    ))
    try:
        sp.extension.append(x)
    except AttributeError:
        sp.extension = [x]
    # print('add ors extension')
    return sp


new_constraints = {
    'ands': sp_multipleAnd,
    'ors': sp_multipleOr,
    'modifiers': 'modifier',
    'comparators': 'comparator',
    'references': 'target',
    'chains': 'chain'
    }

sp_list=[]
for d in data:
    fullUrl = f'http://hl7.org/fhir/SearchParameter/{d.resource}-{d.parameter}'
    for i in b.entry:
        if i.fullUrl == fullUrl and d.update == 'Y': #update sp
            # print(dumps(i.resource.as_json(),indent = 3))
            sp = i.resource
            # change id and url, publisher, and contact, draft etc
            sp.derivedFrom =sp.url
            #sp.id = f'{base_id}-{sp.id}'
            sp.url = f'{canon_base}{sp.id}'
            sp.publisher = publisher
            sp.contact = [CD.ContactDetail( {"telecom" : [ publisher_endpoint ] })]
            sp.date = D.FHIRDate(f'{datetime.utcnow().isoformat()}Z')
            sp.name = sp.id.replace('-','_').lower()
            sp.status = 'active'

            for k,v in new_constraints.items():
                print(getattr(d,k))
                if getattr(d,k) =='Y':
                    v(sp)
                elif getattr(d,k) not in none_list:
                    a_list = getattr(d,k).split(',')
                    # print(a_list)
                    setattr(sp,v,a_list)



            print(dumps(sp.as_json(),indent = 3))

            #validate and write to file

            print('...validating')
            # print(validate(sp))
            #r = validate(sp)
            #display(Display.HTML(f'<h1>Validation output</h1><h3>Status Code = {r.status_code}</h3> {r.json()["text"]["div"]}'))


            # save to file

            rjson = dumps(sp.as_json(), indent=3)
            name =f'searchparameter-{sp.id.lower()}'
            print(name)
            # write files as json
            # write_file(name, rjson)
            sp_list.append(sp)
            break

        elif i.fullUrl == fullUrl:
            sp = i.resource
            sp_list.append(sp)
            break


for i in sp_list:
    print(i.id, i.name, i.url)
# Out:
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "Questionnaire-status",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "Questionnaire"
#    ],
#    "code": "status",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.867688Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-status",
#    "description": "The current status of the questionnaire",
#    "experimental": false,
#    "expression": "Questionnaire.status",
#    "name": "questionnaire_status",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "type": "token",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-status",
#    "xpath": "f:Questionnaire/f:status",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaire-status
# Y
# Y
# contains
# n/a
# n/a
# n/a
# {
#    "id": "Questionnaire-title",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "Questionnaire"
#    ],
#    "code": "title",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.868685Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-title",
#    "description": "The human-friendly name of the questionnaire",
#    "experimental": false,
#    "expression": "Questionnaire.title",
#    "modifier": [
#       "contains"
#    ],
#    "name": "questionnaire_title",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "type": "string",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-title",
#    "xpath": "f:Questionnaire/f:title",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaire-title
# Y
# Y
# contains
# n/a
# n/a
# n/a
# {
#    "id": "Questionnaire-publisher",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "Questionnaire"
#    ],
#    "code": "publisher",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.870680Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-publisher",
#    "description": "Name of the publisher of the questionnaire",
#    "experimental": false,
#    "expression": "Questionnaire.publisher",
#    "modifier": [
#       "contains"
#    ],
#    "name": "questionnaire_publisher",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "type": "string",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-publisher",
#    "xpath": "f:Questionnaire/f:publisher",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaire-publisher
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "Questionnaire-version",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "Questionnaire"
#    ],
#    "code": "version",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.871678Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-version",
#    "description": "The business version of the questionnaire",
#    "experimental": false,
#    "expression": "Questionnaire.version",
#    "name": "questionnaire_version",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "type": "token",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/Questionnaire-version",
#    "xpath": "f:Questionnaire/f:version",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaire-version
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "QuestionnaireResponse-questionnaire",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "QuestionnaireResponse"
#    ],
#    "code": "questionnaire",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.874670Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-questionnaire",
#    "description": "The questionnaire the answers are provided for",
#    "experimental": false,
#    "expression": "QuestionnaireResponse.questionnaire",
#    "name": "questionnaireresponse_questionnaire",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "target": [
#       "Questionnaire"
#    ],
#    "type": "reference",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-questionnaire",
#    "xpath": "f:QuestionnaireResponse/f:questionnaire",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaireresponse-questionnaire
# Y
# Y
# n/a
# n/a
# n/a
# patient.gender,patient.birthdate,patient.race,patient.ethnicity,patient.address-postalcode
# {
#    "id": "QuestionnaireResponse-patient",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "QuestionnaireResponse"
#    ],
#    "chain": [
#       "patient.gender",
#       "patient.birthdate",
#       "patient.race",
#       "patient.ethnicity",
#       "patient.address-postalcode"
#    ],
#    "code": "patient",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.875667Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-patient",
#    "description": "The patient that is the subject of the questionnaire response",
#    "experimental": false,
#    "expression": "QuestionnaireResponse.subject",
#    "name": "questionnaireresponse_patient",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "target": [
#       "Patient"
#    ],
#    "type": "reference",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-patient",
#    "xpath": "f:QuestionnaireResponse/f:subject",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaireresponse-patient
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "QuestionnaireResponse-context",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "QuestionnaireResponse"
#    ],
#    "code": "context",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.877693Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-context",
#    "description": "Encounter or episode associated with the questionnaire response",
#    "experimental": false,
#    "expression": "QuestionnaireResponse.context",
#    "name": "questionnaireresponse_context",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "target": [
#       "EpisodeOfCare",
#       "Encounter"
#    ],
#    "type": "reference",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-context",
#    "xpath": "f:QuestionnaireResponse/f:context",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaireresponse-context
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "QuestionnaireResponse-status",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "QuestionnaireResponse"
#    ],
#    "code": "status",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.878660Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-status",
#    "description": "The status of the questionnaire response",
#    "experimental": false,
#    "expression": "QuestionnaireResponse.status",
#    "name": "questionnaireresponse_status",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "type": "token",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-status",
#    "xpath": "f:QuestionnaireResponse/f:status",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaireresponse-status
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "QuestionnaireResponse-author",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "QuestionnaireResponse"
#    ],
#    "code": "author",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.881656Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-author",
#    "description": "The author of the questionnaire response",
#    "experimental": false,
#    "expression": "QuestionnaireResponse.author",
#    "name": "questionnaireresponse_author",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "target": [
#       "Practitioner",
#       "Device",
#       "Patient",
#       "RelatedPerson"
#    ],
#    "type": "reference",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-author",
#    "xpath": "f:QuestionnaireResponse/f:author",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaireresponse-author
# Y
# Y
# n/a
# n/a
# n/a
# n/a
# {
#    "id": "QuestionnaireResponse-source",
#    "extension": [
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleAnd",
#          "valueBoolean": true
#       },
#       {
#          "url": "http://fhir.org/guides/argonaut-questionnaire/multipleOr",
#          "valueBoolean": true
#       }
#    ],
#    "base": [
#       "QuestionnaireResponse"
#    ],
#    "code": "source",
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.882648Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-source",
#    "description": "The individual providing the information reflected in the questionnaire respose",
#    "experimental": false,
#    "expression": "QuestionnaireResponse.source",
#    "name": "questionnaireresponse_source",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "target": [
#       "Practitioner",
#       "Patient",
#       "RelatedPerson"
#    ],
#    "type": "reference",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-source",
#    "xpath": "f:QuestionnaireResponse/f:source",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-questionnaireresponse-source
# N
# N
# n/a
# le,ge
# n/a
# n/a
# {
#    "id": "individual-birthdate",
#    "base": [
#       "RelatedPerson",
#       "Person",
#       "Patient"
#    ],
#    "code": "birthdate",
#    "comparator": [
#       "le",
#       "ge"
#    ],
#    "contact": [
#       {
#          "telecom": [
#             {
#                "system": "url",
#                "value": "https://github.com/argonautproject/questionnaire/issues"
#             }
#          ]
#       }
#    ],
#    "date": "2019-02-19T00:24:39.883645Z",
#    "derivedFrom": "http://fhir.org/guides/argonaut-questionnaire/individual-birthdate",
#    "description": "Multiple Resources: \r\n\r\n* [RelatedPerson](relatedperson.html): The Related Person's date of birth\r\n* [Person](person.html): The person's date of birth\r\n* [Patient](patient.html): The patient's date of birth\r\n",
#    "experimental": false,
#    "expression": "RelatedPerson.birthDate | Person.birthDate | Patient.birthDate",
#    "name": "individual_birthdate",
#    "publisher": "The Argonaut Project",
#    "status": "active",
#    "type": "date",
#    "url": "http://fhir.org/guides/argonaut-questionnaire/individual-birthdate",
#    "xpath": "f:RelatedPerson/f:birthDate | f:Person/f:birthDate | f:Patient/f:birthDate",
#    "xpathUsage": "normal",
#    "resourceType": "SearchParameter"
# }
# ...validating
# searchparameter-individual-birthdate
# HealthcareService-active active http://hl7.org/fhir/SearchParameter/HealthcareService-active
# Questionnaire-url url http://hl7.org/fhir/SearchParameter/Questionnaire-url
# Questionnaire-status questionnaire_status http://fhir.org/guides/argonaut-questionnaire/Questionnaire-status
# Questionnaire-title questionnaire_title http://fhir.org/guides/argonaut-questionnaire/Questionnaire-title
# Questionnaire-publisher questionnaire_publisher http://fhir.org/guides/argonaut-questionnaire/Questionnaire-publisher
# Questionnaire-version questionnaire_version http://fhir.org/guides/argonaut-questionnaire/Questionnaire-version
# QuestionnaireResponse-questionnaire questionnaireresponse_questionnaire http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-questionnaire
# QuestionnaireResponse-patient questionnaireresponse_patient http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-patient
# QuestionnaireResponse-context questionnaireresponse_context http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-context
# QuestionnaireResponse-status questionnaireresponse_status http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-status
# QuestionnaireResponse-author questionnaireresponse_author http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-author
# QuestionnaireResponse-source questionnaireresponse_source http://fhir.org/guides/argonaut-questionnaire/QuestionnaireResponse-source
# individual-birthdate individual_birthdate http://fhir.org/guides/argonaut-questionnaire/individual-birthdate

# %% [markdown]
# ### Create SP Resources by assigning CSV data to SP elements

# %% [markdown]
# sp_list = []
#
#
#
# def split_string(s):
#     for r in sep_list:
#         s = s.replace(r, ' ')
#     return s.split()
#
# for d in data:
#     #initiliaze
#     sp = SP.SearchParameter()
#     sp.date = D.FHIRDate(datetime.utcnow().isoformat())
#     sp.publisher = publisher
#     sp.contact = [CD.ContactDetail( {"telecom" : [ publisher_endpoint ] })]
#     # print(d.parameter)
#     sp.id = f'{base_id}-{d.resource.lower()}-{d.parameter}'
#     sp.url = f'{canon_base}{sp.id}'
#     sp.name = sp.id.replace('-','_')
#     sp.derivedFrom = f'http://hl7.org/fhir/SearchParameter/{d.resource}-{d.parameter.lower()}' if d.exists == 'Y' else None
#     # print(sp.derivedFrom)
#     sp.status = 'active'
#     sp.description = d.description
#     sp.code = d.parameter.lower()
#     sp.base = [d.resource]  # list
#     sp.type = d.type.lower()
#     # print(sp.type)
#     sp.expression = d.expression
#     sp.target = [] if d.reference in none_list else split_string(d.reference) # string as space separated list in csv
#     # print(sp.target)
#     # sp.multipleOr = True  add columns to csv for where needed or used otherwise leave blank
#     # sp.multipleAnd = True  add columns to csv for where needed or used
#     sp.comparator = [] if d.comparators in none_list else split_string(d.comparators) # string as space separated list in csv
#     # print(sp.comparator)
#     sp.modifier = [] if d.modifiers in none_list else split_string(d.modifiers) # string as space separated list in csv
#     # print(sp.modifier)
#     sp.chain = [] if d.chains in none_list else split_string(d.chains) # string as space separated list in csv
#     # print(sp.chain)
#     # TODO sp.combo = [] if d.combos in none_list else split_string(d.chains) # string as space separated list in csv
#     # print(sp.combo)
#     sp.conformance = d.conformance_server.upper()
#
#     sp_list.append(sp)

# %% [markdown]
# ### Display SP resources

# %% [markdown]
# for row,i in enumerate(sp_list):
#     print(row,i.base)
#     print(dumps(sp_list[1].as_json(), indent = 3))

# %% [markdown]
# ### Create Markdown Text for Search.
#
# - Using Jinja2 Template create markdown file for search section in profiles profiles

# %%
r_type = ['Questionnaire', 'QuestionnaireResponse', 'Patient']  # TODO  loop over all types in sp_list

template = env.get_template(md_template[0])
for t in r_type:
    sp_bytype = [i for i in sp_list if i.base[0] == r_type]
    display(Markdown(template.render(sp_bytype=sp_bytype,search_type=search_type)))
    search_md = template.render(sp_bytype=sp_bytype,search_type=search_type)

with open(f'{out_path}{r_type}-search.md','w') as f:
    f.write(search_md)
# Out:
# ### Quick Start
# Below is an overview of the required set of RESTful FHIR interactions - for
# example, search and read operations - for this profile. See the [Conformance requirements]
# for a complete list of supported RESTful interactions for this IG.
#
# #### Supported Searches
#
# {% include link-list.md %}
# ### Quick Start
# Below is an overview of the required set of RESTful FHIR interactions - for
# example, search and read operations - for this profile. See the [Conformance requirements]
# for a complete list of supported RESTful interactions for this IG.
#
# #### Supported Searches
#
# {% include link-list.md %}
# ### Quick Start
# Below is an overview of the required set of RESTful FHIR interactions - for
# example, search and read operations - for this profile. See the [Conformance requirements]
# for a complete list of supported RESTful interactions for this IG.
#
# #### Supported Searches
#
# {% include link-list.md %}

# %% [markdown]
# ### Create Markdown Text for SearchParameters Page
#
# - Using Jinja2 Template create markdown file for searchparameters page

# %%
# get types:
r_list = []
for i in sp_list:
    for j in i.base:
        r_list.append(j)

r_list = sorted(set(r_list))

# md_template = 'sp_list_page.j2'

template = env.get_template(md_template[1])
display(Markdown(template.render(sp_list=sp_list,r_list=r_list)))
searchparameters_md = template.render(sp_list=sp_list,r_list=r_list)
with open(f'{out_path}searchparameters.md','w') as f:
    f.write(searchparameters_md)
# Out:
# ---
# title: Operations and Search Parameters
# layout: default
# topofpage: true
# sectionnumbering: true
# ---
#
# The following search parameters have been defined for the {{site.data.fhir.igName}} Implementation Guide.  For more information on the [FHIR RESTful search api]and the standard [Search Param Registry] see the FHIR specification.
#
# <!-- Operations
#
#
#   { % include list-simple-operationdefinitions.xhtml % }
#
#
# -->
#
# Search Parameter
#
#
# **HealthcareService**
#   - [active](SearchParameter-HealthcareService-active.html)
#
# **Patient**
#
# **Person**
#
# **Questionnaire**
#   - [url](SearchParameter-Questionnaire-url.html)
#   - [status](SearchParameter-Questionnaire-status.html)
#   - [title](SearchParameter-Questionnaire-title.html)
#   - [publisher](SearchParameter-Questionnaire-publisher.html)
#   - [version](SearchParameter-Questionnaire-version.html)
#
# **QuestionnaireResponse**
#   - [questionnaire](SearchParameter-QuestionnaireResponse-questionnaire.html)
#   - [patient](SearchParameter-QuestionnaireResponse-patient.html)
#   - [context](SearchParameter-QuestionnaireResponse-context.html)
#   - [status](SearchParameter-QuestionnaireResponse-status.html)
#   - [author](SearchParameter-QuestionnaireResponse-author.html)
#   - [source](SearchParameter-QuestionnaireResponse-source.html)
#
# **RelatedPerson**
#   - [birthdate](SearchParameter-individual-birthdate.html)
#
# {% include link_list.md %}

# %% [markdown]
# ### Update CapabilityStatement for Search
# - instantiate new or existing CapStatement as fhir model
# - add combination extensions
# - add markdown descriptions from above

# %%
# instantiate new or existing CapStatement:

def interaction(code):
    return CS.CapabilityStatementRestResourceInteraction({'code' : code})

def search_cs(sp):
    template = env.get_template(md_template[2])
    return CS.CapabilityStatementRestResourceSearchParam(
    dict(
    name = sp.code,
    definition = sp.url,
    type = sp.type,
    documentation = template.render(sp=sp, search_type=search_type)
    )
    )

cs = CS.CapabilityStatement(dict(
                            date = now,
                            status = 'active',
                            acceptUnknown = 'both',
                            format = ['json','xml'],
                            fhirVersion = '3.0.1',
                            kind = 'requirements'     
                            ))



cs.rest = [CS.CapabilityStatementRest()]  
cs.rest[0].mode = 'server'
cs.rest[0].resource = []



print(r_list)    
for r in r_list:
    rest_resource = CS.CapabilityStatementRestResource()
    rest_resource.type = r
    rest_resource.interaction = [interaction(code) for code in ['read','vread', 'history-instance', 'search-type']]
    cs.rest[0].resource.append(rest_resource)
    rest_resource.searchParam = [search_cs(sp=sp) for sp in sp_list if sp.base[0] == r]
print(dumps(cs.as_json(),indent = 3))

# %% [markdown]
# ### TODO
#
# - Save SearchParameters and CapabilityStatements.
# - Cycle through the quick starts
# - Update the CSV files
