# %%
from fhirclient.r4models.fhirabstractbase import FHIRValidationError
from fhirclient.r4models import searchparameter as SP
from fhirclient.r4models import capabilitystatement as CS
from fhirclient.r4models import bundle as B
from fhirclient.r4models import narrative as N
import fhirclient.models.identifier as I
import fhirclient.r4models.identifier as I
import fhirclient.r4models.coding as C
import fhirclient.r4models.codeableconcept as CC
import fhirclient.r4models.fhirdate as D
import fhirclient.r4models.extension as X
import fhirclient.r4models.contactdetail as CD
import fhirclient.r4models.fhirreference as FR
from json import dumps, loads, load
from requests import get, post, put
import os
from pathlib import Path
from csv import reader as csvreader
from IPython.display import display as Display, HTML, Markdown
from pprint import pprint
from collections import namedtuple
from pandas import *
from datetime import datetime, date
from jinja2 import Environment, FileSystemLoader, select_autoescape
from stringcase import snakecase, titlecase
from itertools import zip_longest
from openpyxl import load_workbook
from commonmark import commonmark
from lxml import etree

# %%
sp = SP.SearchParameter()
help(sp)
# Out:
# Help on SearchParameter in module fhirclient.r4models.searchparameter object:
#
# class SearchParameter(fhirclient.r4models.domainresource.DomainResource)
#  |  SearchParameter(jsondict=None, strict=True)
#  |
#  |  Search parameter for a resource.
#  |
#  |  A search parameter that defines a named search item that can be used to
#  |  search/filter on a resource.
#  |
#  |  Method resolution order:
#  |      SearchParameter
#  |      fhirclient.r4models.domainresource.DomainResource
#  |      fhirclient.r4models.resource.Resource
#  |      fhirclient.r4models.fhirabstractresource.FHIRAbstractResource
#  |      fhirclient.r4models.fhirabstractbase.FHIRAbstractBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, jsondict=None, strict=True)
#  |      Initialize all valid properties.
#  |
#  |      :raises: FHIRValidationError on validation errors, unless strict is False
#  |      :param dict jsondict: A JSON dictionary to use for initialization
#  |      :param bool strict: If True (the default), invalid variables will raise a TypeError
#  |
#  |  elementProperties(self)
#  |      Returns a list of tuples, one tuple for each property that should
#  |      be serialized, as: ("name", "json_name", type, is_list, "of_many", not_optional)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  resource_type = 'SearchParameter'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from fhirclient.r4models.fhirabstractresource.FHIRAbstractResource:
#  |
#  |  as_json(self)
#  |      Serializes to JSON by inspecting `elementProperties()` and creating
#  |      a JSON dictionary of all registered properties. Checks:
#  |
#  |      - whether required properties are not None (and lists not empty)
#  |      - whether not-None properties are of the correct type
#  |
#  |      :raises: FHIRValidationError if properties have the wrong type or if
#  |          required properties are empty
#  |      :returns: A validated dict object that can be JSON serialized
#  |
#  |  create(self, server)
#  |      Attempt to create the receiver on the given server, using a POST
#  |      command.
#  |
#  |      :param FHIRServer server: The server to create the receiver on
#  |      :returns: None or the response JSON on success
#  |
#  |  delete(self)
#  |      Delete the receiver from the given server with a DELETE command.
#  |
#  |      :returns: None or the response JSON on success
#  |
#  |  relativeBase(self)
#  |
#  |  relativePath(self)
#  |
#  |  update(self, server=None)
#  |      Update the receiver's representation on the given server, issuing
#  |      a PUT command.
#  |
#  |      :param FHIRServer server: The server to update the receiver on;
#  |          optional, will use the instance's `server` if needed.
#  |      :returns: None or the response JSON on success
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from fhirclient.r4models.fhirabstractresource.FHIRAbstractResource:
#  |
#  |  read(rem_id, server) from builtins.type
#  |      Read the resource with the given id from the given server. The
#  |      passed-in server instance must support a `request_json()` method call,
#  |      taking a relative path as first (and only mandatory) argument.
#  |
#  |      :param str rem_id: The id of the resource on the remote server
#  |      :param FHIRServer server: An instance of a FHIR server or compatible class
#  |      :returns: An instance of the receiving class
#  |
#  |  read_from(path, server) from builtins.type
#  |      Requests data from the given REST path on the server and creates
#  |      an instance of the receiving class.
#  |
#  |      :param str path: The REST path to read from
#  |      :param FHIRServer server: An instance of a FHIR server or compatible class
#  |      :returns: An instance of the receiving class
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fhirclient.r4models.fhirabstractresource.FHIRAbstractResource:
#  |
#  |  server
#  |      Walks the owner hierarchy until it finds an owner with a server.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from fhirclient.r4models.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  owningBundle(self)
#  |      Walks the owner hierarchy and returns the next parent that is a
#  |      `Bundle` instance.
#  |
#  |  owningResource(self)
#  |      Walks the owner hierarchy and returns the next parent that is a
#  |      `DomainResource` instance.
#  |
#  |  update_with_json(self, jsondict)
#  |      Update the receiver with data in a JSON dictionary.
#  |
#  |      :raises: FHIRValidationError on validation errors
#  |      :param dict jsondict: The JSON dictionary to use to update the receiver
#  |      :returns: None on success, a list of errors if there were errors
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from fhirclient.r4models.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  with_json(jsonobj) from builtins.type
#  |      Initialize an element from a JSON dictionary or array.
#  |
#  |      If the JSON dictionary has a "resourceType" entry and the specified
#  |      resource type is not the receiving classes type, uses
#  |      `FHIRElementFactory` to return a correct class instance.
#  |
#  |      :raises: TypeError on anything but dict or list of dicts
#  |      :raises: FHIRValidationError if instantiation fails
#  |      :param jsonobj: A dict or list of dicts to instantiate from
#  |      :returns: An instance or a list of instances created from JSON data
#  |
#  |  with_json_and_owner(jsonobj, owner) from builtins.type
#  |      Instantiates by forwarding to `with_json()`, then remembers the
#  |      "owner" of the instantiated elements. The "owner" is the resource
#  |      containing the receiver and is used to resolve contained resources.
#  |
#  |      :raises: TypeError on anything but dict or list of dicts
#  |      :raises: FHIRValidationError if instantiation fails
#  |      :param dict jsonobj: Decoded JSON dictionary (or list thereof)
#  |      :param FHIRElement owner: The owning parent
#  |      :returns: An instance or a list of instances created from JSON data
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fhirclient.r4models.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
sp.elementProperties()
# Out:
# [('id', 'id', str, False, None, False),
#  ('implicitRules', 'implicitRules', str, False, None, False),
#  ('_implicitRules',
#   '_implicitRules',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('language', 'language', str, False, None, False),
#  ('_language',
#   '_language',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('meta', 'meta', fhirclient.r4models.meta.Meta, False, None, False),
#  ('contained',
#   'contained',
#   fhirclient.r4models.resource.Resource,
#   True,
#   None,
#   False),
#  ('extension',
#   'extension',
#   fhirclient.r4models.extension.Extension,
#   True,
#   None,
#   False),
#  ('modifierExtension',
#   'modifierExtension',
#   fhirclient.r4models.extension.Extension,
#   True,
#   None,
#   False),
#  ('text', 'text', fhirclient.r4models.narrative.Narrative, False, None, False),
#  ('base', 'base', str, True, None, True),
#  ('_base',
#   '_base',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('chain', 'chain', str, True, None, False),
#  ('_chain',
#   '_chain',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('code', 'code', str, False, None, True),
#  ('_code',
#   '_code',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('comparator', 'comparator', str, True, None, False),
#  ('_comparator',
#   '_comparator',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('component',
#   'component',
#   fhirclient.r4models.searchparameter.SearchParameterComponent,
#   True,
#   None,
#   False),
#  ('contact',
#   'contact',
#   fhirclient.r4models.contactdetail.ContactDetail,
#   True,
#   None,
#   False),
#  ('date', 'date', fhirclient.r4models.fhirdate.FHIRDate, False, None, False),
#  ('derivedFrom', 'derivedFrom', str, False, None, False),
#  ('_derivedFrom',
#   '_derivedFrom',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('description', 'description', str, False, None, True),
#  ('_description',
#   '_description',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('experimental', 'experimental', bool, False, None, False),
#  ('_experimental',
#   '_experimental',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('expression', 'expression', str, False, None, False),
#  ('_expression',
#   '_expression',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('jurisdiction',
#   'jurisdiction',
#   fhirclient.r4models.codeableconcept.CodeableConcept,
#   True,
#   None,
#   False),
#  ('modifier', 'modifier', str, True, None, False),
#  ('_modifier',
#   '_modifier',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('multipleAnd', 'multipleAnd', bool, False, None, False),
#  ('_multipleAnd',
#   '_multipleAnd',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('multipleOr', 'multipleOr', bool, False, None, False),
#  ('_multipleOr',
#   '_multipleOr',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('name', 'name', str, False, None, True),
#  ('_name',
#   '_name',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('publisher', 'publisher', str, False, None, False),
#  ('_publisher',
#   '_publisher',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('purpose', 'purpose', str, False, None, False),
#  ('_purpose',
#   '_purpose',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('status', 'status', str, False, None, True),
#  ('_status',
#   '_status',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('target', 'target', str, True, None, False),
#  ('_target',
#   '_target',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('type', 'type', str, False, None, True),
#  ('_type',
#   '_type',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('url', 'url', str, False, None, True),
#  ('_url',
#   '_url',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('useContext',
#   'useContext',
#   fhirclient.r4models.usagecontext.UsageContext,
#   True,
#   None,
#   False),
#  ('version', 'version', str, False, None, False),
#  ('_version',
#   '_version',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('xpath', 'xpath', str, False, None, False),
#  ('_xpath',
#   '_xpath',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False),
#  ('xpathUsage', 'xpathUsage', str, False, None, False),
#  ('_xpathUsage',
#   '_xpathUsage',
#   fhirclient.r4models.fhirprimitive.FHIRPrimitive,
#   False,
#   None,
#   False)]
